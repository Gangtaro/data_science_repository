# %% [markdown]
# # seaborn 전체 설정

# %%
if os.name == 'posix': # Mac 환경 설정
    plt.rc('font', family='Apple SD Gothic Neo')
    sns.set_theme(style="whitegrid", palette="Paired", font = 'Apple SD Gothic Neo',
                  font_scale=1.2,
                  rc={'lines.linewidth': 2.5, # 그래프 선 굵기 설정
                      #'axes.labelsize': 17,
                      #'axes.titlesize': 19,
                      
                      #'font.size': 19.200000000000003,
                      
                      #'grid.linewidth': 1.6,
                      #'legend.fontsize': 16.0,
                      #'lines.linewidth': 2.8000000000000003,
                      #'lines.markeredgewidth': 0.0,
                      'lines.markersize': 8,
                      #'patch.linewidth': 0.48,
                      #'xtick.labelsize': 16.0,
                      #'xtick.major.pad': 11.200000000000001,
                      #'xtick.major.width': 1.6,
                      #'xtick.minor.width': 0.8,
                      #'ytick.labelsize': 16.0,
                      #'ytick.major.pad': 11.200000000000001,
                      #'ytick.major.width': 1.6,
                      #'ytick.minor.width': 0.8
                     }
                  )
    
elif os.name == 'nt': # Windows 환경 설정
    plt.rc('font', family='Malgun Gothic')
    sns.set_theme(style="whitegrid", palette="pastel", font = 'Malgun Gothic')

# %% [markdown]
# ## lineplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

##########데이터 로드

df = pd.DataFrame([
        ['A01', 2, 1, 60, 139, 'country', 0, 3],
        ['A02', 3, 2, 80, 148, 'country', 0, 5],
        ['A03', 3, 4, 50, 149, 'country', 0, 7],
        ['A04', 5, 5, 40, 151, 'country', 0, 10],
        ['A05', 7, 5, 35, 154, 'city', 0, 12],
        ['A06', 2, 5, 45, 149, 'country', 0, 7],
        ['A07',8, 9, 40, 155, 'city', 1, 13],
        ['A08', 9, 10, 70, 155, 'city', 3, 13],
        ['A09', 6, 12, 55, 154, 'city', 0, 12],
        ['A10', 9, 2, 40, 156, 'city', 1, 13],
        ['A11', 6, 10, 60, 153, 'city', 0, 12],
        ['A12', 2, 4, 75, 151, 'country', 0, 6]
    ], columns=['ID', 'hour', 'attendance', 'weight', 'iq', 'region', 'library', 'score'])

##########데이터 분석

sns.lineplot(x=df['ID'], y=df['score'])
plt.show()

sns.lineplot(x='ID', y='score', data=df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

##########데이터 로드

df = pd.DataFrame([
        ['A01', 2, 1, 60, 139, 'country', 0, 3],
        ['A02', 3, 2, 80, 148, 'country', 0, 5],
        ['A03', 3, 4, 50, 149, 'country', 0, 7],
        ['A04', 5, 5, 40, 151, 'country', 0, 10],
        ['A05', 7, 5, 35, 154, 'city', 0, 12],
        ['A06', 2, 5, 45, 149, 'country', 0, 7],
        ['A07',8, 9, 40, 155, 'city', 1, 13],
        ['A08', 9, 10, 70, 155, 'city', 3, 13],
        ['A09', 6, 12, 55, 154, 'city', 0, 12],
        ['A10', 9, 2, 40, 156, 'city', 1, 13],
        ['A11', 6, 10, 60, 153, 'city', 0, 12],
        ['A12', 2, 4, 75, 151, 'country', 0, 6]
    ], columns=['ID', 'hour', 'attendance', 'weight', 'iq', 'region', 'library', 'score'])

##########데이터 분석

sns.lineplot(x=df['ID'], y=df['score'], linestyle='-', color='blue', marker=',')
plt.show()

# %% [markdown]
# ### 참고 정보
# ```python
#
# # 선 스타일 옵션
# linestyle='-' #linestyle='solid' #디폴트값, https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html
# linestyle='--' #linestyle='dashed'
# linestyle='-.' #linestyle='dashdot'
# linestyle=':' #linestyle='dotted'
#
# # 색 옵션
# color='red' #빨간색
# color='green' #녹색
# color='blue' #파란색 #디폴트값
# color='cyan' #청록색
# color='magenta' #마젠타색
# color='yellow' #노란색
# color='black' #검은색
# color='white' #흰색
# color=[0.4,0.6,0.1] #R,G,B (0~1)
# color='#000000'
#
# # 마커 옵션
# marker=',' #pixel #디폴트값, 표시 안남 https://matplotlib.org/api/markers_api.html
# marker='.' #point
# marker='o' #circle
#
# marker='^' #triangle_up
# marker='v' #triangle_down
# marker='<' #triangle_left
# marker='>' #triangle_right
# marker='1' #tri_down
# marker='2' #tri_up
# marker='3' #tri_left
# marker='4' #tri_right
#
# marker='s' #square #사각형
# marker='p' #pentagon #오각형 #소문자 p
# marker='h' #hexagon1 #육각형
# marker='H' #hexagon2
# marker='8' #octagon #팔각형
#
# marker='d' #thin_diamond
# marker='D' #diamond
# marker='*' #star
#
# marker='P' #plus (filled) #대문자 P
# marker='+' #plus
# marker='x' #x
# marker='X' #x (filled)
# marker='|' #vline
# marker='_' #hline
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

##########데이터 로드

df = pd.DataFrame([
        ['A01', 2, 1, 60, 139, 'country', 0, 3],
        ['A02', 3, 2, 80, 148, 'country', 0, 5],
        ['A03', 3, 4, 50, 149, 'country', 0, 7],
        ['A04', 5, 5, 40, 151, 'country', 0, 10],
        ['A05', 7, 5, 35, 154, 'city', 0, 12],
        ['A06', 2, 5, 45, 149, 'country', 0, 7],
        ['A07',8, 9, 40, 155, 'city', 1, 13],
        ['A08', 9, 10, 70, 155, 'city', 3, 13],
        ['A09', 6, 12, 55, 154, 'city', 0, 12],
        ['A10', 9, 2, 40, 156, 'city', 1, 13],
        ['A11', 6, 10, 60, 153, 'city', 0, 12],
        ['A12', 2, 4, 75, 151, 'country', 0, 6]
    ], columns=['ID', 'hour', 'attendance', 'weight', 'iq', 'region', 'library', 'score'])

##########데이터 분석

sns.lineplot(x=range(len(df['score'])), y=df['score'])
plt.show()

# %% [markdown]
# ## Annotation aka. 포인트에 숫자 찍기

# %%
# seaborn에 내장되어 있는 데이터셋을 불러옵니다.
mpg = sns.load_dataset('mpg')
# 불러온 데이터셋을 확인합니다.
mpg.sample()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 223  15.5          8         318.0       145.0    4140          13.7
#
#      model_year origin                   name
# 223          77    usa  dodge monaco brougham

# %%
# countplot으로 origin에 해당되는 데이터의 수를 세어서 그래프로 시각화 합니다.
# 여기에 각 데이터의 값을 그래프에 표현할 예정입니다.
sns.countplot(data=mpg, x="origin")

# %%
# origin 별로 갯수를 집계한 결과를 재사용하기 위해 변수에 담습니다.
mpg_origin = mpg["origin"].value_counts()
mpg_origin
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
# mpg_origin_count에 담겨진 series 에서 원하는 데이터를 가져옵니다.
mpg_origin["usa"]
# Out:
# 249

# %%
# 인덱스 번호로 가져올 수도 있습니다.
# 반복된 작업을 피하기 위해 여기에서는 인덱스 번호를 사용할 예정입니다.
mpg_origin[0]
# Out:
# 249

# %%
g = sns.countplot(data=mpg, x="origin")
for i in range(mpg_origin.shape[0]):
    g.text(x=i, y=mpg_origin[i], s=mpg_origin[i], 
           horizontalalignment='center')

# %% [markdown]
# ### regplot으로 그려보기

# %%
g = sns.regplot(data=mpg, x="horsepower", y="acceleration", fit_reg=False)

g.text(x=200, y=20, s="200", horizontalalignment='left', size='medium', color='black', weight='semibold')
# Out:
# Text(200, 20, '200')

# %%
mpg_xy = mpg[["horsepower", "acceleration"]].copy()
mpg_xy.columns = ["x", "y"]
mpg_xy.sample()
# Out:
#         x    y
# 12  150.0  9.5

# %%
mpg_row_count = mpg_xy.shape[0]
mpg_row_count
# Out:
# 398

# %%
g = sns.regplot(data=mpg, x="horsepower", y="acceleration", fit_reg=False)
for mpg_row_no in range(mpg_row_count):
    # 매번 다 찍으면 너무 많기 때문에 10개에 하나씩만 찍도록
    if mpg_row_no % 10 == 0:
        g.text(x=mpg_xy.loc[mpg_row_no, "x"], 
               y=mpg_xy.loc[mpg_row_no, "y"], 
               s=mpg_xy.loc[mpg_row_no, "x"], 
               size='medium')
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 방법 2 - 주로 barplot

# %%
plt.figure(figsize=(8, 6))
g = sns.barplot(x = '시점', y = '가구수', hue = '분류', data = single_total)

for p in g.patches:
    g.annotate(number_with_sep(p.get_height(),1), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
    
plt.xlabel("년도", size=14)
plt.ylabel("가구 수 (단위: 천 가구)", size=14)
plt.title('1인 가구 비중', fontsize = 16)

# %% [markdown]
# # Matplotlib 가능한 서체 확인

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())

print ('설정파일 위치: ', mpl.matplotlib_fname())


font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# ttf 폰트 전체갯수
print(len(font_list)) 

font_list[:]
# Out:
# 버전:  3.2.2
# 설치 위치:  /Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py
# 설정 위치:  /Users/gangtaro/.matplotlib
# 캐시 위치:  /Users/gangtaro/.matplotlib
# 설정파일 위치:  /Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc
# 360
# ['/System/Library/Fonts/SFCompact.ttf',
#  '/System/Library/Fonts/Monaco.ttf',
#  '/System/Library/Fonts/Supplemental/Ayuthaya.ttf',
#  '/System/Library/Fonts/Supplemental/Phosphate.ttc',
#  '/System/Library/Fonts/Supplemental/Apple Chancery.ttf',
#  '/System/Library/Fonts/Supplemental/Baskerville.ttc',
#  '/System/Library/Fonts/Supplemental/Bangla MN.ttc',
#  '/System/Library/Fonts/Supplemental/Cochin.ttc',
#  '/System/Library/Fonts/Supplemental/NotoSansMultani-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansMahajani-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/SignPainter.ttc',
#  '/System/Library/Fonts/Supplemental/NewPeninimMT.ttc',
# ...

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'SD' in f.name]
# Out:
# [('Apple SD Gothic Neo', '/System/Library/Fonts/AppleSDGothicNeo.ttc')]

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Bold' in f.fname]
# Out:
# [('DejaVu Serif',
#   '/Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf'),
#  ('DejaVu Sans Mono',
#   '/Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf'),
#  ('DejaVu Sans',
#   '/Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf'),
#  ('DejaVu Serif',
#   '/Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf'),
#  ('DejaVu Sans Mono',
#   '/Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf'),
#  ('DejaVu Sans',
#   '/Users/gangtaro/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf'),
#  ('Courier New',
#   '/System/Library/Fonts/Supplemental/Courier New Bold Italic.ttf'),
# ...
