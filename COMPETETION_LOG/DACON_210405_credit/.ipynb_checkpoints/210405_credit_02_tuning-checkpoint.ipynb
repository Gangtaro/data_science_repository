# %%
# import modules
import warnings
warnings.filterwarnings('ignore')


import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss

from math import floor
from scipy.stats import norm

sns.set()
sns.set_color_codes()
sns.set_theme(style="ticks", palette="pastel")
print('<Check the versions of modules>')
print("- Seaborn version : ", sns.__version__)


# upload data
train = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/train.csv',index_col=0)
test = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/test.csv',index_col=0)
submit = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/sample_submission.csv')
# Out:
# <Check the versions of modules>
# - Seaborn version :  0.11.1

# %%
# outliers
train.drop((train[train['child_num']>=6]).index, inplace = True)

# %%
for df in [train, test]:
    # no information
    df.drop('FLAG_MOBIL',axis = 1, inplace = True)
    
    
    df.family_type[(df.family_type == 'Single / not married')&(df.family_size - df.child_num == 2)] = 'Married'
    df.family_type[df.family_type == 'Single / not married'] = 'Absolutely Single'

    whether_married_new = df.family_type.copy()
    whether_married_new.replace({'Married':2, 'Civil marriage':2, 'Separated':1, 'Absolutely Single':1, 'Widow':1}, inplace = True)
    df.family_size = whether_married_new + df.child_num

    df.occyp_type.fillna('Missing occyp', inplace=True)
    df.loc[(df.DAYS_EMPLOYED == 0)&(df.occyp_type == 'Missing occyp'), 'occyp_type'] = 'inoccyp'
    df.loc[(df.DAYS_EMPLOYED != 0)&(df.occyp_type == 'Missing occyp'), 'occyp_type'] = 'blank'
    df.occyp_type[df.income_type == 'Pensioner'] = 'inoccyp'
    df.DAYS_EMPLOYED[df.income_type == 'Pensioner'] = 0

    df['ID'] = \
    df['gender'].astype('str') + \
    df['car'].astype('str') + \
    df['reality'].astype('str') + '_' + \
    df['child_num'].astype('str') + '_' + \
    df['income_total'].astype('str') + '_' + \
    df['income_type'].astype('str') + '_' + \
    df['family_type'].astype('str') + '_' + \
    df['house_type'].astype('str') + '_' + \
    df['phone'].astype('str') + '_' + \
    df['email'].astype('str') + '_' + \
    df['family_size'].astype('str') + '_' + \
    df['DAYS_BIRTH'].astype('str') + '_' + \
    df['DAYS_EMPLOYED'].astype('str') + '_' + \
    df['occyp_type'].astype('str') 

    # 로그 변환(income_total)
    df['income_total_log'] = np.log(df['income_total']+1)

    # 음수로 표현된 수치형 변수 양수화
    df['DAYS_BIRTH']    = -df['DAYS_BIRTH']
    df['DAYS_EMPLOYED'] = -df['DAYS_EMPLOYED']
    df['begin_month']   = -df['begin_month']

    # 동산/부동산 보유 정보
    df['group_property'] = df['car'].astype(str)   + df['reality'].astype(str)

    # 연락처 종류에 관한 정보
    df['group_contacts'] = df['phone'].astype(str) + df['work_phone'].astype(str) + df['email'].astype(str)

    # 어떤 성별의, 어떤 가정을 이루고 있는지에 대한 정보
    df['group_whoare_u'] = df['gender'].astype(str)+ df['family_type'].astype(str) + (df['child_num'] > 0).replace({True : 'hav child', False : 'dont hav child'}) 

    # 소득원천, 직업종류에 대한 결합 정보                                                                                               
    df['group_your_job'] = df['income_type'] +'_'+ df['occyp_type']

    # 현재 하고 있는 일을 시작하게 된 나이(날짜) = 일을 하지 않았던 기간 
    df['DAYS_nowork'] = df['DAYS_BIRTH'] - df['DAYS_EMPLOYED']

    # 소득과 관련된 변수와 조합
    df['income_per_child'] = df['income_total']/ df['child_num']  
    df['income_per_family']= df['income_total']/ df['family_size']
    df['income_per_age']   = df['income_total']/ df['DAYS_BIRTH']

    # 날짜표기 변환(begin_month) : 4로 나누어 계절로 분할
    df['begin_season'] = df['begin_month'].apply(lambda x: floor(x/4))

    # 날짜표기 변환(DAYS_EMPLOYED) : 개월로 binning
    df['mm_EMPLOYED'] = df['DAYS_EMPLOYED'].apply(lambda x: floor(x/30.4375))

    # 날쨔 표기 변환(DAYS_EMPLOYED): 연차로 binning
    df['yy_EMPLOYED'] = df['DAYS_EMPLOYED'].apply(lambda x: floor(x/365.25))

# %%
# 카드사용자의 능력에 대한 정보
personal_info = train.drop(['credit', 'begin_month'], axis = 1).drop_duplicates(subset='ID', keep='first', inplace=False, ignore_index=True)

F, F_birth_labels = pd.qcut(personal_info.DAYS_BIRTH[personal_info.gender == 'F'], q = 20, retbins=True)
M, M_birth_labels = pd.qcut(personal_info.DAYS_BIRTH[personal_info.gender == 'M'], q = 20, retbins=True)
F_birth_labels.put(0, F_birth_labels[0]-.001)
M_birth_labels.put(0, M_birth_labels[0]-.001)

personal_info['age_F_bins'] = F
personal_info['n_F_age'] = personal_info.groupby('age_F_bins').gender.count()
personal_info['age_M_bins'] = M
personal_info['n_M_age'] = personal_info.groupby('age_M_bins').gender.count()

personal_info['income_mean_F_age']  = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = F_birth_labels), 'gender']).income_total.transform(np.mean)
personal_info['income_mean_M_age']  = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = M_birth_labels), 'gender']).income_total.transform(np.mean)
personal_info['income_std_F_age']   = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = F_birth_labels), 'gender']).income_total.transform(np.std)
personal_info['income_std_M_age']   = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = M_birth_labels), 'gender']).income_total.transform(np.std)

F_age_info = personal_info.groupby('age_F_bins')[['income_mean_F_age', 'income_std_F_age', 'n_F_age']].apply(np.mean)
M_age_info = personal_info.groupby('age_M_bins')[['income_mean_M_age', 'income_std_M_age', 'n_M_age']].apply(np.mean)

# %%
pre_ = test.DAYS_BIRTH.iloc[6031]
test.DAYS_BIRTH.iloc[6031] = 7757

for df in [train, test]:
    df['age_F_bins'] = pd.cut(df.DAYS_BIRTH, bins = F_birth_labels)
    df['age_M_bins'] = pd.cut(df.DAYS_BIRTH, bins = M_birth_labels)

#예외 발생(test)
test.DAYS_BIRTH.iloc[6031] = pre_

train = pd.merge(train, F_age_info, how = 'left', on = 'age_F_bins')
train = pd.merge(train, M_age_info, how = 'left', on = 'age_M_bins')
test = pd.merge(test, F_age_info, how = 'left', on = 'age_F_bins')
test = pd.merge(test, M_age_info, how = 'left', on = 'age_M_bins')

for df in [train, test]:
    df['ability_income_per_age_by_gen'] = 0
    df['ability_income_per_age_by_gen'][df.gender == 'F'] = ((df['income_total'] - df['income_mean_F_age'])/(df['income_std_F_age']/df['n_F_age'].apply(np.sqrt)))[df.gender == 'F']
    df['ability_income_per_age_by_gen'][df.gender == 'M'] = ((df['income_total'] - df['income_mean_M_age'])/(df['income_std_M_age']/df['n_M_age'].apply(np.sqrt)))[df.gender == 'M']

# %%
# 여유성 자금 확보에 대한 정보
## 자녀양육비
### 자녀 1인 기준 기본 양육비
one_child_fee = (personal_info.income_total/personal_info.family_size)[(personal_info.DAYS_BIRTH > 33*365) & (personal_info.DAYS_BIRTH < 37*365) & (personal_info.child_num == 1)].mean()

### 교육 수준에 따른 소득의 평균을 프레임에 저장
df_weight_edu = personal_info.groupby('edu_type').income_total.apply(np.mean)
df_weight_edu.name = 'weight_edu'
df_weight_edu = df_weight_edu.reset_index()

d_age_mu  = 35.00059114405094 #계수1
d_age_std = 7.977814929279566 #계수2
train = pd.merge(train, df_weight_edu, how = 'left', on = 'edu_type')
train['weight_chd'] = train['child_num'].transform(lambda x: np.log(1+x)/np.log(2))
train['weight_age'] = train['DAYS_BIRTH'].transform(lambda x: norm(d_age_mu, scale = d_age_std).pdf((x/365.25))/norm(d_age_mu, scale = d_age_std).pdf(d_age_mu))
test  = pd.merge(test , df_weight_edu, how = 'left', on = 'edu_type') 
test['weight_chd'] = test['child_num'].transform(lambda x: np.log(1+x)/np.log(2))
test['weight_age'] = test['DAYS_BIRTH'].transform(lambda x: norm(d_age_mu, scale = d_age_std).pdf((x/365.25))/norm(d_age_mu, scale = d_age_std).pdf(d_age_mu))


### 가정한 공식에 따른 "자녀 양육비"
train['child_fee_total'] = one_child_fee*train['weight_edu']*train['weight_chd']*train['weight_age']
test['child_fee_total'] = one_child_fee*test['weight_edu']*test['weight_chd']*test['weight_age']


## 차량 유지비용
### 소득에 따른 자동차 유지비에 대한 가중치 함수
def car_weight(x, loc_par_car):
    _max = personal_info.income_total.max()
    _med = loc_par_car
    if x < _med : 
        return 1
    else:
        return 1+(x-_med)/(_max-_med)*5

### 가정한 공식에 따른 "차량 유지비용"
loc_par_car = 183585 #계수3
train['car_fees_total'] = train.income_total.median()*0.1*(train.car == 'Y').astype('int')*train.income_total.apply(lambda x: car_weight(x, loc_par_car))
test['car_fees_total'] = train.income_total.median()*0.1*(test.car == 'Y').astype('int')*test.income_total.apply(lambda x: car_weight(x, loc_par_car))

## 여유성 자금 확보 변수 생성
c_1 = 1.4633527457954487 
c_2 = 1.2772905851450718
train['save_income'] = train['income_total'] - c_1*train['child_fee_total'] - c_2*train['car_fees_total']
test['save_income'] = test['income_total'] - c_1*test['child_fee_total'] - c_2*test['car_fees_total']

# %%
drop_list = ['income_total',
             'age_F_bins', 'age_M_bins', 
             'income_mean_F_age', 'income_std_F_age', 'n_F_age',
             'income_mean_M_age', 'income_std_M_age', 'n_M_age', 
             'weight_edu', 'weight_chd', 'weight_age', 'child_fee_total', 'car_fees_total'
            ]

for df in [train, test]:
    df.drop(drop_list, axis = 1, inplace = True)

# %%
# save the train/test data which is prepared to do modeling by pickle
with open('train.pickle', 'wb') as f:
    pickle.dump(train, f, pickle.HIGHEST_PROTOCOL)
with open('test.pickle', 'wb') as f:
    pickle.dump(test, f, pickle.HIGHEST_PROTOCOL)

# %%
numerical_feats = train.dtypes[train.dtypes != "object"].index.tolist()
numerical_feats.remove('credit')
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = train.dtypes[train.dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  18
# Number of Categorical features:  13

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26451 entries, 0 to 26450
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gender                         26451 non-null  object
#  1   car                            26451 non-null  object
#  2   reality                        26451 non-null  object
#  3   child_num                      26451 non-null  int64
#  4   income_type                    26451 non-null  object
#  5   edu_type                       26451 non-null  object
#  6   family_type                    26451 non-null  object
#  7   house_type                     26451 non-null  object
#  8   DAYS_BIRTH                     26451 non-null  int64
#  9   DAYS_EMPLOYED                  26451 non-null  int64
#  10  work_phone                     26451 non-null  int64
#  11  phone                          26451 non-null  int64
#  12  email                          26451 non-null  int64
#  13  occyp_type                     26451 non-null  object
#  14  family_size                    26451 non-null  int64
#  15  begin_month                    26451 non-null  float64
#  16  credit                         26451 non-null  float64
#  17  ID                             26451 non-null  object
#  18  income_total_log               26451 non-null  float64
#  19  group_property                 26451 non-null  object
#  20  group_contacts                 26451 non-null  object
#  21  group_whoare_u                 26451 non-null  object
#  22  group_your_job                 26451 non-null  object
#  23  DAYS_nowork                    26451 non-null  int64
#  24  income_per_child               26451 non-null  float64
#  25  income_per_family              26451 non-null  float64
#  26  income_per_age                 26451 non-null  float64
#  27  begin_season                   26451 non-null  int64
#  28  mm_EMPLOYED                    26451 non-null  int64
#  29  yy_EMPLOYED                    26451 non-null  int64
#  30  ability_income_per_age_by_gen  26451 non-null  float64
#  31  save_income                    26451 non-null  float64
# dtypes: float64(8), int64(11), object(13)
# memory usage: 6.7+ MB

# %%
import optuna
from optuna.samplers import TPESampler

# preset option for model
n_class  =3
n_fold = 10
seed = 55

target = 'credit'
X = train.drop(target, axis=1)
y = train[target]
X_test = test

def objective(trial):
    skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
    folds=[]
    for train_idx, valid_idx in skfold.split(X, y):
            folds.append((train_idx, valid_idx))
            
    cat_pred = np.zeros((X.shape[0], n_class))
    cat_pred_test = np.zeros((X_test.shape[0], n_class))
    cat_cols = categorical_feats

    param = {
        #"objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "learning_rate":     trial.suggest_float("learning_rate", 0.01, 0.05),
        "n_estimators":      trial.suggest_int("n_estimators", 2400, 4400, 200),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.2),
        "depth": trial.suggest_int("depth", 8, 16, 1),
        #"boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        #"bootstrap_type": trial.suggest_categorical(
        #    "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        #),
        "subsample" : trial.suggest_float("subsample", 0.6, 0.98), #only=> bootstrap_type = 'Bernoulli'
        "used_ram_limit": "14gb",
    }

    #if param["bootstrap_type"] == "Bayesian":
    #    param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    #elif param["bootstrap_type"] == "Bernoulli":
    #    param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        
    model_folds = []    
    for fold in range(n_fold):
        print(f'\n----------------- Fold {fold+1} -----------------\n')
        train_idx, valid_idx = folds[fold]
        X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
        train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        model_cat = CatBoostClassifier(**param, 
                                       boosting_type = 'Ordered', 
                                       bootstrap_type = 'Bernoulli')
        model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=200)
        
        model_folds.append(model_cat)
        cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
        cat_pred_test += model_cat.predict_proba(X_test) / n_fold
        print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')

    print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
    logloss = log_loss(y, cat_pred)
    return logloss

# %%
study_make_model_params = optuna.create_study(direction="minimize")
study_make_model_params.optimize(objective)
# Out:
# [I 2021-07-04 08:52:14,022] A new study created in memory with name: no-name-ea94be68-6c53-4077-b477-d173087a2ea4
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0873115	test: 1.0873242	best: 1.0873242 (0)	total: 67.1ms	remaining: 3m 47s
# 200:	learn: 0.7905962	test: 0.7799713	best: 0.7799713 (200)	total: 4.17s	remaining: 1m 6s
# 400:	learn: 0.7445592	test: 0.7209176	best: 0.7209176 (400)	total: 8.18s	remaining: 1m 1s
# 600:	learn: 0.7275407	test: 0.6980181	best: 0.6980126 (599)	total: 12.6s	remaining: 58.8s
# 800:	learn: 0.7163698	test: 0.6835692	best: 0.6835692 (800)	total: 17.9s	remaining: 58.1s
# 1000:	learn: 0.7108149	test: 0.6786037	best: 0.6786037 (1000)	total: 22.8s	remaining: 54.6s
# 1200:	learn: 0.7057896	test: 0.6759531	best: 0.6759372 (1188)	total: 28s	remaining: 51.3s
# 1400:	learn: 0.7021060	test: 0.6746338	best: 0.6746206 (1391)	total: 32.9s	remaining: 47s
# 1600:	learn: 0.6981612	test: 0.6736541	best: 0.6736494 (1594)	total: 38.1s	remaining: 42.8s
# 1800:	learn: 0.6943677	test: 0.6722667	best: 0.6722093 (1794)	total: 43.4s	remaining: 38.5s
# 2000:	learn: 0.6902657	test: 0.6717021	best: 0.6717016 (1997)	total: 48.9s	remaining: 34.2s
# 2200:	learn: 0.6862713	test: 0.6711185	best: 0.6711185 (2200)	total: 54.5s	remaining: 29.7s
# 2400:	learn: 0.6837306	test: 0.6707591	best: 0.6707419 (2389)	total: 59.1s	remaining: 24.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6705637987
# bestIteration = 2465
#
# Shrink model to first 2466 iterations.
# CV Log Loss Score: 0.670564
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0873166	test: 1.0873117	best: 1.0873117 (0)	total: 14.1ms	remaining: 48s
# 200:	learn: 0.7835183	test: 0.7652542	best: 0.7652542 (200)	total: 3.87s	remaining: 1m 1s
# 400:	learn: 0.7431401	test: 0.7115555	best: 0.7115555 (400)	total: 8.11s	remaining: 1m
# 600:	learn: 0.7253120	test: 0.6880648	best: 0.6880648 (600)	total: 13.2s	remaining: 1m 1s
# 800:	learn: 0.7172316	test: 0.6790117	best: 0.6790116 (799)	total: 18.2s	remaining: 58.9s
# 1000:	learn: 0.7110132	test: 0.6741805	best: 0.6741805 (1000)	total: 23.4s	remaining: 56s
# 1200:	learn: 0.7060471	test: 0.6710666	best: 0.6710666 (1200)	total: 29s	remaining: 53.2s
# 1400:	learn: 0.7023353	test: 0.6696448	best: 0.6696447 (1399)	total: 34.4s	remaining: 49s
# 1600:	learn: 0.6978376	test: 0.6684253	best: 0.6684035 (1588)	total: 40.5s	remaining: 45.5s
# 1800:	learn: 0.6942769	test: 0.6679702	best: 0.6679702 (1799)	total: 46.2s	remaining: 41s
# 2000:	learn: 0.6908192	test: 0.6675003	best: 0.6674529 (1983)	total: 52s	remaining: 36.3s
# 2200:	learn: 0.6878876	test: 0.6675091	best: 0.6673829 (2139)	total: 57s	remaining: 31.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6673829177
# bestIteration = 2139
#
# Shrink model to first 2140 iterations.
# CV Log Loss Score: 0.667383
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0873152	test: 1.0873349	best: 1.0873349 (0)	total: 22.4ms	remaining: 1m 16s
# 200:	learn: 0.7875564	test: 0.7610564	best: 0.7610564 (200)	total: 4.01s	remaining: 1m 3s
# 400:	learn: 0.7489826	test: 0.7080826	best: 0.7080826 (400)	total: 8.39s	remaining: 1m 2s
# 600:	learn: 0.7289609	test: 0.6779411	best: 0.6779411 (600)	total: 13s	remaining: 1m
# 800:	learn: 0.7202319	test: 0.6669637	best: 0.6669637 (800)	total: 17.7s	remaining: 57.6s
# 1000:	learn: 0.7148468	test: 0.6603748	best: 0.6603732 (996)	total: 22.4s	remaining: 53.8s
# 1200:	learn: 0.7093616	test: 0.6560584	best: 0.6560568 (1198)	total: 27.4s	remaining: 50.2s
# 1400:	learn: 0.7054432	test: 0.6540156	best: 0.6540077 (1397)	total: 32.5s	remaining: 46.4s
# 1600:	learn: 0.7018425	test: 0.6526069	best: 0.6526069 (1600)	total: 37.8s	remaining: 42.4s
# 1800:	learn: 0.6986881	test: 0.6518554	best: 0.6518408 (1798)	total: 42.8s	remaining: 38s
# 2000:	learn: 0.6956725	test: 0.6515562	best: 0.6515310 (1998)	total: 47.9s	remaining: 33.5s
# 2200:	learn: 0.6923223	test: 0.6513176	best: 0.6511371 (2170)	total: 53.2s	remaining: 29s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6511370935
# bestIteration = 2170
#
# Shrink model to first 2171 iterations.
# CV Log Loss Score: 0.651137
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0873156	test: 1.0873119	best: 1.0873119 (0)	total: 19.8ms	remaining: 1m 7s
# 200:	learn: 0.7851330	test: 0.7668782	best: 0.7668600 (198)	total: 3.93s	remaining: 1m 2s
# 400:	learn: 0.7497210	test: 0.7226241	best: 0.7226241 (400)	total: 7.82s	remaining: 58.5s
# 600:	learn: 0.7266390	test: 0.6915775	best: 0.6915774 (599)	total: 12.6s	remaining: 58.6s
# 800:	learn: 0.7163352	test: 0.6814026	best: 0.6814016 (798)	total: 17.7s	remaining: 57.5s
# 1000:	learn: 0.7114897	test: 0.6780188	best: 0.6780126 (999)	total: 22.4s	remaining: 53.7s
# 1200:	learn: 0.7063853	test: 0.6757993	best: 0.6757879 (1197)	total: 28.1s	remaining: 51.4s
# 1400:	learn: 0.7026456	test: 0.6748004	best: 0.6748003 (1399)	total: 33.2s	remaining: 47.4s
# 1600:	learn: 0.6990063	test: 0.6744914	best: 0.6744660 (1580)	total: 38.7s	remaining: 43.5s
# 1800:	learn: 0.6956809	test: 0.6743667	best: 0.6743516 (1795)	total: 43.6s	remaining: 38.7s
# 2000:	learn: 0.6917480	test: 0.6741034	best: 0.6740749 (1993)	total: 49.1s	remaining: 34.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6739524351
# bestIteration = 2074
#
# Shrink model to first 2075 iterations.
# CV Log Loss Score: 0.673952
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0873162	test: 1.0873131	best: 1.0873131 (0)	total: 14.4ms	remaining: 48.9s
# 200:	learn: 0.7955887	test: 0.7862816	best: 0.7862816 (200)	total: 3.54s	remaining: 56.4s
# 400:	learn: 0.7485106	test: 0.7269655	best: 0.7269654 (399)	total: 7.68s	remaining: 57.4s
# 600:	learn: 0.7266853	test: 0.6979002	best: 0.6979002 (600)	total: 12.1s	remaining: 56.2s
# 800:	learn: 0.7173298	test: 0.6870919	best: 0.6870840 (795)	total: 17s	remaining: 55.3s
# 1000:	learn: 0.7117423	test: 0.6813476	best: 0.6813351 (999)	total: 21.8s	remaining: 52.3s
# 1200:	learn: 0.7072285	test: 0.6782402	best: 0.6782402 (1200)	total: 26.9s	remaining: 49.2s
# 1400:	learn: 0.7029605	test: 0.6761353	best: 0.6761353 (1400)	total: 31.9s	remaining: 45.5s
# 1600:	learn: 0.6989632	test: 0.6750881	best: 0.6750881 (1599)	total: 36.9s	remaining: 41.5s
# 1800:	learn: 0.6954210	test: 0.6746062	best: 0.6745384 (1779)	total: 42.2s	remaining: 37.5s
# 2000:	learn: 0.6918505	test: 0.6741160	best: 0.6741160 (2000)	total: 47.4s	remaining: 33.2s
# 2200:	learn: 0.6885215	test: 0.6740063	best: 0.6739820 (2156)	total: 52.7s	remaining: 28.7s
# 2400:	learn: 0.6854160	test: 0.6738953	best: 0.6738869 (2329)	total: 58.1s	remaining: 24.2s
# 2600:	learn: 0.6823695	test: 0.6735489	best: 0.6735489 (2600)	total: 1m 3s	remaining: 19.4s
# 2800:	learn: 0.6797239	test: 0.6734772	best: 0.6734191 (2730)	total: 1m 8s	remaining: 14.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6734191371
# bestIteration = 2730
#
# Shrink model to first 2731 iterations.
# CV Log Loss Score: 0.673419
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0873116	test: 1.0873039	best: 1.0873039 (0)	total: 20.2ms	remaining: 1m 8s
# 200:	learn: 0.7805272	test: 0.7616482	best: 0.7616482 (200)	total: 4.25s	remaining: 1m 7s
# 400:	learn: 0.7426785	test: 0.7124415	best: 0.7124413 (398)	total: 8.49s	remaining: 1m 3s
# 600:	learn: 0.7265064	test: 0.6903138	best: 0.6903136 (598)	total: 13.2s	remaining: 1m 1s
# 800:	learn: 0.7178982	test: 0.6795811	best: 0.6795811 (800)	total: 17.7s	remaining: 57.5s
# 1000:	learn: 0.7123192	test: 0.6738289	best: 0.6738289 (1000)	total: 22.7s	remaining: 54.5s
# 1200:	learn: 0.7075186	test: 0.6707698	best: 0.6707608 (1192)	total: 28s	remaining: 51.3s
# 1400:	learn: 0.7034886	test: 0.6694060	best: 0.6694060 (1400)	total: 32.7s	remaining: 46.6s
# 1600:	learn: 0.6999874	test: 0.6682975	best: 0.6682928 (1598)	total: 38.1s	remaining: 42.8s
# 1800:	learn: 0.6966094	test: 0.6674927	best: 0.6674878 (1796)	total: 43.2s	remaining: 38.3s
# 2000:	learn: 0.6928505	test: 0.6667098	best: 0.6667096 (1998)	total: 48.9s	remaining: 34.2s
# 2200:	learn: 0.6897194	test: 0.6662166	best: 0.6662166 (2200)	total: 53.9s	remaining: 29.4s
# 2400:	learn: 0.6866134	test: 0.6658760	best: 0.6658657 (2398)	total: 59.3s	remaining: 24.7s
# 2600:	learn: 0.6836043	test: 0.6656205	best: 0.6655618 (2594)	total: 1m 4s	remaining: 19.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6655617558
# bestIteration = 2594
#
# Shrink model to first 2595 iterations.
# CV Log Loss Score: 0.665562
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0873118	test: 1.0873053	best: 1.0873053 (0)	total: 24.4ms	remaining: 1m 22s
# 200:	learn: 0.7881430	test: 0.7705962	best: 0.7705895 (199)	total: 4.16s	remaining: 1m 6s
# 400:	learn: 0.7580360	test: 0.7333831	best: 0.7333831 (400)	total: 7.83s	remaining: 58.5s
# 600:	learn: 0.7300121	test: 0.6919765	best: 0.6919737 (597)	total: 12.4s	remaining: 57.8s
# 800:	learn: 0.7184780	test: 0.6754636	best: 0.6754636 (800)	total: 17.6s	remaining: 57s
# 1000:	learn: 0.7124391	test: 0.6698202	best: 0.6698202 (1000)	total: 22.8s	remaining: 54.5s
# 1200:	learn: 0.7083647	test: 0.6673999	best: 0.6673999 (1200)	total: 27.6s	remaining: 50.6s
# 1400:	learn: 0.7031974	test: 0.6651160	best: 0.6651160 (1400)	total: 33.3s	remaining: 47.5s
# 1600:	learn: 0.6998806	test: 0.6640305	best: 0.6640305 (1600)	total: 38.5s	remaining: 43.3s
# 1800:	learn: 0.6962444	test: 0.6633782	best: 0.6633740 (1796)	total: 44.2s	remaining: 39.2s
# 2000:	learn: 0.6927233	test: 0.6625169	best: 0.6625169 (2000)	total: 49.1s	remaining: 34.3s
# 2200:	learn: 0.6897032	test: 0.6619666	best: 0.6619436 (2198)	total: 54.2s	remaining: 29.5s
# 2400:	learn: 0.6866352	test: 0.6615574	best: 0.6615559 (2398)	total: 59.6s	remaining: 24.8s
# 2600:	learn: 0.6839177	test: 0.6610589	best: 0.6610417 (2586)	total: 1m 4s	remaining: 19.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6609960074
# bestIteration = 2641
#
# Shrink model to first 2642 iterations.
# CV Log Loss Score: 0.660996
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0873204	test: 1.0873047	best: 1.0873047 (0)	total: 17.5ms	remaining: 59.6s
# 200:	learn: 0.7965449	test: 0.7803155	best: 0.7803155 (200)	total: 3.98s	remaining: 1m 3s
# 400:	learn: 0.7536958	test: 0.7217085	best: 0.7217057 (399)	total: 8.41s	remaining: 1m 2s
# 600:	learn: 0.7276988	test: 0.6836687	best: 0.6836682 (598)	total: 13.7s	remaining: 1m 3s
# 800:	learn: 0.7183237	test: 0.6720331	best: 0.6720331 (800)	total: 19.2s	remaining: 1m 2s
# 1000:	learn: 0.7122841	test: 0.6663294	best: 0.6663294 (1000)	total: 24.7s	remaining: 59.2s
# 1200:	learn: 0.7075879	test: 0.6637474	best: 0.6637474 (1200)	total: 29.9s	remaining: 54.8s
# 1400:	learn: 0.7041313	test: 0.6616499	best: 0.6616378 (1393)	total: 35.4s	remaining: 50.5s
# 1600:	learn: 0.6999701	test: 0.6599276	best: 0.6599267 (1598)	total: 41.1s	remaining: 46.2s
# 1800:	learn: 0.6965760	test: 0.6593891	best: 0.6593872 (1797)	total: 46.7s	remaining: 41.4s
# 2000:	learn: 0.6925288	test: 0.6587491	best: 0.6587194 (1989)	total: 52.2s	remaining: 36.5s
# 2200:	learn: 0.6898162	test: 0.6583000	best: 0.6582858 (2198)	total: 57.3s	remaining: 31.2s
# 2400:	learn: 0.6870966	test: 0.6580762	best: 0.6580762 (2400)	total: 1m 2s	remaining: 25.8s
# 2600:	learn: 0.6841519	test: 0.6576797	best: 0.6576797 (2600)	total: 1m 7s	remaining: 20.6s
# 2800:	learn: 0.6810030	test: 0.6572270	best: 0.6572118 (2799)	total: 1m 12s	remaining: 15.5s
# 3000:	learn: 0.6780904	test: 0.6570749	best: 0.6570310 (2965)	total: 1m 17s	remaining: 10.3s
# 3200:	learn: 0.6743582	test: 0.6566984	best: 0.6566590 (3131)	total: 1m 23s	remaining: 5.19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6566194025
# bestIteration = 3250
#
# Shrink model to first 3251 iterations.
# CV Log Loss Score: 0.656619
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0873179	test: 1.0872968	best: 1.0872968 (0)	total: 15.2ms	remaining: 51.6s
# 200:	learn: 0.7795603	test: 0.7623160	best: 0.7623160 (200)	total: 4.26s	remaining: 1m 7s
# 400:	learn: 0.7480065	test: 0.7203491	best: 0.7203491 (399)	total: 8.23s	remaining: 1m 1s
# 600:	learn: 0.7272669	test: 0.6904208	best: 0.6904198 (598)	total: 13s	remaining: 1m
# 800:	learn: 0.7173246	test: 0.6777746	best: 0.6777745 (799)	total: 18.5s	remaining: 1m
# 1000:	learn: 0.7113040	test: 0.6721479	best: 0.6721479 (1000)	total: 24.3s	remaining: 58.2s
# 1200:	learn: 0.7066098	test: 0.6690977	best: 0.6690936 (1197)	total: 30.5s	remaining: 55.8s
# 1400:	learn: 0.7024282	test: 0.6674904	best: 0.6674904 (1400)	total: 36.2s	remaining: 51.6s
# 1600:	learn: 0.6985472	test: 0.6667846	best: 0.6667743 (1599)	total: 42.3s	remaining: 47.5s
# 1800:	learn: 0.6946728	test: 0.6663213	best: 0.6662799 (1786)	total: 48s	remaining: 42.6s
# 2000:	learn: 0.6919921	test: 0.6660916	best: 0.6660270 (1959)	total: 53.6s	remaining: 37.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6660270158
# bestIteration = 1959
#
# Shrink model to first 1960 iterations.
# CV Log Loss Score: 0.666027
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0873159	test: 1.0873149	best: 1.0873149 (0)	total: 21.1ms	remaining: 1m 11s
# 200:	learn: 0.7764707	test: 0.7565258	best: 0.7565153 (198)	total: 4.29s	remaining: 1m 8s
# 400:	learn: 0.7417625	test: 0.7115618	best: 0.7115617 (399)	total: 8.52s	remaining: 1m 3s
# 600:	learn: 0.7252856	test: 0.6909795	best: 0.6909795 (600)	total: 13.2s	remaining: 1m 1s
# 800:	learn: 0.7163534	test: 0.6814302	best: 0.6814302 (800)	total: 18.4s	remaining: 59.9s
# 1000:	learn: 0.7104657	test: 0.6776641	best: 0.6776641 (1000)	total: 23.7s	remaining: 56.8s
# 1200:	learn: 0.7063185	test: 0.6753234	best: 0.6753071 (1197)	total: 29s	remaining: 53s
# 1400:	learn: 0.7024133	test: 0.6737301	best: 0.6737301 (1400)	total: 34.2s	remaining: 48.9s
# 1600:	learn: 0.6992553	test: 0.6730666	best: 0.6730666 (1600)	total: 39.4s	remaining: 44.3s
# 1800:	learn: 0.6954955	test: 0.6727710	best: 0.6727373 (1787)	total: 45s	remaining: 40s
# 2000:	learn: 0.6919739	test: 0.6720937	best: 0.6720937 (2000)	total: 50.6s	remaining: 35.4s
# 2200:	learn: 0.6882316	test: 0.6719218	best: 0.6718764 (2155)	total: 56.2s	remaining: 30.6s
# 2400:	learn: 0.6849455	test: 0.6715834	best: 0.6715834 (2400)	total: 1m 1s	remaining: 25.7s
# 2600:	learn: 0.6813983	test: 0.6713011	best: 0.6712761 (2564)	total: 1m 7s	remaining: 20.6s
# 2800:	learn: 0.6784807	test: 0.6711980	best: 0.6711765 (2796)	total: 1m 12s	remaining: 15.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6711758624
# bestIteration = 2801
#
# Shrink model to first 2802 iterations.
# CV Log Loss Score: 0.671176
# 	Log Loss: 0.665684
# [I 2021-07-04 09:03:15,205] Trial 0 finished with value: 0.665683727124693 and parameters: {'learning_rate': 0.025639478386043843, 'n_estimators': 3400, 'colsample_bylevel': 0.034244272134555324, 'depth': 9, 'subsample': 0.7261702509869272}. Best is trial 0 with value: 0.665683727124693.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0804241	test: 1.0804447	best: 1.0804447 (0)	total: 24.1ms	remaining: 1m 31s
# 200:	learn: 0.7175159	test: 0.6770375	best: 0.6770375 (200)	total: 11.5s	remaining: 3m 26s
# 400:	learn: 0.7001486	test: 0.6702795	best: 0.6702243 (398)	total: 33.6s	remaining: 4m 44s
# 600:	learn: 0.6806754	test: 0.6680461	best: 0.6680461 (600)	total: 1m 3s	remaining: 5m 36s
# 800:	learn: 0.6628901	test: 0.6674175	best: 0.6671176 (719)	total: 1m 31s	remaining: 5m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6671175745
# bestIteration = 719
#
# Shrink model to first 720 iterations.
# CV Log Loss Score: 0.667118
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0745851	test: 1.0744996	best: 1.0744996 (0)	total: 66.3ms	remaining: 4m 11s
# 200:	learn: 0.7181782	test: 0.6702222	best: 0.6702222 (200)	total: 12.6s	remaining: 3m 45s
# 400:	learn: 0.7020520	test: 0.6662426	best: 0.6662132 (397)	total: 34.5s	remaining: 4m 52s
# 600:	learn: 0.6836468	test: 0.6653376	best: 0.6650982 (565)	total: 1m 1s	remaining: 5m 27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6650981592
# bestIteration = 565
#
# Shrink model to first 566 iterations.
# CV Log Loss Score: 0.665098
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0746705	test: 1.0741734	best: 1.0741734 (0)	total: 31.8ms	remaining: 2m
# 200:	learn: 0.7194550	test: 0.6567034	best: 0.6566968 (199)	total: 11.4s	remaining: 3m 23s
# 400:	learn: 0.7015608	test: 0.6491972	best: 0.6491745 (393)	total: 33.5s	remaining: 4m 43s
# 600:	learn: 0.6822796	test: 0.6479544	best: 0.6478042 (594)	total: 1m 2s	remaining: 5m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6476458701
# bestIteration = 682
#
# Shrink model to first 683 iterations.
# CV Log Loss Score: 0.647646
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0745643	test: 1.0747128	best: 1.0747128 (0)	total: 49.1ms	remaining: 3m 6s
# 200:	learn: 0.7170514	test: 0.6744637	best: 0.6744637 (200)	total: 12.5s	remaining: 3m 43s
# 400:	learn: 0.6997252	test: 0.6720831	best: 0.6718813 (325)	total: 34.7s	remaining: 4m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6718813435
# bestIteration = 325
#
# Shrink model to first 326 iterations.
# CV Log Loss Score: 0.671881
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0745566	test: 1.0747464	best: 1.0747464 (0)	total: 29.4ms	remaining: 1m 51s
# 200:	learn: 0.7164940	test: 0.6777870	best: 0.6777870 (200)	total: 11.6s	remaining: 3m 28s
# 400:	learn: 0.6990717	test: 0.6729353	best: 0.6726053 (374)	total: 35.5s	remaining: 5m
# 600:	learn: 0.6792010	test: 0.6727803	best: 0.6725673 (566)	total: 1m 4s	remaining: 5m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6725673389
# bestIteration = 566
#
# Shrink model to first 567 iterations.
# CV Log Loss Score: 0.672567
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0745478	test: 1.0744746	best: 1.0744746 (0)	total: 26ms	remaining: 1m 38s
# 200:	learn: 0.7180787	test: 0.6735604	best: 0.6735565 (197)	total: 12.3s	remaining: 3m 40s
# 400:	learn: 0.7005875	test: 0.6651696	best: 0.6651404 (398)	total: 36.4s	remaining: 5m 8s
# 600:	learn: 0.6822823	test: 0.6644861	best: 0.6644204 (588)	total: 1m 6s	remaining: 5m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6641026165
# bestIteration = 652
#
# Shrink model to first 653 iterations.
# CV Log Loss Score: 0.664103
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0745853	test: 1.0746189	best: 1.0746189 (0)	total: 62.5ms	remaining: 3m 57s
# 200:	learn: 0.7196932	test: 0.6675519	best: 0.6675519 (200)	total: 11.6s	remaining: 3m 28s
# 400:	learn: 0.7010671	test: 0.6595568	best: 0.6595568 (400)	total: 35.2s	remaining: 4m 58s
# 600:	learn: 0.6809353	test: 0.6587009	best: 0.6586940 (596)	total: 1m 4s	remaining: 5m 41s
# 800:	learn: 0.6610393	test: 0.6571968	best: 0.6571968 (800)	total: 1m 32s	remaining: 5m 47s
# 1000:	learn: 0.6425332	test: 0.6572447	best: 0.6570402 (930)	total: 2m 1s	remaining: 5m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6570402485
# bestIteration = 930
#
# Shrink model to first 931 iterations.
# CV Log Loss Score: 0.657040
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0745875	test: 1.0744539	best: 1.0744539 (0)	total: 33.3ms	remaining: 2m 6s
# 200:	learn: 0.7187235	test: 0.6624724	best: 0.6624724 (200)	total: 12.4s	remaining: 3m 41s
# 400:	learn: 0.7015313	test: 0.6567866	best: 0.6567658 (389)	total: 35.1s	remaining: 4m 57s
# 600:	learn: 0.6835386	test: 0.6560528	best: 0.6559048 (590)	total: 1m 2s	remaining: 5m 33s
# 800:	learn: 0.6641830	test: 0.6557480	best: 0.6555418 (726)	total: 1m 29s	remaining: 5m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6555417865
# bestIteration = 726
#
# Shrink model to first 727 iterations.
# CV Log Loss Score: 0.655542
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0746262	test: 1.0745669	best: 1.0745669 (0)	total: 52.8ms	remaining: 3m 20s
# 200:	learn: 0.7178062	test: 0.6694218	best: 0.6694218 (200)	total: 10.4s	remaining: 3m 6s
# 400:	learn: 0.7010961	test: 0.6636664	best: 0.6636664 (400)	total: 32.1s	remaining: 4m 32s
# 600:	learn: 0.6814223	test: 0.6629126	best: 0.6624255 (568)	total: 59.8s	remaining: 5m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.662425512
# bestIteration = 568
#
# Shrink model to first 569 iterations.
# CV Log Loss Score: 0.662426
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0746325	test: 1.0745188	best: 1.0745188 (0)	total: 49.6ms	remaining: 3m 8s
# 200:	learn: 0.7173099	test: 0.6749762	best: 0.6749762 (200)	total: 10.9s	remaining: 3m 16s
# 400:	learn: 0.6992761	test: 0.6709701	best: 0.6709610 (381)	total: 32.6s	remaining: 4m 36s
# 600:	learn: 0.6798133	test: 0.6705622	best: 0.6701516 (523)	total: 1m	remaining: 5m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6701516326
# bestIteration = 523
#
# Shrink model to first 524 iterations.
# CV Log Loss Score: 0.670152
# 	Log Loss: 0.663357
# [I 2021-07-04 09:16:47,291] Trial 1 finished with value: 0.6633573503896221 and parameters: {'learning_rate': 0.04160502952238434, 'n_estimators': 3800, 'colsample_bylevel': 0.1832000117969863, 'depth': 9, 'subsample': 0.8101208520516356}. Best is trial 1 with value: 0.6633573503896221.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0786668	test: 1.0786894	best: 1.0786894 (0)	total: 16.5ms	remaining: 1m 12s
# 200:	learn: 0.7178850	test: 0.6776434	best: 0.6776434 (200)	total: 15s	remaining: 5m 14s
# 400:	learn: 0.6956108	test: 0.6714936	best: 0.6714858 (399)	total: 1m 24s	remaining: 14m 6s
# 600:	learn: 0.6721000	test: 0.6700615	best: 0.6700196 (592)	total: 2m 55s	remaining: 18m 31s
# 800:	learn: 0.6488936	test: 0.6693230	best: 0.6689319 (719)	total: 4m 23s	remaining: 19m 44s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6689318672
# bestIteration = 719
#
# Shrink model to first 720 iterations.
# CV Log Loss Score: 0.668932
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0786836	test: 1.0786247	best: 1.0786247 (0)	total: 32.8ms	remaining: 2m 24s
# 200:	learn: 0.7161059	test: 0.6692692	best: 0.6692685 (199)	total: 22s	remaining: 7m 40s
# 400:	learn: 0.6940473	test: 0.6659300	best: 0.6658030 (389)	total: 1m 33s	remaining: 15m 30s
# 600:	learn: 0.6682398	test: 0.6657905	best: 0.6655429 (553)	total: 3m 4s	remaining: 19m 26s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6655428887
# bestIteration = 553
#
# Shrink model to first 554 iterations.
# CV Log Loss Score: 0.665543
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0786899	test: 1.0786558	best: 1.0786558 (0)	total: 29.2ms	remaining: 2m 8s
# 200:	learn: 0.7176893	test: 0.6535682	best: 0.6535682 (200)	total: 17.7s	remaining: 6m 8s
# 400:	learn: 0.6961390	test: 0.6476614	best: 0.6475402 (395)	total: 1m 26s	remaining: 14m 27s
# 600:	learn: 0.6700602	test: 0.6467511	best: 0.6467170 (594)	total: 3m 1s	remaining: 19m 4s
# 800:	learn: 0.6453636	test: 0.6470188	best: 0.6464887 (704)	total: 4m 34s	remaining: 20m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6464887142
# bestIteration = 704
#
# Shrink model to first 705 iterations.
# CV Log Loss Score: 0.646489
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0786887	test: 1.0787043	best: 1.0787043 (0)	total: 30.7ms	remaining: 2m 14s
# 200:	learn: 0.7165164	test: 0.6748675	best: 0.6748675 (200)	total: 18.1s	remaining: 6m 17s
# 400:	learn: 0.6952339	test: 0.6716595	best: 0.6713353 (358)	total: 1m 32s	remaining: 15m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6713352743
# bestIteration = 358
#
# Shrink model to first 359 iterations.
# CV Log Loss Score: 0.671335
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0787034	test: 1.0786465	best: 1.0786465 (0)	total: 32.7ms	remaining: 2m 23s
# 200:	learn: 0.7146445	test: 0.6760199	best: 0.6760199 (200)	total: 19.4s	remaining: 6m 44s
# 400:	learn: 0.6939699	test: 0.6724164	best: 0.6723813 (397)	total: 1m 34s	remaining: 15m 45s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6722837764
# bestIteration = 441
#
# Shrink model to first 442 iterations.
# CV Log Loss Score: 0.672284
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0786705	test: 1.0786490	best: 1.0786490 (0)	total: 34.8ms	remaining: 2m 32s
# 200:	learn: 0.7162982	test: 0.6709572	best: 0.6709570 (199)	total: 20.6s	remaining: 7m 10s
# 400:	learn: 0.6937393	test: 0.6646108	best: 0.6646108 (400)	total: 1m 38s	remaining: 16m 26s
# 600:	learn: 0.6710017	test: 0.6638886	best: 0.6638122 (539)	total: 3m 19s	remaining: 21m 2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6638121812
# bestIteration = 539
#
# Shrink model to first 540 iterations.
# CV Log Loss Score: 0.663812
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0786902	test: 1.0787777	best: 1.0787777 (0)	total: 39ms	remaining: 2m 51s
# 200:	learn: 0.7162806	test: 0.6655419	best: 0.6655419 (200)	total: 20.5s	remaining: 7m 8s
# 400:	learn: 0.6941533	test: 0.6597483	best: 0.6597483 (400)	total: 1m 39s	remaining: 16m 32s
# 600:	learn: 0.6684125	test: 0.6581366	best: 0.6581050 (599)	total: 3m 18s	remaining: 20m 52s
# 800:	learn: 0.6421029	test: 0.6577492	best: 0.6577492 (800)	total: 4m 56s	remaining: 22m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6574960194
# bestIteration = 827
#
# Shrink model to first 828 iterations.
# CV Log Loss Score: 0.657496
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0786840	test: 1.0786535	best: 1.0786535 (0)	total: 33.9ms	remaining: 2m 29s
# 200:	learn: 0.7179172	test: 0.6620594	best: 0.6620594 (200)	total: 18.3s	remaining: 6m 22s
# 400:	learn: 0.6956000	test: 0.6575341	best: 0.6573633 (365)	total: 1m 37s	remaining: 16m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6569901366
# bestIteration = 467
#
# Shrink model to first 468 iterations.
# CV Log Loss Score: 0.656990
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0786820	test: 1.0787186	best: 1.0787186 (0)	total: 32.7ms	remaining: 2m 23s
# 200:	learn: 0.7154843	test: 0.6675435	best: 0.6675435 (200)	total: 25.3s	remaining: 8m 47s
# 400:	learn: 0.6935746	test: 0.6631845	best: 0.6631845 (400)	total: 1m 40s	remaining: 16m 40s
# 600:	learn: 0.6681727	test: 0.6624309	best: 0.6622779 (508)	total: 3m 21s	remaining: 21m 11s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6622779227
# bestIteration = 508
#
# Shrink model to first 509 iterations.
# CV Log Loss Score: 0.662278
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0786791	test: 1.0786925	best: 1.0786925 (0)	total: 28.5ms	remaining: 2m 5s
# 200:	learn: 0.7142793	test: 0.6731031	best: 0.6731031 (200)	total: 23.5s	remaining: 8m 9s
# 400:	learn: 0.6931955	test: 0.6693989	best: 0.6693310 (386)	total: 1m 39s	remaining: 16m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6693191255
# bestIteration = 405
#
# Shrink model to first 406 iterations.
# CV Log Loss Score: 0.669319
# 	Log Loss: 0.663448
# [I 2021-07-04 09:52:48,965] Trial 2 finished with value: 0.6634479979427051 and parameters: {'learning_rate': 0.045721884216426596, 'n_estimators': 4400, 'colsample_bylevel': 0.16548282906074485, 'depth': 11, 'subsample': 0.9679705760891386}. Best is trial 1 with value: 0.6633573503896221.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0809347	test: 1.0809547	best: 1.0809547 (0)	total: 16.9ms	remaining: 53.9s
# 200:	learn: 0.7196106	test: 0.6820394	best: 0.6820268 (199)	total: 6.68s	remaining: 1m 39s
# 400:	learn: 0.7046408	test: 0.6732726	best: 0.6732591 (398)	total: 15.7s	remaining: 1m 49s
# 600:	learn: 0.6896693	test: 0.6707955	best: 0.6707717 (595)	total: 26.2s	remaining: 1m 53s
# 800:	learn: 0.6758466	test: 0.6703492	best: 0.6703038 (783)	total: 37.1s	remaining: 1m 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6702078248
# bestIteration = 845
#
# Shrink model to first 846 iterations.
# CV Log Loss Score: 0.670208
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0809321	test: 1.0809249	best: 1.0809249 (0)	total: 44ms	remaining: 2m 20s
# 200:	learn: 0.7205988	test: 0.6760225	best: 0.6760225 (200)	total: 6.91s	remaining: 1m 43s
# 400:	learn: 0.7043187	test: 0.6673872	best: 0.6673449 (399)	total: 16.1s	remaining: 1m 52s
# 600:	learn: 0.6904516	test: 0.6669458	best: 0.6668128 (576)	total: 26.7s	remaining: 1m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6668128063
# bestIteration = 576
#
# Shrink model to first 577 iterations.
# CV Log Loss Score: 0.666813
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0809804	test: 1.0809431	best: 1.0809431 (0)	total: 48.7ms	remaining: 2m 35s
# 200:	learn: 0.7228012	test: 0.6632121	best: 0.6632121 (200)	total: 6.4s	remaining: 1m 35s
# 400:	learn: 0.7059811	test: 0.6515380	best: 0.6515340 (399)	total: 15.6s	remaining: 1m 49s
# 600:	learn: 0.6909150	test: 0.6496989	best: 0.6496520 (587)	total: 26.5s	remaining: 1m 54s
# 800:	learn: 0.6769745	test: 0.6493843	best: 0.6492459 (723)	total: 37.3s	remaining: 1m 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6492458973
# bestIteration = 723
#
# Shrink model to first 724 iterations.
# CV Log Loss Score: 0.649246
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0809284	test: 1.0809619	best: 1.0809619 (0)	total: 41ms	remaining: 2m 11s
# 200:	learn: 0.7213002	test: 0.6808801	best: 0.6808801 (200)	total: 6s	remaining: 1m 29s
# 400:	learn: 0.7044863	test: 0.6731505	best: 0.6731495 (386)	total: 14.8s	remaining: 1m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6729939986
# bestIteration = 472
#
# Shrink model to first 473 iterations.
# CV Log Loss Score: 0.672994
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0809586	test: 1.0808880	best: 1.0808880 (0)	total: 41.9ms	remaining: 2m 14s
# 200:	learn: 0.7199876	test: 0.6828735	best: 0.6828735 (200)	total: 6.38s	remaining: 1m 35s
# 400:	learn: 0.7026834	test: 0.6724932	best: 0.6724932 (400)	total: 15.4s	remaining: 1m 47s
# 600:	learn: 0.6873518	test: 0.6713089	best: 0.6710695 (557)	total: 26.3s	remaining: 1m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6710694926
# bestIteration = 557
#
# Shrink model to first 558 iterations.
# CV Log Loss Score: 0.671069
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0809481	test: 1.0808491	best: 1.0808491 (0)	total: 46.1ms	remaining: 2m 27s
# 200:	learn: 0.7234074	test: 0.6823230	best: 0.6823230 (200)	total: 6.2s	remaining: 1m 32s
# 400:	learn: 0.7062178	test: 0.6669702	best: 0.6669702 (400)	total: 14.9s	remaining: 1m 44s
# 600:	learn: 0.6922021	test: 0.6654898	best: 0.6653285 (579)	total: 25.6s	remaining: 1m 50s
# 800:	learn: 0.6787854	test: 0.6647880	best: 0.6647880 (800)	total: 36.5s	remaining: 1m 49s
# 1000:	learn: 0.6652597	test: 0.6650460	best: 0.6647215 (945)	total: 47.2s	remaining: 1m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6647214663
# bestIteration = 945
#
# Shrink model to first 946 iterations.
# CV Log Loss Score: 0.664721
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0809504	test: 1.0809255	best: 1.0809255 (0)	total: 50.1ms	remaining: 2m 40s
# 200:	learn: 0.7241655	test: 0.6758981	best: 0.6758981 (200)	total: 5.99s	remaining: 1m 29s
# 400:	learn: 0.7064557	test: 0.6623573	best: 0.6623573 (400)	total: 15.5s	remaining: 1m 48s
# 600:	learn: 0.6917974	test: 0.6604819	best: 0.6604564 (587)	total: 26.5s	remaining: 1m 54s
# 800:	learn: 0.6769215	test: 0.6591499	best: 0.6591214 (793)	total: 37.5s	remaining: 1m 52s
# 1000:	learn: 0.6619748	test: 0.6584197	best: 0.6581885 (954)	total: 48.5s	remaining: 1m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6581884935
# bestIteration = 954
#
# Shrink model to first 955 iterations.
# CV Log Loss Score: 0.658188
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0809465	test: 1.0808566	best: 1.0808566 (0)	total: 46.4ms	remaining: 2m 28s
# 200:	learn: 0.7213619	test: 0.6688814	best: 0.6688814 (200)	total: 6.34s	remaining: 1m 34s
# 400:	learn: 0.7054521	test: 0.6584238	best: 0.6583818 (399)	total: 15.8s	remaining: 1m 50s
# 600:	learn: 0.6920507	test: 0.6567040	best: 0.6567040 (600)	total: 26.5s	remaining: 1m 54s
# 800:	learn: 0.6789515	test: 0.6562899	best: 0.6562326 (780)	total: 37.5s	remaining: 1m 52s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6560617134
# bestIteration = 841
#
# Shrink model to first 842 iterations.
# CV Log Loss Score: 0.656062
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0809149	test: 1.0809646	best: 1.0809646 (0)	total: 48.6ms	remaining: 2m 35s
# 200:	learn: 0.7193469	test: 0.6746334	best: 0.6746334 (200)	total: 7.3s	remaining: 1m 48s
# 400:	learn: 0.7040960	test: 0.6644717	best: 0.6644700 (399)	total: 16.4s	remaining: 1m 54s
# 600:	learn: 0.6885609	test: 0.6633984	best: 0.6632571 (592)	total: 27.6s	remaining: 1m 59s
# 800:	learn: 0.6749272	test: 0.6631242	best: 0.6631039 (745)	total: 38.3s	remaining: 1m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6630858478
# bestIteration = 818
#
# Shrink model to first 819 iterations.
# CV Log Loss Score: 0.663086
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0809654	test: 1.0809319	best: 1.0809319 (0)	total: 45.1ms	remaining: 2m 24s
# 200:	learn: 0.7191327	test: 0.6793290	best: 0.6793290 (200)	total: 6.98s	remaining: 1m 44s
# 400:	learn: 0.7047271	test: 0.6716645	best: 0.6716270 (387)	total: 16.1s	remaining: 1m 52s
# 600:	learn: 0.6889516	test: 0.6701688	best: 0.6701538 (596)	total: 27.2s	remaining: 1m 57s
# 800:	learn: 0.6746521	test: 0.6703053	best: 0.6699377 (726)	total: 38.3s	remaining: 1m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6699377293
# bestIteration = 726
#
# Shrink model to first 727 iterations.
# CV Log Loss Score: 0.669938
# 	Log Loss: 0.664233
# [I 2021-07-04 09:59:31,737] Trial 3 finished with value: 0.6642327528961203 and parameters: {'learning_rate': 0.04041215540542881, 'n_estimators': 3200, 'colsample_bylevel': 0.09331790915027285, 'depth': 8, 'subsample': 0.6992674668944645}. Best is trial 1 with value: 0.6633573503896221.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0804288	test: 1.0804494	best: 1.0804494 (0)	total: 19.9ms	remaining: 47.6s
# 200:	learn: 0.7191538	test: 0.6792795	best: 0.6792795 (200)	total: 7.67s	remaining: 1m 23s
# 400:	learn: 0.7042530	test: 0.6719840	best: 0.6719840 (400)	total: 18.4s	remaining: 1m 31s
# 600:	learn: 0.6887454	test: 0.6696113	best: 0.6695801 (599)	total: 32s	remaining: 1m 35s
# 800:	learn: 0.6726936	test: 0.6689673	best: 0.6689126 (788)	total: 45.4s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6685061874
# bestIteration = 895
#
# Shrink model to first 896 iterations.
# CV Log Loss Score: 0.668506
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0750026	test: 1.0749830	best: 1.0749830 (0)	total: 75.8ms	remaining: 3m 1s
# 200:	learn: 0.7192126	test: 0.6744871	best: 0.6744871 (200)	total: 7.5s	remaining: 1m 22s
# 400:	learn: 0.7030139	test: 0.6678665	best: 0.6677612 (390)	total: 18.8s	remaining: 1m 33s
# 600:	learn: 0.6861556	test: 0.6667178	best: 0.6666606 (595)	total: 32.4s	remaining: 1m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6662799481
# bestIteration = 642
#
# Shrink model to first 643 iterations.
# CV Log Loss Score: 0.666280
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0804565	test: 1.0804250	best: 1.0804250 (0)	total: 36.9ms	remaining: 1m 28s
# 200:	learn: 0.7206810	test: 0.6583993	best: 0.6583993 (200)	total: 7.42s	remaining: 1m 21s
# 400:	learn: 0.7035127	test: 0.6503867	best: 0.6503360 (394)	total: 18.8s	remaining: 1m 33s
# 600:	learn: 0.6870033	test: 0.6488178	best: 0.6486294 (570)	total: 32.7s	remaining: 1m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.648629417
# bestIteration = 570
#
# Shrink model to first 571 iterations.
# CV Log Loss Score: 0.648629
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0748917	test: 1.0753688	best: 1.0753688 (0)	total: 94.4ms	remaining: 3m 46s
# 200:	learn: 0.7188116	test: 0.6778616	best: 0.6778553 (199)	total: 7.92s	remaining: 1m 26s
# 400:	learn: 0.7021754	test: 0.6739583	best: 0.6738332 (394)	total: 19.4s	remaining: 1m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6737713796
# bestIteration = 465
#
# Shrink model to first 466 iterations.
# CV Log Loss Score: 0.673771
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0804477	test: 1.0804487	best: 1.0804487 (0)	total: 38.2ms	remaining: 1m 31s
# 200:	learn: 0.7175435	test: 0.6799158	best: 0.6799020 (199)	total: 7.75s	remaining: 1m 24s
# 400:	learn: 0.7016478	test: 0.6731707	best: 0.6730153 (390)	total: 19.5s	remaining: 1m 37s
# 600:	learn: 0.6841053	test: 0.6731343	best: 0.6727632 (555)	total: 33.2s	remaining: 1m 39s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6727632499
# bestIteration = 555
#
# Shrink model to first 556 iterations.
# CV Log Loss Score: 0.672763
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0750058	test: 1.0750147	best: 1.0750147 (0)	total: 101ms	remaining: 4m 3s
# 200:	learn: 0.7183535	test: 0.6734829	best: 0.6734829 (200)	total: 8.19s	remaining: 1m 29s
# 400:	learn: 0.7017399	test: 0.6658448	best: 0.6658448 (400)	total: 20.1s	remaining: 1m 40s
# 600:	learn: 0.6855233	test: 0.6643062	best: 0.6643062 (600)	total: 34s	remaining: 1m 41s
# 800:	learn: 0.6694242	test: 0.6644131	best: 0.6640538 (760)	total: 47.7s	remaining: 1m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6640537929
# bestIteration = 760
#
# Shrink model to first 761 iterations.
# CV Log Loss Score: 0.664054
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0750045	test: 1.0749241	best: 1.0749241 (0)	total: 97.5ms	remaining: 3m 53s
# 200:	learn: 0.7207822	test: 0.6698182	best: 0.6698182 (200)	total: 7.49s	remaining: 1m 21s
# 400:	learn: 0.7028707	test: 0.6613746	best: 0.6613739 (379)	total: 19.6s	remaining: 1m 37s
# 600:	learn: 0.6859560	test: 0.6594183	best: 0.6593842 (597)	total: 33.8s	remaining: 1m 41s
# 800:	learn: 0.6699827	test: 0.6590705	best: 0.6590705 (800)	total: 47.9s	remaining: 1m 35s
# 1000:	learn: 0.6545127	test: 0.6581042	best: 0.6581042 (1000)	total: 1m 1s	remaining: 1m 26s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6579407462
# bestIteration = 1030
#
# Shrink model to first 1031 iterations.
# CV Log Loss Score: 0.657941
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0804646	test: 1.0804876	best: 1.0804876 (0)	total: 35.5ms	remaining: 1m 25s
# 200:	learn: 0.7199771	test: 0.6645506	best: 0.6645506 (200)	total: 7.81s	remaining: 1m 25s
# 400:	learn: 0.7042359	test: 0.6577251	best: 0.6575999 (391)	total: 19.7s	remaining: 1m 38s
# 600:	learn: 0.6868521	test: 0.6559339	best: 0.6559339 (600)	total: 33.8s	remaining: 1m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6554539388
# bestIteration = 689
#
# Shrink model to first 690 iterations.
# CV Log Loss Score: 0.655454
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0749838	test: 1.0749545	best: 1.0749545 (0)	total: 88ms	remaining: 3m 31s
# 200:	learn: 0.7191747	test: 0.6712216	best: 0.6712216 (200)	total: 8.32s	remaining: 1m 31s
# 400:	learn: 0.7033548	test: 0.6643082	best: 0.6643082 (400)	total: 20.4s	remaining: 1m 41s
# 600:	learn: 0.6850826	test: 0.6631663	best: 0.6631476 (599)	total: 34.5s	remaining: 1m 43s
# 800:	learn: 0.6696834	test: 0.6628449	best: 0.6627274 (732)	total: 48.3s	remaining: 1m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6627274439
# bestIteration = 732
#
# Shrink model to first 733 iterations.
# CV Log Loss Score: 0.662727
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0750325	test: 1.0748578	best: 1.0748578 (0)	total: 94.5ms	remaining: 3m 46s
# 200:	learn: 0.7185653	test: 0.6771794	best: 0.6771794 (200)	total: 7.93s	remaining: 1m 26s
# 400:	learn: 0.7027419	test: 0.6717117	best: 0.6717117 (400)	total: 19.6s	remaining: 1m 37s
# 600:	learn: 0.6857121	test: 0.6712719	best: 0.6712463 (592)	total: 34s	remaining: 1m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6710352237
# bestIteration = 640
#
# Shrink model to first 641 iterations.
# CV Log Loss Score: 0.671035
# 	Log Loss: 0.664116
# [I 2021-07-04 10:07:25,653] Trial 4 finished with value: 0.6641162987125543 and parameters: {'learning_rate': 0.04159397390768506, 'n_estimators': 2400, 'colsample_bylevel': 0.15221470001243506, 'depth': 8, 'subsample': 0.638305299754207}. Best is trial 1 with value: 0.6633573503896221.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0919215	test: 1.0919290	best: 1.0919290 (0)	total: 13.7ms	remaining: 54.8s
# 200:	learn: 0.7473485	test: 0.7239129	best: 0.7239129 (200)	total: 7.04s	remaining: 2m 13s
# 400:	learn: 0.7229058	test: 0.6848352	best: 0.6848352 (400)	total: 15s	remaining: 2m 14s
# 600:	learn: 0.7171854	test: 0.6776483	best: 0.6776483 (600)	total: 23.4s	remaining: 2m 12s
# 800:	learn: 0.7124352	test: 0.6741563	best: 0.6741563 (800)	total: 33.1s	remaining: 2m 12s
# 1000:	learn: 0.7058075	test: 0.6721714	best: 0.6721714 (1000)	total: 47.3s	remaining: 2m 21s
# 1200:	learn: 0.6995922	test: 0.6710880	best: 0.6710787 (1198)	total: 1m 1s	remaining: 2m 23s
# 1400:	learn: 0.6935572	test: 0.6704323	best: 0.6704002 (1385)	total: 1m 16s	remaining: 2m 21s
# 1600:	learn: 0.6873589	test: 0.6699095	best: 0.6699095 (1600)	total: 1m 30s	remaining: 2m 15s
# 1800:	learn: 0.6814722	test: 0.6696591	best: 0.6696591 (1800)	total: 1m 44s	remaining: 2m 7s
# 2000:	learn: 0.6757877	test: 0.6693610	best: 0.6693235 (1990)	total: 1m 58s	remaining: 1m 58s
# 2200:	learn: 0.6702057	test: 0.6689802	best: 0.6689499 (2182)	total: 2m 13s	remaining: 1m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.668822481
# bestIteration = 2281
#
# Shrink model to first 2282 iterations.
# CV Log Loss Score: 0.668822
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0898023	test: 1.0898064	best: 1.0898064 (0)	total: 28.1ms	remaining: 1m 52s
# 200:	learn: 0.7432720	test: 0.7102650	best: 0.7102650 (200)	total: 8.36s	remaining: 2m 37s
# 400:	learn: 0.7218151	test: 0.6764642	best: 0.6764635 (399)	total: 16.8s	remaining: 2m 30s
# 600:	learn: 0.7166957	test: 0.6700831	best: 0.6700831 (600)	total: 24.8s	remaining: 2m 20s
# 800:	learn: 0.7120709	test: 0.6671337	best: 0.6671337 (800)	total: 34s	remaining: 2m 15s
# 1000:	learn: 0.7055668	test: 0.6661364	best: 0.6661171 (991)	total: 48.4s	remaining: 2m 25s
# 1200:	learn: 0.6991789	test: 0.6653383	best: 0.6653383 (1200)	total: 1m 2s	remaining: 2m 26s
# 1400:	learn: 0.6931293	test: 0.6652162	best: 0.6651621 (1347)	total: 1m 17s	remaining: 2m 23s
# 1600:	learn: 0.6871459	test: 0.6649496	best: 0.6648842 (1582)	total: 1m 31s	remaining: 2m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6648841873
# bestIteration = 1582
#
# Shrink model to first 1583 iterations.
# CV Log Loss Score: 0.664884
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0898400	test: 1.0896590	best: 1.0896590 (0)	total: 67.9ms	remaining: 4m 31s
# 200:	learn: 0.7438991	test: 0.6960821	best: 0.6960821 (200)	total: 8.16s	remaining: 2m 34s
# 400:	learn: 0.7240240	test: 0.6624745	best: 0.6624745 (400)	total: 16.6s	remaining: 2m 28s
# 600:	learn: 0.7191356	test: 0.6565754	best: 0.6565754 (600)	total: 24.5s	remaining: 2m 18s
# 800:	learn: 0.7143579	test: 0.6532634	best: 0.6532634 (800)	total: 34.5s	remaining: 2m 17s
# 1000:	learn: 0.7073155	test: 0.6510957	best: 0.6510957 (1000)	total: 48.8s	remaining: 2m 26s
# 1200:	learn: 0.7007342	test: 0.6500686	best: 0.6500629 (1199)	total: 1m 3s	remaining: 2m 27s
# 1400:	learn: 0.6941858	test: 0.6496942	best: 0.6496942 (1400)	total: 1m 17s	remaining: 2m 24s
# 1600:	learn: 0.6880316	test: 0.6494729	best: 0.6494699 (1569)	total: 1m 32s	remaining: 2m 19s
# 1800:	learn: 0.6824694	test: 0.6490944	best: 0.6490665 (1799)	total: 1m 47s	remaining: 2m 10s
# 2000:	learn: 0.6765781	test: 0.6487880	best: 0.6487000 (1969)	total: 2m 1s	remaining: 2m 1s
# 2200:	learn: 0.6708940	test: 0.6486055	best: 0.6485209 (2188)	total: 2m 16s	remaining: 1m 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6485208766
# bestIteration = 2188
#
# Shrink model to first 2189 iterations.
# CV Log Loss Score: 0.648521
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0897849	test: 1.0898538	best: 1.0898538 (0)	total: 32.1ms	remaining: 2m 8s
# 200:	learn: 0.7442294	test: 0.7103614	best: 0.7103614 (200)	total: 7.66s	remaining: 2m 24s
# 400:	learn: 0.7240686	test: 0.6806723	best: 0.6806723 (400)	total: 15.1s	remaining: 2m 15s
# 600:	learn: 0.7180967	test: 0.6749354	best: 0.6749354 (600)	total: 23.4s	remaining: 2m 12s
# 800:	learn: 0.7132399	test: 0.6728381	best: 0.6728085 (790)	total: 32.9s	remaining: 2m 11s
# 1000:	learn: 0.7060771	test: 0.6720312	best: 0.6719687 (990)	total: 47.7s	remaining: 2m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6719315198
# bestIteration = 1047
#
# Shrink model to first 1048 iterations.
# CV Log Loss Score: 0.671932
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0897940	test: 1.0898484	best: 1.0898484 (0)	total: 74ms	remaining: 4m 55s
# 200:	learn: 0.7430652	test: 0.7166555	best: 0.7166555 (200)	total: 8.42s	remaining: 2m 39s
# 400:	learn: 0.7206748	test: 0.6827638	best: 0.6827638 (400)	total: 16.9s	remaining: 2m 31s
# 600:	learn: 0.7159980	test: 0.6774179	best: 0.6774179 (600)	total: 24.6s	remaining: 2m 19s
# 800:	learn: 0.7113965	test: 0.6743591	best: 0.6743591 (800)	total: 34.4s	remaining: 2m 17s
# 1000:	learn: 0.7048226	test: 0.6730872	best: 0.6730768 (999)	total: 49.3s	remaining: 2m 27s
# 1200:	learn: 0.6983564	test: 0.6725285	best: 0.6725285 (1200)	total: 1m 4s	remaining: 2m 29s
# 1400:	learn: 0.6924102	test: 0.6721303	best: 0.6721303 (1400)	total: 1m 19s	remaining: 2m 26s
# 1600:	learn: 0.6860097	test: 0.6719782	best: 0.6719251 (1586)	total: 1m 33s	remaining: 2m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6719000018
# bestIteration = 1671
#
# Shrink model to first 1672 iterations.
# CV Log Loss Score: 0.671900
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0898052	test: 1.0898139	best: 1.0898139 (0)	total: 72.5ms	remaining: 4m 49s
# 200:	learn: 0.7446035	test: 0.7143407	best: 0.7143407 (200)	total: 8.13s	remaining: 2m 33s
# 400:	learn: 0.7229661	test: 0.6794960	best: 0.6794960 (400)	total: 15.6s	remaining: 2m 20s
# 600:	learn: 0.7173154	test: 0.6717105	best: 0.6717105 (600)	total: 24.1s	remaining: 2m 16s
# 800:	learn: 0.7125658	test: 0.6678217	best: 0.6678217 (800)	total: 34s	remaining: 2m 15s
# 1000:	learn: 0.7058852	test: 0.6658236	best: 0.6658236 (1000)	total: 48.6s	remaining: 2m 25s
# 1200:	learn: 0.6997089	test: 0.6647589	best: 0.6647589 (1200)	total: 1m 3s	remaining: 2m 28s
# 1400:	learn: 0.6935474	test: 0.6642164	best: 0.6641993 (1380)	total: 1m 18s	remaining: 2m 26s
# 1600:	learn: 0.6875660	test: 0.6639820	best: 0.6639771 (1566)	total: 1m 33s	remaining: 2m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6638141935
# bestIteration = 1647
#
# Shrink model to first 1648 iterations.
# CV Log Loss Score: 0.663814
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0897950	test: 1.0898630	best: 1.0898630 (0)	total: 68.8ms	remaining: 4m 35s
# 200:	learn: 0.7458219	test: 0.7098550	best: 0.7098550 (200)	total: 7.85s	remaining: 2m 28s
# 400:	learn: 0.7241487	test: 0.6740732	best: 0.6740732 (400)	total: 16.1s	remaining: 2m 24s
# 600:	learn: 0.7186306	test: 0.6673188	best: 0.6673082 (599)	total: 24.2s	remaining: 2m 16s
# 800:	learn: 0.7136969	test: 0.6633762	best: 0.6633762 (800)	total: 34.1s	remaining: 2m 16s
# 1000:	learn: 0.7068195	test: 0.6615952	best: 0.6615952 (1000)	total: 48.7s	remaining: 2m 25s
# 1200:	learn: 0.7002252	test: 0.6608851	best: 0.6608715 (1194)	total: 1m 3s	remaining: 2m 28s
# 1400:	learn: 0.6935355	test: 0.6601852	best: 0.6601659 (1396)	total: 1m 18s	remaining: 2m 25s
# 1600:	learn: 0.6872197	test: 0.6596221	best: 0.6596221 (1600)	total: 1m 33s	remaining: 2m 19s
# 1800:	learn: 0.6811909	test: 0.6592413	best: 0.6592368 (1780)	total: 1m 48s	remaining: 2m 12s
# 2000:	learn: 0.6750699	test: 0.6587844	best: 0.6587673 (1998)	total: 2m 3s	remaining: 2m 3s
# 2200:	learn: 0.6693866	test: 0.6584268	best: 0.6583982 (2181)	total: 2m 18s	remaining: 1m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6583982263
# bestIteration = 2181
#
# Shrink model to first 2182 iterations.
# CV Log Loss Score: 0.658398
#
# ----------------- Fold 8 -----------------
#
# ...
#
# Shrink model to first 2195 iterations.
# CV Log Loss Score: 0.667568
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0854521	test: 1.0854751	best: 1.0854751 (0)	total: 24.6ms	remaining: 59s
# 200:	learn: 0.7957903	test: 0.7739169	best: 0.7739169 (200)	total: 3.89s	remaining: 42.6s
# 400:	learn: 0.7495309	test: 0.7073054	best: 0.7072823 (397)	total: 8.06s	remaining: 40.2s
# 600:	learn: 0.7293702	test: 0.6773528	best: 0.6773498 (598)	total: 13.4s	remaining: 40.1s
# 800:	learn: 0.7189256	test: 0.6635779	best: 0.6635778 (799)	total: 19.2s	remaining: 38.3s
# 1000:	learn: 0.7136734	test: 0.6582807	best: 0.6582738 (993)	total: 24.3s	remaining: 34s
# 1200:	learn: 0.7094400	test: 0.6553523	best: 0.6553523 (1200)	total: 29.6s	remaining: 29.6s
# 1400:	learn: 0.7053578	test: 0.6537325	best: 0.6537325 (1400)	total: 35.2s	remaining: 25.1s
# 1600:	learn: 0.7022992	test: 0.6525837	best: 0.6525837 (1600)	total: 40.8s	remaining: 20.4s
# 1800:	learn: 0.6980120	test: 0.6515442	best: 0.6515339 (1795)	total: 47s	remaining: 15.6s
# 2000:	learn: 0.6954645	test: 0.6507497	best: 0.6507470 (1994)	total: 52.1s	remaining: 10.4s
# 2200:	learn: 0.6921643	test: 0.6503839	best: 0.6503347 (2198)	total: 58.9s	remaining: 5.33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6503347405
# bestIteration = 2198
#
# Shrink model to first 2199 iterations.
# CV Log Loss Score: 0.650335
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0854525	test: 1.0854483	best: 1.0854483 (0)	total: 15.5ms	remaining: 37.2s
# 200:	learn: 0.7978522	test: 0.7814516	best: 0.7814516 (200)	total: 4.15s	remaining: 45.4s
# 400:	learn: 0.7525236	test: 0.7250703	best: 0.7250703 (400)	total: 8.43s	remaining: 42s
# 600:	learn: 0.7295048	test: 0.6965405	best: 0.6965402 (597)	total: 14s	remaining: 42s
# 800:	learn: 0.7187463	test: 0.6845489	best: 0.6845489 (800)	total: 19.9s	remaining: 39.7s
# 1000:	learn: 0.7125208	test: 0.6800433	best: 0.6799934 (986)	total: 25.4s	remaining: 35.4s
# 1200:	learn: 0.7081650	test: 0.6776431	best: 0.6776283 (1199)	total: 30.8s	remaining: 30.8s
# 1400:	learn: 0.7039799	test: 0.6766064	best: 0.6766064 (1400)	total: 36.8s	remaining: 26.2s
# 1600:	learn: 0.7011790	test: 0.6761355	best: 0.6761355 (1600)	total: 41.6s	remaining: 20.7s
# 1800:	learn: 0.6974868	test: 0.6755282	best: 0.6754880 (1792)	total: 46.8s	remaining: 15.5s
# 2000:	learn: 0.6947705	test: 0.6752239	best: 0.6752007 (1902)	total: 51.8s	remaining: 10.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6752007112
# bestIteration = 1902
#
# Shrink model to first 1903 iterations.
# CV Log Loss Score: 0.675201
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0854533	test: 1.0854497	best: 1.0854497 (0)	total: 14.7ms	remaining: 35.3s
# 200:	learn: 0.7762494	test: 0.7610184	best: 0.7610184 (200)	total: 4.28s	remaining: 46.8s
# 400:	learn: 0.7390183	test: 0.7138796	best: 0.7138795 (399)	total: 8.53s	remaining: 42.5s
# 600:	learn: 0.7217486	test: 0.6919404	best: 0.6919239 (595)	total: 13.9s	remaining: 41.5s
# 800:	learn: 0.7138564	test: 0.6837288	best: 0.6837287 (798)	total: 19.7s	remaining: 39.3s
# 1000:	learn: 0.7093244	test: 0.6800622	best: 0.6800619 (998)	total: 25s	remaining: 35s
# 1200:	learn: 0.7044628	test: 0.6770706	best: 0.6770706 (1200)	total: 30.9s	remaining: 30.9s
# 1400:	learn: 0.7002733	test: 0.6755713	best: 0.6755713 (1399)	total: 36.4s	remaining: 26s
# 1600:	learn: 0.6954510	test: 0.6747865	best: 0.6747865 (1600)	total: 42.9s	remaining: 21.4s
# 1800:	learn: 0.6915842	test: 0.6741950	best: 0.6741950 (1800)	total: 48.9s	remaining: 16.3s
# 2000:	learn: 0.6880254	test: 0.6737694	best: 0.6737671 (1998)	total: 55.3s	remaining: 11s
# 2200:	learn: 0.6848220	test: 0.6735538	best: 0.6734998 (2185)	total: 1m	remaining: 5.51s
# 2399:	learn: 0.6817968	test: 0.6734675	best: 0.6733991 (2364)	total: 1m 6s	remaining: 0us
#
# bestTest = 0.6733990627
# bestIteration = 2364
#
# Shrink model to first 2365 iterations.
# CV Log Loss Score: 0.673399
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0854480	test: 1.0854390	best: 1.0854390 (0)	total: 16.4ms	remaining: 39.4s
# 200:	learn: 0.7774833	test: 0.7592686	best: 0.7592686 (200)	total: 3.98s	remaining: 43.5s
# 400:	learn: 0.7462609	test: 0.7190256	best: 0.7190254 (399)	total: 8.23s	remaining: 41s
# 600:	learn: 0.7266312	test: 0.6915656	best: 0.6915656 (599)	total: 13.2s	remaining: 39.5s
# 800:	learn: 0.7174106	test: 0.6801171	best: 0.6801171 (799)	total: 18.6s	remaining: 37.2s
# 1000:	learn: 0.7106757	test: 0.6739911	best: 0.6739910 (999)	total: 24.8s	remaining: 34.7s
# 1200:	learn: 0.7054071	test: 0.6700012	best: 0.6699955 (1194)	total: 31.6s	remaining: 31.5s
# 1400:	learn: 0.7013170	test: 0.6681541	best: 0.6681541 (1400)	total: 38s	remaining: 27.1s
# 1600:	learn: 0.6978757	test: 0.6669638	best: 0.6669256 (1592)	total: 43.5s	remaining: 21.7s
# 1800:	learn: 0.6945151	test: 0.6660987	best: 0.6660972 (1799)	total: 48.9s	remaining: 16.3s
# 2000:	learn: 0.6921173	test: 0.6656194	best: 0.6656159 (1998)	total: 53.9s	remaining: 10.8s
# 2200:	learn: 0.6885926	test: 0.6653127	best: 0.6653044 (2191)	total: 59.6s	remaining: 5.39s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6650892131
# bestIteration = 2270
#
# Shrink model to first 2271 iterations.
# CV Log Loss Score: 0.665089
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0854482	test: 1.0854406	best: 1.0854406 (0)	total: 14.6ms	remaining: 34.9s
# 200:	learn: 0.7763478	test: 0.7557768	best: 0.7557766 (199)	total: 4.35s	remaining: 47.6s
# 400:	learn: 0.7469766	test: 0.7173590	best: 0.7173590 (400)	total: 8.76s	remaining: 43.7s
# 600:	learn: 0.7258033	test: 0.6866432	best: 0.6866431 (598)	total: 14.8s	remaining: 44.2s
# 800:	learn: 0.7159587	test: 0.6740125	best: 0.6740125 (798)	total: 20.9s	remaining: 41.7s
# 1000:	learn: 0.7096943	test: 0.6680658	best: 0.6680658 (1000)	total: 26.5s	remaining: 37s
# 1200:	learn: 0.7052664	test: 0.6654663	best: 0.6654663 (1200)	total: 32.7s	remaining: 32.6s
# 1400:	learn: 0.7014631	test: 0.6639854	best: 0.6639801 (1389)	total: 38.8s	remaining: 27.6s
# 1600:	learn: 0.6982161	test: 0.6630878	best: 0.6630876 (1598)	total: 44s	remaining: 21.9s
# 1800:	learn: 0.6947852	test: 0.6624865	best: 0.6624860 (1793)	total: 49.8s	remaining: 16.6s
# 2000:	learn: 0.6913401	test: 0.6619232	best: 0.6619194 (1999)	total: 55.1s	remaining: 11s
# 2200:	learn: 0.6887217	test: 0.6616893	best: 0.6616893 (2200)	total: 1m 1s	remaining: 5.53s
# 2399:	learn: 0.6858473	test: 0.6613811	best: 0.6613626 (2351)	total: 1m 6s	remaining: 0us
#
# bestTest = 0.6613626446
# bestIteration = 2351
#
# Shrink model to first 2352 iterations.
# CV Log Loss Score: 0.661363
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0854581	test: 1.0854399	best: 1.0854399 (0)	total: 24ms	remaining: 57.6s
# 200:	learn: 0.7804860	test: 0.7553244	best: 0.7553244 (200)	total: 3.77s	remaining: 41.2s
# 400:	learn: 0.7437083	test: 0.7054480	best: 0.7054453 (399)	total: 8.15s	remaining: 40.6s
# 600:	learn: 0.7236818	test: 0.6769480	best: 0.6769478 (598)	total: 13.9s	remaining: 41.7s
# 800:	learn: 0.7163398	test: 0.6691309	best: 0.6691309 (800)	total: 20s	remaining: 39.8s
# 1000:	learn: 0.7112033	test: 0.6648473	best: 0.6648473 (1000)	total: 25.5s	remaining: 35.6s
# 1200:	learn: 0.7055544	test: 0.6613986	best: 0.6613986 (1200)	total: 31.2s	remaining: 31.1s
# 1400:	learn: 0.7029084	test: 0.6605713	best: 0.6605571 (1392)	total: 35.6s	remaining: 25.4s
# 1600:	learn: 0.6984537	test: 0.6594649	best: 0.6594649 (1599)	total: 42s	remaining: 21s
# 1800:	learn: 0.6945291	test: 0.6588861	best: 0.6588610 (1785)	total: 47.9s	remaining: 15.9s
# 2000:	learn: 0.6914171	test: 0.6582032	best: 0.6581976 (1994)	total: 53.6s	remaining: 10.7s
# 2200:	learn: 0.6885810	test: 0.6574458	best: 0.6574415 (2195)	total: 58.6s	remaining: 5.3s
# 2399:	learn: 0.6848219	test: 0.6570382	best: 0.6570370 (2398)	total: 1m 4s	remaining: 0us
#
# bestTest = 0.6570369862
# bestIteration = 2398
#
# Shrink model to first 2399 iterations.
# CV Log Loss Score: 0.657037
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0854552	test: 1.0854307	best: 1.0854307 (0)	total: 20.8ms	remaining: 49.8s
# 200:	learn: 0.7983893	test: 0.7860135	best: 0.7860135 (200)	total: 3.45s	remaining: 37.7s
# 400:	learn: 0.7536398	test: 0.7275764	best: 0.7275764 (400)	total: 7.18s	remaining: 35.8s
# 600:	learn: 0.7311689	test: 0.6954176	best: 0.6954175 (598)	total: 11.9s	remaining: 35.7s
# 800:	learn: 0.7177307	test: 0.6787957	best: 0.6787828 (798)	total: 18.7s	remaining: 37.3s
# 1000:	learn: 0.7122272	test: 0.6734169	best: 0.6734154 (998)	total: 24.4s	remaining: 34.1s
# 1200:	learn: 0.7068053	test: 0.6702544	best: 0.6702513 (1198)	total: 30.2s	remaining: 30.2s
# 1400:	learn: 0.7024091	test: 0.6683485	best: 0.6683454 (1398)	total: 35.8s	remaining: 25.5s
# 1600:	learn: 0.6989123	test: 0.6674076	best: 0.6674074 (1598)	total: 41.2s	remaining: 20.6s
# 1800:	learn: 0.6957661	test: 0.6664896	best: 0.6664836 (1797)	total: 46.9s	remaining: 15.6s
# 2000:	learn: 0.6927351	test: 0.6661995	best: 0.6661620 (1986)	total: 52.9s	remaining: 10.6s
# 2200:	learn: 0.6892362	test: 0.6659294	best: 0.6659204 (2195)	total: 58.5s	remaining: 5.29s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6658033598
# bestIteration = 2263
#
# Shrink model to first 2264 iterations.
# CV Log Loss Score: 0.665803
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0854530	test: 1.0854518	best: 1.0854518 (0)	total: 22.1ms	remaining: 52.9s
# 200:	learn: 0.7929125	test: 0.7773805	best: 0.7773805 (200)	total: 3.55s	remaining: 38.9s
# 400:	learn: 0.7429447	test: 0.7150493	best: 0.7150493 (400)	total: 8.47s	remaining: 42.2s
# 600:	learn: 0.7246921	test: 0.6912974	best: 0.6912959 (596)	total: 13.5s	remaining: 40.3s
# 800:	learn: 0.7148514	test: 0.6810940	best: 0.6810938 (798)	total: 19.5s	remaining: 39s
# 1000:	learn: 0.7102857	test: 0.6777438	best: 0.6777437 (999)	total: 24.6s	remaining: 34.3s
# 1200:	learn: 0.7058611	test: 0.6751481	best: 0.6751481 (1200)	total: 30.4s	remaining: 30.4s
# 1400:	learn: 0.7011303	test: 0.6734193	best: 0.6734112 (1388)	total: 36.8s	remaining: 26.2s
# 1600:	learn: 0.6973367	test: 0.6727452	best: 0.6727452 (1600)	total: 42.5s	remaining: 21.2s
# 1800:	learn: 0.6934970	test: 0.6718597	best: 0.6718585 (1799)	total: 48.9s	remaining: 16.3s
# 2000:	learn: 0.6908686	test: 0.6712941	best: 0.6712939 (1995)	total: 54s	remaining: 10.8s
# 2200:	learn: 0.6872569	test: 0.6710809	best: 0.6710366 (2164)	total: 1m	remaining: 5.43s
# 2399:	learn: 0.6841595	test: 0.6706444	best: 0.6706248 (2395)	total: 1m 5s	remaining: 0us
#
# bestTest = 0.6706247918
# bestIteration = 2395
#
# Shrink model to first 2396 iterations.
# CV Log Loss Score: 0.670625
# 	Log Loss: 0.665627
# [I 2021-07-04 13:00:15,634] Trial 9 finished with value: 0.6656269397963898 and parameters: {'learning_rate': 0.029933382828200558, 'n_estimators': 2400, 'colsample_bylevel': 0.030470406163246824, 'depth': 10, 'subsample': 0.802013782407934}. Best is trial 1 with value: 0.6633573503896221.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0829408	test: 1.0829585	best: 1.0829585 (0)	total: 17.8ms	remaining: 53.5s
# 200:	learn: 0.7181254	test: 0.6779857	best: 0.6779857 (200)	total: 2m 49s	remaining: 39m 37s
# 400:	learn: 0.6999033	test: 0.6702978	best: 0.6702978 (400)	total: 15m 6s	remaining: 1h 38m 11s
# 600:	learn: 0.6668854	test: 0.6689595	best: 0.6689579 (589)	total: 49m 49s	remaining: 3h 19m 13s
# 800:	learn: 0.6356423	test: 0.6675777	best: 0.6674239 (798)	total: 1h 24m 15s	remaining: 3h 51m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6674239424
# bestIteration = 798
#
# Shrink model to first 799 iterations.
# CV Log Loss Score: 0.667424
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0781593	test: 1.0779584	best: 1.0779584 (0)	total: 28.7ms	remaining: 1m 26s
# 200:	learn: 0.7186528	test: 0.6725967	best: 0.6725967 (200)	total: 1m 45s	remaining: 24m 43s
# 400:	learn: 0.6987929	test: 0.6663944	best: 0.6663944 (400)	total: 14m 31s	remaining: 1h 34m 19s
# 600:	learn: 0.6652662	test: 0.6661757	best: 0.6660261 (513)	total: 48m 30s	remaining: 3h 13m 57s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-446c96ede7d2> in <module>
#       1 study_make_model_params = optuna.create_study(direction="minimize")
# ----> 2 study_make_model_params.optimize(objective)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     399             )
#     400
# --> 401         _optimize(
#     402             study=self,
#     403             func=func,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      63     try:
#      64         if n_jobs == 1:
# ---> 65             _optimize_sequential(
#      66                 study,
#      67                 func,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160
#     161         try:
# --> 162             trial = _run_trial(study, func, catch)
#     163         except Exception:
#     164             raise
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _run_trial(study, func, catch)
#     214
#     215     try:
# --> 216         value_or_values = func(trial)
#     217     except exceptions.TrialPruned as e:
#     218         # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-10-c8003b2851b0> in objective(trial)
#      52                                        boosting_type = 'Ordered',
#      53                                        bootstrap_type = 'Bernoulli')
# ---> 54         model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=200)
#      55
#      56         model_folds.append(model_cat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    4671             CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
#    4672
# -> 4673         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4674                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
#    4675                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    1992         with log_fixup(log_cout, log_cerr), \
#    1993             plot_wrapper(plot, [_get_train_dir(self.get_params())]):
# -> 1994             self._train(
#    1995                 train_pool,
#    1996                 train_params["eval_sets"],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1423
#    1424     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1425         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1426         self._set_trained_model_attributes()
#    1427
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
study_make_model_params.best_params
# Out:
# {'learning_rate': 0.04160502952238434,
#  'n_estimators': 3800,
#  'colsample_bylevel': 0.1832000117969863,
#  'depth': 9,
#  'subsample': 0.8101208520516356}

# %%
params_df = study_make_model_params.trials_dataframe()
params_df.drop(10, inplace = True)
params_df.drop(['datetime_start', 'datetime_complete', 'duration', 'state'], axis = 1, inplace=True)

# %%
# save the outcome of tuning
with open('params_df.pickle', 'wb') as f:
    pickle.dump(params_df, f, pickle.HIGHEST_PROTOCOL)

params_df.sort_values('value').head(8)
# Out:
#    number     value  params_colsample_bylevel  params_depth  \
# 1       1  0.663357                  0.183200             9
# 2       2  0.663448                  0.165483            11
# 7       7  0.663664                  0.146746            12
# 5       5  0.663719                  0.170999             8
# 4       4  0.664116                  0.152215             8
# 3       3  0.664233                  0.093318             8
# 6       6  0.664792                  0.043101            11
# 8       8  0.665043                  0.035533            12
#
#    params_learning_rate  params_n_estimators  params_subsample
# 1              0.041605                 3800          0.810121
# 2              0.045722                 4400          0.967971
# 7              0.019852                 3800          0.681546
# 5              0.015099                 4000          0.697891
# 4              0.041594                 2400          0.638305
# 3              0.040412                 3200          0.699267
# 6              0.044280                 4200          0.712504
# 8              0.043147                 3400          0.893303

# %%
# best parameters as result tunning
params_df.sort_values('value').iloc[0,2:]
# Out:
# params_colsample_bylevel       0.183200
# params_depth                   9.000000
# params_learning_rate           0.041605
# params_n_estimators         3800.000000
# params_subsample               0.810121
# Name: 1, dtype: float64
