# %%
# import modules
import warnings
warnings.filterwarnings('ignore')

import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import lightgbm as lgb
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, log_loss, f1_score

import random
from math import floor
from scipy.stats import mode, scoreatpercentile

print("Seaborn version : ", sns.__version__)
sns.set()
#sns.set_style('whitegrid')
sns.set_color_codes()
sns.set_theme(style="ticks", palette="pastel")
# Out:
# Seaborn version :  0.11.1

# %%
# upload data
train = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/train.csv',
                   index_col=0)
test = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/test.csv',
                  index_col=0)
submit = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/sample_submission.csv')

# %%
for df in [train, test]:
    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['gender', 'car', 'reality', 'work_phone', 'phone', 'email']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    df.drop('FLAG_MOBIL', axis = 1, inplace = True)
    df['adj_DAYS_EMPLOYED_replace_0'] = -df.DAYS_EMPLOYED.replace({365243 : 0})
    df['DAYS_EMPLOYED_missing'] = (df.DAYS_EMPLOYED == 365243).astype('int')
    df['adj_begin_month'] = -df.begin_month
    df['adj_income_type'] = df.income_type
    df.loc[df.income_type == 'Student', 'adj_income_type'] = 'Working'
    df['adj_edu_type'] = df.edu_type 
    df.loc[df.edu_type == 'Academic degree', 'adj_edu_type'] = 'Higher education'
    df['adj_family_type'] = df['family_type']
    df['adj_family_type'].loc[(df.family_type == 'Single / not married')&(df.family_size - df.child_num == 2)] = 'Married'
    df['exp_num'] = 0
    df['exp_num'].loc[df.family_type == 'Married'] = 2
    df['exp_num'].loc[df.family_type == 'Civil marriage'] = 2
    df['exp_num'].loc[df.family_type == 'Separated'] = 1
    df['exp_num'].loc[df.family_type == 'Single / not married'] = 1
    df['exp_num'].loc[df.family_type == 'Widow'] = 1
    df['odd_family_size'] = 0
    df['odd_family_size'].loc[(df.family_size - df.child_num) != df.exp_num] = 1
    df['_single_parents'] = ((df.family_type == 'Single / not married')&(df.child_num != 0)).astype('int')
    df['_single_live'] = (df.family_size == 1).astype('int')
    df['adj_occyp_type'] = df.occyp_type.fillna('missing')
    df['_missing_occyp_type'] = df.occyp_type.isna().astype('int')
    df.loc[(df.DAYS_EMPLOYED == 365243)&(df.occyp_type.isna()), 'adj_occyp_type'] = 'inoccyp'
    df.loc[(df.DAYS_EMPLOYED != 365243)&(df.occyp_type.isna()), 'adj_occyp_type'] = 'non_enter'
    df['_age'] = -df.DAYS_BIRTH/365.25

    df['ID'] = \
    df['gender'].astype('str') + \
    df['car'].astype('str') + \
    df['reality'].astype('str') + '_' + \
    df['child_num'].astype('str') + '_' + \
    df['income_total'].astype('str') + '_' + \
    df['income_type'].astype('str') + '_' + \
    df['family_type'].astype('str') + '_' + \
    df['house_type'].astype('str') + '_' + \
    df['phone'].astype('str') + '_' + \
    df['email'].astype('str') + '_' + \
    df['family_size'].astype('str') + '_' + \
    df['DAYS_BIRTH'].astype('str') + '_' + \
    df['DAYS_EMPLOYED'].astype('str') + '_' + \
    df['occyp_type'].astype('str') 
    
    df['_card_num'] = df.groupby('ID').ID.transform(len)
    
    df['adj_begin_month'] = -df.begin_month
    df['_begin_month_max'] = df.groupby('ID').adj_begin_month.transform(max)
    df['_begin_month_mean'] = df.groupby('ID').adj_begin_month.transform(np.mean)
    df['_begin_month_min'] = df.groupby('ID').adj_begin_month.transform(min)

# %%
personal_info = train.drop(['credit', 'begin_month'], axis = 1).drop_duplicates(subset="ID", keep='first', inplace=False, ignore_index=True)
personal_info_test = pd.concat([train.drop(['credit'], axis = 1), test]).drop(['begin_month'], axis = 1).drop_duplicates(subset="ID", keep='first', inplace=False, ignore_index=True)

# %%
personal_info = train.drop(['credit', 'begin_month'], axis = 1).drop_duplicates(subset="ID", keep='first', inplace=False, ignore_index=True)
personal_info_test = pd.concat([train.drop(['credit'], axis = 1), test]).drop(['begin_month'], axis = 1).drop_duplicates(subset="ID", keep='first', inplace=False, ignore_index=True)

for personal_df in [personal_info, personal_info_test]:
    ####### 양육비 변수 ######
    child_fee = (personal_df.income_total/personal_df.family_size)[(personal_df._age > 33) & (personal_df._age < 37) & (personal_df.child_num == 1)].mean()

    def child_fee_age_weights(x) : 
        from scipy.stats import norm
        sd = personal_df._age.std()
        return norm(35, scale = sd).pdf(x) / norm(35, scale = sd).pdf(35)
    personal_df['child_fees'] = (np.log(personal_df.child_num + 1)/np.log(2)) * (child_fee) * personal_df._age.apply(child_fee_age_weights)

    ####### 차유지비 변수 ######
    personal_df.income_total.median()*0.1
    def car_weight(x):
        _med = personal_df.income_total.median()
        _max = personal_df.income_total.max()
        if x < _med : 
            return 1
        else:
            return 1+(x-_med)/(_max-_med)*5
    personal_df['car_fees'] = personal_df.income_total.median()*0.1*personal_df.car*personal_df.income_total.apply(car_weight)

    ####### 여유금 변수 ######
    personal_df['_save_income'] = personal_df.income_total - personal_df.child_fees - personal_df.car_fees

    ####### 능력 변수 ######
    personal_df['_ability_income_per_age'] = 0
    personal_df['_ability_employ_per_age'] = 0
    personal_df['_ability_income_per_emp'] = 0
    for i in range(len(personal_df)) : 
        L_age = personal_df._age[i] - 3
        R_age = personal_df._age[i] + 3
        _gen = personal_df.gender[i]
        _ages_df = personal_df[['income_total', 'adj_DAYS_EMPLOYED_replace_0']][(personal_df._age > L_age) & (personal_df._age < R_age) & (personal_df.gender == _gen)]
        _med_income = _ages_df['income_total'].median()
        _std_income = _ages_df['income_total'].std()
        _med_employ = _ages_df['adj_DAYS_EMPLOYED_replace_0'].median()
        _std_employ = _ages_df['adj_DAYS_EMPLOYED_replace_0'].std()
        _n_df       = _ages_df.shape[0]
        personal_df.loc[i, '_ability_income_per_age'] = (personal_df.income_total.iloc[i] - _med_income) / (_std_income /np.sqrt(_n_df))
        personal_df.loc[i, '_ability_employ_per_age'] = (personal_df.adj_DAYS_EMPLOYED_replace_0.iloc[i] - _med_employ) / (_std_employ/np.sqrt(_n_df))

        if personal_df.adj_DAYS_EMPLOYED_replace_0.iloc[i] != 0:    
            L_emp = personal_df.adj_DAYS_EMPLOYED_replace_0 - 365
            R_emp = personal_df.adj_DAYS_EMPLOYED_replace_0 + 365
            _emps_df = personal_df.income_total[(personal_df.adj_DAYS_EMPLOYED_replace_0 > L_emp)&(personal_df.adj_DAYS_EMPLOYED_replace_0 < R_emp)]
            _med = _emps_df.median()
            _std = _emps_df.std()
            personal_df.loc[i, '_ability_income_per_emp'] = (personal_df.income_total.iloc[i] - _med)/(_std/np.sqrt(_n_df))

# %%
train  = pd.merge(train, personal_info[['ID', '_save_income', 'child_fees', 'car_fees', '_ability_income_per_age', '_ability_employ_per_age', '_ability_income_per_emp']], on = 'ID', how = 'left')
test = pd.merge(test, personal_info_test[['ID', '_save_income', 'child_fees', 'car_fees', '_ability_income_per_age', '_ability_employ_per_age', '_ability_income_per_emp']], on = 'ID', how = 'left')

# %%
for df in [train, test]:
    #카드 소유자가 가진 카드들에 할당할 수 있는 금액을 고려
    df['_income_per_cards']  = df.income_total / np.log(1+df._card_num)
    df['_save_per_cards']    = df._save_income / np.log(1+df._card_num)

    # 가족들에게 할당 될 수 있는 소득 그리고 여유자금을 고려
    df['_income_per_family'] = df.income_total / df.family_size
    df['_save_per_family']   = df._save_income / df.family_size

# %%
# dont touch : original
features = ['gender', 'car', 'reality', 'child_num', 'income_total', 'adj_income_type', 'adj_edu_type', 
            'adj_family_type', 'house_type', '_age', 'adj_DAYS_EMPLOYED_replace_0', 'DAYS_EMPLOYED_missing',
            'adj_begin_month', 'work_phone', 'phone', 'email', 'adj_occyp_type', '_missing_occyp_type', 'odd_family_size', 
            '_single_parents', '_single_live', 'ID', '_card_num', '_begin_month_max', '_begin_month_mean', '_begin_month_min',
            '_income_per_cards', '_save_per_cards', '_income_per_family', '_save_per_family', '_save_income',
            '_ability_income_per_age', '_ability_employ_per_age', '_ability_income_per_emp']

# %%
features = ['gender', 'car', 'reality', 'child_num', 'adj_income_type', 'adj_edu_type', 
            'adj_family_type', 'house_type', '_age', 'adj_DAYS_EMPLOYED_replace_0',
            'adj_begin_month', 'work_phone', 'phone', 'email', 'adj_occyp_type', 
            'ID', '_begin_month_min',
            '_save_per_cards', '_save_per_family', '_save_income',
            '_ability_income_per_age']

# %%
features = ['gender', 'car', 'reality', 'child_num',
            'adj_income_type', 'adj_edu_type', 'adj_family_type', 'house_type', 'adj_occyp_type',
            'work_phone', 'phone', 'email',
            '_age',
            'adj_DAYS_EMPLOYED_replace_0', 'ID',
            '_income_per_family', '_save_income', 
            'adj_begin_month','_begin_month_min'            
           ]

# %%
numerical_feats = train[features].dtypes[train[features].dtypes != "object"].index.tolist()
#numerical_feats.remove('credit')
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = train[features].dtypes[train[features].dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  13
# Number of Categorical features:  6

# %%
train[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26457 entries, 0 to 26456
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       26457 non-null  int64
#  1   car                          26457 non-null  int64
#  2   reality                      26457 non-null  int64
#  3   child_num                    26457 non-null  int64
#  4   adj_income_type              26457 non-null  object
#  5   adj_edu_type                 26457 non-null  object
#  6   adj_family_type              26457 non-null  object
#  7   house_type                   26457 non-null  object
#  8   adj_occyp_type               26457 non-null  object
#  9   work_phone                   26457 non-null  int64
#  10  phone                        26457 non-null  int64
#  11  email                        26457 non-null  int64
#  12  _age                         26457 non-null  float64
#  13  adj_DAYS_EMPLOYED_replace_0  26457 non-null  int64
#  14  ID                           26457 non-null  object
#  15  _income_per_family           26457 non-null  float64
#  16  _save_income                 26457 non-null  float64
#  17  adj_begin_month              26457 non-null  float64
#  18  _begin_month_min             26457 non-null  float64
# dtypes: float64(5), int64(8), object(6)
# memory usage: 4.0+ MB

# %%
#from category_encoders.ordinal import OrdinalEncoder
#encoder = OrdinalEncoder(categorical_feats)
#train[categorical_feats] = encoder.fit_transform(train[categorical_feats], train['credit'])
#test[categorical_feats] = encoder.transform(test[categorical_feats])

# %%
#train['ID'] = train['ID'].astype('int64')
#test['ID'] = test['ID'].astype('int64')

# %%
#from sklearn.cluster import KMeans
#kmeans_train = train.drop(['credit'], axis=1)[features]
#kmeans = KMeans(n_clusters=36, random_state=42).fit(kmeans_train)
#train['cluster'] = kmeans.predict(kmeans_train)
#test['cluster'] = kmeans.predict(test[features])
#features.append('cluster')

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#train[numerical_feats] = scaler.fit_transform(train[numerical_feats])
#test[numerical_feats] = scaler.transform(test[numerical_feats])

# %%
n_est = 2000
seed = 42
n_fold = 15
n_class = 3

target = 'credit'
X = train.drop(target, axis=1)[features]
y = train[target]
X_test = test[features]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26457 entries, 0 to 26456
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       26457 non-null  int64
#  1   car                          26457 non-null  int64
#  2   reality                      26457 non-null  int64
#  3   child_num                    26457 non-null  int64
#  4   adj_income_type              26457 non-null  object
#  5   adj_edu_type                 26457 non-null  object
#  6   adj_family_type              26457 non-null  object
#  7   house_type                   26457 non-null  object
#  8   adj_occyp_type               26457 non-null  object
#  9   work_phone                   26457 non-null  int64
#  10  phone                        26457 non-null  int64
#  11  email                        26457 non-null  int64
#  12  _age                         26457 non-null  float64
#  13  adj_DAYS_EMPLOYED_replace_0  26457 non-null  int64
#  14  ID                           26457 non-null  object
#  15  _income_per_family           26457 non-null  float64
#  16  _save_income                 26457 non-null  float64
#  17  adj_begin_month              26457 non-null  float64
#  18  _begin_month_min             26457 non-null  float64
# dtypes: float64(5), int64(8), object(6)
# memory usage: 4.0+ MB

# %%
#cat_cols = ['adj_income_type', 'adj_edu_type', 'adj_family_type', 'house_type', 'adj_occyp_type', 'odd_family_size', 'ID']

# %%
categorical_feats
# Out:
# ['adj_income_type',
#  'adj_edu_type',
#  'adj_family_type',
#  'house_type',
#  'adj_occyp_type',
#  'ID']

# %%
categorical_feats + ['gender', 'car', 'reality', 'phone', 'email', 'work_phone']
# Out:
# ['adj_income_type',
#  'adj_edu_type',
#  'adj_family_type',
#  'house_type',
#  'adj_occyp_type',
#  'ID',
#  'gender',
#  'car',
#  'reality',
#  'phone',
#  'email',
#  'work_phone']

# %%
skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
folds=[]
for train_idx, valid_idx in skfold.split(X, y):
        folds.append((train_idx, valid_idx))

cat_pred = np.zeros((X.shape[0], n_class))
cat_pred_test = np.zeros((X_test.shape[0], n_class))
cat_cols = ['adj_income_type', 'adj_edu_type', 'adj_family_type', 'house_type', 'adj_occyp_type', 'ID']
cat_cols = categorical_feats+ ['gender', 'car', 'reality', 'phone', 'email', 'work_phone']
for fold in range(n_fold):
    print(f'\n----------------- Fold {fold} -----------------\n')
    train_idx, valid_idx = folds[fold]
    X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
    train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
    valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

    model_cat = CatBoostClassifier()
    model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=100)

    cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
    cat_pred_test += model_cat.predict_proba(X_test) / n_fold
    print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')
    
print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
# Out:
# ----------------- Fold 0 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0346589	test: 1.0332291	best: 1.0332291 (0)	total: 27.7ms	remaining: 27.7s
# 100:	learn: 0.7059345	test: 0.6584556	best: 0.6583900 (99)	total: 2.06s	remaining: 18.4s
# 200:	learn: 0.6866960	test: 0.6550458	best: 0.6546910 (162)	total: 4.39s	remaining: 17.4s
# 300:	learn: 0.6692819	test: 0.6535300	best: 0.6532773 (281)	total: 6.81s	remaining: 15.8s
# 400:	learn: 0.6522475	test: 0.6537207	best: 0.6528907 (377)	total: 9.14s	remaining: 13.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6528907354
# bestIteration = 377
#
# Shrink model to first 378 iterations.
# CV Log Loss Score: 0.652891
#
# ----------------- Fold 1 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0346782	test: 1.0340504	best: 1.0340504 (0)	total: 26.5ms	remaining: 26.5s
# 100:	learn: 0.7056664	test: 0.6536446	best: 0.6536446 (100)	total: 2.12s	remaining: 18.9s
# 200:	learn: 0.6850021	test: 0.6500769	best: 0.6496127 (183)	total: 4.63s	remaining: 18.4s
# 300:	learn: 0.6681306	test: 0.6502123	best: 0.6492738 (247)	total: 6.91s	remaining: 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6492737828
# bestIteration = 247
#
# Shrink model to first 248 iterations.
# CV Log Loss Score: 0.649274
#
# ----------------- Fold 2 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0344724	test: 1.0356142	best: 1.0356142 (0)	total: 25.4ms	remaining: 25.3s
# 100:	learn: 0.7060093	test: 0.6572342	best: 0.6572342 (100)	total: 1.96s	remaining: 17.5s
# 200:	learn: 0.6855761	test: 0.6525151	best: 0.6525151 (200)	total: 4.3s	remaining: 17.1s
# 300:	learn: 0.6688272	test: 0.6526283	best: 0.6518567 (243)	total: 6.92s	remaining: 16.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6518566629
# bestIteration = 243
#
# Shrink model to first 244 iterations.
# CV Log Loss Score: 0.651857
#
# ----------------- Fold 3 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0342940	test: 1.0362189	best: 1.0362189 (0)	total: 25.2ms	remaining: 25.2s
# 100:	learn: 0.7021261	test: 0.6788288	best: 0.6785858 (96)	total: 2.02s	remaining: 18s
# 200:	learn: 0.6827980	test: 0.6775397	best: 0.6771633 (145)	total: 4.47s	remaining: 17.8s
# 300:	learn: 0.6661773	test: 0.6768526	best: 0.6765542 (294)	total: 6.97s	remaining: 16.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6765541998
# bestIteration = 294
#
# Shrink model to first 295 iterations.
# CV Log Loss Score: 0.676554
#
# ----------------- Fold 4 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0328855	test: 1.0330539	best: 1.0330539 (0)	total: 13.1ms	remaining: 13s
# 100:	learn: 0.7031474	test: 0.6745448	best: 0.6745448 (100)	total: 2.06s	remaining: 18.4s
# 200:	learn: 0.6828318	test: 0.6722777	best: 0.6722471 (198)	total: 4.54s	remaining: 18s
# 300:	learn: 0.6660148	test: 0.6731271	best: 0.6718663 (206)	total: 7.22s	remaining: 16.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6718663483
# bestIteration = 206
#
# Shrink model to first 207 iterations.
# CV Log Loss Score: 0.671866
#
# ----------------- Fold 5 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0346642	test: 1.0335684	best: 1.0335684 (0)	total: 25.9ms	remaining: 25.9s
# 100:	learn: 0.7037952	test: 0.6661724	best: 0.6661724 (100)	total: 2.2s	remaining: 19.6s
# 200:	learn: 0.6849296	test: 0.6631023	best: 0.6628558 (188)	total: 4.65s	remaining: 18.5s
# 300:	learn: 0.6677902	test: 0.6627353	best: 0.6616587 (246)	total: 7.1s	remaining: 16.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6616586775
# bestIteration = 246
#
# Shrink model to first 247 iterations.
# CV Log Loss Score: 0.661659
#
# ----------------- Fold 6 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0347196	test: 1.0333341	best: 1.0333341 (0)	total: 27.2ms	remaining: 27.1s
# 100:	learn: 0.7030737	test: 0.6828581	best: 0.6828581 (100)	total: 2.21s	remaining: 19.7s
# 200:	learn: 0.6840371	test: 0.6815957	best: 0.6812968 (197)	total: 4.68s	remaining: 18.6s
# 300:	learn: 0.6678088	test: 0.6810747	best: 0.6805341 (253)	total: 7.14s	remaining: 16.6s
# 400:	learn: 0.6526357	test: 0.6796179	best: 0.6792690 (377)	total: 9.57s	remaining: 14.3s
# 500:	learn: 0.6366673	test: 0.6796661	best: 0.6786967 (424)	total: 12.1s	remaining: 12.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6786966726
# bestIteration = 424
#
# Shrink model to first 425 iterations.
# CV Log Loss Score: 0.678697
#
# ----------------- Fold 7 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0345871	test: 1.0351145	best: 1.0351145 (0)	total: 27.7ms	remaining: 27.6s
# 100:	learn: 0.7028867	test: 0.6697806	best: 0.6697806 (100)	total: 2.22s	remaining: 19.7s
# 200:	learn: 0.6836586	test: 0.6660211	best: 0.6659997 (194)	total: 4.58s	remaining: 18.2s
# 300:	learn: 0.6669568	test: 0.6651782	best: 0.6651376 (288)	total: 7s	remaining: 16.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6651375847
# bestIteration = 288
#
# Shrink model to first 289 iterations.
# CV Log Loss Score: 0.665138
#
# ----------------- Fold 8 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0344500	test: 1.0355463	best: 1.0355463 (0)	total: 26.1ms	remaining: 26.1s
# 100:	learn: 0.7032173	test: 0.6878719	best: 0.6877591 (97)	total: 2.32s	remaining: 20.7s
# 200:	learn: 0.6835312	test: 0.6837977	best: 0.6832051 (176)	total: 4.86s	remaining: 19.3s
# 300:	learn: 0.6683397	test: 0.6833573	best: 0.6830016 (237)	total: 7.35s	remaining: 17.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6830016161
# bestIteration = 237
#
# Shrink model to first 238 iterations.
# CV Log Loss Score: 0.683002
#
# ----------------- Fold 9 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0345440	test: 1.0345330	best: 1.0345330 (0)	total: 30.5ms	remaining: 30.5s
# 100:	learn: 0.7031525	test: 0.6553960	best: 0.6552030 (97)	total: 2.48s	remaining: 22.1s
# 200:	learn: 0.6862762	test: 0.6539504	best: 0.6532995 (177)	total: 5.36s	remaining: 21.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6532995351
# bestIteration = 177
#
# Shrink model to first 178 iterations.
# CV Log Loss Score: 0.653300
#
# ----------------- Fold 10 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0346837	test: 1.0347108	best: 1.0347108 (0)	total: 31.3ms	remaining: 31.3s
# 100:	learn: 0.7050309	test: 0.6549754	best: 0.6547687 (99)	total: 2.38s	remaining: 21.2s
# 200:	learn: 0.6875098	test: 0.6523300	best: 0.6521413 (182)	total: 5.22s	remaining: 20.8s
# 300:	learn: 0.6705270	test: 0.6525735	best: 0.6514043 (251)	total: 8.06s	remaining: 18.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6514042597
# bestIteration = 251
#
# Shrink model to first 252 iterations.
# CV Log Loss Score: 0.651404
#
# ----------------- Fold 11 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0344898	test: 1.0345835	best: 1.0345835 (0)	total: 30ms	remaining: 29.9s
# 100:	learn: 0.7033982	test: 0.6872554	best: 0.6872098 (99)	total: 2.4s	remaining: 21.4s
# 200:	learn: 0.6841723	test: 0.6864036	best: 0.6859839 (120)	total: 5.14s	remaining: 20.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6859839188
# bestIteration = 120
#
# Shrink model to first 121 iterations.
# CV Log Loss Score: 0.685984
#
# ----------------- Fold 12 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0344525	test: 1.0356513	best: 1.0356513 (0)	total: 18.4ms	remaining: 18.4s
# 100:	learn: 0.7032831	test: 0.6569842	best: 0.6569842 (100)	total: 2.53s	remaining: 22.6s
# 200:	learn: 0.6857001	test: 0.6553521	best: 0.6551647 (163)	total: 5.37s	remaining: 21.3s
# 300:	learn: 0.6693026	test: 0.6559242	best: 0.6548483 (216)	total: 8.09s	remaining: 18.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6548483267
# bestIteration = 216
#
# Shrink model to first 217 iterations.
# CV Log Loss Score: 0.654848
#
# ----------------- Fold 13 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0356205	test: 1.0341774	best: 1.0341774 (0)	total: 21.9ms	remaining: 21.9s
# 100:	learn: 0.7008816	test: 0.6910232	best: 0.6910006 (99)	total: 2.53s	remaining: 22.5s
# 200:	learn: 0.6826057	test: 0.6893795	best: 0.6893795 (200)	total: 5.33s	remaining: 21.2s
# 300:	learn: 0.6656381	test: 0.6902893	best: 0.6892579 (207)	total: 8.29s	remaining: 19.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6892579241
# bestIteration = 207
#
# Shrink model to first 208 iterations.
# CV Log Loss Score: 0.689258
#
# ----------------- Fold 14 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0346859	test: 1.0338951	best: 1.0338951 (0)	total: 20.4ms	remaining: 20.4s
# 100:	learn: 0.7029032	test: 0.6637114	best: 0.6636182 (97)	total: 2.6s	remaining: 23.1s
# 200:	learn: 0.6851255	test: 0.6613300	best: 0.6613300 (200)	total: 5.49s	remaining: 21.8s
# 300:	learn: 0.6682137	test: 0.6615924	best: 0.6607445 (245)	total: 8.45s	remaining: 19.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6607445289
# bestIteration = 245
#
# Shrink model to first 246 iterations.
# CV Log Loss Score: 0.660745
# 	Log Loss: 0.665765

# %%
def plot_feature_importance(importance,names,model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')

plot_feature_importance(model_cat.get_feature_importance(),X_test.columns,'CATBOOST')

# %%
cat_pred_test
# Out:
# array([[0.09475178, 0.1140067 , 0.79124153],
#        [0.11892507, 0.12880349, 0.75227144],
#        [0.10010351, 0.13645667, 0.76343982],
#        ...,
#        [0.09191289, 0.19017982, 0.71790729],
#        [0.09782811, 0.13807456, 0.76409733],
#        [0.09979694, 0.18339486, 0.71680819]])

# %%
for i in range(3):
    submit[str(i)] = cat_pred_test[:,i]

# %%
submit.to_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/preprocessing/catboost_basic01.csv', index = False)

# %% [markdown]
# ## OPTUNA

# %%
def objective(trial):
    train_x, valid_x, train_y, valid_y = train_test_split(X,y, test_size=0.3)

    param = {
        #"objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        
    

    gbm = cb.CatBoostClassifier(**param)
    gbm.fit(train_x, train_y, eval_set=[(valid_x, valid_y)], verbose=0, early_stopping_rounds=100)
    
    model_cat = CatBoostClassifier(**param)
    model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=100)

    preds = gbm.predict(valid_x)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(valid_y, pred_labels)
    return log_loss

# %%
import optuna
def objective(trial):
    skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
    folds=[]
    for train_idx, valid_idx in skfold.split(X, y):
            folds.append((train_idx, valid_idx))
            
    cat_pred = np.zeros((X.shape[0], n_class))
    cat_pred_test = np.zeros((X_test.shape[0], n_class))
    cat_cols = categorical_feats+ ['gender', 'car', 'reality', 'phone', 'email', 'work_phone']

    param = {
        #"objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        
    for fold in range(n_fold):
        print(f'\n----------------- Fold {fold} -----------------\n')
        train_idx, valid_idx = folds[fold]
        X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
        train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        model_cat = CatBoostClassifier(**param)
        model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=100)

        cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
        cat_pred_test += model_cat.predict_proba(X_test) / n_fold
        print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')

    print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
    logloss = log_loss(y, cat_pred)
    return logloss

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50, timeout=600)
# Out:
# [I 2021-06-13 11:47:08,087] A new study created in memory with name: no-name-819cfa5d-a383-4192-8fe7-8028ccb21c65
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# ----------------- Fold 0 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501583	test: 1.0503820	best: 1.0503820 (0)	total: 24.1ms	remaining: 24.1s
# 100:	learn: 0.7313911	test: 0.6861480	best: 0.6861477 (98)	total: 1.91s	remaining: 17s
# 200:	learn: 0.7188599	test: 0.6692676	best: 0.6692675 (199)	total: 3.52s	remaining: 14s
# 300:	learn: 0.7153297	test: 0.6668464	best: 0.6668155 (294)	total: 5.16s	remaining: 12s
# 400:	learn: 0.7119636	test: 0.6647809	best: 0.6647809 (400)	total: 6.79s	remaining: 10.1s
# 500:	learn: 0.7094833	test: 0.6641824	best: 0.6641638 (491)	total: 8.37s	remaining: 8.34s
# 600:	learn: 0.7068466	test: 0.6624817	best: 0.6624817 (600)	total: 10.1s	remaining: 6.7s
# 700:	learn: 0.7043704	test: 0.6623856	best: 0.6622581 (634)	total: 11.9s	remaining: 5.06s
# 800:	learn: 0.7023935	test: 0.6616710	best: 0.6616710 (800)	total: 13.7s	remaining: 3.39s
# 900:	learn: 0.7002756	test: 0.6614710	best: 0.6613624 (810)	total: 15.4s	remaining: 1.69s
# 999:	learn: 0.6982415	test: 0.6612920	best: 0.6611881 (982)	total: 17.2s	remaining: 0us
#
# bestTest = 0.6611880784
# bestIteration = 982
#
# Shrink model to first 983 iterations.
# CV Log Loss Score: 0.661188
#
# ----------------- Fold 1 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501466	test: 1.0503584	best: 1.0503584 (0)	total: 18.5ms	remaining: 18.5s
# 100:	learn: 0.7424275	test: 0.7002976	best: 0.7002975 (99)	total: 1.94s	remaining: 17.3s
# 200:	learn: 0.7226475	test: 0.6696878	best: 0.6696135 (195)	total: 3.9s	remaining: 15.5s
# 300:	learn: 0.7176641	test: 0.6636831	best: 0.6636831 (300)	total: 5.95s	remaining: 13.8s
# 400:	learn: 0.7135140	test: 0.6600903	best: 0.6600903 (400)	total: 7.99s	remaining: 11.9s
# 500:	learn: 0.7105291	test: 0.6587681	best: 0.6585784 (484)	total: 9.96s	remaining: 9.92s
# 600:	learn: 0.7083657	test: 0.6579538	best: 0.6579374 (599)	total: 12s	remaining: 7.96s
# 700:	learn: 0.7057885	test: 0.6563968	best: 0.6563115 (694)	total: 14.2s	remaining: 6.04s
# 800:	learn: 0.7038604	test: 0.6561568	best: 0.6557645 (734)	total: 16.3s	remaining: 4.05s
# 900:	learn: 0.7020196	test: 0.6552465	best: 0.6551994 (898)	total: 18.4s	remaining: 2.02s
# 999:	learn: 0.6998855	test: 0.6544077	best: 0.6543406 (995)	total: 20.4s	remaining: 0us
#
# bestTest = 0.6543405691
# bestIteration = 995
#
# Shrink model to first 996 iterations.
# CV Log Loss Score: 0.654341
#
# ----------------- Fold 2 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501669	test: 1.0503401	best: 1.0503401 (0)	total: 23.3ms	remaining: 23.3s
# 100:	learn: 0.7345633	test: 0.6913439	best: 0.6912735 (98)	total: 2.1s	remaining: 18.7s
# 200:	learn: 0.7220170	test: 0.6717500	best: 0.6717183 (189)	total: 4.18s	remaining: 16.6s
# 300:	learn: 0.7166295	test: 0.6665607	best: 0.6665607 (300)	total: 6.25s	remaining: 14.5s
# 400:	learn: 0.7124151	test: 0.6628830	best: 0.6628706 (398)	total: 8.24s	remaining: 12.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6628706156
# bestIteration = 398
#
# Shrink model to first 399 iterations.
# CV Log Loss Score: 0.662871
#
# ----------------- Fold 3 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501813	test: 1.0500742	best: 1.0500742 (0)	total: 18.7ms	remaining: 18.7s
# 100:	learn: 0.7302094	test: 0.7044774	best: 0.7044774 (100)	total: 1.92s	remaining: 17.1s
# 200:	learn: 0.7184921	test: 0.6895662	best: 0.6895662 (200)	total: 3.85s	remaining: 15.3s
# 300:	learn: 0.7142970	test: 0.6865623	best: 0.6865429 (299)	total: 5.78s	remaining: 13.4s
# 400:	learn: 0.7109189	test: 0.6844904	best: 0.6844440 (396)	total: 7.69s	remaining: 11.5s
# 500:	learn: 0.7083918	test: 0.6844485	best: 0.6842648 (482)	total: 9.61s	remaining: 9.57s
# 600:	learn: 0.7058353	test: 0.6841146	best: 0.6840465 (560)	total: 11.6s	remaining: 7.68s
# 700:	learn: 0.7034073	test: 0.6838576	best: 0.6835471 (653)	total: 13.5s	remaining: 5.76s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6835471471
# bestIteration = 653
#
# Shrink model to first 654 iterations.
# CV Log Loss Score: 0.683547
#
# ----------------- Fold 4 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501587	test: 1.0503862	best: 1.0503862 (0)	total: 22.3ms	remaining: 22.3s
# 100:	learn: 0.7368896	test: 0.7088672	best: 0.7088672 (100)	total: 1.85s	remaining: 16.5s
# 200:	learn: 0.7203489	test: 0.6842355	best: 0.6842169 (197)	total: 3.75s	remaining: 14.9s
# 300:	learn: 0.7145205	test: 0.6790148	best: 0.6788771 (299)	total: 5.69s	remaining: 13.2s
# 400:	learn: 0.7105711	test: 0.6758812	best: 0.6758808 (396)	total: 7.6s	remaining: 11.4s
# 500:	learn: 0.7078922	test: 0.6741974	best: 0.6741974 (500)	total: 9.49s	remaining: 9.45s
# 600:	learn: 0.7052371	test: 0.6735498	best: 0.6735345 (598)	total: 11.4s	remaining: 7.58s
# 700:	learn: 0.7032029	test: 0.6727093	best: 0.6726554 (693)	total: 13.3s	remaining: 5.69s
# 800:	learn: 0.7010413	test: 0.6720595	best: 0.6719745 (799)	total: 15.2s	remaining: 3.78s
# 900:	learn: 0.6988750	test: 0.6716296	best: 0.6716123 (897)	total: 17.1s	remaining: 1.88s
# 999:	learn: 0.6969963	test: 0.6712465	best: 0.6710737 (954)	total: 19.1s	remaining: 0us
#
# bestTest = 0.6710736575
# bestIteration = 954
#
# Shrink model to first 955 iterations.
# CV Log Loss Score: 0.671074
#
# ----------------- Fold 5 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501588	test: 1.0503279	best: 1.0503279 (0)	total: 19.1ms	remaining: 19.1s
# 100:	learn: 0.7398101	test: 0.7050906	best: 0.7050906 (100)	total: 1.92s	remaining: 17.1s
# 200:	learn: 0.7241056	test: 0.6849346	best: 0.6849140 (198)	total: 3.83s	remaining: 15.2s
# 300:	learn: 0.7179238	test: 0.6771711	best: 0.6771683 (299)	total: 5.75s	remaining: 13.4s
# 400:	learn: 0.7126561	test: 0.6737284	best: 0.6737284 (400)	total: 7.65s	remaining: 11.4s
# 500:	learn: 0.7093137	test: 0.6716590	best: 0.6716454 (497)	total: 9.57s	remaining: 9.53s
# 600:	learn: 0.7070872	test: 0.6719370	best: 0.6715380 (548)	total: 11.6s	remaining: 7.68s
# 700:	learn: 0.7047278	test: 0.6712640	best: 0.6711113 (693)	total: 13.6s	remaining: 5.78s
# 800:	learn: 0.7023324	test: 0.6708302	best: 0.6708302 (800)	total: 15.5s	remaining: 3.85s
# 900:	learn: 0.7003631	test: 0.6710729	best: 0.6706906 (816)	total: 17.4s	remaining: 1.91s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.670690551
# bestIteration = 816
#
# Shrink model to first 817 iterations.
# CV Log Loss Score: 0.670691
#
# ----------------- Fold 6 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501719	test: 1.0502513	best: 1.0502513 (0)	total: 20.1ms	remaining: 20.1s
# 100:	learn: 0.7334195	test: 0.7071044	best: 0.7071044 (100)	total: 2.02s	remaining: 18s
# 200:	learn: 0.7198263	test: 0.6920226	best: 0.6920207 (199)	total: 3.94s	remaining: 15.7s
# 300:	learn: 0.7147336	test: 0.6884693	best: 0.6884693 (300)	total: 5.99s	remaining: 13.9s
# 400:	learn: 0.7106701	test: 0.6852931	best: 0.6852931 (400)	total: 7.98s	remaining: 11.9s
# 500:	learn: 0.7082006	test: 0.6849085	best: 0.6848618 (497)	total: 9.93s	remaining: 9.89s
# 600:	learn: 0.7057425	test: 0.6847195	best: 0.6846746 (595)	total: 11.9s	remaining: 7.9s
# 700:	learn: 0.7033662	test: 0.6837547	best: 0.6837274 (696)	total: 13.9s	remaining: 5.93s
# 800:	learn: 0.7013574	test: 0.6838036	best: 0.6836163 (702)	total: 15.9s	remaining: 3.95s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6836162944
# bestIteration = 702
#
# Shrink model to first 703 iterations.
# CV Log Loss Score: 0.683616
#
# ----------------- Fold 7 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501701	test: 1.0502129	best: 1.0502129 (0)	total: 26.9ms	remaining: 26.9s
# 100:	learn: 0.7356077	test: 0.7019598	best: 0.7019598 (100)	total: 1.83s	remaining: 16.3s
# 200:	learn: 0.7206145	test: 0.6818434	best: 0.6818434 (200)	total: 3.61s	remaining: 14.4s
# 300:	learn: 0.7149237	test: 0.6768765	best: 0.6768765 (300)	total: 5.45s	remaining: 12.7s
# 400:	learn: 0.7108003	test: 0.6741980	best: 0.6741393 (396)	total: 7.32s	remaining: 10.9s
# 500:	learn: 0.7082716	test: 0.6737631	best: 0.6737631 (500)	total: 9.22s	remaining: 9.19s
# 600:	learn: 0.7059876	test: 0.6738697	best: 0.6735090 (576)	total: 11.1s	remaining: 7.34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6735089502
# bestIteration = 576
#
# Shrink model to first 577 iterations.
# CV Log Loss Score: 0.673509
#
# ----------------- Fold 8 -----------------
# Learning rate set to 0.115128
# 0:	learn: 1.0501767	test: 1.0501851	best: 1.0501851 (0)	total: 20.6ms	remaining: 20.6s
# 100:	learn: 0.7343519	test: 0.7128669	best: 0.7128608 (97)	total: 1.87s	remaining: 16.7s
# 200:	learn: 0.7203634	test: 0.6976482	best: 0.6975920 (198)	total: 3.75s	remaining: 14.9s
# 300:	learn: 0.7133846	test: 0.6908183	best: 0.6908183 (300)	total: 5.72s	remaining: 13.3s
# 400:	learn: 0.7096286	test: 0.6877630	best: 0.6877629 (399)	total: 7.61s	remaining: 11.4s
# 500:	learn: 0.7069707	test: 0.6868629	best: 0.6867451 (486)	total: 9.54s	remaining: 9.5s
# 600:	learn: 0.7049741	test: 0.6863671	best: 0.6861828 (595)	total: 11.4s	remaining: 7.54s
# 700:	learn: 0.7022152	test: 0.6849481	best: 0.6848529 (696)	total: 13.3s	remaining: 5.66s
# 800:	learn: 0.6998803	test: 0.6839656	best: 0.6839514 (798)	total: 15.2s	remaining: 3.77s
# 900:	learn: 0.6982440	test: 0.6839153	best: 0.6837768 (878)	total: 17s	remaining: 1.87s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6837767631
# bestIteration = 878
#
# Shrink model to first 879 iterations.
# CV Log Loss Score: 0.683777
#
# ----------------- Fold 9 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501506	test: 1.0504175	best: 1.0504175 (0)	total: 20.3ms	remaining: 20.2s
# 100:	learn: 0.7385682	test: 0.6968718	best: 0.6968718 (100)	total: 1.86s	remaining: 16.6s
# 200:	learn: 0.7210738	test: 0.6731691	best: 0.6731691 (200)	total: 3.71s	remaining: 14.8s
# 300:	learn: 0.7157004	test: 0.6680580	best: 0.6679093 (296)	total: 5.61s	remaining: 13s
# 400:	learn: 0.7120361	test: 0.6648136	best: 0.6648136 (400)	total: 7.54s	remaining: 11.3s
# 500:	learn: 0.7093758	test: 0.6641689	best: 0.6639349 (490)	total: 9.52s	remaining: 9.48s
# 600:	learn: 0.7070983	test: 0.6636216	best: 0.6636216 (600)	total: 11.5s	remaining: 7.66s
# 700:	learn: 0.7048074	test: 0.6622646	best: 0.6622561 (697)	total: 13.5s	remaining: 5.76s
# 800:	learn: 0.7025492	test: 0.6611885	best: 0.6611673 (799)	total: 15.4s	remaining: 3.83s
# 900:	learn: 0.7007212	test: 0.6611344	best: 0.6608209 (848)	total: 17.3s	remaining: 1.91s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6608208972
# bestIteration = 848
#
# Shrink model to first 849 iterations.
# CV Log Loss Score: 0.660821
#
# ----------------- Fold 10 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501542	test: 1.0503543	best: 1.0503543 (0)	total: 27ms	remaining: 27s
# 100:	learn: 0.7408850	test: 0.6907328	best: 0.6906595 (99)	total: 1.92s	remaining: 17.1s
# 200:	learn: 0.7246078	test: 0.6664485	best: 0.6664485 (200)	total: 3.78s	remaining: 15s
# 300:	learn: 0.7182174	test: 0.6611824	best: 0.6611824 (300)	total: 5.71s	remaining: 13.3s
# 400:	learn: 0.7140562	test: 0.6587113	best: 0.6587113 (400)	total: 7.71s	remaining: 11.5s
# 500:	learn: 0.7105142	test: 0.6569149	best: 0.6568200 (477)	total: 9.69s	remaining: 9.65s
# 600:	learn: 0.7079923	test: 0.6564722	best: 0.6564212 (592)	total: 11.8s	remaining: 7.82s
# 700:	learn: 0.7052801	test: 0.6553125	best: 0.6550374 (684)	total: 13.8s	remaining: 5.89s
# 800:	learn: 0.7025883	test: 0.6546117	best: 0.6544873 (782)	total: 15.7s	remaining: 3.91s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6544872999
# bestIteration = 782
#
# Shrink model to first 783 iterations.
# CV Log Loss Score: 0.654487
#
# ----------------- Fold 11 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501611	test: 1.0502162	best: 1.0502162 (0)	total: 27.1ms	remaining: 27.1s
# 100:	learn: 0.7327471	test: 0.7122838	best: 0.7122838 (100)	total: 2.01s	remaining: 17.9s
# 200:	learn: 0.7198522	test: 0.6977761	best: 0.6977761 (200)	total: 3.9s	remaining: 15.5s
# 300:	learn: 0.7131510	test: 0.6917429	best: 0.6916909 (296)	total: 5.88s	remaining: 13.6s
# 400:	learn: 0.7096702	test: 0.6901427	best: 0.6899319 (391)	total: 7.85s	remaining: 11.7s
# 500:	learn: 0.7068384	test: 0.6897204	best: 0.6897204 (500)	total: 9.88s	remaining: 9.84s
# 600:	learn: 0.7045569	test: 0.6890404	best: 0.6890394 (599)	total: 11.9s	remaining: 7.87s
# 700:	learn: 0.7023378	test: 0.6885654	best: 0.6885540 (689)	total: 13.8s	remaining: 5.89s
# 800:	learn: 0.7003171	test: 0.6880194	best: 0.6879914 (798)	total: 15.8s	remaining: 3.92s
# 900:	learn: 0.6985469	test: 0.6886749	best: 0.6879860 (806)	total: 17.7s	remaining: 1.95s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6879859915
# bestIteration = 806
#
# Shrink model to first 807 iterations.
# CV Log Loss Score: 0.687986
#
# ----------------- Fold 12 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0419785	test: 1.0413148	best: 1.0413148 (0)	total: 24.5ms	remaining: 24.5s
# 100:	learn: 0.7315819	test: 0.6835030	best: 0.6835030 (100)	total: 1.94s	remaining: 17.3s
# 200:	learn: 0.7215124	test: 0.6694773	best: 0.6694773 (200)	total: 3.88s	remaining: 15.4s
# 300:	learn: 0.7170217	test: 0.6660625	best: 0.6660625 (300)	total: 5.89s	remaining: 13.7s
# 400:	learn: 0.7136354	test: 0.6635483	best: 0.6633122 (382)	total: 7.88s	remaining: 11.8s
# 500:	learn: 0.7107726	test: 0.6619907	best: 0.6619080 (489)	total: 9.78s	remaining: 9.74s
# 600:	learn: 0.7084301	test: 0.6619705	best: 0.6618411 (525)	total: 11.7s	remaining: 7.76s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6618410558
# bestIteration = 525
#
# Shrink model to first 526 iterations.
# CV Log Loss Score: 0.661841
#
# ----------------- Fold 13 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0419293	test: 1.0419589	best: 1.0419589 (0)	total: 20.7ms	remaining: 20.7s
# 100:	learn: 0.7342348	test: 0.7129789	best: 0.7129789 (100)	total: 1.91s	remaining: 17s
# 200:	learn: 0.7207501	test: 0.7008264	best: 0.7008264 (200)	total: 3.83s	remaining: 15.2s
# 300:	learn: 0.7136737	test: 0.6947331	best: 0.6946609 (297)	total: 5.85s	remaining: 13.6s
# 400:	learn: 0.7094844	test: 0.6916206	best: 0.6916206 (400)	total: 7.74s	remaining: 11.6s
# 500:	learn: 0.7067844	test: 0.6918770	best: 0.6909250 (423)	total: 9.71s	remaining: 9.67s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6909249932
# bestIteration = 423
#
# Shrink model to first 424 iterations.
# CV Log Loss Score: 0.690925
#
# ----------------- Fold 14 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0419887	test: 1.0409443	best: 1.0409443 (0)	total: 23.9ms	remaining: 23.9s
# 100:	learn: 0.7373319	test: 0.6942109	best: 0.6942109 (100)	total: 2.02s	remaining: 18s
# 200:	learn: 0.7207267	test: 0.6732348	best: 0.6732242 (199)	total: 3.95s	remaining: 15.7s
# 300:	learn: 0.7145091	test: 0.6672805	best: 0.6672805 (300)	total: 5.84s	remaining: 13.6s
# 400:	learn: 0.7111609	test: 0.6660585	best: 0.6660585 (400)	total: 7.76s	remaining: 11.6s
# 500:	learn: 0.7085798	test: 0.6653797	best: 0.6653050 (498)	total: 9.73s	remaining: 9.69s
# 600:	learn: 0.7061083	test: 0.6642431	best: 0.6642431 (600)	total: 11.7s	remaining: 7.75s
# 700:	learn: 0.7039429	test: 0.6638316	best: 0.6638128 (699)	total: 13.6s	remaining: 5.81s
# 800:	learn: 0.7008034	test: 0.6630574	best: 0.6628624 (778)	total: 15.7s	remaining: 3.89s
# 900:	learn: 0.6990165	test: 0.6627187	best: 0.6626626 (899)	total: 17.5s	remaining: 1.92s
# [I 2021-06-13 11:51:14,859] Trial 0 finished with value: 0.6708670298294468 and parameters: {'colsample_bylevel': 0.07591531396851062, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6708670298294468.
# 999:	learn: 0.6968355	test: 0.6624694	best: 0.6623340 (925)	total: 19.4s	remaining: 0us
#
# bestTest = 0.6623340001
# bestIteration = 925
#
# Shrink model to first 926 iterations.
# CV Log Loss Score: 0.662334
# 	Log Loss: 0.670867
#
# ----------------- Fold 0 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0463447	test: 1.0462352	best: 1.0462352 (0)	total: 9.01ms	remaining: 9.01s
# 100:	learn: 0.7344867	test: 0.6948548	best: 0.6948548 (100)	total: 648ms	remaining: 5.77s
# 200:	learn: 0.7198421	test: 0.6792878	best: 0.6792787 (198)	total: 1.31s	remaining: 5.23s
# 300:	learn: 0.7121361	test: 0.6754204	best: 0.6754154 (299)	total: 2.01s	remaining: 4.66s
# 400:	learn: 0.7054217	test: 0.6702749	best: 0.6702722 (398)	total: 2.68s	remaining: 4.01s
# 500:	learn: 0.6993571	test: 0.6674394	best: 0.6673381 (465)	total: 3.38s	remaining: 3.36s
# 600:	learn: 0.6951386	test: 0.6665847	best: 0.6665200 (569)	total: 4.01s	remaining: 2.67s
# 700:	learn: 0.6905318	test: 0.6646623	best: 0.6646620 (699)	total: 4.67s	remaining: 1.99s
# 800:	learn: 0.6863017	test: 0.6634274	best: 0.6634274 (800)	total: 5.33s	remaining: 1.32s
# 900:	learn: 0.6824523	test: 0.6626830	best: 0.6626793 (897)	total: 6.03s	remaining: 662ms
# 999:	learn: 0.6790290	test: 0.6624912	best: 0.6624280 (994)	total: 6.7s	remaining: 0us
#
# bestTest = 0.6624280103
# bestIteration = 994
#
# Shrink model to first 995 iterations.
# CV Log Loss Score: 0.662428
#
# ----------------- Fold 1 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0437075	test: 1.0446961	best: 1.0446961 (0)	total: 9.5ms	remaining: 9.49s
# 100:	learn: 0.7407024	test: 0.7085453	best: 0.7085453 (100)	total: 680ms	remaining: 6.05s
# 200:	learn: 0.7206541	test: 0.6783632	best: 0.6783632 (200)	total: 1.3s	remaining: 5.19s
# 300:	learn: 0.7109992	test: 0.6675363	best: 0.6675363 (300)	total: 1.94s	remaining: 4.51s
# 400:	learn: 0.7058690	test: 0.6637688	best: 0.6637688 (400)	total: 2.54s	remaining: 3.8s
# 500:	learn: 0.7003162	test: 0.6618173	best: 0.6618132 (496)	total: 3.18s	remaining: 3.17s
# 600:	learn: 0.6959582	test: 0.6594368	best: 0.6593420 (591)	total: 3.8s	remaining: 2.52s
# 700:	learn: 0.6916182	test: 0.6572989	best: 0.6572989 (700)	total: 4.4s	remaining: 1.88s
# 800:	learn: 0.6874580	test: 0.6565029	best: 0.6563122 (774)	total: 5.05s	remaining: 1.25s
# 900:	learn: 0.6835773	test: 0.6550436	best: 0.6550423 (897)	total: 5.64s	remaining: 620ms
# 999:	learn: 0.6792305	test: 0.6540770	best: 0.6538969 (981)	total: 6.38s	remaining: 0us
#
# bestTest = 0.6538969107
# bestIteration = 981
#
# Shrink model to first 982 iterations.
# CV Log Loss Score: 0.653897
#
# ----------------- Fold 2 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0415773	test: 1.0417526	best: 1.0417526 (0)	total: 10.9ms	remaining: 10.8s
# 100:	learn: 0.7406015	test: 0.7102792	best: 0.7102792 (100)	total: 675ms	remaining: 6s
# 200:	learn: 0.7233826	test: 0.6875482	best: 0.6875482 (200)	total: 1.27s	remaining: 5.05s
# 300:	learn: 0.7137331	test: 0.6787091	best: 0.6787019 (298)	total: 1.94s	remaining: 4.5s
# 400:	learn: 0.7058016	test: 0.6736815	best: 0.6736815 (400)	total: 2.63s	remaining: 3.92s
# 500:	learn: 0.6995767	test: 0.6695392	best: 0.6695000 (499)	total: 3.32s	remaining: 3.3s
# 600:	learn: 0.6948178	test: 0.6668946	best: 0.6666869 (574)	total: 3.92s	remaining: 2.6s
# 700:	learn: 0.6903657	test: 0.6657179	best: 0.6657174 (697)	total: 4.56s	remaining: 1.94s
# 800:	learn: 0.6867053	test: 0.6635342	best: 0.6635099 (795)	total: 5.2s	remaining: 1.29s
# 900:	learn: 0.6829176	test: 0.6641527	best: 0.6634892 (815)	total: 5.81s	remaining: 638ms
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6634891537
# bestIteration = 815
#
# Shrink model to first 816 iterations.
# CV Log Loss Score: 0.663489
#
# ----------------- Fold 3 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0414653	test: 1.0422858	best: 1.0422858 (0)	total: 8.67ms	remaining: 8.66s
# 100:	learn: 0.7376781	test: 0.7202140	best: 0.7201619 (99)	total: 645ms	remaining: 5.74s
# 200:	learn: 0.7191349	test: 0.6997422	best: 0.6997422 (200)	total: 1.31s	remaining: 5.21s
# 300:	learn: 0.7094991	test: 0.6924212	best: 0.6923652 (294)	total: 1.93s	remaining: 4.49s
# 400:	learn: 0.7033141	test: 0.6900691	best: 0.6899786 (399)	total: 2.57s	remaining: 3.84s
# 500:	learn: 0.6976228	test: 0.6883666	best: 0.6883229 (497)	total: 3.25s	remaining: 3.23s
# 600:	learn: 0.6925783	test: 0.6868505	best: 0.6868121 (594)	total: 3.96s	remaining: 2.63s
# 700:	learn: 0.6881078	test: 0.6863306	best: 0.6860558 (681)	total: 4.63s	remaining: 1.97s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6860558035
# bestIteration = 681
#
# Shrink model to first 682 iterations.
# CV Log Loss Score: 0.686056
#
# ----------------- Fold 4 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0456076	test: 1.0453374	best: 1.0453374 (0)	total: 10.1ms	remaining: 10.1s
# 100:	learn: 0.7387873	test: 0.7115520	best: 0.7114990 (99)	total: 704ms	remaining: 6.26s
# 200:	learn: 0.7192336	test: 0.6880111	best: 0.6880111 (200)	total: 1.35s	remaining: 5.35s
# 300:	learn: 0.7106873	test: 0.6808376	best: 0.6808376 (300)	total: 2.05s	remaining: 4.77s
# 400:	learn: 0.7036858	test: 0.6767915	best: 0.6767007 (394)	total: 2.75s	remaining: 4.1s
# 500:	learn: 0.6982009	test: 0.6736829	best: 0.6736829 (500)	total: 3.42s	remaining: 3.41s
# 600:	learn: 0.6943168	test: 0.6733108	best: 0.6731706 (530)	total: 4.07s	remaining: 2.7s
# 700:	learn: 0.6902941	test: 0.6720400	best: 0.6719578 (694)	total: 4.69s	remaining: 2s
# 800:	learn: 0.6865535	test: 0.6718309	best: 0.6716400 (730)	total: 5.34s	remaining: 1.33s
# 900:	learn: 0.6823581	test: 0.6716433	best: 0.6712688 (870)	total: 6.01s	remaining: 660ms
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6712688204
# bestIteration = 870
#
# Shrink model to first 871 iterations.
# CV Log Loss Score: 0.671269
#
# ----------------- Fold 5 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0438269	test: 1.0448744	best: 1.0448744 (0)	total: 10.8ms	remaining: 10.8s
# 100:	learn: 0.7403829	test: 0.7144633	best: 0.7142867 (94)	total: 685ms	remaining: 6.1s
# 200:	learn: 0.7193900	test: 0.6896727	best: 0.6896727 (199)	total: 1.35s	remaining: 5.38s
# 300:	learn: 0.7110886	test: 0.6813840	best: 0.6813840 (300)	total: 2.07s	remaining: 4.8s
# 400:	learn: 0.7049766	test: 0.6769784	best: 0.6769784 (400)	total: 2.76s	remaining: 4.12s
# 500:	learn: 0.7002744	test: 0.6749939	best: 0.6749939 (500)	total: 3.37s	remaining: 3.35s
# 600:	learn: 0.6957805	test: 0.6726013	best: 0.6726013 (600)	total: 4s	remaining: 2.65s
# 700:	learn: 0.6920261	test: 0.6726998	best: 0.6721143 (614)	total: 4.64s	remaining: 1.98s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6721143394
# bestIteration = 614
#
# Shrink model to first 615 iterations.
# CV Log Loss Score: 0.672114
#
# ----------------- Fold 6 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0416362	test: 1.0405115	best: 1.0405115 (0)	total: 9.63ms	remaining: 9.62s
# 100:	learn: 0.7349826	test: 0.7149260	best: 0.7149260 (100)	total: 697ms	remaining: 6.21s
# 200:	learn: 0.7178222	test: 0.6990329	best: 0.6990329 (200)	total: 1.36s	remaining: 5.42s
# 300:	learn: 0.7090553	test: 0.6925817	best: 0.6925817 (300)	total: 2.02s	remaining: 4.7s
# 400:	learn: 0.7021460	test: 0.6896583	best: 0.6894412 (382)	total: 2.7s	remaining: 4.03s
# 500:	learn: 0.6965191	test: 0.6872623	best: 0.6872622 (499)	total: 3.37s	remaining: 3.35s
# 600:	learn: 0.6923448	test: 0.6861145	best: 0.6859543 (585)	total: 3.97s	remaining: 2.64s
# 700:	learn: 0.6885480	test: 0.6851280	best: 0.6849936 (679)	total: 4.6s	remaining: 1.96s
# 800:	learn: 0.6842576	test: 0.6851772	best: 0.6848069 (757)	total: 5.26s	remaining: 1.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6848068801
# bestIteration = 757
#
# Shrink model to first 758 iterations.
# CV Log Loss Score: 0.684807
#
# ----------------- Fold 7 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0416995	test: 1.0431515	best: 1.0431515 (0)	total: 10.8ms	remaining: 10.8s
# 100:	learn: 0.7358282	test: 0.7047786	best: 0.7047786 (100)	total: 688ms	remaining: 6.12s
# 200:	learn: 0.7193163	test: 0.6868469	best: 0.6867303 (198)	total: 1.39s	remaining: 5.51s
# 300:	learn: 0.7099625	test: 0.6806961	best: 0.6804701 (294)	total: 2.1s	remaining: 4.88s
# 400:	learn: 0.7026253	test: 0.6758973	best: 0.6756528 (393)	total: 2.77s	remaining: 4.13s
# 500:	learn: 0.6973204	test: 0.6730608	best: 0.6729365 (494)	total: 3.4s	remaining: 3.38s
# 600:	learn: 0.6924914	test: 0.6720327	best: 0.6720327 (600)	total: 4.1s	remaining: 2.72s
# 700:	learn: 0.6884554	test: 0.6712080	best: 0.6711310 (699)	total: 4.77s	remaining: 2.03s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6711310278
# bestIteration = 699
#
# Shrink model to first 700 iterations.
# CV Log Loss Score: 0.671131
#
# ----------------- Fold 8 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0412101	test: 1.0428082	best: 1.0428082 (0)	total: 9.71ms	remaining: 9.71s
# 100:	learn: 0.7347352	test: 0.7223969	best: 0.7223969 (100)	total: 690ms	remaining: 6.14s
# 200:	learn: 0.7193153	test: 0.7066199	best: 0.7066199 (200)	total: 1.33s	remaining: 5.3s
# 300:	learn: 0.7102322	test: 0.6994544	best: 0.6994011 (299)	total: 1.99s	remaining: 4.61s
# 400:	learn: 0.7031722	test: 0.6946435	best: 0.6945502 (395)	total: 2.65s	remaining: 3.95s
# 500:	learn: 0.6974803	test: 0.6922719	best: 0.6922684 (498)	total: 3.3s	remaining: 3.29s
# 600:	learn: 0.6927903	test: 0.6902296	best: 0.6902296 (600)	total: 3.93s	remaining: 2.61s
# 700:	learn: 0.6884717	test: 0.6897173	best: 0.6895780 (683)	total: 4.57s	remaining: 1.95s
# 800:	learn: 0.6843189	test: 0.6893990	best: 0.6890943 (788)	total: 5.2s	remaining: 1.29s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6890943005
# bestIteration = 788
#
# Shrink model to first 789 iterations.
# CV Log Loss Score: 0.689094
#
# ----------------- Fold 9 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0417101	test: 1.0407482	best: 1.0407482 (0)	total: 9.93ms	remaining: 9.92s
# 100:	learn: 0.7347109	test: 0.6934269	best: 0.6934269 (100)	total: 778ms	remaining: 6.92s
# 200:	learn: 0.7190521	test: 0.6754293	best: 0.6754293 (200)	total: 1.43s	remaining: 5.67s
# 300:	learn: 0.7108976	test: 0.6685156	best: 0.6685114 (296)	total: 2.08s	remaining: 4.84s
# 400:	learn: 0.7040762	test: 0.6646909	best: 0.6645193 (379)	total: 2.8s	remaining: 4.19s
# 500:	learn: 0.6992745	test: 0.6625018	best: 0.6624386 (492)	total: 3.51s	remaining: 3.5s
# 600:	learn: 0.6953121	test: 0.6611107	best: 0.6608719 (597)	total: 4.15s	remaining: 2.75s
# 700:	learn: 0.6916306	test: 0.6606693	best: 0.6604999 (672)	total: 4.76s	remaining: 2.03s
# 800:	learn: 0.6875448	test: 0.6599261	best: 0.6597051 (767)	total: 5.45s	remaining: 1.35s
# 900:	learn: 0.6834786	test: 0.6588382	best: 0.6588341 (899)	total: 6.1s	remaining: 670ms
# 999:	learn: 0.6801775	test: 0.6588843	best: 0.6586631 (917)	total: 6.76s	remaining: 0us
#
# bestTest = 0.6586631393
# bestIteration = 917
#
# Shrink model to first 918 iterations.
# CV Log Loss Score: 0.658663
#
# ----------------- Fold 10 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0446577	test: 1.0443193	best: 1.0443193 (0)	total: 9.29ms	remaining: 9.28s
# 100:	learn: 0.7317891	test: 0.6829421	best: 0.6829421 (100)	total: 691ms	remaining: 6.15s
# 200:	learn: 0.7185887	test: 0.6665493	best: 0.6665005 (194)	total: 1.36s	remaining: 5.41s
# 300:	learn: 0.7092823	test: 0.6575495	best: 0.6575462 (293)	total: 2.03s	remaining: 4.71s
# 400:	learn: 0.7035181	test: 0.6558956	best: 0.6558153 (358)	total: 2.76s	remaining: 4.12s
# 500:	learn: 0.6980956	test: 0.6552083	best: 0.6550903 (469)	total: 3.47s	remaining: 3.46s
# 600:	learn: 0.6935192	test: 0.6550272	best: 0.6549437 (586)	total: 4.13s	remaining: 2.74s
# 700:	learn: 0.6896157	test: 0.6548327	best: 0.6545411 (639)	total: 4.77s	remaining: 2.03s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6545411327
# bestIteration = 639
#
# Shrink model to first 640 iterations.
# CV Log Loss Score: 0.654541
#
# ----------------- Fold 11 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0413656	test: 1.0428003	best: 1.0428003 (0)	total: 9.52ms	remaining: 9.51s
# 100:	learn: 0.7337511	test: 0.7174925	best: 0.7174698 (99)	total: 693ms	remaining: 6.17s
# 200:	learn: 0.7178287	test: 0.7032168	best: 0.7031540 (196)	total: 1.4s	remaining: 5.58s
# 300:	learn: 0.7092524	test: 0.6964701	best: 0.6964701 (300)	total: 2.12s	remaining: 4.92s
# 400:	learn: 0.7022691	test: 0.6944568	best: 0.6943044 (361)	total: 2.79s	remaining: 4.17s
# 500:	learn: 0.6977673	test: 0.6928281	best: 0.6927741 (492)	total: 3.45s	remaining: 3.43s
# 600:	learn: 0.6928840	test: 0.6910720	best: 0.6910720 (600)	total: 4.08s	remaining: 2.71s
# 700:	learn: 0.6893410	test: 0.6912020	best: 0.6907325 (627)	total: 4.67s	remaining: 1.99s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6907324763
# bestIteration = 627
#
# Shrink model to first 628 iterations.
# CV Log Loss Score: 0.690732
#
# ----------------- Fold 12 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0398145	test: 1.0387474	best: 1.0387474 (0)	total: 10.8ms	remaining: 10.8s
# 100:	learn: 0.7382636	test: 0.6986123	best: 0.6986123 (100)	total: 626ms	remaining: 5.57s
# 200:	learn: 0.7231265	test: 0.6752518	best: 0.6752518 (200)	total: 1.24s	remaining: 4.93s
# 300:	learn: 0.7146404	test: 0.6679604	best: 0.6679604 (300)	total: 1.85s	remaining: 4.29s
# 400:	learn: 0.7080477	test: 0.6665586	best: 0.6663816 (382)	total: 2.45s	remaining: 3.66s
# 500:	learn: 0.7025208	test: 0.6648381	best: 0.6648229 (499)	total: 3.08s	remaining: 3.07s
# 600:	learn: 0.6985477	test: 0.6638485	best: 0.6637796 (592)	total: 3.71s	remaining: 2.46s
# 700:	learn: 0.6944370	test: 0.6636518	best: 0.6632718 (632)	total: 4.41s	remaining: 1.88s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6632718314
# bestIteration = 632
#
# Shrink model to first 633 iterations.
# CV Log Loss Score: 0.663272
#
# ----------------- Fold 13 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0328751	test: 1.0314526	best: 1.0314526 (0)	total: 10.7ms	remaining: 10.7s
# 100:	learn: 0.7342910	test: 0.7167863	best: 0.7166456 (97)	total: 679ms	remaining: 6.05s
# 200:	learn: 0.7177475	test: 0.7040130	best: 0.7040130 (200)	total: 1.34s	remaining: 5.32s
# 300:	learn: 0.7090276	test: 0.6982375	best: 0.6981331 (293)	total: 2.03s	remaining: 4.71s
# 400:	learn: 0.7017974	test: 0.6948901	best: 0.6948901 (400)	total: 2.69s	remaining: 4.01s
# 500:	learn: 0.6970252	test: 0.6951616	best: 0.6947699 (425)	total: 3.31s	remaining: 3.3s
# 600:	learn: 0.6920699	test: 0.6944969	best: 0.6940045 (582)	total: 3.94s	remaining: 2.61s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.694004488
# bestIteration = 582
#
# Shrink model to first 583 iterations.
# CV Log Loss Score: 0.694004
#
# ----------------- Fold 14 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0387861	test: 1.0367030	best: 1.0367030 (0)	total: 11.6ms	remaining: 11.6s
# 100:	learn: 0.7348423	test: 0.6970162	best: 0.6970162 (100)	total: 665ms	remaining: 5.92s
# 200:	learn: 0.7193349	test: 0.6791842	best: 0.6791842 (200)	total: 1.3s	remaining: 5.15s
# 300:	learn: 0.7113454	test: 0.6728320	best: 0.6728320 (300)	total: 1.91s	remaining: 4.44s
# 400:	learn: 0.7036788	test: 0.6683061	best: 0.6682344 (388)	total: 2.59s	remaining: 3.87s
# 500:	learn: 0.6986101	test: 0.6661397	best: 0.6661069 (497)	total: 3.16s	remaining: 3.15s
# 600:	learn: 0.6938230	test: 0.6640781	best: 0.6640781 (600)	total: 3.77s	remaining: 2.51s
# 700:	learn: 0.6893428	test: 0.6633113	best: 0.6633113 (700)	total: 4.44s	remaining: 1.89s
# 800:	learn: 0.6847333	test: 0.6625147	best: 0.6624544 (792)	total: 5.13s	remaining: 1.27s
# 900:	learn: 0.6807805	test: 0.6619468	best: 0.6618365 (882)	total: 5.83s	remaining: 640ms
# [I 2021-06-13 11:52:44,862] Trial 1 finished with value: 0.6718221810214896 and parameters: {'colsample_bylevel': 0.08735162877190666, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.3902893698102545}. Best is trial 0 with value: 0.6708670298294468.
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6618364683
# bestIteration = 882
#
# Shrink model to first 883 iterations.
# CV Log Loss Score: 0.661836
# 	Log Loss: 0.671822
#
# ----------------- Fold 0 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0439884	test: 1.0430371	best: 1.0430371 (0)	total: 25.9ms	remaining: 25.9s
# 100:	learn: 0.7353186	test: 0.6932719	best: 0.6932410 (99)	total: 2.38s	remaining: 21.2s
# 200:	learn: 0.7213056	test: 0.6775516	best: 0.6775390 (190)	total: 4.67s	remaining: 18.6s
# 300:	learn: 0.7146040	test: 0.6725102	best: 0.6724517 (294)	total: 6.92s	remaining: 16.1s
# 400:	learn: 0.7082663	test: 0.6683372	best: 0.6681456 (383)	total: 9.29s	remaining: 13.9s
# 500:	learn: 0.7043603	test: 0.6666774	best: 0.6666774 (500)	total: 11.6s	remaining: 11.5s
# 600:	learn: 0.7009361	test: 0.6655458	best: 0.6655317 (596)	total: 13.8s	remaining: 9.15s
# 700:	learn: 0.6982566	test: 0.6652502	best: 0.6652502 (700)	total: 16.1s	remaining: 6.87s
# 800:	learn: 0.6957855	test: 0.6650173	best: 0.6645762 (777)	total: 18.4s	remaining: 4.57s
# 900:	learn: 0.6930525	test: 0.6644070	best: 0.6643843 (899)	total: 20.7s	remaining: 2.28s
# 999:	learn: 0.6900891	test: 0.6638233	best: 0.6637536 (984)	total: 23.1s	remaining: 0us
#
# bestTest = 0.6637536469
# bestIteration = 984
#
# Shrink model to first 985 iterations.
# CV Log Loss Score: 0.663754
#
# ----------------- Fold 1 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0493216	test: 1.0495439	best: 1.0495439 (0)	total: 26.7ms	remaining: 26.6s
# 100:	learn: 0.7444718	test: 0.7086773	best: 0.7086211 (98)	total: 2.21s	remaining: 19.7s
# 200:	learn: 0.7261661	test: 0.6829635	best: 0.6829024 (198)	total: 4.52s	remaining: 18s
# 300:	learn: 0.7168604	test: 0.6709934	best: 0.6709934 (300)	total: 6.79s	remaining: 15.8s
# 400:	learn: 0.7123204	test: 0.6677397	best: 0.6676678 (399)	total: 9.01s	remaining: 13.5s
# 500:	learn: 0.7055033	test: 0.6617931	best: 0.6616458 (498)	total: 11.2s	remaining: 11.1s
# 600:	learn: 0.7019443	test: 0.6603672	best: 0.6602824 (593)	total: 13.4s	remaining: 8.89s
# 700:	learn: 0.6986547	test: 0.6591679	best: 0.6591679 (700)	total: 15.5s	remaining: 6.63s
# 800:	learn: 0.6959216	test: 0.6585545	best: 0.6583321 (781)	total: 17.7s	remaining: 4.41s
# 900:	learn: 0.6934234	test: 0.6578820	best: 0.6578309 (889)	total: 20s	remaining: 2.2s
# 999:	learn: 0.6904741	test: 0.6573432	best: 0.6571670 (981)	total: 22.2s	remaining: 0us
#
# bestTest = 0.6571670283
# bestIteration = 981
#
# Shrink model to first 982 iterations.
# CV Log Loss Score: 0.657167
#
# ----------------- Fold 2 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0438817	test: 1.0437797	best: 1.0437797 (0)	total: 25.5ms	remaining: 25.5s
# 100:	learn: 0.7392665	test: 0.6980309	best: 0.6979598 (99)	total: 2.24s	remaining: 19.9s
# 200:	learn: 0.7250357	test: 0.6809719	best: 0.6809719 (200)	total: 4.54s	remaining: 18s
# 300:	learn: 0.7166194	test: 0.6719639	best: 0.6719629 (299)	total: 6.89s	remaining: 16s
# 400:	learn: 0.7097295	test: 0.6671379	best: 0.6670579 (399)	total: 9.08s	remaining: 13.6s
# 500:	learn: 0.7060961	test: 0.6655721	best: 0.6655226 (499)	total: 11.3s	remaining: 11.2s
# 600:	learn: 0.7024169	test: 0.6637332	best: 0.6637332 (600)	total: 13.5s	remaining: 8.93s
# 700:	learn: 0.6991689	test: 0.6626606	best: 0.6626497 (694)	total: 15.8s	remaining: 6.72s
# 800:	learn: 0.6949057	test: 0.6610780	best: 0.6610531 (776)	total: 18.1s	remaining: 4.5s
# 900:	learn: 0.6917101	test: 0.6612404	best: 0.6609388 (846)	total: 20.4s	remaining: 2.24s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6609388223
# bestIteration = 846
#
# Shrink model to first 847 iterations.
# CV Log Loss Score: 0.660939
#
# ----------------- Fold 3 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0500956	test: 1.0506674	best: 1.0506674 (0)	total: 34.1ms	remaining: 34.1s
# 100:	learn: 0.7357318	test: 0.7129885	best: 0.7129885 (100)	total: 2.25s	remaining: 20s
# 200:	learn: 0.7212142	test: 0.6950312	best: 0.6950276 (199)	total: 4.57s	remaining: 18.2s
# 300:	learn: 0.7138769	test: 0.6898273	best: 0.6898273 (300)	total: 6.86s	remaining: 15.9s
# 400:	learn: 0.7087418	test: 0.6863654	best: 0.6863653 (399)	total: 9.13s	remaining: 13.6s
# 500:	learn: 0.7053630	test: 0.6849726	best: 0.6849726 (500)	total: 11.4s	remaining: 11.3s
# 600:	learn: 0.7000805	test: 0.6835445	best: 0.6835327 (591)	total: 13.8s	remaining: 9.15s
# 700:	learn: 0.6963476	test: 0.6827434	best: 0.6825149 (647)	total: 16.1s	remaining: 6.88s
# 800:	learn: 0.6930912	test: 0.6818720	best: 0.6818376 (791)	total: 18.3s	remaining: 4.56s
# 900:	learn: 0.6901241	test: 0.6819663	best: 0.6818303 (802)	total: 20.6s	remaining: 2.27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6818303372
# bestIteration = 802
#
# Shrink model to first 803 iterations.
# CV Log Loss Score: 0.681830
#
# ----------------- Fold 4 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0433655	test: 1.0433237	best: 1.0433237 (0)	total: 22.8ms	remaining: 22.8s
# 100:	learn: 0.7411949	test: 0.7115809	best: 0.7115809 (100)	total: 2.33s	remaining: 20.7s
# 200:	learn: 0.7229301	test: 0.6938534	best: 0.6938534 (200)	total: 4.64s	remaining: 18.4s
# 300:	learn: 0.7140199	test: 0.6853330	best: 0.6853243 (297)	total: 7.02s	remaining: 16.3s
# 400:	learn: 0.7078000	test: 0.6809735	best: 0.6808697 (397)	total: 9.3s	remaining: 13.9s
# 500:	learn: 0.7031083	test: 0.6787252	best: 0.6787252 (500)	total: 11.7s	remaining: 11.7s
# 600:	learn: 0.6994867	test: 0.6777303	best: 0.6776812 (594)	total: 14.1s	remaining: 9.34s
# 700:	learn: 0.6960276	test: 0.6765322	best: 0.6765093 (699)	total: 16.5s	remaining: 7.04s
# 800:	learn: 0.6930587	test: 0.6749174	best: 0.6749174 (800)	total: 18.8s	remaining: 4.68s
# 900:	learn: 0.6896060	test: 0.6736810	best: 0.6735521 (897)	total: 21.2s	remaining: 2.33s
# 999:	learn: 0.6868663	test: 0.6728591	best: 0.6728478 (992)	total: 23.6s	remaining: 0us
#
# bestTest = 0.6728478452
# bestIteration = 992
#
# Shrink model to first 993 iterations.
# CV Log Loss Score: 0.672848
#
# ----------------- Fold 5 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0462547	test: 1.0471264	best: 1.0471264 (0)	total: 25.4ms	remaining: 25.4s
# 100:	learn: 0.7457416	test: 0.7164293	best: 0.7164293 (100)	total: 2.38s	remaining: 21.2s
# 200:	learn: 0.7278114	test: 0.6952569	best: 0.6952569 (200)	total: 4.78s	remaining: 19s
# 300:	learn: 0.7184315	test: 0.6867029	best: 0.6867029 (300)	total: 6.96s	remaining: 16.2s
# 400:	learn: 0.7118928	test: 0.6813579	best: 0.6810210 (390)	total: 9.27s	remaining: 13.8s
# 500:	learn: 0.7078669	test: 0.6784272	best: 0.6783523 (489)	total: 11.6s	remaining: 11.6s
# 600:	learn: 0.7037929	test: 0.6757254	best: 0.6757254 (600)	total: 13.9s	remaining: 9.23s
# 700:	learn: 0.7002724	test: 0.6746795	best: 0.6745105 (674)	total: 16.2s	remaining: 6.89s
# 800:	learn: 0.6971588	test: 0.6738416	best: 0.6736425 (776)	total: 18.5s	remaining: 4.59s
# 900:	learn: 0.6937586	test: 0.6726089	best: 0.6724705 (875)	total: 20.9s	remaining: 2.29s
# 999:	learn: 0.6908459	test: 0.6726062	best: 0.6723096 (960)	total: 23.2s	remaining: 0us
#
# bestTest = 0.6723095666
# bestIteration = 960
#
# Shrink model to first 961 iterations.
# CV Log Loss Score: 0.672310
#
# ----------------- Fold 6 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0416708	test: 1.0405788	best: 1.0405788 (0)	total: 28.2ms	remaining: 28.2s
# 100:	learn: 0.7334992	test: 0.7067703	best: 0.7067703 (100)	total: 2.48s	remaining: 22.1s
# 200:	learn: 0.7202707	test: 0.6943848	best: 0.6943266 (197)	total: 4.8s	remaining: 19.1s
# 300:	learn: 0.7128571	test: 0.6900187	best: 0.6899079 (286)	total: 7.24s	remaining: 16.8s
# 400:	learn: 0.7076502	test: 0.6877313	best: 0.6877313 (400)	total: 9.67s	remaining: 14.4s
# 500:	learn: 0.7036011	test: 0.6877894	best: 0.6872172 (438)	total: 12s	remaining: 11.9s
# 600:	learn: 0.6987726	test: 0.6855434	best: 0.6855434 (600)	total: 14.3s	remaining: 9.48s
# 700:	learn: 0.6951677	test: 0.6859058	best: 0.6854186 (610)	total: 16.6s	remaining: 7.09s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6854186436
# bestIteration = 610
#
# Shrink model to first 611 iterations.
# CV Log Loss Score: 0.685419
#
# ----------------- Fold 7 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0477735	test: 1.0479519	best: 1.0479519 (0)	total: 26.5ms	remaining: 26.4s
# 100:	learn: 0.7373865	test: 0.7079241	best: 0.7079241 (100)	total: 2.35s	remaining: 20.9s
# 200:	learn: 0.7214037	test: 0.6883215	best: 0.6883215 (200)	total: 4.63s	remaining: 18.4s
# 300:	learn: 0.7135031	test: 0.6818191	best: 0.6817711 (294)	total: 6.9s	remaining: 16s
# 400:	learn: 0.7084980	test: 0.6796929	best: 0.6796810 (394)	total: 9.2s	remaining: 13.7s
# 500:	learn: 0.7037788	test: 0.6768109	best: 0.6768109 (500)	total: 11.7s	remaining: 11.6s
# 600:	learn: 0.7002157	test: 0.6758779	best: 0.6758038 (590)	total: 14s	remaining: 9.26s
# 700:	learn: 0.6971745	test: 0.6744524	best: 0.6744370 (695)	total: 16.2s	remaining: 6.91s
# 800:	learn: 0.6940903	test: 0.6741048	best: 0.6738654 (761)	total: 18.5s	remaining: 4.6s
# 900:	learn: 0.6899982	test: 0.6723897	best: 0.6723896 (899)	total: 20.9s	remaining: 2.29s
# 999:	learn: 0.6872820	test: 0.6729048	best: 0.6723896 (899)	total: 23.3s	remaining: 0us
#
# bestTest = 0.6723896182
# bestIteration = 899
#
# Shrink model to first 900 iterations.
# CV Log Loss Score: 0.672390
#
# ----------------- Fold 8 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0454914	test: 1.0461743	best: 1.0461743 (0)	total: 24.5ms	remaining: 24.5s
# 100:	learn: 0.7375742	test: 0.7225642	best: 0.7225642 (100)	total: 2.32s	remaining: 20.7s
# 200:	learn: 0.7224681	test: 0.7085547	best: 0.7085547 (200)	total: 4.6s	remaining: 18.3s
# 300:	learn: 0.7155778	test: 0.7024734	best: 0.7024435 (296)	total: 6.9s	remaining: 16s
# 400:	learn: 0.7104975	test: 0.6990235	best: 0.6990235 (400)	total: 9.24s	remaining: 13.8s
# 500:	learn: 0.7060947	test: 0.6965422	best: 0.6965422 (500)	total: 11.6s	remaining: 11.6s
# 600:	learn: 0.7022933	test: 0.6951772	best: 0.6951772 (600)	total: 13.9s	remaining: 9.21s
# 700:	learn: 0.6991505	test: 0.6942936	best: 0.6941397 (667)	total: 16.1s	remaining: 6.87s
# 800:	learn: 0.6954225	test: 0.6923719	best: 0.6923719 (800)	total: 18.5s	remaining: 4.59s
# 900:	learn: 0.6919951	test: 0.6915217	best: 0.6914889 (885)	total: 20.8s	remaining: 2.29s
# 999:	learn: 0.6891828	test: 0.6913663	best: 0.6911403 (978)	total: 23s	remaining: 0us
#
# bestTest = 0.6911403004
# bestIteration = 978
#
# Shrink model to first 979 iterations.
# CV Log Loss Score: 0.691140
#
# ----------------- Fold 9 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0420706	test: 1.0407826	best: 1.0407826 (0)	total: 25ms	remaining: 25s
# 100:	learn: 0.7429547	test: 0.7052149	best: 0.7051421 (98)	total: 2.41s	remaining: 21.4s
# 200:	learn: 0.7235244	test: 0.6782906	best: 0.6782906 (200)	total: 4.96s	remaining: 19.7s
# 300:	learn: 0.7167858	test: 0.6723050	best: 0.6722737 (299)	total: 7.4s	remaining: 17.2s
# 400:	learn: 0.7097932	test: 0.6669868	best: 0.6669868 (400)	total: 9.8s	remaining: 14.6s
# 500:	learn: 0.7051963	test: 0.6646058	best: 0.6646057 (498)	total: 12.2s	remaining: 12.2s
# 600:	learn: 0.7012395	test: 0.6636376	best: 0.6636292 (597)	total: 14.8s	remaining: 9.83s
# 700:	learn: 0.6976230	test: 0.6626550	best: 0.6622825 (670)	total: 17.4s	remaining: 7.4s
# 800:	learn: 0.6944690	test: 0.6613334	best: 0.6613008 (794)	total: 19.9s	remaining: 4.96s
# 900:	learn: 0.6919106	test: 0.6608865	best: 0.6607675 (853)	total: 22.5s	remaining: 2.47s
# 999:	learn: 0.6890627	test: 0.6605015	best: 0.6604926 (997)	total: 25.1s	remaining: 0us
#
# bestTest = 0.6604926264
# bestIteration = 997
#
# Shrink model to first 998 iterations.
# CV Log Loss Score: 0.660493
#
# ----------------- Fold 10 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0433805	test: 1.0419504	best: 1.0419504 (0)	total: 34.4ms	remaining: 34.4s
# 100:	learn: 0.7439393	test: 0.6957875	best: 0.6957664 (98)	total: 2.54s	remaining: 22.6s
# 200:	learn: 0.7250912	test: 0.6716192	best: 0.6716192 (200)	total: 5.11s	remaining: 20.3s
# 300:	learn: 0.7154777	test: 0.6640497	best: 0.6640497 (300)	total: 7.54s	remaining: 17.5s
# 400:	learn: 0.7102128	test: 0.6597303	best: 0.6596970 (393)	total: 10s	remaining: 15s
# 500:	learn: 0.7046191	test: 0.6573659	best: 0.6573659 (500)	total: 12.4s	remaining: 12.3s
# 600:	learn: 0.7007934	test: 0.6561737	best: 0.6560887 (591)	total: 14.7s	remaining: 9.76s
# 700:	learn: 0.6977100	test: 0.6551133	best: 0.6551027 (698)	total: 17.1s	remaining: 7.27s
# 800:	learn: 0.6948828	test: 0.6552163	best: 0.6548700 (725)	total: 19.3s	remaining: 4.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6548700242
# bestIteration = 725
#
# Shrink model to first 726 iterations.
# CV Log Loss Score: 0.654870
#
# ----------------- Fold 11 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0441149	test: 1.0454911	best: 1.0454911 (0)	total: 24.9ms	remaining: 24.8s
# 100:	learn: 0.7365150	test: 0.7224985	best: 0.7224678 (98)	total: 2.37s	remaining: 21.1s
# 200:	learn: 0.7236042	test: 0.7081269	best: 0.7081269 (200)	total: 4.7s	remaining: 18.7s
# 300:	learn: 0.7146468	test: 0.7017405	best: 0.7017405 (300)	total: 7.02s	remaining: 16.3s
# 400:	learn: 0.7093257	test: 0.6984849	best: 0.6984849 (400)	total: 9.25s	remaining: 13.8s
# 500:	learn: 0.7038112	test: 0.6954826	best: 0.6954608 (487)	total: 11.6s	remaining: 11.5s
# 600:	learn: 0.7002295	test: 0.6936333	best: 0.6935387 (576)	total: 13.9s	remaining: 9.22s
# 700:	learn: 0.6975085	test: 0.6928706	best: 0.6927866 (691)	total: 16.2s	remaining: 6.89s
# 800:	learn: 0.6935747	test: 0.6918620	best: 0.6916096 (778)	total: 18.5s	remaining: 4.59s
# 900:	learn: 0.6902970	test: 0.6909201	best: 0.6909163 (899)	total: 20.8s	remaining: 2.29s
# 999:	learn: 0.6875348	test: 0.6910048	best: 0.6906759 (922)	total: 23.2s	remaining: 0us
#
# bestTest = 0.6906759111
# bestIteration = 922
#
# Shrink model to first 923 iterations.
# CV Log Loss Score: 0.690676
#
# ----------------- Fold 12 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0391767	test: 1.0383002	best: 1.0383002 (0)	total: 27ms	remaining: 27s
# 100:	learn: 0.7389363	test: 0.6974947	best: 0.6974564 (98)	total: 2.36s	remaining: 21s
# 200:	learn: 0.7228467	test: 0.6770849	best: 0.6770849 (200)	total: 4.73s	remaining: 18.8s
# 300:	learn: 0.7164233	test: 0.6725822	best: 0.6724944 (294)	total: 7.18s	remaining: 16.7s
# 400:	learn: 0.7103312	test: 0.6686183	best: 0.6685903 (394)	total: 9.58s	remaining: 14.3s
# 500:	learn: 0.7053655	test: 0.6661674	best: 0.6660863 (494)	total: 11.8s	remaining: 11.8s
# 600:	learn: 0.7018618	test: 0.6656447	best: 0.6654522 (574)	total: 14.1s	remaining: 9.35s
# 700:	learn: 0.6989093	test: 0.6652114	best: 0.6652114 (700)	total: 16.5s	remaining: 7.03s
# 800:	learn: 0.6956517	test: 0.6643750	best: 0.6643353 (798)	total: 18.8s	remaining: 4.66s
# 900:	learn: 0.6922280	test: 0.6640214	best: 0.6639253 (893)	total: 21.2s	remaining: 2.33s
# 999:	learn: 0.6888162	test: 0.6633888	best: 0.6632558 (979)	total: 23.5s	remaining: 0us
#
# bestTest = 0.6632558171
# bestIteration = 979
#
# Shrink model to first 980 iterations.
# CV Log Loss Score: 0.663256
#
# ----------------- Fold 13 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0338339	test: 1.0320066	best: 1.0320066 (0)	total: 27.2ms	remaining: 27.2s
# 100:	learn: 0.7357840	test: 0.7129899	best: 0.7129899 (97)	total: 2.35s	remaining: 20.9s
# 200:	learn: 0.7196128	test: 0.6999542	best: 0.6998185 (196)	total: 4.69s	remaining: 18.6s
# 300:	learn: 0.7117143	test: 0.6963274	best: 0.6962803 (289)	total: 7.07s	remaining: 16.4s
# 400:	learn: 0.7070491	test: 0.6956566	best: 0.6956474 (365)	total: 9.41s	remaining: 14.1s
# 500:	learn: 0.7031844	test: 0.6952991	best: 0.6950341 (484)	total: 11.6s	remaining: 11.6s
# 600:	learn: 0.6999389	test: 0.6939862	best: 0.6939224 (592)	total: 14s	remaining: 9.3s
# 700:	learn: 0.6960851	test: 0.6937373	best: 0.6930957 (645)	total: 16.5s	remaining: 7.05s
# 800:	learn: 0.6930082	test: 0.6930572	best: 0.6926990 (718)	total: 18.9s	remaining: 4.69s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6926990299
# bestIteration = 718
#
# Shrink model to first 719 iterations.
# CV Log Loss Score: 0.692699
#
# ----------------- Fold 14 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0411456	test: 1.0391454	best: 1.0391454 (0)	total: 30.3ms	remaining: 30.2s
# 100:	learn: 0.7380747	test: 0.6990491	best: 0.6989698 (96)	total: 2.39s	remaining: 21.3s
# 200:	learn: 0.7220568	test: 0.6794906	best: 0.6794504 (199)	total: 4.83s	remaining: 19.2s
# 300:	learn: 0.7151875	test: 0.6741986	best: 0.6741986 (300)	total: 7.35s	remaining: 17.1s
# 400:	learn: 0.7082503	test: 0.6689812	best: 0.6689249 (398)	total: 9.72s	remaining: 14.5s
# 500:	learn: 0.7043422	test: 0.6676598	best: 0.6676457 (498)	total: 12s	remaining: 12s
# 600:	learn: 0.7003696	test: 0.6658514	best: 0.6657786 (572)	total: 14.4s	remaining: 9.55s
# 700:	learn: 0.6958493	test: 0.6641420	best: 0.6641404 (685)	total: 16.8s	remaining: 7.16s
# 800:	learn: 0.6928394	test: 0.6628780	best: 0.6628780 (799)	total: 19.2s	remaining: 4.78s
# 900:	learn: 0.6901480	test: 0.6619728	best: 0.6619728 (900)	total: 21.6s	remaining: 2.37s
# [I 2021-06-13 11:58:24,041] Trial 2 finished with value: 0.672089778045155 and parameters: {'colsample_bylevel': 0.09506074103465388, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.684640072331112}. Best is trial 0 with value: 0.6708670298294468.
# 999:	learn: 0.6872941	test: 0.6622276	best: 0.6615582 (914)	total: 24s	remaining: 0us
#
# bestTest = 0.6615581585
# bestIteration = 914
#
# Shrink model to first 915 iterations.
# CV Log Loss Score: 0.661558
# 	Log Loss: 0.672090

# %%
print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 3
# Best trial:
#   Value: 0.6708670298294468
#   Params:
#     colsample_bylevel: 0.07591531396851062
#     depth: 3
#     boosting_type: Ordered
#     bootstrap_type: MVS

# %%
trial.params
# Out:
# {'colsample_bylevel': 0.07591531396851062,
#  'depth': 3,
#  'boosting_type': 'Ordered',
#  'bootstrap_type': 'MVS'}

# %%
skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
folds=[]
for train_idx, valid_idx in skfold.split(X, y):
        folds.append((train_idx, valid_idx))

cat_pred = np.zeros((X.shape[0], n_class))
cat_pred_test = np.zeros((X_test.shape[0], n_class))
cat_cols = categorical_feats+ ['gender', 'car', 'reality', 'phone', 'email', 'work_phone']
for fold in range(n_fold):
    print(f'\n----------------- Fold {fold} -----------------\n')
    train_idx, valid_idx = folds[fold]
    X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
    train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
    valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

    model_cat = CatBoostClassifier(**trial.params)
    model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=100)

    cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
    cat_pred_test += model_cat.predict_proba(X_test) / n_fold
    print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')
    
print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
# Out:
# ----------------- Fold 0 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501583	test: 1.0503820	best: 1.0503820 (0)	total: 19.2ms	remaining: 19.2s
# 100:	learn: 0.7313911	test: 0.6861480	best: 0.6861477 (98)	total: 1.65s	remaining: 14.7s
# 200:	learn: 0.7188599	test: 0.6692676	best: 0.6692675 (199)	total: 3.28s	remaining: 13s
# 300:	learn: 0.7153297	test: 0.6668464	best: 0.6668155 (294)	total: 4.92s	remaining: 11.4s
# 400:	learn: 0.7119636	test: 0.6647809	best: 0.6647809 (400)	total: 6.5s	remaining: 9.71s
# 500:	learn: 0.7094833	test: 0.6641824	best: 0.6641638 (491)	total: 8.16s	remaining: 8.13s
# 600:	learn: 0.7068466	test: 0.6624817	best: 0.6624817 (600)	total: 9.85s	remaining: 6.54s
# 700:	learn: 0.7043704	test: 0.6623856	best: 0.6622581 (634)	total: 11.6s	remaining: 4.97s
# 800:	learn: 0.7023935	test: 0.6616710	best: 0.6616710 (800)	total: 13.4s	remaining: 3.34s
# 900:	learn: 0.7002756	test: 0.6614710	best: 0.6613624 (810)	total: 15.1s	remaining: 1.66s
# 999:	learn: 0.6982415	test: 0.6612920	best: 0.6611881 (982)	total: 16.8s	remaining: 0us
#
# bestTest = 0.6611880784
# bestIteration = 982
#
# Shrink model to first 983 iterations.
# CV Log Loss Score: 0.661188
#
# ----------------- Fold 1 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501466	test: 1.0503584	best: 1.0503584 (0)	total: 18.1ms	remaining: 18.1s
# 100:	learn: 0.7424275	test: 0.7002976	best: 0.7002975 (99)	total: 1.63s	remaining: 14.5s
# 200:	learn: 0.7226475	test: 0.6696878	best: 0.6696135 (195)	total: 3.2s	remaining: 12.7s
# 300:	learn: 0.7176641	test: 0.6636831	best: 0.6636831 (300)	total: 4.81s	remaining: 11.2s
# 400:	learn: 0.7135140	test: 0.6600903	best: 0.6600903 (400)	total: 6.51s	remaining: 9.72s
# 500:	learn: 0.7105291	test: 0.6587681	best: 0.6585784 (484)	total: 8.22s	remaining: 8.19s
# 600:	learn: 0.7083657	test: 0.6579538	best: 0.6579374 (599)	total: 9.81s	remaining: 6.51s
# 700:	learn: 0.7057885	test: 0.6563968	best: 0.6563115 (694)	total: 11.4s	remaining: 4.86s
# 800:	learn: 0.7038604	test: 0.6561568	best: 0.6557645 (734)	total: 13s	remaining: 3.24s
# 900:	learn: 0.7020196	test: 0.6552465	best: 0.6551994 (898)	total: 14.6s	remaining: 1.6s
# 999:	learn: 0.6998855	test: 0.6544077	best: 0.6543406 (995)	total: 16.2s	remaining: 0us
#
# bestTest = 0.6543405691
# bestIteration = 995
#
# Shrink model to first 996 iterations.
# CV Log Loss Score: 0.654341
#
# ----------------- Fold 2 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501669	test: 1.0503401	best: 1.0503401 (0)	total: 20.9ms	remaining: 20.9s
# 100:	learn: 0.7345633	test: 0.6913439	best: 0.6912735 (98)	total: 1.64s	remaining: 14.6s
# 200:	learn: 0.7220170	test: 0.6717500	best: 0.6717183 (189)	total: 3.29s	remaining: 13.1s
# 300:	learn: 0.7166295	test: 0.6665607	best: 0.6665607 (300)	total: 4.9s	remaining: 11.4s
# 400:	learn: 0.7124151	test: 0.6628830	best: 0.6628706 (398)	total: 6.49s	remaining: 9.69s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6628706156
# bestIteration = 398
#
# Shrink model to first 399 iterations.
# CV Log Loss Score: 0.662871
#
# ----------------- Fold 3 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501813	test: 1.0500742	best: 1.0500742 (0)	total: 22.7ms	remaining: 22.7s
# 100:	learn: 0.7302094	test: 0.7044774	best: 0.7044774 (100)	total: 1.86s	remaining: 16.6s
# 200:	learn: 0.7184921	test: 0.6895662	best: 0.6895662 (200)	total: 3.57s	remaining: 14.2s
# 300:	learn: 0.7142970	test: 0.6865623	best: 0.6865429 (299)	total: 5.45s	remaining: 12.7s
# 400:	learn: 0.7109189	test: 0.6844904	best: 0.6844440 (396)	total: 7.24s	remaining: 10.8s
# 500:	learn: 0.7083918	test: 0.6844485	best: 0.6842648 (482)	total: 9.03s	remaining: 8.99s
# 600:	learn: 0.7058353	test: 0.6841146	best: 0.6840465 (560)	total: 10.9s	remaining: 7.23s
# 700:	learn: 0.7034073	test: 0.6838576	best: 0.6835471 (653)	total: 12.8s	remaining: 5.46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6835471471
# bestIteration = 653
#
# Shrink model to first 654 iterations.
# CV Log Loss Score: 0.683547
#
# ----------------- Fold 4 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501587	test: 1.0503862	best: 1.0503862 (0)	total: 21.2ms	remaining: 21.2s
# 100:	learn: 0.7368896	test: 0.7088672	best: 0.7088672 (100)	total: 1.97s	remaining: 17.6s
# 200:	learn: 0.7203489	test: 0.6842355	best: 0.6842169 (197)	total: 3.86s	remaining: 15.3s
# 300:	learn: 0.7145205	test: 0.6790148	best: 0.6788771 (299)	total: 5.74s	remaining: 13.3s
# 400:	learn: 0.7105711	test: 0.6758812	best: 0.6758808 (396)	total: 7.57s	remaining: 11.3s
# 500:	learn: 0.7078922	test: 0.6741974	best: 0.6741974 (500)	total: 9.52s	remaining: 9.48s
# 600:	learn: 0.7052371	test: 0.6735498	best: 0.6735345 (598)	total: 11.4s	remaining: 7.57s
# 700:	learn: 0.7032029	test: 0.6727093	best: 0.6726554 (693)	total: 13.3s	remaining: 5.66s
# 800:	learn: 0.7010413	test: 0.6720595	best: 0.6719745 (799)	total: 15.1s	remaining: 3.75s
# 900:	learn: 0.6988750	test: 0.6716296	best: 0.6716123 (897)	total: 16.9s	remaining: 1.86s
# 999:	learn: 0.6969963	test: 0.6712465	best: 0.6710737 (954)	total: 19s	remaining: 0us
#
# bestTest = 0.6710736575
# bestIteration = 954
#
# Shrink model to first 955 iterations.
# CV Log Loss Score: 0.671074
#
# ----------------- Fold 5 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501588	test: 1.0503279	best: 1.0503279 (0)	total: 30.8ms	remaining: 30.7s
# 100:	learn: 0.7398101	test: 0.7050906	best: 0.7050906 (100)	total: 2.03s	remaining: 18.1s
# 200:	learn: 0.7241056	test: 0.6849346	best: 0.6849140 (198)	total: 3.96s	remaining: 15.7s
# 300:	learn: 0.7179238	test: 0.6771711	best: 0.6771683 (299)	total: 5.89s	remaining: 13.7s
# 400:	learn: 0.7126561	test: 0.6737284	best: 0.6737284 (400)	total: 7.79s	remaining: 11.6s
# 500:	learn: 0.7093137	test: 0.6716590	best: 0.6716454 (497)	total: 9.76s	remaining: 9.72s
# 600:	learn: 0.7070872	test: 0.6719370	best: 0.6715380 (548)	total: 11.7s	remaining: 7.78s
# 700:	learn: 0.7047278	test: 0.6712640	best: 0.6711113 (693)	total: 13.6s	remaining: 5.8s
# 800:	learn: 0.7023324	test: 0.6708302	best: 0.6708302 (800)	total: 15.6s	remaining: 3.87s
# 900:	learn: 0.7003631	test: 0.6710729	best: 0.6706906 (816)	total: 17.4s	remaining: 1.92s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.670690551
# bestIteration = 816
#
# Shrink model to first 817 iterations.
# CV Log Loss Score: 0.670691
#
# ----------------- Fold 6 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501719	test: 1.0502513	best: 1.0502513 (0)	total: 19.7ms	remaining: 19.7s
# 100:	learn: 0.7334195	test: 0.7071044	best: 0.7071044 (100)	total: 1.91s	remaining: 17s
# 200:	learn: 0.7198263	test: 0.6920226	best: 0.6920207 (199)	total: 3.73s	remaining: 14.8s
# 300:	learn: 0.7147336	test: 0.6884693	best: 0.6884693 (300)	total: 5.62s	remaining: 13.1s
# 400:	learn: 0.7106701	test: 0.6852931	best: 0.6852931 (400)	total: 7.51s	remaining: 11.2s
# 500:	learn: 0.7082006	test: 0.6849085	best: 0.6848618 (497)	total: 9.43s	remaining: 9.39s
# 600:	learn: 0.7057425	test: 0.6847195	best: 0.6846746 (595)	total: 11.3s	remaining: 7.52s
# 700:	learn: 0.7033662	test: 0.6837547	best: 0.6837274 (696)	total: 13.3s	remaining: 5.66s
# 800:	learn: 0.7013574	test: 0.6838036	best: 0.6836163 (702)	total: 15.2s	remaining: 3.79s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6836162944
# bestIteration = 702
#
# Shrink model to first 703 iterations.
# CV Log Loss Score: 0.683616
#
# ----------------- Fold 7 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501701	test: 1.0502129	best: 1.0502129 (0)	total: 26ms	remaining: 26s
# 100:	learn: 0.7356077	test: 0.7019598	best: 0.7019598 (100)	total: 1.92s	remaining: 17.1s
# 200:	learn: 0.7206145	test: 0.6818434	best: 0.6818434 (200)	total: 3.86s	remaining: 15.4s
# 300:	learn: 0.7149237	test: 0.6768765	best: 0.6768765 (300)	total: 5.73s	remaining: 13.3s
# 400:	learn: 0.7108003	test: 0.6741980	best: 0.6741393 (396)	total: 7.78s	remaining: 11.6s
# 500:	learn: 0.7082716	test: 0.6737631	best: 0.6737631 (500)	total: 9.83s	remaining: 9.79s
# 600:	learn: 0.7059876	test: 0.6738697	best: 0.6735090 (576)	total: 11.8s	remaining: 7.82s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6735089502
# bestIteration = 576
#
# Shrink model to first 577 iterations.
# CV Log Loss Score: 0.673509
#
# ----------------- Fold 8 -----------------
# Learning rate set to 0.115128
# 0:	learn: 1.0501767	test: 1.0501851	best: 1.0501851 (0)	total: 21ms	remaining: 21s
# 100:	learn: 0.7343519	test: 0.7128669	best: 0.7128608 (97)	total: 2s	remaining: 17.8s
# 200:	learn: 0.7203634	test: 0.6976482	best: 0.6975920 (198)	total: 4.02s	remaining: 16s
# 300:	learn: 0.7133846	test: 0.6908183	best: 0.6908183 (300)	total: 6.07s	remaining: 14.1s
# 400:	learn: 0.7096286	test: 0.6877630	best: 0.6877629 (399)	total: 8.1s	remaining: 12.1s
# 500:	learn: 0.7069707	test: 0.6868629	best: 0.6867451 (486)	total: 10.2s	remaining: 10.1s
# 600:	learn: 0.7049741	test: 0.6863671	best: 0.6861828 (595)	total: 12.2s	remaining: 8.11s
# 700:	learn: 0.7022152	test: 0.6849481	best: 0.6848529 (696)	total: 14.3s	remaining: 6.1s
# 800:	learn: 0.6998803	test: 0.6839656	best: 0.6839514 (798)	total: 16.3s	remaining: 4.06s
# 900:	learn: 0.6982440	test: 0.6839153	best: 0.6837768 (878)	total: 18.4s	remaining: 2.02s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6837767631
# bestIteration = 878
#
# Shrink model to first 879 iterations.
# CV Log Loss Score: 0.683777
#
# ----------------- Fold 9 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501506	test: 1.0504175	best: 1.0504175 (0)	total: 25.6ms	remaining: 25.6s
# 100:	learn: 0.7385682	test: 0.6968718	best: 0.6968718 (100)	total: 2.09s	remaining: 18.6s
# 200:	learn: 0.7210738	test: 0.6731691	best: 0.6731691 (200)	total: 4.13s	remaining: 16.4s
# 300:	learn: 0.7157004	test: 0.6680580	best: 0.6679093 (296)	total: 6.19s	remaining: 14.4s
# 400:	learn: 0.7120361	test: 0.6648136	best: 0.6648136 (400)	total: 8.39s	remaining: 12.5s
# 500:	learn: 0.7093758	test: 0.6641689	best: 0.6639349 (490)	total: 10.5s	remaining: 10.4s
# 600:	learn: 0.7070983	test: 0.6636216	best: 0.6636216 (600)	total: 12.5s	remaining: 8.29s
# 700:	learn: 0.7048074	test: 0.6622646	best: 0.6622561 (697)	total: 14.5s	remaining: 6.18s
# 800:	learn: 0.7025492	test: 0.6611885	best: 0.6611673 (799)	total: 16.6s	remaining: 4.12s
# 900:	learn: 0.7007212	test: 0.6611344	best: 0.6608209 (848)	total: 18.5s	remaining: 2.04s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6608208972
# bestIteration = 848
#
# Shrink model to first 849 iterations.
# CV Log Loss Score: 0.660821
#
# ----------------- Fold 10 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501542	test: 1.0503543	best: 1.0503543 (0)	total: 24.6ms	remaining: 24.6s
# 100:	learn: 0.7408850	test: 0.6907328	best: 0.6906595 (99)	total: 1.99s	remaining: 17.7s
# 200:	learn: 0.7246078	test: 0.6664485	best: 0.6664485 (200)	total: 3.85s	remaining: 15.3s
# 300:	learn: 0.7182174	test: 0.6611824	best: 0.6611824 (300)	total: 5.84s	remaining: 13.6s
# 400:	learn: 0.7140562	test: 0.6587113	best: 0.6587113 (400)	total: 7.84s	remaining: 11.7s
# 500:	learn: 0.7105142	test: 0.6569149	best: 0.6568200 (477)	total: 9.72s	remaining: 9.68s
# 600:	learn: 0.7079923	test: 0.6564722	best: 0.6564212 (592)	total: 11.6s	remaining: 7.67s
# 700:	learn: 0.7052801	test: 0.6553125	best: 0.6550374 (684)	total: 13.5s	remaining: 5.74s
# 800:	learn: 0.7025883	test: 0.6546117	best: 0.6544873 (782)	total: 15.3s	remaining: 3.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6544872999
# bestIteration = 782
#
# Shrink model to first 783 iterations.
# CV Log Loss Score: 0.654487
#
# ----------------- Fold 11 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0501611	test: 1.0502162	best: 1.0502162 (0)	total: 21.4ms	remaining: 21.4s
# 100:	learn: 0.7327471	test: 0.7122838	best: 0.7122838 (100)	total: 1.95s	remaining: 17.3s
# 200:	learn: 0.7198522	test: 0.6977761	best: 0.6977761 (200)	total: 3.79s	remaining: 15.1s
# 300:	learn: 0.7131510	test: 0.6917429	best: 0.6916909 (296)	total: 5.69s	remaining: 13.2s
# 400:	learn: 0.7096702	test: 0.6901427	best: 0.6899319 (391)	total: 7.57s	remaining: 11.3s
# 500:	learn: 0.7068384	test: 0.6897204	best: 0.6897204 (500)	total: 9.55s	remaining: 9.51s
# 600:	learn: 0.7045569	test: 0.6890404	best: 0.6890394 (599)	total: 11.4s	remaining: 7.6s
# 700:	learn: 0.7023378	test: 0.6885654	best: 0.6885540 (689)	total: 13.4s	remaining: 5.7s
# 800:	learn: 0.7003171	test: 0.6880194	best: 0.6879914 (798)	total: 15.3s	remaining: 3.79s
# 900:	learn: 0.6985469	test: 0.6886749	best: 0.6879860 (806)	total: 17.1s	remaining: 1.88s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6879859915
# bestIteration = 806
#
# Shrink model to first 807 iterations.
# CV Log Loss Score: 0.687986
#
# ----------------- Fold 12 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0419785	test: 1.0413148	best: 1.0413148 (0)	total: 20.1ms	remaining: 20.1s
# 100:	learn: 0.7315819	test: 0.6835030	best: 0.6835030 (100)	total: 1.97s	remaining: 17.6s
# 200:	learn: 0.7215124	test: 0.6694773	best: 0.6694773 (200)	total: 3.92s	remaining: 15.6s
# 300:	learn: 0.7170217	test: 0.6660625	best: 0.6660625 (300)	total: 5.91s	remaining: 13.7s
# 400:	learn: 0.7136354	test: 0.6635483	best: 0.6633122 (382)	total: 7.92s	remaining: 11.8s
# 500:	learn: 0.7107726	test: 0.6619907	best: 0.6619080 (489)	total: 9.89s	remaining: 9.85s
# 600:	learn: 0.7084301	test: 0.6619705	best: 0.6618411 (525)	total: 11.8s	remaining: 7.85s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6618410558
# bestIteration = 525
#
# Shrink model to first 526 iterations.
# CV Log Loss Score: 0.661841
#
# ----------------- Fold 13 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0419293	test: 1.0419589	best: 1.0419589 (0)	total: 21ms	remaining: 21s
# 100:	learn: 0.7342348	test: 0.7129789	best: 0.7129789 (100)	total: 1.97s	remaining: 17.6s
# 200:	learn: 0.7207501	test: 0.7008264	best: 0.7008264 (200)	total: 3.94s	remaining: 15.7s
# 300:	learn: 0.7136737	test: 0.6947331	best: 0.6946609 (297)	total: 5.92s	remaining: 13.7s
# 400:	learn: 0.7094844	test: 0.6916206	best: 0.6916206 (400)	total: 7.85s	remaining: 11.7s
# 500:	learn: 0.7067844	test: 0.6918770	best: 0.6909250 (423)	total: 9.82s	remaining: 9.78s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6909249932
# bestIteration = 423
#
# Shrink model to first 424 iterations.
# CV Log Loss Score: 0.690925
#
# ----------------- Fold 14 -----------------
#
# Learning rate set to 0.115128
# 0:	learn: 1.0419887	test: 1.0409443	best: 1.0409443 (0)	total: 29.5ms	remaining: 29.5s
# 100:	learn: 0.7373319	test: 0.6942109	best: 0.6942109 (100)	total: 1.95s	remaining: 17.3s
# 200:	learn: 0.7207267	test: 0.6732348	best: 0.6732242 (199)	total: 4.01s	remaining: 16s
# 300:	learn: 0.7145091	test: 0.6672805	best: 0.6672805 (300)	total: 6.01s	remaining: 14s
# 400:	learn: 0.7111609	test: 0.6660585	best: 0.6660585 (400)	total: 7.97s	remaining: 11.9s
# 500:	learn: 0.7085798	test: 0.6653797	best: 0.6653050 (498)	total: 9.9s	remaining: 9.86s
# 600:	learn: 0.7061083	test: 0.6642431	best: 0.6642431 (600)	total: 11.9s	remaining: 7.9s
# 700:	learn: 0.7039429	test: 0.6638316	best: 0.6638128 (699)	total: 13.9s	remaining: 5.92s
# 800:	learn: 0.7008034	test: 0.6630574	best: 0.6628624 (778)	total: 15.9s	remaining: 3.96s
# 900:	learn: 0.6990165	test: 0.6627187	best: 0.6626626 (899)	total: 17.8s	remaining: 1.96s
# 999:	learn: 0.6968355	test: 0.6624694	best: 0.6623340 (925)	total: 19.7s	remaining: 0us
#
# bestTest = 0.6623340001
# bestIteration = 925
#
# Shrink model to first 926 iterations.
# CV Log Loss Score: 0.662334
# 	Log Loss: 0.670867

# %%
def plot_feature_importance(importance,names,model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')

plot_feature_importance(model_cat.get_feature_importance(),X_test.columns,'CATBOOST')

# %%
for i in range(3):
    submit[str(i)] = cat_pred_test[:,i]

# %%
submit.to_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/preprocessing/catboost_basic+optuna.csv', index = False)
