# %%
# import modules
import warnings
warnings.filterwarnings('ignore')

import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import lightgbm as lgb
from catboost import CatBoostClassifier, Pool
import optuna
from optuna.samplers import TPESampler

from sklearn.model_selection import StratifiedKFold, KFold, train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, minmax_scale
from sklearn.metrics import confusion_matrix, log_loss, f1_score

import random
from math import floor
from scipy.stats import mode, scoreatpercentile

print("Seaborn version : ", sns.__version__)
sns.set()
#sns.set_style('whitegrid')
sns.set_color_codes()
sns.set_theme(style="ticks", palette="pastel")



# upload data
train = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/train.csv',index_col=0)
test = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/test.csv',index_col=0)
submit = pd.read_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/sample_submission.csv')
# Out:
# Seaborn version :  0.11.1

# %%
# defs
def show_4digits(x) : 
    return str(x)[:3]

# %%
# outliers
train.drop((train[train['child_num']>=6]).index, inplace = True)

# %%
for df in [train, test] : 
    # no information
    df.drop('FLAG_MOBIL',axis = 1, inplace = True)

    # negative to positive
    df['DAYS_BIRTH'] = -df['DAYS_BIRTH']
    df['DAYS_EMPLOYED'] = -df['DAYS_EMPLOYED']
    df['begin_month'] = -df['begin_month']

    # handling the missing values
    ## occyp_type == NaN
    df['occyp_type'] = df.occyp_type.fillna('missing')
    df.loc[(df.DAYS_EMPLOYED == -365243)&(df.occyp_type.isna()), 'occyp_type'] = 'in_occyp'
    ## DAYS_EMPLOYED == 365243
    df['DAYS_EMPLOYED'][df['DAYS_EMPLOYED'] == -365243] = 0

# %%
for df in [train, test] : 
    # personal_id
    df['personal_id']= \
    df['gender']+\
    df['car']+\
    df['income_total'].apply(lambda x: str(int(x)).zfill(7))+\
    df['edu_type'].apply(show_4digits)+\
    df['family_type'].apply(show_4digits)+\
    df['house_type'].apply(show_4digits)+\
    df['DAYS_BIRTH'].apply(lambda x: str(x).zfill(5))+\
    df['DAYS_EMPLOYED'].apply(lambda x: str(x).zfill(5))+\
    df['occyp_type'].apply(show_4digits)

    # 재산, 연락처에 관한 정보들을 묶어서 분류
    df['group_property'] = df['car'].astype(str)   + df['reality'].astype(str)
    df['group_contacts'] = df['phone'].astype(str) + df['work_phone'].astype(str) + df['email'].astype(str)
    df['group_whoare_u'] = df['gender'].astype(str)+ df['family_type'].astype(str)
    df['group_your_job'] = df['income_type'] +'_'+ df['occyp_type']

# %%
for df in [train, test] : 
    # 현재 하고 있는 일을 시작하게 된 나이(날짜) = 일을 하지 않았던 기간 
    df['DAYS_nowork'] = df['DAYS_BIRTH'] - df['DAYS_EMPLOYED']

    # 가족 수와 관련된 변수
    df['adult_num'] = df['family_size'] - df['child_num']
    df.loc[df.child_num >= 5, 'child_num'] = 5
    df.loc[df.child_num >= 5, 'family_size'] = df.loc[df.child_num >= 5, 'child_num'] + df.loc[df.child_num >= 5, 'adult_num']

    # 소득과 관련된 변수와 조합
    df['income_per_child'] = df['income_total']/ df['child_num']  #소득을 아이 수로 나눠 각 아이에게 할당 될 수 있는 금액을 계산 
    df['income_per_family']= df['income_total']/ df['family_size']#소득을 가족 수로 나눠 각 인원에게 할당 될 수 있는 금액을 계산
    df['income_per_age']   = df['income_total']/ df['DAYS_BIRTH'] #소득을 나이로 나눠 나이 대비 얼마나 버는지에 대한 지표 생성

    # 로그 변환(income_total)
    df['income_total_log'] = np.log(df['income_total']+1)

    # 날짜표기 변환(begin_month) : 4로 나누어 계절로 분할
    df['begin_season'] = df['begin_month'].apply(lambda x: floor(x/4))

    # 날짜표기 변환(DAYS_EMPLOYED) : 개월로 binning
    df['mm_EMPLOYED'] = df['DAYS_EMPLOYED'].apply(lambda x: floor(x/30.4375))

    # 날쨔 표기 변환(DAYS_EMPLOYED): 연차로 binning
    df['yy_EMPLOYED'] = df['DAYS_EMPLOYED'].apply(lambda x: floor(x/365.25))

# %%
personal_info = train.drop(['credit', 'begin_month'], axis = 1).drop_duplicates(subset='personal_id', keep='first', inplace=False, ignore_index=True)

F, F_birth_labels = pd.qcut(personal_info.DAYS_BIRTH[personal_info.gender == 'F'], q = 20, retbins=True)
M, M_birth_labels = pd.qcut(personal_info.DAYS_BIRTH[personal_info.gender == 'M'], q = 20, retbins=True)
F_birth_labels.put(0, F_birth_labels[0]-.001)
M_birth_labels.put(0, M_birth_labels[0]-.001)


personal_info['age_F_bins'] = F
personal_info['n_F_age'] = personal_info.groupby('age_F_bins').gender.count()
personal_info['age_M_bins'] = M
personal_info['n_M_age'] = personal_info.groupby('age_M_bins').gender.count()

personal_info['income_mean_F_age']  = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = F_birth_labels), 'gender']).income_total.transform(np.mean)
personal_info['income_mean_M_age']  = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = M_birth_labels), 'gender']).income_total.transform(np.mean)
personal_info['income_std_F_age']   = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = F_birth_labels), 'gender']).income_total.transform(np.std)
personal_info['income_std_M_age']   = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = M_birth_labels), 'gender']).income_total.transform(np.std)

personal_info['employed_mean_F_age']= personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = F_birth_labels), 'gender']).DAYS_EMPLOYED.transform(np.mean)
personal_info['employed_mean_M_age']= personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = M_birth_labels), 'gender']).DAYS_EMPLOYED.transform(np.mean)
personal_info['employed_std_F_age'] = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = F_birth_labels), 'gender']).DAYS_EMPLOYED.transform(np.std)
personal_info['employed_std_M_age'] = personal_info.groupby([pd.cut(personal_info.DAYS_BIRTH, bins = M_birth_labels), 'gender']).DAYS_EMPLOYED.transform(np.std)

F_age_info = personal_info.groupby('age_F_bins')[['income_mean_F_age', 'income_std_F_age', 'employed_mean_F_age', 'employed_std_F_age', 'n_F_age']].apply(np.mean)
M_age_info = personal_info.groupby('age_M_bins')[['income_mean_M_age', 'income_std_M_age', 'employed_mean_M_age', 'employed_std_M_age', 'n_M_age']].apply(np.mean)

# %%
pre_ = test.DAYS_BIRTH.iloc[6031]
test.DAYS_BIRTH.iloc[6031] = 7757

for df in [train, test]:
    df['age_F_bins'] = pd.cut(df.DAYS_BIRTH, bins = F_birth_labels)
    df['age_M_bins'] = pd.cut(df.DAYS_BIRTH, bins = M_birth_labels)

#예외 발생(test)
test.DAYS_BIRTH.iloc[6031] = pre_

train = pd.merge(train, F_age_info, how = 'left', on = 'age_F_bins')
train = pd.merge(train, M_age_info, how = 'left', on = 'age_M_bins')
test = pd.merge(test, F_age_info, how = 'left', on = 'age_F_bins')
test = pd.merge(test, M_age_info, how = 'left', on = 'age_M_bins')

for df in [train, test]:
    df['ability_income_per_age_by_gen'] = 0
    df['ability_income_per_age_by_gen'][df.gender == 'F'] = ((df['income_total'] - df['income_mean_F_age'])/(df['income_std_F_age']/df['n_F_age'].apply(np.sqrt)))[df.gender == 'F']
    df['ability_income_per_age_by_gen'][df.gender == 'M'] = ((df['income_total'] - df['income_mean_M_age'])/(df['income_std_M_age']/df['n_M_age'].apply(np.sqrt)))[df.gender == 'M']
    df['ability_emp_per_age_by_gen'] = 0
    df['ability_emp_per_age_by_gen'][df.gender == 'F'] = ((df['DAYS_EMPLOYED'] - df['employed_mean_F_age'])/(df['employed_std_F_age']/df['n_F_age'].apply(np.sqrt)))[df.gender == 'F']
    df['ability_emp_per_age_by_gen'][df.gender == 'M'] = ((df['DAYS_EMPLOYED'] - df['employed_mean_M_age'])/(df['employed_std_M_age']/df['n_M_age'].apply(np.sqrt)))[df.gender == 'M']

# %%
drop_list = [#'income_total', 
             'age_F_bins', 'age_M_bins', 
             'income_mean_F_age', 'income_std_F_age', 'employed_mean_F_age', 'employed_std_F_age', 'n_F_age',
             'income_mean_M_age', 'income_std_M_age', 'employed_mean_M_age', 'employed_std_M_age', 'n_M_age', 
            ]

for df in [train, test]:
    df.drop(drop_list, axis = 1, inplace = True)

# %%
one_child_fee = (personal_info.income_total/personal_info.family_size)[(personal_info.DAYS_BIRTH > 33*365) & (personal_info.DAYS_BIRTH < 37*365) & (personal_info.child_num == 1)].mean()

# %%
# 부모의 학력이 올라갈 수록 자녀에 투자하는 금액이 많을것이다.
# 버는 만큼? => 소득 수준
# 아이의 수 만큼?
# 부모의 나이 만큼?

# 부모의 학력에 대한 가중치 * 아이의 수 가중치 * 부모의 나이 가중치* 부모의 소득 가중치
# merge형태(모수가 있다.)
#personal_info['weight_edu'] = personal_info.groupby('edu_type').income_total.transform(np.mean)
# 함수 형태(모수는 없음.) => 데이터에 직접 적용
#personal_info['weight_chd'] = personal_info['child_num'].transform(lambda x: np.log(1+x)/np.log(2))
#personal_info['weight_age'] = personal_info['']

# %%
df_weight_edu = personal_info.groupby('edu_type').income_total.apply(np.mean)#.reset_index()
df_weight_edu.name = 'weight_edu'
df_weight_edu = df_weight_edu.reset_index()

# %%
from scipy.stats import norm

# %%
# car fee
def car_weight(x, loc_par_car):
    _max = personal_info.income_total.max()
    _med = loc_par_car
    if x < _med : 
        return 1
    else:
        return 1+(x-_med)/(_max-_med)*5

# %%
n_fold = 5
n_class = 3

def objective(trial):
            
    d_age_std = trial.suggest_float("d_age_std", 5, 8)
    d_age_mu = trial.suggest_float("d_age_mu", 34, 36)
    weight_c = trial.suggest_float("weight_c", 1.3, 1.7)
    weight_b = trial.suggest_float("weight_b", 0.1, 2)
    loc_par_car = trial.suggest_int("loc_par_car", 127500.0, 187500.0)

    train_money = pd.merge(train, df_weight_edu, how = 'left', on = 'edu_type') # 'weight_edu'
    train_money['weight_chd'] = train_money['child_num'].transform(lambda x: np.log(1+x)/np.log(2))
    train_money['weight_age'] = train_money['DAYS_BIRTH'].transform(lambda x: norm(d_age_mu, scale = d_age_std).pdf((x/365.25))/norm(d_age_mu, scale = d_age_std).pdf(d_age_mu))
    train_money['child_fee_total'] = one_child_fee*train_money['weight_edu']*train_money['weight_chd']*train_money['weight_age']
    train_money['car_fees_total'] = train_money.income_total.median()*0.1*(train_money.car == 'Y').astype('int')*train_money.income_total.apply(lambda x: car_weight(x, loc_par_car))
    train_money['save_income'] = train_money['income_total'] - weight_c*train_money['child_fee_total'] - weight_b*train_money['car_fees_total']
    train_money.drop(['weight_edu', 'weight_chd', 'weight_age', 'child_fee_total', 'car_fees_total'], axis = 1, inplace = True)
    
    numerical_feats = train_money.dtypes[train_money.dtypes != "object"].index.tolist()
    categorical_feats = train_money.dtypes[train_money.dtypes == "object"].index.tolist()
    
    target = 'credit'
    X_money = train_money.drop(target, axis=1)
    y_money = train_money[target]

    cat_pred = np.zeros((X_money.shape[0], n_class))
    cat_cols = categorical_feats
    
    skfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=55)
    folds=[]
    for train_idx, valid_idx in skfold.split(X_money, y_money):
            folds.append((train_idx, valid_idx))


    # 5Fold-CV (StratifiedKFold)
    for fold in range(len(folds)):
        print(f'\n----------------- Fold {fold+1} -----------------\n')
        train_idx, valid_idx = folds[fold]
        X_train, X_valid, y_train, y_valid = X_money.iloc[train_idx], X_money.iloc[valid_idx], y_money.iloc[train_idx], y_money.iloc[valid_idx]
        train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        model_cat = CatBoostClassifier(max_depth=8, random_seed=42,
                                       learning_rate=0.1, 
                                       bootstrap_type ='Bernoulli',
                                       used_ram_limit ="8gb",
                                      )
        model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=50, verbose=100)

        cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
        print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')

    print(f'\tLog Loss: {log_loss(y_money, cat_pred):.6f}')
    return log_loss(y_money, cat_pred)

# %%
money_weight_study = optuna.create_study(direction="minimize")
money_weight_study.optimize(objective, n_trials=50)
# Out:
# [I 2021-06-19 22:00:31,994] A new study created in memory with name: no-name-479c902f-9fd3-4b03-b7f6-90691334b960
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 15.3ms	remaining: 15.3s
# 100:	learn: 0.6961838	test: 0.6777607	best: 0.6777491 (99)	total: 4.24s	remaining: 37.8s
# 200:	learn: 0.6561606	test: 0.6724926	best: 0.6724041 (198)	total: 9.23s	remaining: 36.7s
# 300:	learn: 0.6173495	test: 0.6720756	best: 0.6714871 (285)	total: 14.8s	remaining: 34.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6714871493
# bestIteration = 285
#
# Shrink model to first 286 iterations.
# CV Log Loss Score: 0.671487
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429140	test: 1.0431616	best: 1.0431616 (0)	total: 37.3ms	remaining: 37.3s
# 100:	learn: 0.6973563	test: 0.6714851	best: 0.6714851 (100)	total: 4.28s	remaining: 38.1s
# 200:	learn: 0.6621481	test: 0.6697619	best: 0.6694670 (152)	total: 9.84s	remaining: 39.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6694669505
# bestIteration = 152
#
# Shrink model to first 153 iterations.
# CV Log Loss Score: 0.669467
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0435074	test: 1.0426950	best: 1.0426950 (0)	total: 53.5ms	remaining: 53.4s
# 100:	learn: 0.6976910	test: 0.6554075	best: 0.6554075 (100)	total: 4.39s	remaining: 39s
# 200:	learn: 0.6610667	test: 0.6522774	best: 0.6522545 (199)	total: 10s	remaining: 39.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6520815583
# bestIteration = 210
#
# Shrink model to first 211 iterations.
# CV Log Loss Score: 0.652082
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432414	test: 1.0439126	best: 1.0439126 (0)	total: 52.6ms	remaining: 52.5s
# 100:	learn: 0.6954120	test: 0.6774054	best: 0.6773964 (90)	total: 4.48s	remaining: 39.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6764415855
# bestIteration = 116
#
# Shrink model to first 117 iterations.
# CV Log Loss Score: 0.676442
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432632	test: 1.0439168	best: 1.0439168 (0)	total: 53.9ms	remaining: 53.8s
# 100:	learn: 0.6947788	test: 0.6780610	best: 0.6777204 (92)	total: 4.64s	remaining: 41.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.67638379
# bestIteration = 148
#
# Shrink model to first 149 iterations.
# CV Log Loss Score: 0.676384
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0433753	test: 1.0433838	best: 1.0433838 (0)	total: 57.2ms	remaining: 57.1s
# 100:	learn: 0.6975172	test: 0.6666518	best: 0.6665780 (99)	total: 4.53s	remaining: 40.3s
# 200:	learn: 0.6618935	test: 0.6632475	best: 0.6632328 (199)	total: 10.5s	remaining: 41.7s
# 300:	learn: 0.6260854	test: 0.6619458	best: 0.6619237 (264)	total: 16.6s	remaining: 38.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6619236703
# bestIteration = 264
#
# Shrink model to first 265 iterations.
# CV Log Loss Score: 0.661924
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433384	test: 1.0435168	best: 1.0435168 (0)	total: 62.9ms	remaining: 1m 2s
# 100:	learn: 0.6944756	test: 0.6649873	best: 0.6649813 (99)	total: 5.59s	remaining: 49.8s
# 200:	learn: 0.6584701	test: 0.6638331	best: 0.6637278 (157)	total: 12s	remaining: 47.8s
# 300:	learn: 0.6211505	test: 0.6603962	best: 0.6603906 (299)	total: 18.3s	remaining: 42.4s
# 400:	learn: 0.5852137	test: 0.6611637	best: 0.6600734 (358)	total: 24.5s	remaining: 36.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6600733594
# bestIteration = 358
#
# Shrink model to first 359 iterations.
# CV Log Loss Score: 0.660073
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433375	test: 1.0436764	best: 1.0436764 (0)	total: 59.6ms	remaining: 59.6s
# 100:	learn: 0.6956510	test: 0.6613196	best: 0.6613196 (100)	total: 5.31s	remaining: 47.2s
# 200:	learn: 0.6598328	test: 0.6581470	best: 0.6580431 (182)	total: 11.5s	remaining: 45.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6579576978
# bestIteration = 212
#
# Shrink model to first 213 iterations.
# CV Log Loss Score: 0.657958
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433157	test: 1.0436331	best: 1.0436331 (0)	total: 70.2ms	remaining: 1m 10s
# 100:	learn: 0.6984134	test: 0.6705603	best: 0.6705603 (100)	total: 5.41s	remaining: 48.1s
# 200:	learn: 0.6613689	test: 0.6675918	best: 0.6674371 (196)	total: 11.7s	remaining: 46.4s
# 300:	learn: 0.6250821	test: 0.6669452	best: 0.6669452 (300)	total: 17.7s	remaining: 41.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6669449341
# bestIteration = 302
#
# Shrink model to first 303 iterations.
# CV Log Loss Score: 0.666945
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433299	test: 1.0433357	best: 1.0433357 (0)	total: 59.5ms	remaining: 59.5s
# 100:	learn: 0.6990798	test: 0.6731895	best: 0.6731895 (100)	total: 5.08s	remaining: 45.2s
# 200:	learn: 0.6608771	test: 0.6704683	best: 0.6703583 (190)	total: 11.1s	remaining: 44.3s
# 300:	learn: 0.6226232	test: 0.6698592	best: 0.6693519 (293)	total: 17.3s	remaining: 40.1s
# [I 2021-06-19 22:03:43,593] Trial 0 finished with value: 0.6662114575473512 and parameters: {'d_age_std': 6.894984844693635, 'd_age_mu': 35.34994118762474, 'weight_c': 1.5906297429702407, 'weight_b': 0.8256965264738497, 'loc_par_car': 171224}. Best is trial 0 with value: 0.6662114575473512.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6693518856
# bestIteration = 293
#
# Shrink model to first 294 iterations.
# CV Log Loss Score: 0.669352
# 	Log Loss: 0.666211
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 13.6ms	remaining: 13.6s
# 100:	learn: 0.6943251	test: 0.6764220	best: 0.6764220 (100)	total: 4.31s	remaining: 38.4s
# 200:	learn: 0.6580805	test: 0.6728678	best: 0.6727102 (197)	total: 9.49s	remaining: 37.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6726111697
# bestIteration = 246
#
# Shrink model to first 247 iterations.
# CV Log Loss Score: 0.672611
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0428930	test: 1.0431760	best: 1.0431760 (0)	total: 38.9ms	remaining: 38.9s
# 100:	learn: 0.6969073	test: 0.6712249	best: 0.6710875 (97)	total: 4.62s	remaining: 41.1s
# 200:	learn: 0.6617470	test: 0.6688796	best: 0.6686388 (194)	total: 10.5s	remaining: 41.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6686387616
# bestIteration = 194
#
# Shrink model to first 195 iterations.
# CV Log Loss Score: 0.668639
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0434833	test: 1.0426804	best: 1.0426804 (0)	total: 61.1ms	remaining: 1m 1s
# 100:	learn: 0.7001592	test: 0.6559320	best: 0.6559320 (100)	total: 5.31s	remaining: 47.2s
# 200:	learn: 0.6616036	test: 0.6515751	best: 0.6515614 (179)	total: 11.8s	remaining: 47s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.650820879
# bestIteration = 235
#
# Shrink model to first 236 iterations.
# CV Log Loss Score: 0.650821
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432434	test: 1.0438756	best: 1.0438756 (0)	total: 68.1ms	remaining: 1m 8s
# 100:	learn: 0.6968238	test: 0.6770452	best: 0.6770452 (100)	total: 5.44s	remaining: 48.4s
# 200:	learn: 0.6593990	test: 0.6768343	best: 0.6767325 (197)	total: 11.6s	remaining: 46s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6763246094
# bestIteration = 235
#
# Shrink model to first 236 iterations.
# CV Log Loss Score: 0.676325
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432528	test: 1.0439012	best: 1.0439012 (0)	total: 67.1ms	remaining: 1m 7s
# 100:	learn: 0.6942704	test: 0.6766848	best: 0.6765765 (93)	total: 5.18s	remaining: 46.1s
# 200:	learn: 0.6558920	test: 0.6756853	best: 0.6752276 (165)	total: 11.4s	remaining: 45.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6752276447
# bestIteration = 165
#
# Shrink model to first 166 iterations.
# CV Log Loss Score: 0.675228
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434006	test: 1.0434123	best: 1.0434123 (0)	total: 62.2ms	remaining: 1m 2s
# 100:	learn: 0.6970510	test: 0.6674258	best: 0.6674258 (100)	total: 4.98s	remaining: 44.3s
# 200:	learn: 0.6563869	test: 0.6638614	best: 0.6633241 (185)	total: 11s	remaining: 43.6s
# 300:	learn: 0.6196835	test: 0.6621577	best: 0.6619852 (283)	total: 16.9s	remaining: 39.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6618379214
# bestIteration = 304
#
# Shrink model to first 305 iterations.
# CV Log Loss Score: 0.661838
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433124	test: 1.0435335	best: 1.0435335 (0)	total: 59.7ms	remaining: 59.6s
# 100:	learn: 0.6949275	test: 0.6648735	best: 0.6648735 (100)	total: 5.32s	remaining: 47.4s
# 200:	learn: 0.6580000	test: 0.6615976	best: 0.6614592 (192)	total: 11.4s	remaining: 45.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6609128483
# bestIteration = 236
#
# Shrink model to first 237 iterations.
# CV Log Loss Score: 0.660913
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433215	test: 1.0436968	best: 1.0436968 (0)	total: 62.7ms	remaining: 1m 2s
# 100:	learn: 0.6949850	test: 0.6601453	best: 0.6601453 (100)	total: 5.25s	remaining: 46.8s
# 200:	learn: 0.6578600	test: 0.6582752	best: 0.6577291 (169)	total: 11.3s	remaining: 44.9s
# 300:	learn: 0.6259204	test: 0.6572273	best: 0.6571048 (264)	total: 17.2s	remaining: 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6569690653
# bestIteration = 310
#
# Shrink model to first 311 iterations.
# CV Log Loss Score: 0.656969
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0432997	test: 1.0435760	best: 1.0435760 (0)	total: 59.3ms	remaining: 59.3s
# 100:	learn: 0.7002307	test: 0.6702868	best: 0.6702656 (99)	total: 4.86s	remaining: 43.3s
# 200:	learn: 0.6608905	test: 0.6687860	best: 0.6684219 (190)	total: 10.8s	remaining: 42.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6684219223
# bestIteration = 190
#
# Shrink model to first 191 iterations.
# CV Log Loss Score: 0.668422
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433388	test: 1.0432694	best: 1.0432694 (0)	total: 64.4ms	remaining: 1m 4s
# 100:	learn: 0.6992491	test: 0.6732828	best: 0.6730826 (94)	total: 5.05s	remaining: 45s
# 200:	learn: 0.6634423	test: 0.6699182	best: 0.6695862 (192)	total: 11s	remaining: 43.9s
# [I 2021-06-19 22:06:58,215] Trial 1 finished with value: 0.6661353456132341 and parameters: {'d_age_std': 7.748407359896198, 'd_age_mu': 34.07878315402039, 'weight_c': 1.5639904334504728, 'weight_b': 1.792813365377898, 'loc_par_car': 146128}. Best is trial 1 with value: 0.6661353456132341.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6695861861
# bestIteration = 192
#
# Shrink model to first 193 iterations.
# CV Log Loss Score: 0.669586
# 	Log Loss: 0.666135
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 14ms	remaining: 14s
# 100:	learn: 0.6927981	test: 0.6772895	best: 0.6772682 (99)	total: 4.28s	remaining: 38.1s
# 200:	learn: 0.6563139	test: 0.6743615	best: 0.6740225 (173)	total: 9.11s	remaining: 36.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.674022514
# bestIteration = 173
#
# Shrink model to first 174 iterations.
# CV Log Loss Score: 0.674023
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0428982	test: 1.0431954	best: 1.0431954 (0)	total: 39.8ms	remaining: 39.8s
# 100:	learn: 0.6965623	test: 0.6711531	best: 0.6709874 (99)	total: 4.51s	remaining: 40.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6695798812
# bestIteration = 139
#
# Shrink model to first 140 iterations.
# CV Log Loss Score: 0.669580
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0434772	test: 1.0426764	best: 1.0426764 (0)	total: 52.9ms	remaining: 52.9s
# 100:	learn: 0.6993001	test: 0.6576013	best: 0.6574876 (98)	total: 4.63s	remaining: 41.2s
# 200:	learn: 0.6618338	test: 0.6543665	best: 0.6543665 (200)	total: 10.3s	remaining: 40.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6542613659
# bestIteration = 208
#
# Shrink model to first 209 iterations.
# CV Log Loss Score: 0.654261
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432356	test: 1.0438849	best: 1.0438849 (0)	total: 61.9ms	remaining: 1m 1s
# 100:	learn: 0.6980817	test: 0.6762695	best: 0.6762628 (97)	total: 5.27s	remaining: 46.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6742038707
# bestIteration = 125
#
# Shrink model to first 126 iterations.
# CV Log Loss Score: 0.674204
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432540	test: 1.0439319	best: 1.0439319 (0)	total: 64.1ms	remaining: 1m 4s
# 100:	learn: 0.6946817	test: 0.6772181	best: 0.6770518 (99)	total: 5.42s	remaining: 48.3s
# 200:	learn: 0.6574113	test: 0.6755099	best: 0.6755099 (200)	total: 11.7s	remaining: 46.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6751462976
# bestIteration = 235
#
# Shrink model to first 236 iterations.
# CV Log Loss Score: 0.675146
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434004	test: 1.0434047	best: 1.0434047 (0)	total: 60.8ms	remaining: 1m
# 100:	learn: 0.6955236	test: 0.6682119	best: 0.6682119 (100)	total: 5.02s	remaining: 44.7s
# 200:	learn: 0.6590771	test: 0.6644053	best: 0.6643249 (189)	total: 11s	remaining: 43.6s
# 300:	learn: 0.6240600	test: 0.6626463	best: 0.6624536 (297)	total: 17.1s	remaining: 39.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6624536045
# bestIteration = 297
#
# Shrink model to first 298 iterations.
# CV Log Loss Score: 0.662454
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433123	test: 1.0435288	best: 1.0435288 (0)	total: 62.3ms	remaining: 1m 2s
# 100:	learn: 0.6943452	test: 0.6655349	best: 0.6655349 (100)	total: 5.24s	remaining: 46.6s
# 200:	learn: 0.6561494	test: 0.6617746	best: 0.6614062 (191)	total: 11.2s	remaining: 44.7s
# 300:	learn: 0.6228222	test: 0.6611887	best: 0.6606449 (280)	total: 17.5s	remaining: 40.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6606449401
# bestIteration = 280
#
# Shrink model to first 281 iterations.
# CV Log Loss Score: 0.660645
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433267	test: 1.0436800	best: 1.0436800 (0)	total: 59.2ms	remaining: 59.1s
# 100:	learn: 0.6942400	test: 0.6621698	best: 0.6621698 (100)	total: 5.06s	remaining: 45s
# 200:	learn: 0.6597622	test: 0.6597158	best: 0.6590600 (167)	total: 10.8s	remaining: 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6590600194
# bestIteration = 167
#
# Shrink model to first 168 iterations.
# CV Log Loss Score: 0.659060
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0432985	test: 1.0435408	best: 1.0435408 (0)	total: 58.1ms	remaining: 58s
# 100:	learn: 0.7000445	test: 0.6705854	best: 0.6701345 (95)	total: 4.7s	remaining: 41.9s
# 200:	learn: 0.6650159	test: 0.6699028	best: 0.6693836 (174)	total: 10.6s	remaining: 42.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6693835667
# bestIteration = 174
#
# Shrink model to first 175 iterations.
# CV Log Loss Score: 0.669384
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433376	test: 1.0432745	best: 1.0432745 (0)	total: 62.9ms	remaining: 1m 2s
# 100:	learn: 0.6980309	test: 0.6731117	best: 0.6730293 (93)	total: 5.12s	remaining: 45.5s
# 200:	learn: 0.6596712	test: 0.6700727	best: 0.6697856 (194)	total: 11s	remaining: 43.8s
# [I 2021-06-19 22:09:50,560] Trial 2 finished with value: 0.6668544359107861 and parameters: {'d_age_std': 7.075996824647775, 'd_age_mu': 34.45154636462815, 'weight_c': 1.5724855762417136, 'weight_b': 0.8821816611283809, 'loc_par_car': 176809}. Best is trial 1 with value: 0.6661353456132341.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.669785589
# bestIteration = 194
#
# Shrink model to first 195 iterations.
# CV Log Loss Score: 0.669786
# 	Log Loss: 0.666854
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 15.7ms	remaining: 15.7s
# 100:	learn: 0.6947129	test: 0.6788803	best: 0.6782655 (97)	total: 4.16s	remaining: 37s
# 200:	learn: 0.6571542	test: 0.6747790	best: 0.6745884 (171)	total: 9.22s	remaining: 36.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6745883611
# bestIteration = 171
#
# Shrink model to first 172 iterations.
# CV Log Loss Score: 0.674588
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429162	test: 1.0432321	best: 1.0432321 (0)	total: 41.9ms	remaining: 41.9s
# 100:	learn: 0.6968612	test: 0.6710702	best: 0.6710702 (100)	total: 4.37s	remaining: 38.9s
# 200:	learn: 0.6605854	test: 0.6688429	best: 0.6685817 (191)	total: 9.61s	remaining: 38.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6685816557
# bestIteration = 191
#
# Shrink model to first 192 iterations.
# CV Log Loss Score: 0.668582
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0435193	test: 1.0427038	best: 1.0427038 (0)	total: 56.4ms	remaining: 56.3s
# 100:	learn: 0.6987479	test: 0.6564387	best: 0.6564387 (100)	total: 4.83s	remaining: 43s
# 200:	learn: 0.6606670	test: 0.6525615	best: 0.6520595 (190)	total: 10.8s	remaining: 43.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6520595233
# bestIteration = 190
#
# Shrink model to first 191 iterations.
# CV Log Loss Score: 0.652060
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432486	test: 1.0439455	best: 1.0439455 (0)	total: 56.1ms	remaining: 56.1s
# 100:	learn: 0.6975115	test: 0.6765090	best: 0.6764208 (94)	total: 5.15s	remaining: 45.9s
# 200:	learn: 0.6622067	test: 0.6760627	best: 0.6754029 (151)	total: 11.3s	remaining: 45.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.675402865
# bestIteration = 151
#
# Shrink model to first 152 iterations.
# CV Log Loss Score: 0.675403
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432676	test: 1.0439233	best: 1.0439233 (0)	total: 67.7ms	remaining: 1m 7s
# 100:	learn: 0.6983375	test: 0.6778904	best: 0.6778904 (100)	total: 5.27s	remaining: 46.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6767376893
# bestIteration = 126
#
# Shrink model to first 127 iterations.
# CV Log Loss Score: 0.676738
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434188	test: 1.0434090	best: 1.0434090 (0)	total: 69.2ms	remaining: 1m 9s
# 100:	learn: 0.6976826	test: 0.6675982	best: 0.6675982 (100)	total: 5.39s	remaining: 48s
# 200:	learn: 0.6623729	test: 0.6623067	best: 0.6622979 (198)	total: 11.3s	remaining: 44.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6615601433
# bestIteration = 233
#
# Shrink model to first 234 iterations.
# CV Log Loss Score: 0.661560
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433204	test: 1.0435339	best: 1.0435339 (0)	total: 59.4ms	remaining: 59.3s
# 100:	learn: 0.6944564	test: 0.6660139	best: 0.6660139 (100)	total: 5.02s	remaining: 44.7s
# 200:	learn: 0.6579661	test: 0.6613115	best: 0.6611164 (181)	total: 10.9s	remaining: 43.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6604529453
# bestIteration = 239
#
# Shrink model to first 240 iterations.
# CV Log Loss Score: 0.660453
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433576	test: 1.0436652	best: 1.0436652 (0)	total: 60.9ms	remaining: 1m
# 100:	learn: 0.6974349	test: 0.6604268	best: 0.6604268 (100)	total: 4.84s	remaining: 43s
# 200:	learn: 0.6632452	test: 0.6586148	best: 0.6577664 (154)	total: 10.6s	remaining: 42.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6577663678
# bestIteration = 154
#
# Shrink model to first 155 iterations.
# CV Log Loss Score: 0.657766
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433080	test: 1.0435373	best: 1.0435373 (0)	total: 57.4ms	remaining: 57.3s
# 100:	learn: 0.6995157	test: 0.6695888	best: 0.6695888 (100)	total: 4.8s	remaining: 42.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6687050459
# bestIteration = 127
#
# Shrink model to first 128 iterations.
# CV Log Loss Score: 0.668705
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433442	test: 1.0432481	best: 1.0432481 (0)	total: 58.6ms	remaining: 58.6s
# 100:	learn: 0.6996277	test: 0.6738456	best: 0.6738456 (100)	total: 4.97s	remaining: 44.3s
# [I 2021-06-19 22:12:26,527] Trial 3 finished with value: 0.6667699082961513 and parameters: {'d_age_std': 6.191340214907488, 'd_age_mu': 34.158575266512656, 'weight_c': 1.6034557896732344, 'weight_b': 0.9026322040081834, 'loc_par_car': 150125}. Best is trial 1 with value: 0.6661353456132341.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6718415302
# bestIteration = 142
#
# Shrink model to first 143 iterations.
# CV Log Loss Score: 0.671842
# 	Log Loss: 0.666770
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 14ms	remaining: 13.9s
# 100:	learn: 0.6956832	test: 0.6761613	best: 0.6761613 (100)	total: 4.04s	remaining: 36s
# 200:	learn: 0.6600385	test: 0.6725958	best: 0.6721692 (172)	total: 9.1s	remaining: 36.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6721691646
# bestIteration = 172
#
# Shrink model to first 173 iterations.
# CV Log Loss Score: 0.672169
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429033	test: 1.0431807	best: 1.0431807 (0)	total: 37.5ms	remaining: 37.5s
# 100:	learn: 0.6970887	test: 0.6710849	best: 0.6710790 (97)	total: 4.4s	remaining: 39.1s
# 200:	learn: 0.6589431	test: 0.6693437	best: 0.6692703 (196)	total: 9.69s	remaining: 38.5s
# 300:	learn: 0.6222065	test: 0.6688433	best: 0.6682181 (281)	total: 15s	remaining: 34.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6682181113
# bestIteration = 281
#
# Shrink model to first 282 iterations.
# CV Log Loss Score: 0.668218
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0434753	test: 1.0426643	best: 1.0426643 (0)	total: 57.8ms	remaining: 57.8s
# 100:	learn: 0.6993999	test: 0.6570590	best: 0.6569908 (99)	total: 5.16s	remaining: 46s
# 200:	learn: 0.6638044	test: 0.6540533	best: 0.6533178 (183)	total: 11.1s	remaining: 44.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6533178375
# bestIteration = 183
#
# Shrink model to first 184 iterations.
# CV Log Loss Score: 0.653318
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432141	test: 1.0438801	best: 1.0438801 (0)	total: 66.5ms	remaining: 1m 6s
# 100:	learn: 0.6951538	test: 0.6751626	best: 0.6751626 (100)	total: 5.41s	remaining: 48.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6741525621
# bestIteration = 141
#
# Shrink model to first 142 iterations.
# CV Log Loss Score: 0.674153
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432310	test: 1.0439106	best: 1.0439106 (0)	total: 68.8ms	remaining: 1m 8s
# 100:	learn: 0.6962192	test: 0.6760278	best: 0.6760278 (100)	total: 5.34s	remaining: 47.6s
# 200:	learn: 0.6600317	test: 0.6761870	best: 0.6750395 (173)	total: 11.6s	remaining: 46.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6750395068
# bestIteration = 173
#
# Shrink model to first 174 iterations.
# CV Log Loss Score: 0.675040
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434089	test: 1.0434042	best: 1.0434042 (0)	total: 61.9ms	remaining: 1m 1s
# 100:	learn: 0.6973050	test: 0.6678944	best: 0.6678944 (100)	total: 4.89s	remaining: 43.6s
# 200:	learn: 0.6613040	test: 0.6651159	best: 0.6648857 (182)	total: 10.9s	remaining: 43.2s
# 300:	learn: 0.6257809	test: 0.6643867	best: 0.6637587 (262)	total: 16.8s	remaining: 39s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6637586898
# bestIteration = 262
#
# Shrink model to first 263 iterations.
# CV Log Loss Score: 0.663759
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433027	test: 1.0435475	best: 1.0435475 (0)	total: 61.2ms	remaining: 1m 1s
# 100:	learn: 0.6936704	test: 0.6650716	best: 0.6650716 (100)	total: 5.09s	remaining: 45.3s
# 200:	learn: 0.6550857	test: 0.6625595	best: 0.6625595 (200)	total: 10.9s	remaining: 43.5s
# 300:	learn: 0.6225722	test: 0.6618886	best: 0.6615994 (257)	total: 16.7s	remaining: 38.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6615993642
# bestIteration = 257
#
# Shrink model to first 258 iterations.
# CV Log Loss Score: 0.661599
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433078	test: 1.0436601	best: 1.0436601 (0)	total: 61.9ms	remaining: 1m 1s
# 100:	learn: 0.6966183	test: 0.6612687	best: 0.6612687 (100)	total: 5.31s	remaining: 47.3s
# 200:	learn: 0.6625440	test: 0.6583262	best: 0.6580325 (181)	total: 11.2s	remaining: 44.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6573232603
# bestIteration = 245
#
# Shrink model to first 246 iterations.
# CV Log Loss Score: 0.657323
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0432937	test: 1.0435692	best: 1.0435692 (0)	total: 58.9ms	remaining: 58.8s
# 100:	learn: 0.6984273	test: 0.6709378	best: 0.6709378 (100)	total: 5.05s	remaining: 44.9s
# 200:	learn: 0.6619767	test: 0.6690102	best: 0.6687376 (162)	total: 10.9s	remaining: 43.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6687376364
# bestIteration = 162
#
# Shrink model to first 163 iterations.
# CV Log Loss Score: 0.668738
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433270	test: 1.0432429	best: 1.0432429 (0)	total: 63ms	remaining: 1m 2s
# 100:	learn: 0.7016590	test: 0.6728389	best: 0.6728389 (100)	total: 4.97s	remaining: 44.3s
# 200:	learn: 0.6642982	test: 0.6696679	best: 0.6696679 (200)	total: 10.9s	remaining: 43.4s
# [I 2021-06-19 22:15:24,374] Trial 4 finished with value: 0.6663755701571271 and parameters: {'d_age_std': 6.954864342159008, 'd_age_mu': 34.15761914445323, 'weight_c': 1.4439704915060267, 'weight_b': 1.2167620530021748, 'loc_par_car': 150729}. Best is trial 1 with value: 0.6661353456132341.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6694373783
# bestIteration = 206
#
# Shrink model to first 207 iterations.
# CV Log Loss Score: 0.669437
# 	Log Loss: 0.666376
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 14.2ms	remaining: 14.1s
# 100:	learn: 0.6944030	test: 0.6773965	best: 0.6773965 (100)	total: 4.26s	remaining: 37.9s
# 200:	learn: 0.6564845	test: 0.6739020	best: 0.6738130 (157)	total: 9.23s	remaining: 36.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6734480718
# bestIteration = 229
#
# Shrink model to first 230 iterations.
# CV Log Loss Score: 0.673448
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429123	test: 1.0431612	best: 1.0431612 (0)	total: 39ms	remaining: 39s
# 100:	learn: 0.6939700	test: 0.6712198	best: 0.6712198 (100)	total: 4.33s	remaining: 38.5s
# 200:	learn: 0.6604576	test: 0.6694175	best: 0.6690834 (182)	total: 9.63s	remaining: 38.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6690834046
# bestIteration = 182
#
# Shrink model to first 183 iterations.
# CV Log Loss Score: 0.669083
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0435025	test: 1.0427036	best: 1.0427036 (0)	total: 54.5ms	remaining: 54.4s
# 100:	learn: 0.6984216	test: 0.6551656	best: 0.6551656 (100)	total: 5s	remaining: 44.5s
# 200:	learn: 0.6623443	test: 0.6507566	best: 0.6507158 (198)	total: 11s	remaining: 43.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6506437191
# bestIteration = 230
#
# Shrink model to first 231 iterations.
# CV Log Loss Score: 0.650644
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432369	test: 1.0439084	best: 1.0439084 (0)	total: 66.7ms	remaining: 1m 6s
# 100:	learn: 0.6963055	test: 0.6769183	best: 0.6768727 (99)	total: 5.32s	remaining: 47.4s
# 200:	learn: 0.6583025	test: 0.6758847	best: 0.6756896 (198)	total: 11.7s	remaining: 46.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6753959558
# bestIteration = 228
#
# Shrink model to first 229 iterations.
# CV Log Loss Score: 0.675396
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432550	test: 1.0439292	best: 1.0439292 (0)	total: 62.1ms	remaining: 1m 1s
# 100:	learn: 0.6974207	test: 0.6768851	best: 0.6768851 (100)	total: 5.28s	remaining: 47s
# 200:	learn: 0.6603070	test: 0.6761542	best: 0.6751778 (177)	total: 11.3s	remaining: 44.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6751778254
# bestIteration = 177
#
# Shrink model to first 178 iterations.
# CV Log Loss Score: 0.675178
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434171	test: 1.0434150	best: 1.0434150 (0)	total: 63.4ms	remaining: 1m 3s
# 100:	learn: 0.6947114	test: 0.6670030	best: 0.6670030 (100)	total: 4.89s	remaining: 43.5s
# 200:	learn: 0.6585772	test: 0.6613650	best: 0.6613009 (198)	total: 10.7s	remaining: 42.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6605683952
# bestIteration = 216
#
# Shrink model to first 217 iterations.
# CV Log Loss Score: 0.660568
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433322	test: 1.0435203	best: 1.0435203 (0)	total: 57.3ms	remaining: 57.2s
# 100:	learn: 0.6968690	test: 0.6648052	best: 0.6648052 (100)	total: 4.69s	remaining: 41.7s
# 200:	learn: 0.6614170	test: 0.6617819	best: 0.6617819 (200)	total: 10.6s	remaining: 42.2s
# 300:	learn: 0.6239630	test: 0.6599225	best: 0.6596935 (284)	total: 16.5s	remaining: 38.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6596934837
# bestIteration = 284
#
# Shrink model to first 285 iterations.
# CV Log Loss Score: 0.659693
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433283	test: 1.0436889	best: 1.0436889 (0)	total: 65.1ms	remaining: 1m 5s
# 100:	learn: 0.6953723	test: 0.6616359	best: 0.6616359 (100)	total: 5.13s	remaining: 45.6s
# 200:	learn: 0.6599356	test: 0.6595737	best: 0.6594455 (165)	total: 11.2s	remaining: 44.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6594454867
# bestIteration = 165
#
# Shrink model to first 166 iterations.
# CV Log Loss Score: 0.659445
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433038	test: 1.0436158	best: 1.0436158 (0)	total: 62.7ms	remaining: 1m 2s
# 100:	learn: 0.6994508	test: 0.6713187	best: 0.6713187 (100)	total: 4.58s	remaining: 40.8s
# 200:	learn: 0.6625273	test: 0.6689845	best: 0.6685189 (191)	total: 10.7s	remaining: 42.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6685188901
# bestIteration = 191
#
# Shrink model to first 192 iterations.
# CV Log Loss Score: 0.668519
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433330	test: 1.0433215	best: 1.0433215 (0)	total: 59.4ms	remaining: 59.3s
# 100:	learn: 0.6987755	test: 0.6722166	best: 0.6721139 (99)	total: 4.94s	remaining: 44s
# 200:	learn: 0.6629658	test: 0.6700441	best: 0.6697078 (188)	total: 10.9s	remaining: 43.2s
# [I 2021-06-19 22:18:24,915] Trial 5 finished with value: 0.6660947575715305 and parameters: {'d_age_std': 7.0273994333537075, 'd_age_mu': 35.01097426926515, 'weight_c': 1.5136662054307513, 'weight_b': 0.855360985799734, 'loc_par_car': 157225}. Best is trial 5 with value: 0.6660947575715305.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6689695632
# bestIteration = 238
#
# Shrink model to first 239 iterations.
# CV Log Loss Score: 0.668970
# 	Log Loss: 0.666095
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 15.3ms	remaining: 15.3s
# 100:	learn: 0.6961838	test: 0.6777767	best: 0.6777652 (99)	total: 4.29s	remaining: 38.2s
# 200:	learn: 0.6602351	test: 0.6758172	best: 0.6747337 (169)	total: 9.37s	remaining: 37.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6747337011
# bestIteration = 169
#
# Shrink model to first 170 iterations.
# CV Log Loss Score: 0.674734
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429164	test: 1.0431619	best: 1.0431619 (0)	total: 41.5ms	remaining: 41.5s
# 100:	learn: 0.6982350	test: 0.6710943	best: 0.6710943 (100)	total: 4.41s	remaining: 39.2s
# 200:	learn: 0.6623735	test: 0.6691304	best: 0.6687796 (183)	total: 9.76s	remaining: 38.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6686198174
# bestIteration = 216
#
# Shrink model to first 217 iterations.
# CV Log Loss Score: 0.668620
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0434885	test: 1.0427065	best: 1.0427065 (0)	total: 53.7ms	remaining: 53.7s
# 100:	learn: 0.6989929	test: 0.6553845	best: 0.6553845 (100)	total: 4.82s	remaining: 42.9s
# 200:	learn: 0.6622609	test: 0.6526599	best: 0.6526599 (200)	total: 10.7s	remaining: 42.6s
# 300:	learn: 0.6302878	test: 0.6528681	best: 0.6518945 (270)	total: 16.9s	remaining: 39.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.65189451
# bestIteration = 270
#
# Shrink model to first 271 iterations.
# CV Log Loss Score: 0.651895
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432367	test: 1.0438887	best: 1.0438887 (0)	total: 61.9ms	remaining: 1m 1s
# 100:	learn: 0.6924228	test: 0.6761730	best: 0.6761730 (100)	total: 5.28s	remaining: 47s
# 200:	learn: 0.6561855	test: 0.6741527	best: 0.6738506 (184)	total: 11.6s	remaining: 46s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6738506046
# bestIteration = 184
#
# Shrink model to first 185 iterations.
# CV Log Loss Score: 0.673851
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432599	test: 1.0439261	best: 1.0439261 (0)	total: 64.3ms	remaining: 1m 4s
# 100:	learn: 0.6969406	test: 0.6768094	best: 0.6767314 (99)	total: 5.59s	remaining: 49.8s
# 200:	learn: 0.6589504	test: 0.6760021	best: 0.6757103 (194)	total: 11.7s	remaining: 46.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6757103161
# bestIteration = 194
#
# Shrink model to first 195 iterations.
# CV Log Loss Score: 0.675710
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0433882	test: 1.0434046	best: 1.0434046 (0)	total: 58.6ms	remaining: 58.6s
# 100:	learn: 0.6974669	test: 0.6671723	best: 0.6671723 (100)	total: 4.88s	remaining: 43.5s
# 200:	learn: 0.6622030	test: 0.6640375	best: 0.6639251 (199)	total: 10.9s	remaining: 43.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.663925091
# bestIteration = 199
#
# Shrink model to first 200 iterations.
# CV Log Loss Score: 0.663925
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433338	test: 1.0434941	best: 1.0434941 (0)	total: 58.9ms	remaining: 58.9s
# 100:	learn: 0.6963348	test: 0.6649738	best: 0.6649151 (99)	total: 5s	remaining: 44.5s
# 200:	learn: 0.6582331	test: 0.6615832	best: 0.6614609 (177)	total: 10.8s	remaining: 42.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.660511619
# bestIteration = 239
#
# Shrink model to first 240 iterations.
# CV Log Loss Score: 0.660512
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433393	test: 1.0436863	best: 1.0436863 (0)	total: 60.6ms	remaining: 1m
# 100:	learn: 0.6968115	test: 0.6620212	best: 0.6620062 (99)	total: 5.1s	remaining: 45.4s
# 200:	learn: 0.6598549	test: 0.6578945	best: 0.6578945 (200)	total: 11.1s	remaining: 44.3s
# 300:	learn: 0.6281254	test: 0.6571229	best: 0.6565064 (282)	total: 17.2s	remaining: 39.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6565063916
# bestIteration = 282
#
# Shrink model to first 283 iterations.
# CV Log Loss Score: 0.656506
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433014	test: 1.0436380	best: 1.0436380 (0)	total: 69.4ms	remaining: 1m 9s
# 100:	learn: 0.6970874	test: 0.6704597	best: 0.6703785 (99)	total: 4.89s	remaining: 43.5s
# 200:	learn: 0.6625248	test: 0.6689182	best: 0.6686741 (164)	total: 10.8s	remaining: 42.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.668674056
# bestIteration = 164
#
# Shrink model to first 165 iterations.
# CV Log Loss Score: 0.668674
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433152	test: 1.0433124	best: 1.0433124 (0)	total: 65ms	remaining: 1m 4s
# 100:	learn: 0.6999914	test: 0.6732031	best: 0.6731941 (99)	total: 4.98s	remaining: 44.4s
# 200:	learn: 0.6645873	test: 0.6704949	best: 0.6698363 (182)	total: 11s	remaining: 43.6s
# [I 2021-06-19 22:21:24,145] Trial 6 finished with value: 0.6664265568433457 and parameters: {'d_age_std': 7.9355534094483495, 'd_age_mu': 35.26951018148062, 'weight_c': 1.517506646645677, 'weight_b': 0.6580909119790289, 'loc_par_car': 185437}. Best is trial 5 with value: 0.6660947575715305.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.669836321
# bestIteration = 182
#
# Shrink model to first 183 iterations.
# CV Log Loss Score: 0.669836
# 	Log Loss: 0.666427
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 14.3ms	remaining: 14.3s
# 100:	learn: 0.6947552	test: 0.6767454	best: 0.6767454 (100)	total: 4.28s	remaining: 38.1s
# 200:	learn: 0.6582433	test: 0.6738176	best: 0.6738176 (200)	total: 9.34s	remaining: 37.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6735605272
# bestIteration = 210
#
# Shrink model to first 211 iterations.
# CV Log Loss Score: 0.673561
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429111	test: 1.0431782	best: 1.0431782 (0)	total: 40.7ms	remaining: 40.6s
# 100:	learn: 0.6937987	test: 0.6711204	best: 0.6711204 (100)	total: 4.4s	remaining: 39.2s
# 200:	learn: 0.6583153	test: 0.6701429	best: 0.6700031 (186)	total: 9.65s	remaining: 38.4s
# 300:	learn: 0.6198931	test: 0.6696367	best: 0.6691673 (280)	total: 15.1s	remaining: 35.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6691672945
# bestIteration = 280
#
# Shrink model to first 281 iterations.
# CV Log Loss Score: 0.669167
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0435074	test: 1.0426979	best: 1.0426979 (0)	total: 62.1ms	remaining: 1m 2s
# 100:	learn: 0.6976411	test: 0.6562698	best: 0.6562698 (100)	total: 5.24s	remaining: 46.6s
# 200:	learn: 0.6616510	test: 0.6535528	best: 0.6535370 (199)	total: 11.5s	remaining: 45.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6523625208
# bestIteration = 224
#
# Shrink model to first 225 iterations.
# CV Log Loss Score: 0.652363
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432504	test: 1.0438902	best: 1.0438902 (0)	total: 64.7ms	remaining: 1m 4s
# 100:	learn: 0.6944614	test: 0.6763391	best: 0.6763194 (92)	total: 5.54s	remaining: 49.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6751684917
# bestIteration = 128
#
# Shrink model to first 129 iterations.
# CV Log Loss Score: 0.675168
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432598	test: 1.0439263	best: 1.0439263 (0)	total: 66.5ms	remaining: 1m 6s
# 100:	learn: 0.6957720	test: 0.6767925	best: 0.6767925 (100)	total: 5.57s	remaining: 49.6s
# 200:	learn: 0.6618097	test: 0.6749039	best: 0.6745137 (174)	total: 11.7s	remaining: 46.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6745137314
# bestIteration = 174
#
# Shrink model to first 175 iterations.
# CV Log Loss Score: 0.674514
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0433728	test: 1.0433969	best: 1.0433969 (0)	total: 59.2ms	remaining: 59.2s
# 100:	learn: 0.6971764	test: 0.6682310	best: 0.6681811 (97)	total: 5s	remaining: 44.6s
# 200:	learn: 0.6615175	test: 0.6648772	best: 0.6648110 (192)	total: 11s	remaining: 43.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6641446388
# bestIteration = 249
#
# Shrink model to first 250 iterations.
# CV Log Loss Score: 0.664145
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433347	test: 1.0435216	best: 1.0435216 (0)	total: 58.1ms	remaining: 58.1s
# 100:	learn: 0.6957385	test: 0.6659614	best: 0.6658734 (99)	total: 4.98s	remaining: 44.3s
# 200:	learn: 0.6584121	test: 0.6605982	best: 0.6605982 (200)	total: 10.7s	remaining: 42.7s
# 300:	learn: 0.6222140	test: 0.6604181	best: 0.6592909 (255)	total: 16.7s	remaining: 38.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6592908786
# bestIteration = 255
#
# Shrink model to first 256 iterations.
# CV Log Loss Score: 0.659291
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433352	test: 1.0437117	best: 1.0437117 (0)	total: 60.5ms	remaining: 1m
# 100:	learn: 0.6969458	test: 0.6595869	best: 0.6595869 (100)	total: 5.14s	remaining: 45.7s
# 200:	learn: 0.6623106	test: 0.6579048	best: 0.6573528 (152)	total: 11.2s	remaining: 44.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6573528213
# bestIteration = 152
#
# Shrink model to first 153 iterations.
# CV Log Loss Score: 0.657353
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433177	test: 1.0436254	best: 1.0436254 (0)	total: 58.9ms	remaining: 58.8s
# 100:	learn: 0.7001260	test: 0.6707431	best: 0.6707270 (99)	total: 4.79s	remaining: 42.7s
# 200:	learn: 0.6628291	test: 0.6687271	best: 0.6682082 (179)	total: 10.7s	remaining: 42.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6682081847
# bestIteration = 179
#
# Shrink model to first 180 iterations.
# CV Log Loss Score: 0.668208
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433300	test: 1.0433076	best: 1.0433076 (0)	total: 63.5ms	remaining: 1m 3s
# 100:	learn: 0.7002485	test: 0.6742864	best: 0.6742864 (100)	total: 4.82s	remaining: 42.9s
# 200:	learn: 0.6613986	test: 0.6718799	best: 0.6714032 (192)	total: 10.7s	remaining: 42.6s
# [I 2021-06-19 22:24:19,799] Trial 7 finished with value: 0.6665174959870733 and parameters: {'d_age_std': 7.573476741834542, 'd_age_mu': 35.05462533802956, 'weight_c': 1.5027915163365588, 'weight_b': 1.6534817065890328, 'loc_par_car': 165569}. Best is trial 5 with value: 0.6660947575715305.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6714032081
# bestIteration = 192
#
# Shrink model to first 193 iterations.
# CV Log Loss Score: 0.671403
# 	Log Loss: 0.666517
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 14.2ms	remaining: 14.1s
# 100:	learn: 0.6943669	test: 0.6768663	best: 0.6768663 (100)	total: 4.12s	remaining: 36.7s
# 200:	learn: 0.6579614	test: 0.6743404	best: 0.6736314 (170)	total: 9.09s	remaining: 36.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6736313899
# bestIteration = 170
#
# Shrink model to first 171 iterations.
# CV Log Loss Score: 0.673631
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0428971	test: 1.0431849	best: 1.0431849 (0)	total: 39.9ms	remaining: 39.8s
# 100:	learn: 0.6972928	test: 0.6706089	best: 0.6704777 (98)	total: 4.28s	remaining: 38.1s
# 200:	learn: 0.6624960	test: 0.6690201	best: 0.6686798 (174)	total: 9.43s	remaining: 37.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6686797851
# bestIteration = 174
#
# Shrink model to first 175 iterations.
# CV Log Loss Score: 0.668680
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0434644	test: 1.0426574	best: 1.0426574 (0)	total: 54.6ms	remaining: 54.6s
# 100:	learn: 0.6971532	test: 0.6558179	best: 0.6558179 (100)	total: 4.64s	remaining: 41.3s
# 200:	learn: 0.6631230	test: 0.6520037	best: 0.6519323 (195)	total: 10.6s	remaining: 42s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6515178075
# bestIteration = 208
#
# Shrink model to first 209 iterations.
# CV Log Loss Score: 0.651518
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432007	test: 1.0438287	best: 1.0438287 (0)	total: 61.1ms	remaining: 1m 1s
# 100:	learn: 0.6942732	test: 0.6771042	best: 0.6767454 (96)	total: 5.27s	remaining: 47s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6762892721
# bestIteration = 121
#
# Shrink model to first 122 iterations.
# CV Log Loss Score: 0.676289
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432198	test: 1.0438555	best: 1.0438555 (0)	total: 64ms	remaining: 1m 3s
# 100:	learn: 0.6956746	test: 0.6764414	best: 0.6764414 (100)	total: 5.35s	remaining: 47.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6759377478
# bestIteration = 131
#
# Shrink model to first 132 iterations.
# CV Log Loss Score: 0.675938
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0433551	test: 1.0433526	best: 1.0433526 (0)	total: 64.4ms	remaining: 1m 4s
# 100:	learn: 0.6966829	test: 0.6669119	best: 0.6668999 (99)	total: 5.12s	remaining: 45.6s
# 200:	learn: 0.6582400	test: 0.6617868	best: 0.6617868 (200)	total: 11.2s	remaining: 44.6s
# 300:	learn: 0.6229324	test: 0.6607451	best: 0.6598993 (284)	total: 17.4s	remaining: 40.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6598992964
# bestIteration = 284
#
# Shrink model to first 285 iterations.
# CV Log Loss Score: 0.659899
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0432739	test: 1.0434859	best: 1.0434859 (0)	total: 61.2ms	remaining: 1m 1s
# 100:	learn: 0.6936865	test: 0.6656273	best: 0.6656273 (100)	total: 5.25s	remaining: 46.8s
# 200:	learn: 0.6558825	test: 0.6635509	best: 0.6632827 (158)	total: 11.1s	remaining: 44.1s
# 300:	learn: 0.6189820	test: 0.6615945	best: 0.6615006 (287)	total: 16.9s	remaining: 39.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6611693267
# bestIteration = 307
#
# Shrink model to first 308 iterations.
# CV Log Loss Score: 0.661169
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0432894	test: 1.0436010	best: 1.0436010 (0)	total: 58.3ms	remaining: 58.2s
# 100:	learn: 0.6978730	test: 0.6589047	best: 0.6585875 (95)	total: 5.06s	remaining: 45.1s
# 200:	learn: 0.6611544	test: 0.6569651	best: 0.6567261 (193)	total: 11.1s	remaining: 44.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6564188984
# bestIteration = 209
#
# Shrink model to first 210 iterations.
# CV Log Loss Score: 0.656419
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0429071	test: 1.0431216	best: 1.0431216 (0)	total: 43.5ms	remaining: 43.5s
# 100:	learn: 0.6971627	test: 0.6700874	best: 0.6700874 (100)	total: 5.36s	remaining: 47.7s
# 200:	learn: 0.6595086	test: 0.6673697	best: 0.6669758 (180)	total: 11.3s	remaining: 44.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6667348546
# bestIteration = 220
#
# Shrink model to first 221 iterations.
# CV Log Loss Score: 0.666735
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433011	test: 1.0433207	best: 1.0433207 (0)	total: 64.7ms	remaining: 1m 4s
# 100:	learn: 0.6986253	test: 0.6731327	best: 0.6731047 (95)	total: 4.82s	remaining: 42.9s
# 200:	learn: 0.6622525	test: 0.6706626	best: 0.6699382 (170)	total: 10.9s	remaining: 43.5s
# [I 2021-06-19 22:27:12,649] Trial 8 finished with value: 0.6660219407755484 and parameters: {'d_age_std': 6.337879075116563, 'd_age_mu': 35.56804210466584, 'weight_c': 1.5913204119968496, 'weight_b': 1.7737264794342327, 'loc_par_car': 167850}. Best is trial 8 with value: 0.6660219407755484.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6699381523
# bestIteration = 170
#
# Shrink model to first 171 iterations.
# CV Log Loss Score: 0.669938
# 	Log Loss: 0.666022
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 14.3ms	remaining: 14.3s
# 100:	learn: 0.6965104	test: 0.6773711	best: 0.6773204 (99)	total: 4.25s	remaining: 37.8s
# 200:	learn: 0.6589489	test: 0.6752744	best: 0.6745251 (175)	total: 9.24s	remaining: 36.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6745250503
# bestIteration = 175
#
# Shrink model to first 176 iterations.
# CV Log Loss Score: 0.674525
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429069	test: 1.0431658	best: 1.0431658 (0)	total: 40.5ms	remaining: 40.5s
# 100:	learn: 0.6988290	test: 0.6719650	best: 0.6719091 (99)	total: 4.41s	remaining: 39.2s
# 200:	learn: 0.6626737	test: 0.6696138	best: 0.6693212 (190)	total: 9.71s	remaining: 38.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6693212006
# bestIteration = 190
#
# Shrink model to first 191 iterations.
# CV Log Loss Score: 0.669321
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0434709	test: 1.0426424	best: 1.0426424 (0)	total: 58.4ms	remaining: 58.3s
# 100:	learn: 0.6996534	test: 0.6558103	best: 0.6558103 (100)	total: 4.75s	remaining: 42.3s
# 200:	learn: 0.6615209	test: 0.6515930	best: 0.6514274 (196)	total: 10.6s	remaining: 42.2s
# 300:	learn: 0.6279440	test: 0.6517794	best: 0.6508508 (277)	total: 17s	remaining: 39.5s
# ...
# [I 2021-06-20 00:20:46,037] Trial 46 finished with value: 0.6660918888170498 and parameters: {'d_age_std': 5.823388123297464, 'd_age_mu': 34.813537949819136, 'weight_c': 1.4937171816217165, 'weight_b': 0.964603290431991, 'loc_par_car': 186790}. Best is trial 38 with value: 0.6658748281699809.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.669014279
# bestIteration = 248
#
# Shrink model to first 249 iterations.
# CV Log Loss Score: 0.669014
# 	Log Loss: 0.666092
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 13.5ms	remaining: 13.5s
# 100:	learn: 0.6966129	test: 0.6782953	best: 0.6782067 (99)	total: 4.41s	remaining: 39.3s
# 200:	learn: 0.6589369	test: 0.6750819	best: 0.6750819 (200)	total: 9.62s	remaining: 38.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6745975139
# bestIteration = 236
#
# Shrink model to first 237 iterations.
# CV Log Loss Score: 0.674598
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429159	test: 1.0432247	best: 1.0432247 (0)	total: 38.6ms	remaining: 38.6s
# 100:	learn: 0.6954849	test: 0.6716806	best: 0.6716806 (100)	total: 4.56s	remaining: 40.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6697105195
# bestIteration = 149
#
# Shrink model to first 150 iterations.
# CV Log Loss Score: 0.669711
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0435263	test: 1.0426819	best: 1.0426819 (0)	total: 62.1ms	remaining: 1m 2s
# 100:	learn: 0.6972599	test: 0.6559735	best: 0.6559568 (96)	total: 5.48s	remaining: 48.7s
# 200:	learn: 0.6620833	test: 0.6528086	best: 0.6527783 (199)	total: 12.1s	remaining: 47.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6520957424
# bestIteration = 232
#
# Shrink model to first 233 iterations.
# CV Log Loss Score: 0.652096
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432481	test: 1.0439407	best: 1.0439407 (0)	total: 63.7ms	remaining: 1m 3s
# 100:	learn: 0.6995946	test: 0.6767086	best: 0.6767086 (100)	total: 5.61s	remaining: 50s
# 200:	learn: 0.6633065	test: 0.6763575	best: 0.6757796 (157)	total: 12.2s	remaining: 48.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6757795997
# bestIteration = 157
#
# Shrink model to first 158 iterations.
# CV Log Loss Score: 0.675780
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432674	test: 1.0439443	best: 1.0439443 (0)	total: 69.8ms	remaining: 1m 9s
# 100:	learn: 0.6980657	test: 0.6774311	best: 0.6774311 (100)	total: 5.67s	remaining: 50.4s
# 200:	learn: 0.6593203	test: 0.6762112	best: 0.6757644 (172)	total: 12.1s	remaining: 47.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6757644246
# bestIteration = 172
#
# Shrink model to first 173 iterations.
# CV Log Loss Score: 0.675764
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434188	test: 1.0434355	best: 1.0434355 (0)	total: 59.8ms	remaining: 59.8s
# 100:	learn: 0.6973585	test: 0.6678009	best: 0.6678009 (100)	total: 4.85s	remaining: 43.2s
# 200:	learn: 0.6610110	test: 0.6643215	best: 0.6643215 (200)	total: 11.1s	remaining: 44.1s
# 300:	learn: 0.6265458	test: 0.6626327	best: 0.6626327 (300)	total: 17.3s	remaining: 40.1s
# 400:	learn: 0.5922573	test: 0.6618057	best: 0.6614154 (394)	total: 23.4s	remaining: 35s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6614154117
# bestIteration = 394
#
# Shrink model to first 395 iterations.
# CV Log Loss Score: 0.661415
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433367	test: 1.0435204	best: 1.0435204 (0)	total: 59.9ms	remaining: 59.9s
# 100:	learn: 0.6923876	test: 0.6648508	best: 0.6648508 (100)	total: 5.45s	remaining: 48.5s
# 200:	learn: 0.6571578	test: 0.6617763	best: 0.6615780 (198)	total: 11.9s	remaining: 47.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6615780413
# bestIteration = 198
#
# Shrink model to first 199 iterations.
# CV Log Loss Score: 0.661578
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433623	test: 1.0436633	best: 1.0436633 (0)	total: 62.6ms	remaining: 1m 2s
# 100:	learn: 0.6948865	test: 0.6604952	best: 0.6604952 (100)	total: 5.5s	remaining: 48.9s
# 200:	learn: 0.6609109	test: 0.6581327	best: 0.6579901 (196)	total: 11.9s	remaining: 47.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6579901219
# bestIteration = 196
#
# Shrink model to first 197 iterations.
# CV Log Loss Score: 0.657990
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433249	test: 1.0435532	best: 1.0435532 (0)	total: 62.1ms	remaining: 1m 2s
# 100:	learn: 0.6987919	test: 0.6698743	best: 0.6698743 (100)	total: 5.25s	remaining: 46.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6684226999
# bestIteration = 148
#
# Shrink model to first 149 iterations.
# CV Log Loss Score: 0.668423
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433524	test: 1.0432692	best: 1.0432692 (0)	total: 59.5ms	remaining: 59.4s
# 100:	learn: 0.7004156	test: 0.6737139	best: 0.6737139 (100)	total: 5.11s	remaining: 45.5s
# 200:	learn: 0.6618861	test: 0.6705293	best: 0.6704825 (164)	total: 11.3s	remaining: 45s
# [I 2021-06-20 00:23:54,753] Trial 47 finished with value: 0.66677691310198 and parameters: {'d_age_std': 5.679766128205928, 'd_age_mu': 34.47582581510409, 'weight_c': 1.4890450528975754, 'weight_b': 0.9888570919555533, 'loc_par_car': 186937}. Best is trial 38 with value: 0.6658748281699809.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6704120994
# bestIteration = 206
#
# Shrink model to first 207 iterations.
# CV Log Loss Score: 0.670412
# 	Log Loss: 0.666777
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 15.7ms	remaining: 15.7s
# 100:	learn: 0.6961740	test: 0.6777556	best: 0.6777441 (99)	total: 4.42s	remaining: 39.4s
# 200:	learn: 0.6610206	test: 0.6738898	best: 0.6738303 (193)	total: 9.73s	remaining: 38.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6732924489
# bestIteration = 226
#
# Shrink model to first 227 iterations.
# CV Log Loss Score: 0.673292
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0429085	test: 1.0432148	best: 1.0432148 (0)	total: 40.6ms	remaining: 40.6s
# 100:	learn: 0.6946931	test: 0.6713722	best: 0.6713722 (100)	total: 4.83s	remaining: 43s
# 200:	learn: 0.6580292	test: 0.6687931	best: 0.6684717 (193)	total: 10.6s	remaining: 42s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6678592069
# bestIteration = 224
#
# Shrink model to first 225 iterations.
# CV Log Loss Score: 0.667859
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0435250	test: 1.0426865	best: 1.0426865 (0)	total: 64.9ms	remaining: 1m 4s
# 100:	learn: 0.7006529	test: 0.6574031	best: 0.6574031 (100)	total: 5.39s	remaining: 48s
# 200:	learn: 0.6652151	test: 0.6536348	best: 0.6535238 (190)	total: 12.1s	remaining: 48.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6528804607
# bestIteration = 229
#
# Shrink model to first 230 iterations.
# CV Log Loss Score: 0.652880
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432374	test: 1.0439720	best: 1.0439720 (0)	total: 63.9ms	remaining: 1m 3s
# 100:	learn: 0.6952847	test: 0.6749686	best: 0.6747842 (86)	total: 5.81s	remaining: 51.7s
# 200:	learn: 0.6622360	test: 0.6747546	best: 0.6737622 (156)	total: 12.6s	remaining: 50.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.673762242
# bestIteration = 156
#
# Shrink model to first 157 iterations.
# CV Log Loss Score: 0.673762
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432715	test: 1.0439755	best: 1.0439755 (0)	total: 64.7ms	remaining: 1m 4s
# 100:	learn: 0.6976933	test: 0.6759510	best: 0.6759510 (100)	total: 5.4s	remaining: 48.1s
# 200:	learn: 0.6633766	test: 0.6740569	best: 0.6734015 (181)	total: 11.7s	remaining: 46.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6734014995
# bestIteration = 181
#
# Shrink model to first 182 iterations.
# CV Log Loss Score: 0.673401
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434082	test: 1.0434255	best: 1.0434255 (0)	total: 61.5ms	remaining: 1m 1s
# 100:	learn: 0.6992347	test: 0.6676345	best: 0.6676345 (100)	total: 5.14s	remaining: 45.8s
# 200:	learn: 0.6627086	test: 0.6635607	best: 0.6634506 (199)	total: 11.4s	remaining: 45.2s
# 300:	learn: 0.6268672	test: 0.6621104	best: 0.6616693 (262)	total: 17.7s	remaining: 41s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6616693275
# bestIteration = 262
#
# Shrink model to first 263 iterations.
# CV Log Loss Score: 0.661669
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433510	test: 1.0435296	best: 1.0435296 (0)	total: 63.5ms	remaining: 1m 3s
# 100:	learn: 0.6994284	test: 0.6673160	best: 0.6672783 (97)	total: 5.07s	remaining: 45.1s
# 200:	learn: 0.6611994	test: 0.6626619	best: 0.6624923 (199)	total: 11.3s	remaining: 45s
# 300:	learn: 0.6246132	test: 0.6618645	best: 0.6613714 (266)	total: 17.7s	remaining: 41.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6613713812
# bestIteration = 266
#
# Shrink model to first 267 iterations.
# CV Log Loss Score: 0.661371
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433338	test: 1.0436731	best: 1.0436731 (0)	total: 58.6ms	remaining: 58.6s
# 100:	learn: 0.6977070	test: 0.6605563	best: 0.6605563 (100)	total: 5.13s	remaining: 45.7s
# 200:	learn: 0.6621581	test: 0.6580663	best: 0.6577871 (153)	total: 11.6s	remaining: 45.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6577870752
# bestIteration = 153
#
# Shrink model to first 154 iterations.
# CV Log Loss Score: 0.657787
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433206	test: 1.0435628	best: 1.0435628 (0)	total: 65.4ms	remaining: 1m 5s
# 100:	learn: 0.6992681	test: 0.6700121	best: 0.6700069 (99)	total: 5.03s	remaining: 44.7s
# 200:	learn: 0.6602117	test: 0.6689012	best: 0.6685436 (162)	total: 11.2s	remaining: 44.4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.668543609
# bestIteration = 162
#
# Shrink model to first 163 iterations.
# CV Log Loss Score: 0.668544
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433760	test: 1.0432654	best: 1.0432654 (0)	total: 61.2ms	remaining: 1m 1s
# 100:	learn: 0.7000305	test: 0.6729333	best: 0.6728390 (99)	total: 5.06s	remaining: 45s
# 200:	learn: 0.6648951	test: 0.6702506	best: 0.6701432 (189)	total: 11.2s	remaining: 44.7s
# 300:	learn: 0.6273118	test: 0.6700019	best: 0.6689468 (252)	total: 17.5s	remaining: 40.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6689467661
# bestIteration = 252
#
# Shrink model to first 253 iterations.
# [I 2021-06-20 00:27:04,730] Trial 48 finished with value: 0.6659516792309952 and parameters: {'d_age_std': 5.420657510917441, 'd_age_mu': 34.75663867589985, 'weight_c': 1.464402519477631, 'weight_b': 1.2298419120025792, 'loc_par_car': 183417}. Best is trial 38 with value: 0.6658748281699809.
# CV Log Loss Score: 0.668947
# 	Log Loss: 0.665952
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0424331	test: 1.0432511	best: 1.0432511 (0)	total: 14.9ms	remaining: 14.9s
# 100:	learn: 0.6949977	test: 0.6762562	best: 0.6762562 (100)	total: 4.38s	remaining: 39s
# 200:	learn: 0.6585315	test: 0.6736789	best: 0.6736533 (193)	total: 9.4s	remaining: 37.4s
# 300:	learn: 0.6215466	test: 0.6737019	best: 0.6728383 (256)	total: 15s	remaining: 34.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.67283828
# bestIteration = 256
#
# Shrink model to first 257 iterations.
# CV Log Loss Score: 0.672838
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0428945	test: 1.0432143	best: 1.0432143 (0)	total: 38ms	remaining: 38s
# 100:	learn: 0.6943427	test: 0.6712194	best: 0.6710997 (99)	total: 4.55s	remaining: 40.5s
# 200:	learn: 0.6599435	test: 0.6705886	best: 0.6698816 (174)	total: 10.7s	remaining: 42.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6698451991
# bestIteration = 221
#
# Shrink model to first 222 iterations.
# CV Log Loss Score: 0.669845
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0435215	test: 1.0426839	best: 1.0426839 (0)	total: 64.1ms	remaining: 1m 4s
# 100:	learn: 0.7007717	test: 0.6555480	best: 0.6555480 (100)	total: 5.52s	remaining: 49.2s
# 200:	learn: 0.6612917	test: 0.6544128	best: 0.6539495 (194)	total: 12.2s	remaining: 48.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6539494911
# bestIteration = 194
#
# Shrink model to first 195 iterations.
# CV Log Loss Score: 0.653949
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0432378	test: 1.0439231	best: 1.0439231 (0)	total: 68.7ms	remaining: 1m 8s
# 100:	learn: 0.6956235	test: 0.6758379	best: 0.6758379 (100)	total: 5.7s	remaining: 50.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6749252007
# bestIteration = 127
#
# Shrink model to first 128 iterations.
# CV Log Loss Score: 0.674925
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0432695	test: 1.0439572	best: 1.0439572 (0)	total: 65.6ms	remaining: 1m 5s
# 100:	learn: 0.6994705	test: 0.6769165	best: 0.6769165 (100)	total: 5.4s	remaining: 48.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6749116227
# bestIteration = 144
#
# Shrink model to first 145 iterations.
# CV Log Loss Score: 0.674912
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0434035	test: 1.0434199	best: 1.0434199 (0)	total: 63.7ms	remaining: 1m 3s
# 100:	learn: 0.6980844	test: 0.6683258	best: 0.6683258 (100)	total: 4.95s	remaining: 44s
# 200:	learn: 0.6591031	test: 0.6636354	best: 0.6636354 (200)	total: 11.1s	remaining: 44.1s
# 300:	learn: 0.6248430	test: 0.6624831	best: 0.6619363 (276)	total: 17.2s	remaining: 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6619362755
# bestIteration = 276
#
# Shrink model to first 277 iterations.
# CV Log Loss Score: 0.661936
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0433417	test: 1.0435280	best: 1.0435280 (0)	total: 59.2ms	remaining: 59.1s
# 100:	learn: 0.6972973	test: 0.6657386	best: 0.6657380 (99)	total: 5.06s	remaining: 45.1s
# 200:	learn: 0.6593004	test: 0.6616779	best: 0.6610744 (176)	total: 11.4s	remaining: 45.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6610743995
# bestIteration = 176
#
# Shrink model to first 177 iterations.
# CV Log Loss Score: 0.661074
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0433327	test: 1.0436571	best: 1.0436571 (0)	total: 64.1ms	remaining: 1m 4s
# 100:	learn: 0.6972199	test: 0.6590416	best: 0.6590153 (99)	total: 5.34s	remaining: 47.5s
# 200:	learn: 0.6636947	test: 0.6572117	best: 0.6572117 (200)	total: 11.7s	remaining: 46.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6567605541
# bestIteration = 239
#
# Shrink model to first 240 iterations.
# CV Log Loss Score: 0.656761
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0433181	test: 1.0435881	best: 1.0435881 (0)	total: 68.7ms	remaining: 1m 8s
# 100:	learn: 0.7001398	test: 0.6713583	best: 0.6713583 (100)	total: 5s	remaining: 44.5s
# 200:	learn: 0.6632493	test: 0.6692017	best: 0.6691929 (178)	total: 11.2s	remaining: 44.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6688541647
# bestIteration = 235
#
# Shrink model to first 236 iterations.
# CV Log Loss Score: 0.668854
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0433710	test: 1.0432578	best: 1.0432578 (0)	total: 62.9ms	remaining: 1m 2s
# 100:	learn: 0.6989774	test: 0.6725317	best: 0.6725317 (100)	total: 5.21s	remaining: 46.3s
# 200:	learn: 0.6648723	test: 0.6706384	best: 0.6706148 (199)	total: 11.4s	remaining: 45.3s
# [I 2021-06-20 00:30:13,394] Trial 49 finished with value: 0.6665161100285064 and parameters: {'d_age_std': 5.3604011183899685, 'd_age_mu': 34.662677992512826, 'weight_c': 1.462078695818174, 'weight_b': 1.6517125110109858, 'loc_par_car': 183153}. Best is trial 38 with value: 0.6658748281699809.
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6700635227
# bestIteration = 239
#
# Shrink model to first 240 iterations.
# CV Log Loss Score: 0.670064
# 	Log Loss: 0.666516

# %%
money_weight_study.best_params
# Out:
# {'d_age_std': 7.977814929279566,
#  'd_age_mu': 35.00059114405094,
#  'weight_c': 1.4633527457954487,
#  'weight_b': 1.2772905851450718,
#  'loc_par_car': 183585}

# %%
d_age_std = 7.977814929279566
d_age_mu = 35.00059114405094
weight_c = 1.4633527457954487
weight_b = 1.2772905851450718
loc_par_car = 183585

train_money = pd.merge(train, df_weight_edu, how = 'left', on = 'edu_type') # 'weight_edu'
train_money['weight_chd'] = train_money['child_num'].transform(lambda x: np.log(1+x)/np.log(2))
train_money['weight_age'] = train_money['DAYS_BIRTH'].transform(lambda x: norm(d_age_mu, scale = d_age_std).pdf((x/365.25))/norm(d_age_mu, scale = d_age_std).pdf(d_age_mu))
train_money['child_fee_total'] = one_child_fee*train_money['weight_edu']*train_money['weight_chd']*train_money['weight_age']
train_money['car_fees_total'] = train_money.income_total.median()*0.1*(train_money.car == 'Y').astype('int')*train_money.income_total.apply(lambda x: car_weight(x, loc_par_car))
train_money['save_income'] = train_money['income_total'] - weight_c*train_money['child_fee_total'] - weight_b*train_money['car_fees_total']
train_money.drop(['weight_edu', 'weight_chd', 'weight_age', 'child_fee_total', 'car_fees_total'], axis = 1, inplace = True)

# %%
test = pd.merge(test, df_weight_edu, how = 'left', on = 'edu_type') # 'weight_edu'

# %%
test['weight_chd'] = test['child_num'].transform(lambda x: np.log(1+x)/np.log(2))
test['weight_age'] = test['DAYS_BIRTH'].transform(lambda x: norm(d_age_mu, scale = d_age_std).pdf((x/365.25))/norm(d_age_mu, scale = d_age_std).pdf(d_age_mu))
test['child_fee_total'] = one_child_fee*test['weight_edu']*test['weight_chd']*test['weight_age']
test['car_fees_total'] = test.income_total.median()*0.1*(test.car == 'Y').astype('int')*test.income_total.apply(lambda x: car_weight(x, loc_par_car))
test['save_income'] = test['income_total'] - weight_c*test['child_fee_total'] - weight_b*test['car_fees_total']
test.drop(['weight_edu', 'weight_chd', 'weight_age', 'child_fee_total', 'car_fees_total'], axis = 1, inplace = True)

# %%
numerical_feats = train_money.dtypes[train_money.dtypes != "object"].index.tolist()
numerical_feats.remove('credit')
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = train_money.dtypes[train_money.dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  21
# Number of Categorical features:  13

# %%
train_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26451 entries, 0 to 26450
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gender                         26451 non-null  object
#  1   car                            26451 non-null  object
#  2   reality                        26451 non-null  object
#  3   child_num                      26451 non-null  int64
#  4   income_total                   26451 non-null  float64
#  5   income_type                    26451 non-null  object
#  6   edu_type                       26451 non-null  object
#  7   family_type                    26451 non-null  object
#  8   house_type                     26451 non-null  object
#  9   DAYS_BIRTH                     26451 non-null  int64
#  10  DAYS_EMPLOYED                  26451 non-null  int64
#  11  work_phone                     26451 non-null  int64
#  12  phone                          26451 non-null  int64
#  13  email                          26451 non-null  int64
#  14  occyp_type                     26451 non-null  object
#  15  family_size                    26451 non-null  float64
#  16  begin_month                    26451 non-null  float64
#  17  credit                         26451 non-null  float64
#  18  personal_id                    26451 non-null  object
#  19  group_property                 26451 non-null  object
#  20  group_contacts                 26451 non-null  object
#  21  group_whoare_u                 26451 non-null  object
#  22  group_your_job                 26451 non-null  object
#  23  DAYS_nowork                    26451 non-null  int64
#  24  adult_num                      26451 non-null  float64
#  25  income_per_child               26451 non-null  float64
#  26  income_per_family              26451 non-null  float64
#  27  income_per_age                 26451 non-null  float64
#  28  income_total_log               26451 non-null  float64
#  29  begin_season                   26451 non-null  int64
#  30  mm_EMPLOYED                    26451 non-null  int64
#  31  yy_EMPLOYED                    26451 non-null  int64
#  32  ability_income_per_age_by_gen  26451 non-null  float64
#  33  ability_emp_per_age_by_gen     26451 non-null  float64
#  34  save_income                    26451 non-null  float64
# dtypes: float64(12), int64(10), object(13)
# memory usage: 8.3+ MB

# %%
target = 'credit'
X = train_money.drop(target, axis=1)
y = train_money[target]
X_test = test

# %%
study_make_model_params.best_params
# Out:
# {'learning_rate': 0.02404397268860108,
#  'n_estimators': 3800,
#  'colsample_bylevel': 0.07461193805097653,
#  'depth': 12,
#  'subsample': 0.7562188551097002}

# %%
n_class  =3
n_fold = 10
seed = 55

def objective(trial):
    skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
    folds=[]
    for train_idx, valid_idx in skfold.split(X, y):
            folds.append((train_idx, valid_idx))
            
    cat_pred = np.zeros((X.shape[0], n_class))
    cat_pred_test = np.zeros((X_test.shape[0], n_class))
    cat_cols = categorical_feats

    param = {
        #"objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "learning_rate":     trial.suggest_float("learning_rate", 0.01, 0.05),
        "n_estimators":      trial.suggest_int("n_estimators", 2400, 4400, 200),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.2),
        "depth": trial.suggest_int("depth", 8, 16, 1),
        #"boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        #"bootstrap_type": trial.suggest_categorical(
        #    "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        #),
        "subsample" : trial.suggest_float("subsample", 0.6, 0.98), #only=> bootstrap_type = 'Bernoulli'
        "used_ram_limit": "14gb",
    }

    #if param["bootstrap_type"] == "Bayesian":
    #    param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    #elif param["bootstrap_type"] == "Bernoulli":
    #    param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        
    model_folds = []    
    for fold in range(n_fold):
        print(f'\n----------------- Fold {fold+1} -----------------\n')
        train_idx, valid_idx = folds[fold]
        X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
        train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        model_cat = CatBoostClassifier(**param, 
                                       boosting_type = 'Ordered', 
                                       bootstrap_type = 'Bernoulli')
        model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=200)
        
        model_folds.append(model_cat)
        cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
        cat_pred_test += model_cat.predict_proba(X_test) / n_fold
        print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')

    print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
    logloss = log_loss(y, cat_pred)
    return logloss

# %%
study_make_model_params = optuna.create_study(direction="minimize")
study_make_model_params.optimize(objective)
# Out:
# [I 2021-07-02 18:19:14,081] A new study created in memory with name: no-name-a37d5663-2e97-4a9f-9031-f8e2b84b5f75
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0860156	test: 1.0850165	best: 1.0850165 (0)	total: 64.4ms	remaining: 4m 30s
# 200:	learn: 0.7469787	test: 0.7237296	best: 0.7237296 (200)	total: 15.5s	remaining: 5m 7s
# 400:	learn: 0.7216398	test: 0.6858054	best: 0.6858054 (400)	total: 34.8s	remaining: 5m 29s
# 600:	learn: 0.7137863	test: 0.6765212	best: 0.6765212 (600)	total: 54.3s	remaining: 5m 25s
# 800:	learn: 0.7044106	test: 0.6721466	best: 0.6721434 (799)	total: 1m 38s	remaining: 6m 57s
# 1000:	learn: 0.6946506	test: 0.6701908	best: 0.6701908 (1000)	total: 2m 40s	remaining: 8m 31s
# 1200:	learn: 0.6850336	test: 0.6690782	best: 0.6690538 (1196)	total: 3m 39s	remaining: 9m 7s
# 1400:	learn: 0.6751452	test: 0.6683252	best: 0.6683149 (1398)	total: 4m 42s	remaining: 9m 24s
# 1600:	learn: 0.6655479	test: 0.6678293	best: 0.6678131 (1599)	total: 5m 47s	remaining: 9m 24s
# 1800:	learn: 0.6557403	test: 0.6674006	best: 0.6674006 (1800)	total: 6m 51s	remaining: 9m 8s
# 2000:	learn: 0.6467157	test: 0.6674118	best: 0.6672697 (1913)	total: 7m 55s	remaining: 8m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6672697065
# bestIteration = 1913
#
# Shrink model to first 1914 iterations.
# CV Log Loss Score: 0.667270
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0859191	test: 1.0848078	best: 1.0848078 (0)	total: 429ms	remaining: 30m 1s
# 200:	learn: 0.7455408	test: 0.7137642	best: 0.7137642 (200)	total: 19.3s	remaining: 6m 24s
# 400:	learn: 0.7206031	test: 0.6777739	best: 0.6777739 (400)	total: 38.9s	remaining: 6m 8s
# 600:	learn: 0.7131130	test: 0.6700423	best: 0.6700423 (600)	total: 1m	remaining: 6m 4s
# 800:	learn: 0.7037361	test: 0.6670033	best: 0.6669524 (791)	total: 1m 48s	remaining: 7m 42s
# 1000:	learn: 0.6931363	test: 0.6659071	best: 0.6659071 (1000)	total: 2m 51s	remaining: 9m 8s
# 1200:	learn: 0.6832042	test: 0.6654461	best: 0.6654357 (1198)	total: 3m 59s	remaining: 9m 57s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6654356801
# bestIteration = 1198
#
# Shrink model to first 1199 iterations.
# CV Log Loss Score: 0.665436
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0860741	test: 1.0851896	best: 1.0851896 (0)	total: 439ms	remaining: 30m 43s
# 200:	learn: 0.7423072	test: 0.6959014	best: 0.6959014 (200)	total: 19.3s	remaining: 6m 23s
# 400:	learn: 0.7208404	test: 0.6626313	best: 0.6626313 (400)	total: 39.4s	remaining: 6m 12s
# 600:	learn: 0.7140920	test: 0.6562077	best: 0.6562077 (600)	total: 57.7s	remaining: 5m 45s
# 800:	learn: 0.7057937	test: 0.6526735	best: 0.6526312 (796)	total: 1m 42s	remaining: 7m 15s
# 1000:	learn: 0.6953921	test: 0.6511586	best: 0.6511586 (1000)	total: 2m 45s	remaining: 8m 49s
# 1200:	learn: 0.6853245	test: 0.6504450	best: 0.6504299 (1199)	total: 3m 54s	remaining: 9m 45s
# 1400:	learn: 0.6752699	test: 0.6500635	best: 0.6500635 (1400)	total: 5m 3s	remaining: 10m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6500031634
# bestIteration = 1413
#
# Shrink model to first 1414 iterations.
# CV Log Loss Score: 0.650003
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0882005	test: 1.0873752	best: 1.0873752 (0)	total: 54.2ms	remaining: 3m 47s
# 200:	learn: 0.7476069	test: 0.7170385	best: 0.7170385 (200)	total: 19.4s	remaining: 6m 25s
# 400:	learn: 0.7221413	test: 0.6819340	best: 0.6819327 (399)	total: 40.6s	remaining: 6m 24s
# 600:	learn: 0.7142484	test: 0.6754084	best: 0.6754084 (600)	total: 59s	remaining: 5m 53s
# 800:	learn: 0.7040935	test: 0.6729122	best: 0.6728943 (799)	total: 1m 47s	remaining: 7m 37s
# 1000:	learn: 0.6934349	test: 0.6726598	best: 0.6725015 (921)	total: 3m 2s	remaining: 9m 44s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6725014531
# bestIteration = 921
#
# Shrink model to first 922 iterations.
# CV Log Loss Score: 0.672501
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0859922	test: 1.0854402	best: 1.0854402 (0)	total: 459ms	remaining: 32m 7s
# 200:	learn: 0.7421570	test: 0.7173582	best: 0.7173582 (200)	total: 18.5s	remaining: 6m 8s
# 400:	learn: 0.7202988	test: 0.6850229	best: 0.6850229 (400)	total: 36.6s	remaining: 5m 47s
# 600:	learn: 0.7130837	test: 0.6774412	best: 0.6774412 (598)	total: 1m	remaining: 5m 59s
# 800:	learn: 0.7034123	test: 0.6737891	best: 0.6737891 (800)	total: 1m 51s	remaining: 7m 52s
# 1000:	learn: 0.6932382	test: 0.6729100	best: 0.6729079 (995)	total: 3m 3s	remaining: 9m 47s
# 1200:	learn: 0.6831701	test: 0.6725140	best: 0.6725140 (1200)	total: 4m 17s	remaining: 10m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6724361688
# bestIteration = 1211
#
# Shrink model to first 1212 iterations.
# CV Log Loss Score: 0.672436
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0859160	test: 1.0850485	best: 1.0850485 (0)	total: 495ms	remaining: 34m 38s
# 200:	learn: 0.7469649	test: 0.7181360	best: 0.7181360 (200)	total: 23.2s	remaining: 7m 41s
# 400:	learn: 0.7221203	test: 0.6821794	best: 0.6821794 (400)	total: 45s	remaining: 7m 6s
# 600:	learn: 0.7142653	test: 0.6724045	best: 0.6724045 (600)	total: 1m 6s	remaining: 6m 38s
# 800:	learn: 0.7053200	test: 0.6670616	best: 0.6670616 (800)	total: 1m 54s	remaining: 8m 5s
# 1000:	learn: 0.6948828	test: 0.6653839	best: 0.6653573 (993)	total: 3m 10s	remaining: 10m 7s
# 1200:	learn: 0.6851374	test: 0.6653648	best: 0.6652457 (1143)	total: 4m 28s	remaining: 11m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.665245711
# bestIteration = 1143
#
# Shrink model to first 1144 iterations.
# CV Log Loss Score: 0.665246
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0860606	test: 1.0852786	best: 1.0852786 (0)	total: 464ms	remaining: 32m 28s
# 200:	learn: 0.7515718	test: 0.7210866	best: 0.7210866 (200)	total: 16.3s	remaining: 5m 23s
# 400:	learn: 0.7245308	test: 0.6799387	best: 0.6799387 (400)	total: 36.8s	remaining: 5m 49s
# 600:	learn: 0.7162964	test: 0.6691918	best: 0.6691918 (600)	total: 58s	remaining: 5m 47s
# 800:	learn: 0.7065822	test: 0.6639292	best: 0.6639292 (800)	total: 1m 50s	remaining: 7m 48s
# 1000:	learn: 0.6955352	test: 0.6618227	best: 0.6618227 (1000)	total: 3m 7s	remaining: 9m 58s
# 1200:	learn: 0.6852649	test: 0.6609270	best: 0.6609188 (1199)	total: 4m 21s	remaining: 10m 52s
# 1400:	learn: 0.6744888	test: 0.6603301	best: 0.6603187 (1395)	total: 5m 33s	remaining: 11m 6s
# 1600:	learn: 0.6640960	test: 0.6597951	best: 0.6597828 (1599)	total: 6m 45s	remaining: 10m 58s
# 1800:	learn: 0.6540305	test: 0.6593393	best: 0.6593097 (1798)	total: 7m 53s	remaining: 10m 30s
# 2000:	learn: 0.6443486	test: 0.6590455	best: 0.6590113 (1981)	total: 9m	remaining: 9m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6587012551
# bestIteration = 2090
#
# Shrink model to first 2091 iterations.
# CV Log Loss Score: 0.658701
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0860563	test: 1.0853019	best: 1.0853019 (0)	total: 473ms	remaining: 33m 5s
# 200:	learn: 0.7463844	test: 0.7084566	best: 0.7084566 (200)	total: 21.6s	remaining: 7m 10s
# 400:	learn: 0.7218717	test: 0.6710374	best: 0.6710374 (400)	total: 44.5s	remaining: 7m 1s
# 600:	learn: 0.7145517	test: 0.6621311	best: 0.6621311 (600)	total: 1m 6s	remaining: 6m 38s
# 800:	learn: 0.7054322	test: 0.6580744	best: 0.6580744 (800)	total: 1m 53s	remaining: 8m 1s
# 1000:	learn: 0.6942205	test: 0.6567281	best: 0.6567040 (960)	total: 3m 4s	remaining: 9m 49s
# 1200:	learn: 0.6834922	test: 0.6561122	best: 0.6561122 (1200)	total: 4m 16s	remaining: 10m 41s
# 1400:	learn: 0.6735649	test: 0.6558556	best: 0.6558161 (1385)	total: 5m 30s	remaining: 10m 59s
# 1600:	learn: 0.6638010	test: 0.6556190	best: 0.6555852 (1566)	total: 6m 36s	remaining: 10m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6554802499
# bestIteration = 1666
#
# Shrink model to first 1667 iterations.
# CV Log Loss Score: 0.655480
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0860166	test: 1.0851979	best: 1.0851979 (0)	total: 469ms	remaining: 32m 49s
# 200:	learn: 0.7445595	test: 0.7129784	best: 0.7129784 (200)	total: 17.5s	remaining: 5m 48s
# 400:	learn: 0.7199326	test: 0.6765733	best: 0.6765733 (400)	total: 38.8s	remaining: 6m 8s
# 600:	learn: 0.7137391	test: 0.6696900	best: 0.6696900 (600)	total: 52.9s	remaining: 5m 16s
# 800:	learn: 0.7038506	test: 0.6659900	best: 0.6659877 (799)	total: 1m 40s	remaining: 7m 4s
# 1000:	learn: 0.6939709	test: 0.6650264	best: 0.6650264 (1000)	total: 2m 43s	remaining: 8m 41s
# 1200:	learn: 0.6839290	test: 0.6646394	best: 0.6646394 (1200)	total: 3m 50s	remaining: 9m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6644026293
# bestIteration = 1287
#
# Shrink model to first 1288 iterations.
# CV Log Loss Score: 0.664403
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0859679	test: 1.0850630	best: 1.0850630 (0)	total: 441ms	remaining: 30m 49s
# 200:	learn: 0.7428433	test: 0.7115950	best: 0.7115950 (200)	total: 20.7s	remaining: 6m 51s
# 400:	learn: 0.7190373	test: 0.6798016	best: 0.6798016 (400)	total: 41s	remaining: 6m 28s
# 600:	learn: 0.7121438	test: 0.6743599	best: 0.6743599 (600)	total: 1m	remaining: 6m 1s
# 800:	learn: 0.7031082	test: 0.6716226	best: 0.6716226 (800)	total: 1m 45s	remaining: 7m 27s
# 1000:	learn: 0.6918746	test: 0.6707494	best: 0.6706909 (997)	total: 2m 48s	remaining: 8m 56s
# 1200:	learn: 0.6814431	test: 0.6703554	best: 0.6702569 (1184)	total: 3m 52s	remaining: 9m 41s
# 1400:	learn: 0.6722605	test: 0.6698220	best: 0.6698216 (1399)	total: 4m 56s	remaining: 9m 52s
# 1600:	learn: 0.6626543	test: 0.6696294	best: 0.6696294 (1600)	total: 6m 1s	remaining: 9m 47s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6696293758
# bestIteration = 1600
#
# Shrink model to first 1601 iterations.
# CV Log Loss Score: 0.669629
# 	Log Loss: 0.664111
# [I 2021-07-02 19:19:38,583] Trial 0 finished with value: 0.6641106587122413 and parameters: {'learning_rate': 0.01767320340751323, 'n_estimators': 4200, 'colsample_bylevel': 0.08598451565600354, 'depth': 11, 'subsample': 0.7893132899151443}. Best is trial 0 with value: 0.6641106587122413.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0783096	test: 1.0784637	best: 1.0784637 (0)	total: 40.9ms	remaining: 2m 2s
# 200:	learn: 0.7199208	test: 0.6801961	best: 0.6801961 (200)	total: 32.1s	remaining: 7m 26s
# 400:	learn: 0.7053721	test: 0.6704918	best: 0.6704676 (399)	total: 1m 44s	remaining: 11m 18s
# 600:	learn: 0.6847980	test: 0.6690142	best: 0.6690142 (600)	total: 4m 49s	remaining: 19m 13s
# 800:	learn: 0.6631224	test: 0.6677977	best: 0.6677664 (750)	total: 7m 56s	remaining: 21m 47s
# 1000:	learn: 0.6414395	test: 0.6674367	best: 0.6673851 (998)	total: 10m 55s	remaining: 21m 48s
# 1200:	learn: 0.6210905	test: 0.6669142	best: 0.6667031 (1140)	total: 13m 57s	remaining: 20m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6667030661
# bestIteration = 1140
#
# Shrink model to first 1141 iterations.
# CV Log Loss Score: 0.666703
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0832241	test: 1.0832256	best: 1.0832256 (0)	total: 18.2ms	remaining: 54.5s
# 200:	learn: 0.7187467	test: 0.6740229	best: 0.6740123 (199)	total: 35.9s	remaining: 8m 19s
# 400:	learn: 0.7021415	test: 0.6664889	best: 0.6664632 (394)	total: 1m 59s	remaining: 12m 51s
# 600:	learn: 0.6790323	test: 0.6658995	best: 0.6656271 (539)	total: 5m 9s	remaining: 20m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6656270907
# bestIteration = 539
#
# Shrink model to first 540 iterations.
# CV Log Loss Score: 0.665627
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0832257	test: 1.0832227	best: 1.0832227 (0)	total: 26.7ms	remaining: 1m 20s
# 200:	learn: 0.7211986	test: 0.6595923	best: 0.6595923 (200)	total: 30s	remaining: 6m 57s
# 400:	learn: 0.7063190	test: 0.6503965	best: 0.6503787 (394)	total: 1m 51s	remaining: 12m 2s
# 600:	learn: 0.6832772	test: 0.6492074	best: 0.6490076 (574)	total: 5m	remaining: 19m 57s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6490075725
# bestIteration = 574
#
# Shrink model to first 575 iterations.
# CV Log Loss Score: 0.649008
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0783124	test: 1.0783607	best: 1.0783607 (0)	total: 912ms	remaining: 45m 34s
# 200:	learn: 0.7198081	test: 0.6769327	best: 0.6769327 (200)	total: 28.8s	remaining: 6m 40s
# 400:	learn: 0.7051785	test: 0.6720368	best: 0.6719120 (398)	total: 1m 50s	remaining: 11m 59s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6719119743
# bestIteration = 398
#
# Shrink model to first 399 iterations.
# CV Log Loss Score: 0.671912
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0832258	test: 1.0832250	best: 1.0832250 (0)	total: 19ms	remaining: 57s
# 200:	learn: 0.7165512	test: 0.6785145	best: 0.6785145 (200)	total: 42.9s	remaining: 9m 57s
# 400:	learn: 0.7018686	test: 0.6730524	best: 0.6729667 (388)	total: 2m 7s	remaining: 13m 43s
# 600:	learn: 0.6786768	test: 0.6725360	best: 0.6724715 (525)	total: 5m 19s	remaining: 21m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6724714792
# bestIteration = 525
#
# Shrink model to first 526 iterations.
# CV Log Loss Score: 0.672471
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0783331	test: 1.0781764	best: 1.0781764 (0)	total: 948ms	remaining: 47m 23s
# 200:	learn: 0.7189470	test: 0.6742218	best: 0.6742218 (200)	total: 36.9s	remaining: 8m 33s
# 400:	learn: 0.7047014	test: 0.6651407	best: 0.6651380 (399)	total: 1m 54s	remaining: 12m 22s
# 600:	learn: 0.6819464	test: 0.6635916	best: 0.6635615 (595)	total: 5m 22s	remaining: 21m 26s
# 800:	learn: 0.6589216	test: 0.6631456	best: 0.6631143 (798)	total: 8m 51s	remaining: 24m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.662991116
# bestIteration = 806
#
# Shrink model to first 807 iterations.
# CV Log Loss Score: 0.662991
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0832240	test: 1.0832241	best: 1.0832241 (0)	total: 23.1ms	remaining: 1m 9s
# 200:	learn: 0.7209054	test: 0.6715606	best: 0.6715606 (200)	total: 33.6s	remaining: 7m 47s
# 400:	learn: 0.7054278	test: 0.6627914	best: 0.6627291 (377)	total: 1m 59s	remaining: 12m 56s
# 600:	learn: 0.6828267	test: 0.6607039	best: 0.6606587 (594)	total: 5m 42s	remaining: 22m 48s
# 800:	learn: 0.6584971	test: 0.6596788	best: 0.6595068 (786)	total: 9m 27s	remaining: 25m 57s
# 1000:	learn: 0.6352409	test: 0.6588726	best: 0.6586725 (950)	total: 13m 14s	remaining: 26m 27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6586724625
# bestIteration = 950
#
# Shrink model to first 951 iterations.
# CV Log Loss Score: 0.658672
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0783407	test: 1.0781704	best: 1.0781704 (0)	total: 1.05s	remaining: 52m 24s
# 200:	learn: 0.7204978	test: 0.6661265	best: 0.6661265 (200)	total: 38.4s	remaining: 8m 55s
# 400:	learn: 0.7053572	test: 0.6575663	best: 0.6575663 (400)	total: 2m 12s	remaining: 14m 18s
# 600:	learn: 0.6838609	test: 0.6558207	best: 0.6557998 (599)	total: 5m 56s	remaining: 23m 41s
# 800:	learn: 0.6616309	test: 0.6546347	best: 0.6546347 (800)	total: 9m 45s	remaining: 26m 46s
# 1000:	learn: 0.6407524	test: 0.6540565	best: 0.6540368 (997)	total: 13m 36s	remaining: 27m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6536804619
# bestIteration = 1087
#
# Shrink model to first 1088 iterations.
# CV Log Loss Score: 0.653680
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0783102	test: 1.0782722	best: 1.0782722 (0)	total: 90.8ms	remaining: 4m 32s
# 200:	learn: 0.7199647	test: 0.6720819	best: 0.6720819 (200)	total: 36.5s	remaining: 8m 27s
# 400:	learn: 0.7049308	test: 0.6645729	best: 0.6645729 (400)	total: 2m 3s	remaining: 13m 17s
# 600:	learn: 0.6821170	test: 0.6631035	best: 0.6630958 (599)	total: 5m 44s	remaining: 22m 56s
# 800:	learn: 0.6605263	test: 0.6630950	best: 0.6626878 (751)	total: 9m 25s	remaining: 25m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6626878363
# bestIteration = 751
#
# Shrink model to first 752 iterations.
# CV Log Loss Score: 0.662688
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0832125	test: 1.0832221	best: 1.0832221 (0)	total: 22.9ms	remaining: 1m 8s
# 200:	learn: 0.7163640	test: 0.6745275	best: 0.6745275 (200)	total: 41.7s	remaining: 9m 40s
# 400:	learn: 0.7019963	test: 0.6694247	best: 0.6694247 (400)	total: 2m 17s	remaining: 14m 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6686841659
# bestIteration = 478
#
# Shrink model to first 479 iterations.
# CV Log Loss Score: 0.668684
# 	Log Loss: 0.663244
# [I 2021-07-02 20:53:11,787] Trial 1 finished with value: 0.6632438533115634 and parameters: {'learning_rate': 0.0350892739150892, 'n_estimators': 3000, 'colsample_bylevel': 0.15459010974413953, 'depth': 12, 'subsample': 0.9430980234284306}. Best is trial 1 with value: 0.6632438533115634.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0724913	test: 1.0726578	best: 1.0726578 (0)	total: 30ms	remaining: 1m 23s
# 200:	learn: 0.7154147	test: 0.6767779	best: 0.6767779 (200)	total: 1m 27s	remaining: 18m 50s
# 400:	learn: 0.6833195	test: 0.6699142	best: 0.6698940 (391)	total: 11m 48s	remaining: 1h 10m 40s
# 600:	learn: 0.6450432	test: 0.6677462	best: 0.6676163 (595)	total: 26m 6s	remaining: 1h 35m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6674084236
# bestIteration = 688
#
# Shrink model to first 689 iterations.
# CV Log Loss Score: 0.667408
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0786182	test: 1.0786201	best: 1.0786201 (0)	total: 21.7ms	remaining: 1m
# 200:	learn: 0.7162330	test: 0.6712277	best: 0.6712277 (200)	total: 1m 18s	remaining: 16m 50s
# 400:	learn: 0.6812894	test: 0.6658741	best: 0.6656092 (371)	total: 12m 8s	remaining: 1h 12m 37s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6656091996
# bestIteration = 371
#
# Shrink model to first 372 iterations.
# CV Log Loss Score: 0.665609
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0786182	test: 1.0786201	best: 1.0786201 (0)	total: 19.6ms	remaining: 54.7s
# 200:	learn: 0.7173108	test: 0.6558518	best: 0.6558518 (200)	total: 1m 10s	remaining: 15m 14s
# 400:	learn: 0.6851363	test: 0.6501066	best: 0.6500769 (399)	total: 10m 24s	remaining: 1h 2m 18s
# 600:	learn: 0.6446187	test: 0.6496759	best: 0.6494952 (553)	total: 23m 13s	remaining: 1h 24m 57s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6494952065
# bestIteration = 553
#
# Shrink model to first 554 iterations.
# CV Log Loss Score: 0.649495
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0786182	test: 1.0786201	best: 1.0786201 (0)	total: 18.6ms	remaining: 52s
# 200:	learn: 0.7165424	test: 0.6761741	best: 0.6761741 (200)	total: 48.6s	remaining: 10m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6740148868
# bestIteration = 287
#
# Shrink model to first 288 iterations.
# CV Log Loss Score: 0.674015
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0786182	test: 1.0786201	best: 1.0786201 (0)	total: 14.9ms	remaining: 41.6s
# 200:	learn: 0.7141142	test: 0.6785642	best: 0.6785642 (200)	total: 1m 26s	remaining: 18m 44s
# 400:	learn: 0.6800000	test: 0.6736425	best: 0.6736425 (400)	total: 10m 35s	remaining: 1h 3m 24s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6736424713
# bestIteration = 400
#
# Shrink model to first 401 iterations.
# CV Log Loss Score: 0.673642
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0786182	test: 1.0786201	best: 1.0786201 (0)	total: 18.1ms	remaining: 50.6s
# 200:	learn: 0.7144022	test: 0.6700031	best: 0.6700031 (200)	total: 1m 10s	remaining: 15m 14s
# 400:	learn: 0.6812142	test: 0.6632740	best: 0.6632740 (400)	total: 10m 14s	remaining: 1h 1m 18s
# 600:	learn: 0.6400872	test: 0.6635168	best: 0.6627217 (513)	total: 22m 58s	remaining: 1h 24m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6627216719
# bestIteration = 513
#
# Shrink model to first 514 iterations.
# CV Log Loss Score: 0.662722
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0786182	test: 1.0786201	best: 1.0786201 (0)	total: 17.6ms	remaining: 49.1s
# 200:	learn: 0.7157795	test: 0.6682626	best: 0.6682626 (200)	total: 1m 22s	remaining: 17m 41s
# 400:	learn: 0.6794466	test: 0.6614717	best: 0.6614226 (395)	total: 10m 37s	remaining: 1h 3m 33s
# 600:	learn: 0.6369395	test: 0.6602522	best: 0.6602522 (600)	total: 23m 13s	remaining: 1h 24m 58s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6600278818
# bestIteration = 635
#
# Shrink model to first 636 iterations.
# CV Log Loss Score: 0.660028
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0786227	test: 1.0786013	best: 1.0786013 (0)	total: 15.5ms	remaining: 43.4s
# 200:	learn: 0.7166922	test: 0.6622024	best: 0.6622024 (200)	total: 1m 11s	remaining: 15m 35s
# 400:	learn: 0.6843893	test: 0.6562672	best: 0.6562625 (396)	total: 9m 51s	remaining: 59m 4s
# 600:	learn: 0.6432513	test: 0.6554966	best: 0.6554678 (599)	total: 22m 12s	remaining: 1h 21m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6551475492
# bestIteration = 681
#
# Shrink model to first 682 iterations.
# CV Log Loss Score: 0.655148
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0786227	test: 1.0786013	best: 1.0786013 (0)	total: 19.3ms	remaining: 54s
# 200:	learn: 0.7146763	test: 0.6671455	best: 0.6671455 (200)	total: 1m 9s	remaining: 14m 55s
# 400:	learn: 0.6802122	test: 0.6627441	best: 0.6626507 (369)	total: 10m 27s	remaining: 1h 2m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.66260681
# bestIteration = 424
#
# Shrink model to first 425 iterations.
# CV Log Loss Score: 0.662607
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0786169	test: 1.0786254	best: 1.0786254 (0)	total: 16.8ms	remaining: 47.1s
# 200:	learn: 0.7152476	test: 0.6742239	best: 0.6742239 (200)	total: 40.2s	remaining: 8m 40s
# 400:	learn: 0.6805329	test: 0.6694188	best: 0.6692702 (383)	total: 9m 13s	remaining: 55m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6692702356
# bestIteration = 383
#
# Shrink model to first 384 iterations.
# CV Log Loss Score: 0.669270
# 	Log Loss: 0.663995
# [I 2021-07-03 00:44:42,227] Trial 2 finished with value: 0.6639945627098333 and parameters: {'learning_rate': 0.04584559511181218, 'n_estimators': 2800, 'colsample_bylevel': 0.1520317824979879, 'depth': 14, 'subsample': 0.7656778309940642}. Best is trial 1 with value: 0.6632438533115634.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0844589	test: 1.0845933	best: 1.0845933 (0)	total: 43.9ms	remaining: 2m 55s
# 200:	learn: 0.7296994	test: 0.6971523	best: 0.6971523 (200)	total: 12.9s	remaining: 4m 3s
# 400:	learn: 0.7152205	test: 0.6762798	best: 0.6762798 (400)	total: 29.7s	remaining: 4m 26s
# 600:	learn: 0.7037180	test: 0.6710524	best: 0.6710453 (599)	total: 1m 3s	remaining: 6m 1s
# 800:	learn: 0.6907081	test: 0.6692389	best: 0.6692389 (800)	total: 1m 50s	remaining: 7m 21s
# 1000:	learn: 0.6769572	test: 0.6686394	best: 0.6685981 (997)	total: 2m 37s	remaining: 7m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6685981236
# bestIteration = 997
#
# Shrink model to first 998 iterations.
# CV Log Loss Score: 0.668598
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0877939	test: 1.0877949	best: 1.0877949 (0)	total: 15.7ms	remaining: 1m 2s
# 200:	learn: 0.7257060	test: 0.6836719	best: 0.6836719 (200)	total: 16.7s	remaining: 5m 15s
# 400:	learn: 0.7141943	test: 0.6705419	best: 0.6705419 (400)	total: 34.7s	remaining: 5m 11s
# 600:	learn: 0.7023269	test: 0.6663947	best: 0.6663700 (599)	total: 1m 12s	remaining: 6m 51s
# 800:	learn: 0.6875826	test: 0.6661497	best: 0.6660067 (777)	total: 2m 1s	remaining: 8m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6659930414
# bestIteration = 854
#
# Shrink model to first 855 iterations.
# CV Log Loss Score: 0.665993
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0877939	test: 1.0877949	best: 1.0877949 (0)	total: 18.8ms	remaining: 1m 15s
# 200:	learn: 0.7286149	test: 0.6723156	best: 0.6723156 (200)	total: 16.2s	remaining: 5m 6s
# 400:	learn: 0.7166679	test: 0.6557596	best: 0.6557557 (398)	total: 30.4s	remaining: 4m 32s
# 600:	learn: 0.7041650	test: 0.6502169	best: 0.6501787 (598)	total: 1m 7s	remaining: 6m 22s
# 800:	learn: 0.6909446	test: 0.6489714	best: 0.6489383 (764)	total: 1m 54s	remaining: 7m 39s
# 1000:	learn: 0.6776249	test: 0.6486928	best: 0.6486487 (952)	total: 2m 43s	remaining: 8m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6484395138
# bestIteration = 1067
#
# Shrink model to first 1068 iterations.
# CV Log Loss Score: 0.648440
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0877939	test: 1.0877949	best: 1.0877949 (0)	total: 17.3ms	remaining: 1m 9s
# 200:	learn: 0.7298509	test: 0.6901267	best: 0.6901267 (200)	total: 13.9s	remaining: 4m 22s
# 400:	learn: 0.7162421	test: 0.6756514	best: 0.6756514 (400)	total: 28.3s	remaining: 4m 14s
# 600:	learn: 0.7030877	test: 0.6732102	best: 0.6731551 (573)	total: 1m 5s	remaining: 6m 12s
# 800:	learn: 0.6889812	test: 0.6731215	best: 0.6728909 (749)	total: 1m 52s	remaining: 7m 27s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6728909135
# bestIteration = 749
#
# Shrink model to first 750 iterations.
# CV Log Loss Score: 0.672891
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0877939	test: 1.0877949	best: 1.0877949 (0)	total: 19.2ms	remaining: 1m 16s
# 200:	learn: 0.7253081	test: 0.6919527	best: 0.6919527 (200)	total: 15.7s	remaining: 4m 57s
# 400:	learn: 0.7128183	test: 0.6766486	best: 0.6766486 (400)	total: 33.5s	remaining: 5m
# 600:	learn: 0.7003194	test: 0.6733268	best: 0.6733268 (600)	total: 1m 10s	remaining: 6m 38s
# 800:	learn: 0.6864422	test: 0.6726104	best: 0.6725334 (792)	total: 1m 56s	remaining: 7m 45s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6724583917
# bestIteration = 864
#
# Shrink model to first 865 iterations.
# CV Log Loss Score: 0.672458
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0877939	test: 1.0877949	best: 1.0877949 (0)	total: 15ms	remaining: 1m
# 200:	learn: 0.7264007	test: 0.6863959	best: 0.6863959 (200)	total: 15.8s	remaining: 4m 58s
# 400:	learn: 0.7153726	test: 0.6706095	best: 0.6706095 (400)	total: 32.1s	remaining: 4m 48s
# 600:	learn: 0.7031501	test: 0.6655340	best: 0.6655295 (598)	total: 1m 8s	remaining: 6m 26s
# 800:	learn: 0.6897017	test: 0.6638913	best: 0.6638619 (798)	total: 1m 54s	remaining: 7m 37s
# 1000:	learn: 0.6753780	test: 0.6637087	best: 0.6634951 (941)	total: 2m 42s	remaining: 8m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6634732551
# bestIteration = 1025
#
# Shrink model to first 1026 iterations.
# CV Log Loss Score: 0.663473
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0877939	test: 1.0877949	best: 1.0877949 (0)	total: 16.2ms	remaining: 1m 4s
# 200:	learn: 0.7270543	test: 0.6801965	best: 0.6801965 (200)	total: 15.5s	remaining: 4m 52s
# 400:	learn: 0.7165474	test: 0.6667055	best: 0.6667055 (400)	total: 30.3s	remaining: 4m 31s
# 600:	learn: 0.7051187	test: 0.6615351	best: 0.6615351 (600)	total: 1m 3s	remaining: 5m 57s
# 800:	learn: 0.6909975	test: 0.6603815	best: 0.6603327 (787)	total: 1m 53s	remaining: 7m 32s
# 1000:	learn: 0.6768896	test: 0.6591086	best: 0.6591086 (1000)	total: 2m 43s	remaining: 8m 9s
# 1200:	learn: 0.6635906	test: 0.6584070	best: 0.6583405 (1185)	total: 3m 33s	remaining: 8m 17s
# 1400:	learn: 0.6511154	test: 0.6582081	best: 0.6581824 (1397)	total: 4m 22s	remaining: 8m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6581253024
# bestIteration = 1446
#
# Shrink model to first 1447 iterations.
# CV Log Loss Score: 0.658125
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0877964	test: 1.0877849	best: 1.0877849 (0)	total: 16.2ms	remaining: 1m 4s
# 200:	learn: 0.7271957	test: 0.6765798	best: 0.6765798 (200)	total: 16.6s	remaining: 5m 14s
# 400:	learn: 0.7162105	test: 0.6620062	best: 0.6620062 (400)	total: 33.4s	remaining: 4m 59s
# 600:	learn: 0.7046063	test: 0.6572435	best: 0.6572435 (600)	total: 1m 10s	remaining: 6m 39s
# 800:	learn: 0.6904924	test: 0.6556234	best: 0.6555770 (786)	total: 2m 1s	remaining: 8m 5s
# 1000:	learn: 0.6768184	test: 0.6550268	best: 0.6550251 (992)	total: 2m 51s	remaining: 8m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6548670016
# bestIteration = 1087
#
# Shrink model to first 1088 iterations.
# CV Log Loss Score: 0.654867
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0877964	test: 1.0877849	best: 1.0877849 (0)	total: 15.2ms	remaining: 1m
# 200:	learn: 0.7264146	test: 0.6836712	best: 0.6836712 (200)	total: 17.7s	remaining: 5m 35s
# 400:	learn: 0.7153820	test: 0.6701013	best: 0.6701013 (400)	total: 33.2s	remaining: 4m 57s
# 600:	learn: 0.7026228	test: 0.6661184	best: 0.6660408 (598)	total: 1m 9s	remaining: 6m 34s
# 800:	learn: 0.6887907	test: 0.6648820	best: 0.6648622 (797)	total: 2m	remaining: 8m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6648621706
# bestIteration = 797
#
# Shrink model to first 798 iterations.
# CV Log Loss Score: 0.664862
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0877932	test: 1.0877978	best: 1.0877978 (0)	total: 18.7ms	remaining: 1m 14s
# 200:	learn: 0.7258813	test: 0.6855319	best: 0.6855319 (200)	total: 16.5s	remaining: 5m 11s
# 400:	learn: 0.7145649	test: 0.6740702	best: 0.6740702 (400)	total: 33.8s	remaining: 5m 3s
# 600:	learn: 0.7027649	test: 0.6715185	best: 0.6715185 (600)	total: 1m 11s	remaining: 6m 46s
# 800:	learn: 0.6876566	test: 0.6705037	best: 0.6704920 (797)	total: 2m 2s	remaining: 8m 8s
# 1000:	learn: 0.6739100	test: 0.6705335	best: 0.6702683 (929)	total: 2m 52s	remaining: 8m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6702682587
# bestIteration = 929
#
# Shrink model to first 930 iterations.
# CV Log Loss Score: 0.670268
# 	Log Loss: 0.663998
# [I 2021-07-03 01:15:47,173] Trial 3 finished with value: 0.6639977711672321 and parameters: {'learning_rate': 0.02453624129303724, 'n_estimators': 4000, 'colsample_bylevel': 0.13676286509209967, 'depth': 10, 'subsample': 0.7488677185797978}. Best is trial 1 with value: 0.6632438533115634.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0841606	test: 1.0831682	best: 1.0831682 (0)	total: 79ms	remaining: 4m 12s
# 200:	learn: 0.7739087	test: 0.7616944	best: 0.7616944 (200)	total: 5.34s	remaining: 1m 19s
# 400:	learn: 0.7341658	test: 0.7071927	best: 0.7071927 (400)	total: 11.1s	remaining: 1m 17s
# 600:	learn: 0.7201499	test: 0.6867183	best: 0.6867183 (600)	total: 17.6s	remaining: 1m 16s
# 800:	learn: 0.7110207	test: 0.6763956	best: 0.6763875 (799)	total: 27.7s	remaining: 1m 23s
# 1000:	learn: 0.7045286	test: 0.6736067	best: 0.6736067 (1000)	total: 37.7s	remaining: 1m 22s
# 1200:	learn: 0.6988315	test: 0.6717631	best: 0.6717631 (1200)	total: 47.6s	remaining: 1m 19s
# 1400:	learn: 0.6935114	test: 0.6708175	best: 0.6708175 (1400)	total: 57.2s	remaining: 1m 13s
# 1600:	learn: 0.6883018	test: 0.6700811	best: 0.6700705 (1588)	total: 1m 6s	remaining: 1m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6697506624
# bestIteration = 1674
#
# Shrink model to first 1675 iterations.
# CV Log Loss Score: 0.669751
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0866706	test: 1.0860197	best: 1.0860197 (0)	total: 44.5ms	remaining: 2m 22s
# 200:	learn: 0.7596667	test: 0.7329477	best: 0.7329477 (200)	total: 6.7s	remaining: 1m 39s
# 400:	learn: 0.7295913	test: 0.6935213	best: 0.6935212 (399)	total: 13s	remaining: 1m 30s
# 600:	learn: 0.7173816	test: 0.6778213	best: 0.6778213 (600)	total: 19.5s	remaining: 1m 24s
# 800:	learn: 0.7090737	test: 0.6710026	best: 0.6710026 (800)	total: 30.2s	remaining: 1m 30s
# 1000:	learn: 0.7030262	test: 0.6690521	best: 0.6690483 (999)	total: 39.6s	remaining: 1m 27s
# 1200:	learn: 0.6975009	test: 0.6682304	best: 0.6682304 (1200)	total: 49.3s	remaining: 1m 22s
# 1400:	learn: 0.6919936	test: 0.6675916	best: 0.6675916 (1400)	total: 59.5s	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6674551201
# bestIteration = 1457
#
# Shrink model to first 1458 iterations.
# CV Log Loss Score: 0.667455
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0867336	test: 1.0853843	best: 1.0853843 (0)	total: 41.1ms	remaining: 2m 11s
# 200:	learn: 0.7669975	test: 0.7326195	best: 0.7326048 (199)	total: 5.96s	remaining: 1m 28s
# 400:	learn: 0.7335302	test: 0.6838289	best: 0.6838289 (400)	total: 12.2s	remaining: 1m 25s
# 600:	learn: 0.7195354	test: 0.6632748	best: 0.6632748 (600)	total: 18.3s	remaining: 1m 19s
# 800:	learn: 0.7107846	test: 0.6552908	best: 0.6552908 (800)	total: 28.3s	remaining: 1m 24s
# 1000:	learn: 0.7044940	test: 0.6527384	best: 0.6526978 (991)	total: 38.2s	remaining: 1m 24s
# 1200:	learn: 0.6984043	test: 0.6512747	best: 0.6512747 (1200)	total: 49.1s	remaining: 1m 21s
# 1400:	learn: 0.6936075	test: 0.6507022	best: 0.6506944 (1397)	total: 58.6s	remaining: 1m 15s
# 1600:	learn: 0.6885619	test: 0.6503340	best: 0.6502666 (1554)	total: 1m 8s	remaining: 1m 8s
# 1800:	learn: 0.6827996	test: 0.6501097	best: 0.6500053 (1741)	total: 1m 19s	remaining: 1m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6500052857
# bestIteration = 1741
#
# Shrink model to first 1742 iterations.
# CV Log Loss Score: 0.650005
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0867338	test: 1.0853891	best: 1.0853891 (0)	total: 39.6ms	remaining: 2m 6s
# 200:	learn: 0.7695921	test: 0.7458197	best: 0.7458197 (200)	total: 6.12s	remaining: 1m 31s
# 400:	learn: 0.7342027	test: 0.7004661	best: 0.7004661 (400)	total: 12.5s	remaining: 1m 27s
# 600:	learn: 0.7197306	test: 0.6831003	best: 0.6831003 (600)	total: 19.8s	remaining: 1m 25s
# 800:	learn: 0.7108464	test: 0.6761330	best: 0.6761330 (800)	total: 29.3s	remaining: 1m 27s
# 1000:	learn: 0.7042311	test: 0.6743357	best: 0.6743357 (1000)	total: 39.7s	remaining: 1m 27s
# 1200:	learn: 0.6984708	test: 0.6736729	best: 0.6736729 (1200)	total: 49.6s	remaining: 1m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6735249789
# bestIteration = 1250
#
# Shrink model to first 1251 iterations.
# CV Log Loss Score: 0.673525
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0865241	test: 1.0853775	best: 1.0853775 (0)	total: 34.6ms	remaining: 1m 50s
# 200:	learn: 0.7618317	test: 0.7422217	best: 0.7422217 (200)	total: 6.21s	remaining: 1m 32s
# 400:	learn: 0.7287406	test: 0.6984785	best: 0.6984785 (400)	total: 13.3s	remaining: 1m 32s
# 600:	learn: 0.7173735	test: 0.6846947	best: 0.6846947 (600)	total: 20.2s	remaining: 1m 27s
# 800:	learn: 0.7086109	test: 0.6769935	best: 0.6769935 (800)	total: 31.3s	remaining: 1m 33s
# 1000:	learn: 0.7025480	test: 0.6750004	best: 0.6749613 (992)	total: 43.4s	remaining: 1m 35s
# 1200:	learn: 0.6970297	test: 0.6740292	best: 0.6740292 (1200)	total: 54.5s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6737881929
# bestIteration = 1266
#
# Shrink model to first 1267 iterations.
# CV Log Loss Score: 0.673788
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0867303	test: 1.0861285	best: 1.0861285 (0)	total: 37.7ms	remaining: 2m
# 200:	learn: 0.7650631	test: 0.7428133	best: 0.7428133 (200)	total: 6.11s	remaining: 1m 31s
# 400:	learn: 0.7303493	test: 0.6949373	best: 0.6949373 (400)	total: 13.4s	remaining: 1m 33s
# 600:	learn: 0.7192381	test: 0.6792846	best: 0.6792846 (600)	total: 20.2s	remaining: 1m 27s
# 800:	learn: 0.7107010	test: 0.6711729	best: 0.6711725 (798)	total: 30.2s	remaining: 1m 30s
# 1000:	learn: 0.7037695	test: 0.6681316	best: 0.6681213 (999)	total: 40.7s	remaining: 1m 29s
# 1200:	learn: 0.6978898	test: 0.6665680	best: 0.6665680 (1200)	total: 50.9s	remaining: 1m 24s
# 1400:	learn: 0.6927419	test: 0.6658819	best: 0.6658683 (1392)	total: 1m	remaining: 1m 17s
# 1600:	learn: 0.6879878	test: 0.6653408	best: 0.6652699 (1573)	total: 1m 10s	remaining: 1m 9s
# 1800:	learn: 0.6825779	test: 0.6650348	best: 0.6650138 (1791)	total: 1m 21s	remaining: 1m 3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6650138094
# bestIteration = 1791
#
# Shrink model to first 1792 iterations.
# CV Log Loss Score: 0.665014
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0866539	test: 1.0852338	best: 1.0852338 (0)	total: 35.3ms	remaining: 1m 52s
# 200:	learn: 0.7654672	test: 0.7402066	best: 0.7402066 (200)	total: 6.32s	remaining: 1m 34s
# 400:	learn: 0.7302979	test: 0.6909173	best: 0.6909173 (400)	total: 13s	remaining: 1m 31s
# 600:	learn: 0.7181455	test: 0.6748745	best: 0.6748637 (598)	total: 20.2s	remaining: 1m 27s
# 800:	learn: 0.7095488	test: 0.6667357	best: 0.6667357 (800)	total: 30.9s	remaining: 1m 32s
# 1000:	learn: 0.7030951	test: 0.6639871	best: 0.6639851 (998)	total: 41.8s	remaining: 1m 31s
# 1200:	learn: 0.6974148	test: 0.6625803	best: 0.6625803 (1200)	total: 53.4s	remaining: 1m 28s
# 1400:	learn: 0.6920649	test: 0.6616171	best: 0.6616167 (1399)	total: 1m 4s	remaining: 1m 22s
# 1600:	learn: 0.6868051	test: 0.6608989	best: 0.6608822 (1564)	total: 1m 14s	remaining: 1m 14s
# 1800:	learn: 0.6817610	test: 0.6604249	best: 0.6604076 (1782)	total: 1m 24s	remaining: 1m 5s
# 2000:	learn: 0.6762696	test: 0.6601638	best: 0.6601638 (2000)	total: 1m 34s	remaining: 56.8s
# 2200:	learn: 0.6709799	test: 0.6599266	best: 0.6598880 (2158)	total: 1m 45s	remaining: 48s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6598879751
# bestIteration = 2158
#
# Shrink model to first 2159 iterations.
# CV Log Loss Score: 0.659888
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0866847	test: 1.0852373	best: 1.0852373 (0)	total: 31.2ms	remaining: 1m 39s
# 200:	learn: 0.7691229	test: 0.7424996	best: 0.7424996 (200)	total: 6.14s	remaining: 1m 31s
# 400:	learn: 0.7328369	test: 0.6892752	best: 0.6892752 (400)	total: 12.4s	remaining: 1m 26s
# 600:	learn: 0.7199873	test: 0.6700990	best: 0.6700990 (600)	total: 19.2s	remaining: 1m 23s
# 800:	learn: 0.7110484	test: 0.6621436	best: 0.6620921 (794)	total: 29.8s	remaining: 1m 29s
# 1000:	learn: 0.7044335	test: 0.6595405	best: 0.6595405 (1000)	total: 40.5s	remaining: 1m 28s
# 1200:	learn: 0.6990458	test: 0.6585053	best: 0.6584854 (1194)	total: 51s	remaining: 1m 24s
# 1400:	learn: 0.6940360	test: 0.6576351	best: 0.6576294 (1395)	total: 1m 1s	remaining: 1m 18s
# 1600:	learn: 0.6887209	test: 0.6572212	best: 0.6571839 (1592)	total: 1m 12s	remaining: 1m 12s
# 1800:	learn: 0.6832141	test: 0.6570232	best: 0.6569570 (1748)	total: 1m 24s	remaining: 1m 5s
# 2000:	learn: 0.6773903	test: 0.6564094	best: 0.6564044 (1993)	total: 1m 35s	remaining: 57.2s
# 2200:	learn: 0.6726372	test: 0.6560558	best: 0.6560558 (2200)	total: 1m 44s	remaining: 47.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6560546337
# bestIteration = 2201
#
# Shrink model to first 2202 iterations.
# CV Log Loss Score: 0.656055
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0867322	test: 1.0854145	best: 1.0854145 (0)	total: 35.3ms	remaining: 1m 52s
# 200:	learn: 0.7601813	test: 0.7374671	best: 0.7374671 (200)	total: 6.08s	remaining: 1m 30s
# 400:	learn: 0.7264321	test: 0.6878609	best: 0.6878608 (398)	total: 13.1s	remaining: 1m 31s
# 600:	learn: 0.7171079	test: 0.6757576	best: 0.6757576 (600)	total: 19.7s	remaining: 1m 25s
# 800:	learn: 0.7089148	test: 0.6692218	best: 0.6692218 (799)	total: 30.4s	remaining: 1m 30s
# 1000:	learn: 0.7024074	test: 0.6669230	best: 0.6668824 (989)	total: 40.4s	remaining: 1m 28s
# 1200:	learn: 0.6968573	test: 0.6658372	best: 0.6658372 (1200)	total: 51s	remaining: 1m 24s
# 1400:	learn: 0.6908976	test: 0.6652756	best: 0.6652540 (1375)	total: 1m 2s	remaining: 1m 19s
# 1600:	learn: 0.6861163	test: 0.6651196	best: 0.6650990 (1588)	total: 1m 12s	remaining: 1m 12s
# 1800:	learn: 0.6807976	test: 0.6648569	best: 0.6648284 (1742)	total: 1m 22s	remaining: 1m 4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6647784978
# bestIteration = 1821
#
# Shrink model to first 1822 iterations.
# CV Log Loss Score: 0.664778
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0865827	test: 1.0857127	best: 1.0857127 (0)	total: 37.4ms	remaining: 1m 59s
# 200:	learn: 0.7606855	test: 0.7349990	best: 0.7349990 (200)	total: 6.77s	remaining: 1m 41s
# 400:	learn: 0.7300546	test: 0.6948744	best: 0.6948744 (400)	total: 13.8s	remaining: 1m 36s
# 600:	learn: 0.7165315	test: 0.6789749	best: 0.6789749 (600)	total: 21.8s	remaining: 1m 34s
# 800:	learn: 0.7074199	test: 0.6734121	best: 0.6734121 (800)	total: 33.9s	remaining: 1m 41s
# 1000:	learn: 0.7015835	test: 0.6722503	best: 0.6722215 (979)	total: 44.8s	remaining: 1m 38s
# 1200:	learn: 0.6955810	test: 0.6714109	best: 0.6713731 (1197)	total: 55.8s	remaining: 1m 32s
# 1400:	learn: 0.6906854	test: 0.6710253	best: 0.6710253 (1400)	total: 1m 6s	remaining: 1m 24s
# 1600:	learn: 0.6850513	test: 0.6705709	best: 0.6705684 (1599)	total: 1m 17s	remaining: 1m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6705062194
# bestIteration = 1641
#
# Shrink model to first 1642 iterations.
# CV Log Loss Score: 0.670506
# 	Log Loss: 0.665077
# [I 2021-07-03 01:29:39,191] Trial 4 finished with value: 0.6650767142580198 and parameters: {'learning_rate': 0.020527943608748836, 'n_estimators': 3200, 'colsample_bylevel': 0.04868443791499869, 'depth': 9, 'subsample': 0.8140018821002764}. Best is trial 1 with value: 0.6632438533115634.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0905520	test: 1.0906522	best: 1.0906522 (0)	total: 24.5ms	remaining: 1m 28s
# 200:	learn: 0.7514199	test: 0.7303350	best: 0.7303350 (200)	total: 30.6s	remaining: 8m 36s
# 400:	learn: 0.7238137	test: 0.6873370	best: 0.6873370 (400)	total: 1m 5s	remaining: 8m 43s
# 600:	learn: 0.7167041	test: 0.6779634	best: 0.6779611 (599)	total: 1m 43s	remaining: 8m 35s
# 800:	learn: 0.7125555	test: 0.6746114	best: 0.6746114 (800)	total: 2m 16s	remaining: 7m 57s
# 1000:	learn: 0.7049373	test: 0.6719652	best: 0.6719652 (1000)	total: 4m 19s	remaining: 11m 14s
# 1200:	learn: 0.6973317	test: 0.6708759	best: 0.6708687 (1198)	total: 7m 9s	remaining: 14m 18s
# 1400:	learn: 0.6891286	test: 0.6698901	best: 0.6698849 (1398)	total: 10m 2s	remaining: 15m 45s
# 1600:	learn: 0.6804185	test: 0.6691630	best: 0.6690983 (1581)	total: 12m 52s	remaining: 16m 4s
# 1800:	learn: 0.6723152	test: 0.6686435	best: 0.6686344 (1798)	total: 15m 45s	remaining: 15m 44s
# 2000:	learn: 0.6640640	test: 0.6683720	best: 0.6683534 (1976)	total: 18m 39s	remaining: 14m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.668019393
# bestIteration = 2094
#
# Shrink model to first 2095 iterations.
# CV Log Loss Score: 0.668019
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0925109	test: 1.0925114	best: 1.0925114 (0)	total: 19.8ms	remaining: 1m 11s
# 200:	learn: 0.7497354	test: 0.7185394	best: 0.7185394 (200)	total: 31.5s	remaining: 8m 53s
# 400:	learn: 0.7233633	test: 0.6794350	best: 0.6794350 (400)	total: 1m 5s	remaining: 8m 46s
# 600:	learn: 0.7165079	test: 0.6711606	best: 0.6711606 (600)	total: 1m 41s	remaining: 8m 26s
# 800:	learn: 0.7123750	test: 0.6678412	best: 0.6678412 (800)	total: 2m 17s	remaining: 7m 59s
# 1000:	learn: 0.7049522	test: 0.6659739	best: 0.6659739 (1000)	total: 4m 21s	remaining: 11m 20s
# 1200:	learn: 0.6955240	test: 0.6657467	best: 0.6657122 (1183)	total: 7m 19s	remaining: 14m 37s
# 1400:	learn: 0.6864664	test: 0.6653820	best: 0.6653510 (1367)	total: 10m 22s	remaining: 16m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6653510465
# bestIteration = 1367
#
# Shrink model to first 1368 iterations.
# CV Log Loss Score: 0.665351
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0925109	test: 1.0925114	best: 1.0925114 (0)	total: 13.2ms	remaining: 47.5s
# 200:	learn: 0.7527132	test: 0.7118650	best: 0.7118650 (200)	total: 36.7s	remaining: 10m 20s
# 400:	learn: 0.7244639	test: 0.6651858	best: 0.6651858 (400)	total: 1m 9s	remaining: 9m 11s
# 600:	learn: 0.7179691	test: 0.6563603	best: 0.6563603 (600)	total: 1m 42s	remaining: 8m 33s
# 800:	learn: 0.7136921	test: 0.6530581	best: 0.6530581 (800)	total: 2m 18s	remaining: 8m 4s
# 1000:	learn: 0.7067425	test: 0.6505473	best: 0.6505410 (999)	total: 4m 12s	remaining: 10m 56s
# 1200:	learn: 0.6969972	test: 0.6492464	best: 0.6492375 (1198)	total: 7m 10s	remaining: 14m 19s
# 1400:	learn: 0.6878077	test: 0.6486282	best: 0.6485967 (1346)	total: 10m 8s	remaining: 15m 55s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6485021853
# bestIteration = 1452
#
# Shrink model to first 1453 iterations.
# CV Log Loss Score: 0.648502
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0925109	test: 1.0925114	best: 1.0925114 (0)	total: 13.3ms	remaining: 47.9s
# 200:	learn: 0.7567697	test: 0.7313593	best: 0.7313593 (200)	total: 33.6s	remaining: 9m 28s
# 400:	learn: 0.7236650	test: 0.6824204	best: 0.6824204 (400)	total: 1m 10s	remaining: 9m 24s
# 600:	learn: 0.7170986	test: 0.6754147	best: 0.6754147 (600)	total: 1m 38s	remaining: 8m 12s
# 800:	learn: 0.7124543	test: 0.6728137	best: 0.6728137 (800)	total: 2m 10s	remaining: 7m 34s
# 1000:	learn: 0.7045798	test: 0.6717719	best: 0.6717581 (999)	total: 4m 12s	remaining: 10m 55s
# 1200:	learn: 0.6958221	test: 0.6715662	best: 0.6715193 (1140)	total: 7m 16s	remaining: 14m 32s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6715193095
# bestIteration = 1140
#
# Shrink model to first 1141 iterations.
# CV Log Loss Score: 0.671519
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0925109	test: 1.0925114	best: 1.0925114 (0)	total: 15.1ms	remaining: 54.3s
# 200:	learn: 0.7499062	test: 0.7267971	best: 0.7267971 (200)	total: 35.8s	remaining: 10m 6s
# 400:	learn: 0.7220365	test: 0.6860762	best: 0.6860762 (400)	total: 1m 7s	remaining: 9m 1s
# 600:	learn: 0.7151784	test: 0.6778337	best: 0.6778337 (600)	total: 1m 44s	remaining: 8m 41s
# 800:	learn: 0.7110702	test: 0.6743611	best: 0.6743611 (800)	total: 2m 18s	remaining: 8m 3s
# 1000:	learn: 0.7038570	test: 0.6721224	best: 0.6721224 (1000)	total: 4m 26s	remaining: 11m 31s
# 1200:	learn: 0.6944599	test: 0.6716814	best: 0.6716268 (1165)	total: 7m 33s	remaining: 15m 5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6716214553
# bestIteration = 1242
#
# Shrink model to first 1243 iterations.
# CV Log Loss Score: 0.671621
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0925109	test: 1.0925114	best: 1.0925114 (0)	total: 19.8ms	remaining: 1m 11s
# 200:	learn: 0.7511272	test: 0.7249134	best: 0.7249134 (200)	total: 37.4s	remaining: 10m 32s
# 400:	learn: 0.7228431	test: 0.6808318	best: 0.6808301 (398)	total: 1m 17s	remaining: 10m 17s
# 600:	learn: 0.7168941	test: 0.6724533	best: 0.6724533 (600)	total: 1m 43s	remaining: 8m 37s
# 800:	learn: 0.7128139	test: 0.6685128	best: 0.6685128 (800)	total: 2m 20s	remaining: 8m 11s
# 1000:	learn: 0.7051184	test: 0.6659542	best: 0.6659455 (999)	total: 4m 28s	remaining: 11m 36s
# 1200:	learn: 0.6954870	test: 0.6648452	best: 0.6648452 (1200)	total: 7m 33s	remaining: 15m 5s
# 1400:	learn: 0.6875076	test: 0.6641276	best: 0.6640958 (1393)	total: 10m 35s	remaining: 16m 37s
# 1600:	learn: 0.6788581	test: 0.6638190	best: 0.6638083 (1595)	total: 13m 38s	remaining: 17m 2s
# 1800:	learn: 0.6703620	test: 0.6636427	best: 0.6636247 (1798)	total: 16m 40s	remaining: 16m 39s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6636246767
# bestIteration = 1798
#
# Shrink model to first 1799 iterations.
# CV Log Loss Score: 0.663625
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0925109	test: 1.0925114	best: 1.0925114 (0)	total: 17.5ms	remaining: 1m 2s
# 200:	learn: 0.7495271	test: 0.7159837	best: 0.7159837 (200)	total: 38.3s	remaining: 10m 47s
# 400:	learn: 0.7265552	test: 0.6801529	best: 0.6801529 (400)	total: 58.8s	remaining: 7m 48s
# 600:	learn: 0.7191790	test: 0.6688063	best: 0.6688063 (600)	total: 1m 26s	remaining: 7m 12s
# 800:	learn: 0.7145223	test: 0.6648675	best: 0.6648675 (800)	total: 2m 11s	remaining: 7m 38s
# 1000:	learn: 0.7070647	test: 0.6621277	best: 0.6621277 (1000)	total: 4m 15s	remaining: 11m 3s
# 1200:	learn: 0.6981719	test: 0.6611955	best: 0.6611955 (1200)	total: 7m 23s	remaining: 14m 46s
# 1400:	learn: 0.6889377	test: 0.6604742	best: 0.6604462 (1382)	total: 10m 39s	remaining: 16m 44s
# ...
# 800:	learn: 0.7096803	test: 0.6753661	best: 0.6753661 (800)	total: 3m 58s	remaining: 14m 52s
# 1000:	learn: 0.6992213	test: 0.6733963	best: 0.6733963 (1000)	total: 8m 45s	remaining: 24m 29s
# 1200:	learn: 0.6870457	test: 0.6731111	best: 0.6730287 (1172)	total: 14m 54s	remaining: 32m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6730286555
# bestIteration = 1172
#
# Shrink model to first 1173 iterations.
# CV Log Loss Score: 0.673029
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0924508	test: 1.0924514	best: 1.0924514 (0)	total: 16.9ms	remaining: 1m 4s
# 200:	learn: 0.7520890	test: 0.7253315	best: 0.7253315 (200)	total: 46s	remaining: 13m 43s
# 400:	learn: 0.7242050	test: 0.6825548	best: 0.6825548 (400)	total: 1m 38s	remaining: 13m 53s
# 600:	learn: 0.7175025	test: 0.6736461	best: 0.6736461 (600)	total: 2m 37s	remaining: 13m 59s
# 800:	learn: 0.7125907	test: 0.6692950	best: 0.6692950 (800)	total: 3m 39s	remaining: 13m 42s
# 1000:	learn: 0.7029324	test: 0.6664140	best: 0.6664140 (1000)	total: 7m 45s	remaining: 21m 41s
# 1200:	learn: 0.6902541	test: 0.6651627	best: 0.6651482 (1195)	total: 13m 58s	remaining: 30m 13s
# 1400:	learn: 0.6778817	test: 0.6644431	best: 0.6644257 (1363)	total: 20m 5s	remaining: 34m 24s
# 1600:	learn: 0.6653199	test: 0.6639498	best: 0.6639498 (1600)	total: 26m 18s	remaining: 36m 8s
# 1800:	learn: 0.6528613	test: 0.6635755	best: 0.6635455 (1749)	total: 32m 29s	remaining: 36m 4s
# 2000:	learn: 0.6405436	test: 0.6633663	best: 0.6632496 (1972)	total: 38m 34s	remaining: 34m 40s
# 2200:	learn: 0.6282917	test: 0.6632195	best: 0.6631431 (2123)	total: 44m 46s	remaining: 32m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6631431208
# bestIteration = 2123
#
# Shrink model to first 2124 iterations.
# CV Log Loss Score: 0.663143
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0924508	test: 1.0924514	best: 1.0924514 (0)	total: 16.5ms	remaining: 1m 2s
# 200:	learn: 0.7479495	test: 0.7137105	best: 0.7137105 (200)	total: 42.4s	remaining: 12m 39s
# 400:	learn: 0.7242890	test: 0.6760478	best: 0.6760478 (400)	total: 1m 29s	remaining: 12m 40s
# 600:	learn: 0.7181549	test: 0.6685997	best: 0.6685997 (600)	total: 2m 24s	remaining: 12m 47s
# 800:	learn: 0.7135560	test: 0.6650713	best: 0.6650713 (800)	total: 3m 14s	remaining: 12m 7s
# 1000:	learn: 0.7038340	test: 0.6626713	best: 0.6626659 (997)	total: 7m 22s	remaining: 20m 36s
# 1200:	learn: 0.6906948	test: 0.6614419	best: 0.6614413 (1199)	total: 13m 11s	remaining: 28m 33s
# 1400:	learn: 0.6787269	test: 0.6607035	best: 0.6606998 (1396)	total: 19m 5s	remaining: 32m 42s
# 1600:	learn: 0.6664476	test: 0.6600555	best: 0.6600555 (1600)	total: 25m 1s	remaining: 34m 22s
# 1800:	learn: 0.6537744	test: 0.6595852	best: 0.6595293 (1772)	total: 30m 56s	remaining: 34m 21s
# 2000:	learn: 0.6417954	test: 0.6594186	best: 0.6593501 (1951)	total: 36m 57s	remaining: 33m 14s
# 2200:	learn: 0.6298078	test: 0.6591138	best: 0.6590949 (2198)	total: 42m 57s	remaining: 31m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6590146545
# bestIteration = 2259
#
# Shrink model to first 2260 iterations.
# CV Log Loss Score: 0.659015
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0924522	test: 1.0924457	best: 1.0924457 (0)	total: 16.1ms	remaining: 1m 1s
# 200:	learn: 0.7541583	test: 0.7198857	best: 0.7198857 (200)	total: 57.6s	remaining: 17m 11s
# 400:	learn: 0.7245391	test: 0.6716763	best: 0.6716763 (400)	total: 2m 1s	remaining: 17m 13s
# 600:	learn: 0.7179716	test: 0.6638282	best: 0.6638273 (599)	total: 2m 55s	remaining: 15m 35s
# 800:	learn: 0.7131124	test: 0.6601159	best: 0.6601159 (800)	total: 3m 54s	remaining: 14m 36s
# 1000:	learn: 0.7033356	test: 0.6572474	best: 0.6572384 (999)	total: 8m 26s	remaining: 23m 35s
# 1200:	learn: 0.6910058	test: 0.6559177	best: 0.6559058 (1199)	total: 14m 31s	remaining: 31m 26s
# 1400:	learn: 0.6787418	test: 0.6552298	best: 0.6551901 (1390)	total: 20m 39s	remaining: 35m 22s
# 1600:	learn: 0.6669319	test: 0.6548349	best: 0.6547737 (1579)	total: 26m 39s	remaining: 36m 37s
# 1800:	learn: 0.6541449	test: 0.6542945	best: 0.6542346 (1770)	total: 32m 46s	remaining: 36m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6541081674
# bestIteration = 1836
#
# Shrink model to first 1837 iterations.
# CV Log Loss Score: 0.654108
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0924522	test: 1.0924457	best: 1.0924457 (0)	total: 20.5ms	remaining: 1m 17s
# 200:	learn: 0.7488921	test: 0.7187828	best: 0.7187828 (200)	total: 55.3s	remaining: 16m 30s
# 400:	learn: 0.7233248	test: 0.6790202	best: 0.6790202 (400)	total: 1m 48s	remaining: 15m 15s
# 600:	learn: 0.7164598	test: 0.6713517	best: 0.6713488 (599)	total: 2m 51s	remaining: 15m 12s
# 800:	learn: 0.7118224	test: 0.6678998	best: 0.6678984 (799)	total: 3m 41s	remaining: 13m 48s
# 1000:	learn: 0.7011491	test: 0.6656022	best: 0.6656022 (1000)	total: 8m 12s	remaining: 22m 55s
# 1200:	learn: 0.6883661	test: 0.6647784	best: 0.6647388 (1180)	total: 14m 16s	remaining: 30m 53s
# 1400:	learn: 0.6760027	test: 0.6644524	best: 0.6644452 (1394)	total: 20m 21s	remaining: 34m 52s
# 1600:	learn: 0.6638830	test: 0.6643591	best: 0.6643107 (1501)	total: 26m 35s	remaining: 36m 31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6643107319
# bestIteration = 1501
#
# Shrink model to first 1502 iterations.
# CV Log Loss Score: 0.664311
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0924504	test: 1.0924530	best: 1.0924530 (0)	total: 17.6ms	remaining: 1m 7s
# 200:	learn: 0.7502069	test: 0.7212612	best: 0.7212612 (200)	total: 53.1s	remaining: 15m 50s
# 400:	learn: 0.7219158	test: 0.6807734	best: 0.6807734 (400)	total: 1m 59s	remaining: 16m 53s
# 600:	learn: 0.7153820	test: 0.6749337	best: 0.6749337 (600)	total: 3m 1s	remaining: 16m 3s
# 800:	learn: 0.7106098	test: 0.6724628	best: 0.6724628 (800)	total: 3m 59s	remaining: 14m 58s
# 1000:	learn: 0.7001483	test: 0.6706198	best: 0.6705900 (995)	total: 8m 15s	remaining: 23m 6s
# 1200:	learn: 0.6877865	test: 0.6702315	best: 0.6702174 (1198)	total: 14m 36s	remaining: 31m 37s
# 1400:	learn: 0.6754466	test: 0.6700631	best: 0.6699509 (1366)	total: 20m 47s	remaining: 35m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6699509083
# bestIteration = 1366
#
# Shrink model to first 1367 iterations.
# CV Log Loss Score: 0.669951
# 	Log Loss: 0.664056
# [I 2021-07-03 09:20:03,219] Trial 6 finished with value: 0.6640555483994822 and parameters: {'learning_rate': 0.013899125455788797, 'n_estimators': 3800, 'colsample_bylevel': 0.14597647373878633, 'depth': 13, 'subsample': 0.6155963751132121}. Best is trial 1 with value: 0.6632438533115634.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0844141	test: 1.0840614	best: 1.0840614 (0)	total: 21.2ms	remaining: 1m 33s
# 200:	learn: 0.7556721	test: 0.7373189	best: 0.7373189 (200)	total: 15.2s	remaining: 5m 17s
# 400:	learn: 0.7239786	test: 0.6933758	best: 0.6933715 (397)	total: 40.1s	remaining: 6m 39s
# 600:	learn: 0.7065604	test: 0.6752758	best: 0.6752757 (599)	total: 2m 21s	remaining: 14m 57s
# 800:	learn: 0.6938500	test: 0.6715620	best: 0.6715603 (799)	total: 5m 6s	remaining: 22m 57s
# 1000:	learn: 0.6805577	test: 0.6702233	best: 0.6702233 (1000)	total: 7m 44s	remaining: 26m 18s
# 1200:	learn: 0.6687099	test: 0.6689486	best: 0.6689486 (1200)	total: 10m 19s	remaining: 27m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6688034163
# bestIteration = 1287
#
# Shrink model to first 1288 iterations.
# CV Log Loss Score: 0.668803
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0831369	test: 1.0824593	best: 1.0824593 (0)	total: 19.5ms	remaining: 1m 25s
# 200:	learn: 0.7530384	test: 0.7261235	best: 0.7261235 (200)	total: 27s	remaining: 9m 24s
# 400:	learn: 0.7208836	test: 0.6851065	best: 0.6851065 (400)	total: 57.9s	remaining: 9m 37s
# 600:	learn: 0.7060194	test: 0.6723288	best: 0.6723277 (598)	total: 2m 44s	remaining: 17m 21s
# 800:	learn: 0.6919676	test: 0.6689991	best: 0.6689991 (800)	total: 5m 23s	remaining: 24m 12s
# 1000:	learn: 0.6799983	test: 0.6678881	best: 0.6678623 (989)	total: 7m 57s	remaining: 27m 1s
# 1200:	learn: 0.6670387	test: 0.6672488	best: 0.6671814 (1105)	total: 10m 59s	remaining: 29m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6671814136
# bestIteration = 1105
#
# Shrink model to first 1106 iterations.
# CV Log Loss Score: 0.667181
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0831722	test: 1.0816154	best: 1.0816154 (0)	total: 22.4ms	remaining: 1m 38s
# 200:	learn: 0.7607448	test: 0.7246387	best: 0.7246387 (200)	total: 13.1s	remaining: 4m 33s
# 400:	learn: 0.7242982	test: 0.6706056	best: 0.6705717 (398)	total: 53.5s	remaining: 8m 54s
# 600:	learn: 0.7073161	test: 0.6559985	best: 0.6559985 (600)	total: 2m 26s	remaining: 15m 26s
# 800:	learn: 0.6944457	test: 0.6520183	best: 0.6520165 (798)	total: 4m 53s	remaining: 21m 57s
# 1000:	learn: 0.6804217	test: 0.6503714	best: 0.6503372 (997)	total: 7m 43s	remaining: 26m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6501493571
# bestIteration = 1082
#
# Shrink model to first 1083 iterations.
# CV Log Loss Score: 0.650149
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0831753	test: 1.0816513	best: 1.0816513 (0)	total: 18.2ms	remaining: 1m 20s
# 200:	learn: 0.7490277	test: 0.7208367	best: 0.7208178 (199)	total: 25.2s	remaining: 8m 46s
# 400:	learn: 0.7207015	test: 0.6850674	best: 0.6850674 (400)	total: 54s	remaining: 8m 58s
# 600:	learn: 0.7045275	test: 0.6765368	best: 0.6765368 (600)	total: 2m 54s	remaining: 18m 22s
# 800:	learn: 0.6909263	test: 0.6748399	best: 0.6748399 (800)	total: 5m 30s	remaining: 24m 47s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6746858318
# bestIteration = 852
#
# Shrink model to first 853 iterations.
# CV Log Loss Score: 0.674686
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0831214	test: 1.0824454	best: 1.0824454 (0)	total: 16.7ms	remaining: 1m 13s
# 200:	learn: 0.7489731	test: 0.7276175	best: 0.7276175 (200)	total: 20.6s	remaining: 7m 11s
# 400:	learn: 0.7193540	test: 0.6883984	best: 0.6883984 (400)	total: 57.4s	remaining: 9m 32s
# 600:	learn: 0.7030726	test: 0.6762553	best: 0.6762518 (599)	total: 2m 52s	remaining: 18m 9s
# 800:	learn: 0.6896136	test: 0.6734369	best: 0.6733778 (794)	total: 5m 26s	remaining: 24m 24s
# 1000:	learn: 0.6751968	test: 0.6727755	best: 0.6726397 (951)	total: 8m 47s	remaining: 29m 50s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6726397018
# bestIteration = 951
#
# Shrink model to first 952 iterations.
# CV Log Loss Score: 0.672640
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0831745	test: 1.0826262	best: 1.0826262 (0)	total: 18ms	remaining: 1m 19s
# 200:	learn: 0.7514717	test: 0.7245097	best: 0.7245097 (200)	total: 15.2s	remaining: 5m 21s
# 400:	learn: 0.7211579	test: 0.6838806	best: 0.6838806 (400)	total: 43.1s	remaining: 7m 12s
# 600:	learn: 0.7049214	test: 0.6709118	best: 0.6709118 (600)	total: 2m 49s	remaining: 17m 56s
# 800:	learn: 0.6897626	test: 0.6678230	best: 0.6678230 (800)	total: 6m	remaining: 27m 2s
# 1000:	learn: 0.6779976	test: 0.6665850	best: 0.6665816 (999)	total: 8m 34s	remaining: 29m 10s
# 1200:	learn: 0.6682460	test: 0.6659898	best: 0.6659397 (1193)	total: 11m 11s	remaining: 29m 50s
# 1400:	learn: 0.6570895	test: 0.6658977	best: 0.6656420 (1356)	total: 13m 48s	remaining: 29m 36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6656419722
# bestIteration = 1356
#
# Shrink model to first 1357 iterations.
# CV Log Loss Score: 0.665642
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0831232	test: 1.0813590	best: 1.0813590 (0)	total: 24.6ms	remaining: 1m 48s
# 200:	learn: 0.7617469	test: 0.7361860	best: 0.7361860 (200)	total: 12.9s	remaining: 4m 31s
# 400:	learn: 0.7226883	test: 0.6799621	best: 0.6799621 (400)	total: 45.5s	remaining: 7m 34s
# 600:	learn: 0.7065113	test: 0.6662982	best: 0.6662982 (599)	total: 2m 33s	remaining: 16m 9s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-446c96ede7d2> in <module>
#       1 study_make_model_params = optuna.create_study(direction="minimize")
# ----> 2 study_make_model_params.optimize(objective)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     399             )
#     400
# --> 401         _optimize(
#     402             study=self,
#     403             func=func,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      63     try:
#      64         if n_jobs == 1:
# ---> 65             _optimize_sequential(
#      66                 study,
#      67                 func,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160
#     161         try:
# --> 162             trial = _run_trial(study, func, catch)
#     163         except Exception:
#     164             raise
#
# ~/opt/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _run_trial(study, func, catch)
#     214
#     215     try:
# --> 216         value_or_values = func(trial)
#     217     except exceptions.TrialPruned as e:
#     218         # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-35-6bfc68759ae7> in objective(trial)
#      43                                        boosting_type = 'Ordered',
#      44                                        bootstrap_type = 'Bernoulli')
# ---> 45         model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=200)
#      46
#      47         model_folds.append(model_cat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    4671             CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
#    4672
# -> 4673         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4674                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
#    4675                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    1992         with log_fixup(log_cout, log_cerr), \
#    1993             plot_wrapper(plot, [_get_train_dir(self.get_params())]):
# -> 1994             self._train(
#    1995                 train_pool,
#    1996                 train_params["eval_sets"],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1423
#    1424     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1425         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1426         self._set_trained_model_attributes()
#    1427
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
# with income occyp
study_make_model_params.best_params
# Out:
# {'learning_rate': 0.0350892739150892,
#  'n_estimators': 3000,
#  'colsample_bylevel': 0.15459010974413953,
#  'depth': 12,
#  'subsample': 0.9430980234284306}

# %%
# last trial
study_make_model_params.best_params
# Out:
# {'learning_rate': 0.060083450692291644,
#  'n_estimators': 2400,
#  'colsample_bylevel': 0.08168811223160533,
#  'depth': 12,
#  'boosting_type': 'Ordered',
#  'bootstrap_type': 'Bernoulli',
#  'subsample': 0.5557203853197957}

# %%
study_make_model_params.best_params
# Out:
# {'learning_rate': 0.028850958604560266,
#  'n_estimators': 1600,
#  'colsample_bylevel': 0.07846533692588219,
#  'depth': 12,
#  'subsample': 0.9276269640792167}

# %%
params_df = study_make_model_params.trials_dataframe()
params_df.drop(7, inplace = True)
params_df.drop(['datetime_start', 'datetime_complete', 'duration', 'state'], axis = 1, inplace=True)

# %%
params_df.sort_values('value').head(8)
# Out:
#    number     value  params_colsample_bylevel  params_depth  \
# 1       1  0.663244                  0.154590            12
# 5       5  0.663697                  0.129348            12
# 2       2  0.663995                  0.152032            14
# 3       3  0.663998                  0.136763            10
# 6       6  0.664056                  0.145976            13
# 0       0  0.664111                  0.085985            11
# 4       4  0.665077                  0.048684             9
#
#    params_learning_rate  params_n_estimators  params_subsample
# 1              0.035089                 3000          0.943098
# 5              0.013763                 3600          0.937734
# 2              0.045846                 2800          0.765678
# 3              0.024536                 4000          0.748868
# 6              0.013899                 3800          0.615596
# 0              0.017673                 4200          0.789313
# 4              0.020528                 3200          0.814002

# %%
params_df.sort_values('value').head(8)
# Out:
#     number     value  params_colsample_bylevel  params_depth  \
# 26      26  0.664210                  0.074612            12
# 27      27  0.664230                  0.070277            12
# 23      23  0.664251                  0.096695            12
# 22      22  0.664352                  0.097818            12
# 16      16  0.664382                  0.086957            11
# 28      28  0.664450                  0.060484            12
# 19      19  0.664460                  0.086252            11
# 21      21  0.664478                  0.099834            11
#
#     params_learning_rate  params_n_estimators  params_subsample
# 26              0.024044                 3800          0.756219
# 27              0.010808                 3800          0.762364
# 23              0.021791                 3200          0.508132
# 22              0.040662                 3600          0.660732
# 16              0.062669                 3600          0.749878
# 28              0.020978                 4000          0.758867
# 19              0.036916                 3600          0.615480
# 21              0.040600                 3600          0.647124

# %%
params_df.sort_values('value').head(8)
# Out:
#     number     value  params_colsample_bylevel  params_depth  \
# 30      30  0.663990                  0.078465            12
# 17      17  0.663996                  0.086997            11
# 31      31  0.664081                  0.078792            12
# 28      28  0.664157                  0.078541            12
# 22      22  0.664336                  0.082051            11
# 29      29  0.664348                  0.059227            12
# 5        5  0.664379                  0.099809            11
# 32      32  0.664388                  0.071828            12
#
#     params_learning_rate  params_n_estimators  params_subsample
# 30              0.028851                 1600          0.927627
# 17              0.010959                 2800          0.981585
# 31              0.027849                 1800          0.925066
# 28              0.014341                 3600          0.943007
# 22              0.047369                 2800          0.999109
# 29              0.015948                 3800          0.595570
# 5               0.094225                 2800          0.979322
# 32              0.027176                 1400          0.934883

# %%
study_make_model_params.best_params
# Out:
# {'learning_rate': 0.028850958604560266,
#  'n_estimators': 1600,
#  'colsample_bylevel': 0.07846533692588219,
#  'depth': 12,
#  'subsample': 0.9276269640792167}

# %%
skfold = StratifiedKFold(n_splits=15, shuffle=True, random_state=55)
folds=[]
for train_idx, valid_idx in skfold.split(X, y):
        folds.append((train_idx, valid_idx))

cat_pred = np.zeros((X.shape[0], n_class))
cat_pred_test = np.zeros((X_test.shape[0], n_class))
cat_cols = categorical_feats
model_folds = [] 

# 15Fold-CV (StratifiedKFold)
for fold in range(len(folds)):
    print(f'\n----------------- Fold {fold+1} -----------------\n')
    train_idx, valid_idx = folds[fold]
    X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y.iloc[train_idx], y.iloc[valid_idx]
    train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
    valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

    model_cat = CatBoostClassifier(**study_make_model_params.best_params,
                                   boosting_type = 'Ordered', 
                                   bootstrap_type = 'Bernoulli')
    model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=50, verbose=100)
    model_folds.append(model_cat)

    cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
    cat_pred_test += model_cat.predict_proba(X_test) / len(folds)
    print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')
    
print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
# Out:
# ----------------- Fold 1 -----------------
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# 0:	learn: 1.0832018	test: 1.0831796	best: 1.0831796 (0)	total: 33.8ms	remaining: 1m 41s
# 100:	learn: 0.7312332	test: 0.7045257	best: 0.7045257 (100)	total: 26.8s	remaining: 12m 48s
# 200:	learn: 0.7168025	test: 0.6812067	best: 0.6812067 (200)	total: 42.5s	remaining: 9m 52s
# 300:	learn: 0.7115997	test: 0.6764903	best: 0.6764903 (300)	total: 55.6s	remaining: 8m 18s
# 400:	learn: 0.7032371	test: 0.6723826	best: 0.6723826 (400)	total: 1m 53s	remaining: 12m 14s
# 500:	learn: 0.6923464	test: 0.6712324	best: 0.6711552 (498)	total: 3m 36s	remaining: 18m 1s
# 600:	learn: 0.6802922	test: 0.6695650	best: 0.6695650 (600)	total: 5m 18s	remaining: 21m 13s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6694718863
# bestIteration = 606
#
# Shrink model to first 607 iterations.
# CV Log Loss Score: 0.669472
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0832026	test: 1.0831533	best: 1.0831533 (0)	total: 28.8ms	remaining: 1m 26s
# 100:	learn: 0.7348395	test: 0.6916213	best: 0.6916213 (100)	total: 22s	remaining: 10m 31s
# 200:	learn: 0.7191266	test: 0.6622248	best: 0.6622248 (200)	total: 38.9s	remaining: 9m 1s
# 300:	learn: 0.7141334	test: 0.6557589	best: 0.6557589 (300)	total: 56.7s	remaining: 8m 28s
# 400:	learn: 0.7056761	test: 0.6513099	best: 0.6513099 (400)	total: 1m 56s	remaining: 12m 37s
# 500:	learn: 0.6942509	test: 0.6493398	best: 0.6493398 (500)	total: 3m 44s	remaining: 18m 39s
# 600:	learn: 0.6836569	test: 0.6489163	best: 0.6487360 (585)	total: 5m 30s	remaining: 21m 59s
# 700:	learn: 0.6725767	test: 0.6482840	best: 0.6481193 (692)	total: 7m 17s	remaining: 23m 55s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6480505422
# bestIteration = 722
#
# Shrink model to first 723 iterations.
# CV Log Loss Score: 0.648051
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0831996	test: 1.0831815	best: 1.0831815 (0)	total: 45.7ms	remaining: 2m 16s
# 100:	learn: 0.7326200	test: 0.6989717	best: 0.6989717 (100)	total: 18.5s	remaining: 8m 51s
# 200:	learn: 0.7167229	test: 0.6768653	best: 0.6768653 (200)	total: 32.9s	remaining: 7m 38s
# 300:	learn: 0.7116274	test: 0.6729924	best: 0.6729902 (299)	total: 49.3s	remaining: 7m 21s
# 400:	learn: 0.7027133	test: 0.6719570	best: 0.6719247 (376)	total: 1m 58s	remaining: 12m 45s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6716906741
# bestIteration = 447
#
# Shrink model to first 448 iterations.
# CV Log Loss Score: 0.671691
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0831812	test: 1.0832323	best: 1.0832323 (0)	total: 31.9ms	remaining: 1m 35s
# 100:	learn: 0.7331341	test: 0.6766245	best: 0.6766245 (100)	total: 19.4s	remaining: 9m 16s
# 200:	learn: 0.7177988	test: 0.6512745	best: 0.6512745 (200)	total: 46.7s	remaining: 10m 50s
# 300:	learn: 0.7124909	test: 0.6467642	best: 0.6467439 (296)	total: 1m 8s	remaining: 10m 12s
# 400:	learn: 0.7044293	test: 0.6441402	best: 0.6441402 (400)	total: 2m 15s	remaining: 14m 37s
# 500:	learn: 0.6933962	test: 0.6430069	best: 0.6429093 (497)	total: 4m 4s	remaining: 20m 19s
# 600:	learn: 0.6823012	test: 0.6424225	best: 0.6422526 (590)	total: 5m 50s	remaining: 23m 19s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6422526362
# bestIteration = 590
#
# Shrink model to first 591 iterations.
# CV Log Loss Score: 0.642253
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0831956	test: 1.0832133	best: 1.0832133 (0)	total: 35.5ms	remaining: 1m 46s
# 100:	learn: 0.7355616	test: 0.6960969	best: 0.6960969 (100)	total: 14s	remaining: 6m 43s
# 200:	learn: 0.7189502	test: 0.6692256	best: 0.6692228 (199)	total: 33.5s	remaining: 7m 45s
# 300:	learn: 0.7141074	test: 0.6634394	best: 0.6634394 (300)	total: 49.6s	remaining: 7m 24s
# 400:	learn: 0.7048804	test: 0.6600038	best: 0.6600038 (400)	total: 1m 58s	remaining: 12m 46s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6597584231
# bestIteration = 441
#
# Shrink model to first 442 iterations.
# CV Log Loss Score: 0.659758
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0831945	test: 1.0831645	best: 1.0831645 (0)	total: 47.7ms	remaining: 2m 23s
# 100:	learn: 0.7414095	test: 0.7144060	best: 0.7144060 (100)	total: 22.9s	remaining: 10m 56s
# 200:	learn: 0.7173978	test: 0.6807750	best: 0.6807750 (200)	total: 45.6s	remaining: 10m 34s
# 300:	learn: 0.7111757	test: 0.6765600	best: 0.6765600 (300)	total: 1m 5s	remaining: 9m 45s
# 400:	learn: 0.7015114	test: 0.6750887	best: 0.6750052 (395)	total: 2m 17s	remaining: 14m 48s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6748197902
# bestIteration = 443
#
# Shrink model to first 444 iterations.
# CV Log Loss Score: 0.674820
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0787341	test: 1.0793046	best: 1.0793046 (0)	total: 939ms	remaining: 46m 57s
# 100:	learn: 0.7303543	test: 0.7074607	best: 0.7074607 (100)	total: 22.4s	remaining: 10m 43s
# 200:	learn: 0.7159821	test: 0.6879698	best: 0.6879698 (200)	total: 39.8s	remaining: 9m 13s
# 300:	learn: 0.7114272	test: 0.6843266	best: 0.6843266 (300)	total: 53.1s	remaining: 7m 56s
# 400:	learn: 0.7037735	test: 0.6824319	best: 0.6824319 (400)	total: 1m 59s	remaining: 12m 53s
# 500:	learn: 0.6917131	test: 0.6813403	best: 0.6813403 (500)	total: 3m 45s	remaining: 18m 44s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6813083767
# bestIteration = 508
#
# Shrink model to first 509 iterations.
# CV Log Loss Score: 0.681308
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0787715	test: 1.0794566	best: 1.0794566 (0)	total: 901ms	remaining: 45m 3s
# 100:	learn: 0.7387728	test: 0.6976712	best: 0.6976712 (100)	total: 22.2s	remaining: 10m 38s
# 200:	learn: 0.7170559	test: 0.6605341	best: 0.6605341 (200)	total: 42.9s	remaining: 9m 57s
# 300:	learn: 0.7115095	test: 0.6545525	best: 0.6545119 (299)	total: 1m 12s	remaining: 10m 46s
# 400:	learn: 0.7019584	test: 0.6509889	best: 0.6509865 (399)	total: 2m 23s	remaining: 15m 29s
# 500:	learn: 0.6909629	test: 0.6497050	best: 0.6496592 (497)	total: 4m 10s	remaining: 20m 48s
# 600:	learn: 0.6813971	test: 0.6489375	best: 0.6488852 (597)	total: 5m 56s	remaining: 23m 44s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6488347105
# bestIteration = 621
#
# Shrink model to first 622 iterations.
# CV Log Loss Score: 0.648835
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0788701	test: 1.0788365	best: 1.0788365 (0)	total: 977ms	remaining: 48m 49s
# 100:	learn: 0.7291516	test: 0.6948303	best: 0.6948303 (100)	total: 22.8s	remaining: 10m 55s
# 200:	learn: 0.7166306	test: 0.6757887	best: 0.6757887 (200)	total: 42.2s	remaining: 9m 47s
# 300:	learn: 0.7107797	test: 0.6702709	best: 0.6702709 (300)	total: 1m 5s	remaining: 9m 44s
# 400:	learn: 0.7009031	test: 0.6667703	best: 0.6667703 (400)	total: 2m 14s	remaining: 14m 29s
# 500:	learn: 0.6889822	test: 0.6655481	best: 0.6655252 (499)	total: 4m 2s	remaining: 20m 11s
# 600:	learn: 0.6773159	test: 0.6645287	best: 0.6645168 (596)	total: 5m 56s	remaining: 23m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6645168127
# bestIteration = 596
#
# Shrink model to first 597 iterations.
# CV Log Loss Score: 0.664517
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0787905	test: 1.0786774	best: 1.0786774 (0)	total: 1.03s	remaining: 51m 31s
# 100:	learn: 0.7385497	test: 0.6907588	best: 0.6907588 (100)	total: 24.4s	remaining: 11m 39s
# 200:	learn: 0.7193227	test: 0.6578945	best: 0.6578899 (199)	total: 45.4s	remaining: 10m 32s
# 300:	learn: 0.7128472	test: 0.6500575	best: 0.6500575 (300)	total: 1m 5s	remaining: 9m 46s
# 400:	learn: 0.7041058	test: 0.6462734	best: 0.6462734 (400)	total: 2m 16s	remaining: 14m 45s
# 500:	learn: 0.6927338	test: 0.6444932	best: 0.6444932 (500)	total: 4m 6s	remaining: 20m 29s
# 600:	learn: 0.6822282	test: 0.6438869	best: 0.6437635 (596)	total: 6m 4s	remaining: 24m 13s
# 700:	learn: 0.6710305	test: 0.6430056	best: 0.6429312 (691)	total: 7m 58s	remaining: 26m 9s
# 800:	learn: 0.6600221	test: 0.6423557	best: 0.6423462 (797)	total: 9m 50s	remaining: 27m 1s
# 900:	learn: 0.6474923	test: 0.6419309	best: 0.6417002 (882)	total: 11m 38s	remaining: 27m 8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6417001815
# bestIteration = 882
#
# Shrink model to first 883 iterations.
# CV Log Loss Score: 0.641700
#
# ----------------- Fold 11 -----------------
# 0:	learn: 1.0787334	test: 1.0790109	best: 1.0790109 (0)	total: 1.01s	remaining: 50m 31s
# 100:	learn: 0.7379775	test: 0.7124408	best: 0.7124408 (100)	total: 12.8s	remaining: 6m 8s
# 200:	learn: 0.7167294	test: 0.6801114	best: 0.6800954 (199)	total: 41.6s	remaining: 9m 39s
# 300:	learn: 0.7122837	test: 0.6757079	best: 0.6757079 (300)	total: 55.3s	remaining: 8m 16s
# 400:	learn: 0.7026752	test: 0.6721566	best: 0.6721566 (400)	total: 2m 12s	remaining: 14m 19s
# 500:	learn: 0.6922387	test: 0.6710708	best: 0.6709510 (493)	total: 4m 3s	remaining: 20m 13s
# 600:	learn: 0.6808530	test: 0.6703085	best: 0.6703085 (600)	total: 5m 53s	remaining: 23m 32s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6700876064
# bestIteration = 621
#
# Shrink model to first 622 iterations.
# CV Log Loss Score: 0.670088
#
# ----------------- Fold 12 -----------------
#
# 0:	learn: 1.0787785	test: 1.0788449	best: 1.0788449 (0)	total: 568ms	remaining: 28m 23s
# 100:	learn: 0.7358946	test: 0.6970787	best: 0.6970787 (100)	total: 18.8s	remaining: 9m
# 200:	learn: 0.7175696	test: 0.6685623	best: 0.6685623 (200)	total: 40.8s	remaining: 9m 28s
# 300:	learn: 0.7121700	test: 0.6623017	best: 0.6623017 (300)	total: 57.7s	remaining: 8m 37s
# 400:	learn: 0.7032818	test: 0.6593585	best: 0.6593579 (399)	total: 2m 12s	remaining: 14m 19s
# 500:	learn: 0.6914965	test: 0.6580912	best: 0.6580912 (500)	total: 3m 59s	remaining: 19m 54s
# 600:	learn: 0.6811766	test: 0.6567953	best: 0.6567953 (600)	total: 5m 44s	remaining: 22m 56s
# 700:	learn: 0.6697465	test: 0.6561013	best: 0.6561013 (700)	total: 7m 36s	remaining: 24m 57s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6560260569
# bestIteration = 749
#
# Shrink model to first 750 iterations.
# CV Log Loss Score: 0.656026
#
# ----------------- Fold 13 -----------------
#
# 0:	learn: 1.0786973	test: 1.0786649	best: 1.0786649 (0)	total: 548ms	remaining: 27m 24s
# 100:	learn: 0.7354204	test: 0.7024714	best: 0.7024714 (100)	total: 18s	remaining: 8m 35s
# 200:	learn: 0.7172599	test: 0.6743560	best: 0.6743560 (200)	total: 41.5s	remaining: 9m 37s
# 300:	learn: 0.7123330	test: 0.6684637	best: 0.6684637 (300)	total: 58.9s	remaining: 8m 48s
# 400:	learn: 0.7039792	test: 0.6657248	best: 0.6655714 (393)	total: 2m 4s	remaining: 13m 27s
# 500:	learn: 0.6932975	test: 0.6645775	best: 0.6645775 (500)	total: 3m 54s	remaining: 19m 31s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6644054146
# bestIteration = 543
#
# Shrink model to first 544 iterations.
# CV Log Loss Score: 0.664405
#
# ----------------- Fold 14 -----------------
#
# 0:	learn: 1.0787732	test: 1.0789424	best: 1.0789424 (0)	total: 973ms	remaining: 48m 36s
# 100:	learn: 0.7316634	test: 0.7055843	best: 0.7055843 (100)	total: 19.2s	remaining: 9m 10s
# 200:	learn: 0.7156293	test: 0.6860234	best: 0.6860153 (199)	total: 35.9s	remaining: 8m 19s
# 300:	learn: 0.7097862	test: 0.6833550	best: 0.6832915 (293)	total: 58.1s	remaining: 8m 41s
# 400:	learn: 0.7002996	test: 0.6824050	best: 0.6823772 (392)	total: 2m 12s	remaining: 14m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6823106627
# bestIteration = 419
#
# Shrink model to first 420 iterations.
# CV Log Loss Score: 0.682311
#
# ----------------- Fold 15 -----------------
#
# 0:	learn: 1.0786454	test: 1.0783846	best: 1.0783846 (0)	total: 161ms	remaining: 8m 2s
# 100:	learn: 0.7309022	test: 0.6851396	best: 0.6851396 (100)	total: 27.7s	remaining: 13m 14s
# 200:	learn: 0.7176923	test: 0.6647809	best: 0.6647809 (200)	total: 37.6s	remaining: 8m 43s
# 300:	learn: 0.7127048	test: 0.6597082	best: 0.6597082 (300)	total: 56.3s	remaining: 8m 25s
# 400:	learn: 0.7041209	test: 0.6562746	best: 0.6562676 (399)	total: 2m 9s	remaining: 14m
# 500:	learn: 0.6926862	test: 0.6555624	best: 0.6555624 (500)	total: 3m 59s	remaining: 19m 54s
# 600:	learn: 0.6814743	test: 0.6553831	best: 0.6553831 (600)	total: 5m 53s	remaining: 23m 30s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6550804166
# bestIteration = 629
#
# Shrink model to first 630 iterations.
# CV Log Loss Score: 0.655080
# 	Log Loss: 0.662021

# %%
def plot_feature_importance(importance,names,model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')

plot_feature_importance(model_cat.get_feature_importance(),X_test.columns,'CATBOOST')

# %%
best_submit = submit.copy()
for i in range(3):
    best_submit[str(i)] = (cat_pred_test)[:,i]

# %%
best_submit.set_index('index').apply(np.argmax, axis = 1).value_counts()
# Out:
# 2    8100
# 1    1420
# 0     480
# dtype: int64

# %%
best_submit.to_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/preprocessing/catboost_renew_group_yourjob.csv', index = False)

# %%
sns.histplot(x = train.income_total_log.apply(np.exp) - train.child_fee_total, data = train[train.child_num > 0])

# %%
train.income_total_log.apply(np.exp)
# Out:
# 0        202501.0
# 1        247501.0
# 2        450001.0
# 3        202501.0
# 4        157501.0
#            ...
# 26446    225001.0
# 26447    180001.0
# 26448    292501.0
# 26449    171001.0
# 26450     81001.0
# Name: income_total_log, Length: 26451, dtype: float64

# %%
train.child_fee_total
# Out:
# 0        0.000000e+00
# 1        1.317699e+11
# 2        0.000000e+00
# 3        0.000000e+00
# 4        0.000000e+00
#              ...
# 26446    2.202007e+11
# 26447    1.140941e+11
# 26448    0.000000e+00
# 26449    0.000000e+00
# 26450    0.000000e+00
# Name: child_fee_total, Length: 26451, dtype: float64

# %%
n_fold = 10
seed = 42

def objective(trial):
    skfold = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)
    folds=[]
    for train_idx, valid_idx in skfold.split(X, y):
            folds.append((train_idx, valid_idx))
            
    cat_pred = np.zeros((X.shape[0], n_class))
    cat_pred_test = np.zeros((X_test.shape[0], n_class))
    cat_cols = categorical_feats+ ['gender', 'car', 'reality', 'phone', 'email', 'work_phone']

    param = {
        #"objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1),
        "n_estimators": trial.suggest_int("n_estimators", 1200, 4000, 400),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 6, 12, 2),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "8gb",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        
    model_folds = []    
    for fold in range(n_fold):
        print(f'\n----------------- Fold {fold+1} -----------------\n')
        train_idx, valid_idx = folds[fold]
        X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y[train_idx], y[valid_idx]
        train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
        valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

        model_cat = CatBoostClassifier(**param)
        model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=100, verbose=200)
        
        model_folds.append(model_cat)
        cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
        cat_pred_test += model_cat.predict_proba(X_test) / n_fold
        print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')

    print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
    logloss = log_loss(y, cat_pred)
    return logloss

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30, timeout=6000)
# Out:
# [I 2021-06-17 16:47:55,768] A new study created in memory with name: no-name-13150361-a7d4-4369-a785-4011c721f442
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0719750	test: 1.0715284	best: 1.0715284 (0)	total: 11.4ms	remaining: 31.9s
# 200:	learn: 0.7667121	test: 0.7346153	best: 0.7346145 (198)	total: 954ms	remaining: 12.3s
# 400:	learn: 0.7377638	test: 0.6985819	best: 0.6985478 (396)	total: 1.9s	remaining: 11.4s
# 600:	learn: 0.7252071	test: 0.6825963	best: 0.6825962 (599)	total: 2.82s	remaining: 10.3s
# 800:	learn: 0.7171678	test: 0.6731787	best: 0.6731787 (800)	total: 3.8s	remaining: 9.48s
# 1000:	learn: 0.7124924	test: 0.6690663	best: 0.6690594 (994)	total: 4.75s	remaining: 8.54s
# 1200:	learn: 0.7076381	test: 0.6644963	best: 0.6644941 (1198)	total: 5.71s	remaining: 7.6s
# 1400:	learn: 0.7036144	test: 0.6618116	best: 0.6618116 (1397)	total: 6.75s	remaining: 6.74s
# 1600:	learn: 0.6999179	test: 0.6600589	best: 0.6600589 (1598)	total: 7.86s	remaining: 5.89s
# 1800:	learn: 0.6969317	test: 0.6595488	best: 0.6595478 (1797)	total: 8.9s	remaining: 4.94s
# 2000:	learn: 0.6942792	test: 0.6583610	best: 0.6583610 (2000)	total: 9.89s	remaining: 3.95s
# 2200:	learn: 0.6915196	test: 0.6580780	best: 0.6580742 (2179)	total: 10.9s	remaining: 2.96s
# 2400:	learn: 0.6887848	test: 0.6575499	best: 0.6575499 (2400)	total: 11.8s	remaining: 1.97s
# 2600:	learn: 0.6864626	test: 0.6572792	best: 0.6572480 (2584)	total: 12.8s	remaining: 983ms
# 2799:	learn: 0.6837896	test: 0.6570704	best: 0.6570288 (2750)	total: 13.9s	remaining: 0us
#
# bestTest = 0.6570288163
# bestIteration = 2750
#
# Shrink model to first 2751 iterations.
# CV Log Loss Score: 0.657029
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0784003	test: 1.0784147	best: 1.0784147 (0)	total: 6.7ms	remaining: 18.8s
# 200:	learn: 0.7619377	test: 0.7308387	best: 0.7308387 (200)	total: 997ms	remaining: 12.9s
# 400:	learn: 0.7356607	test: 0.6934338	best: 0.6934338 (400)	total: 2.04s	remaining: 12.2s
# 600:	learn: 0.7235321	test: 0.6769814	best: 0.6769659 (595)	total: 3.04s	remaining: 11.1s
# 800:	learn: 0.7168898	test: 0.6697054	best: 0.6697054 (800)	total: 4.03s	remaining: 10.1s
# 1000:	learn: 0.7123052	test: 0.6649779	best: 0.6649779 (1000)	total: 5.01s	remaining: 9.01s
# 1200:	learn: 0.7090848	test: 0.6625768	best: 0.6625768 (1200)	total: 5.94s	remaining: 7.91s
# 1400:	learn: 0.7055045	test: 0.6604161	best: 0.6604152 (1399)	total: 6.91s	remaining: 6.9s
# 1600:	learn: 0.7019497	test: 0.6593972	best: 0.6593943 (1598)	total: 7.84s	remaining: 5.87s
# 1800:	learn: 0.6987027	test: 0.6582698	best: 0.6582681 (1796)	total: 8.78s	remaining: 4.87s
# 2000:	learn: 0.6958255	test: 0.6575243	best: 0.6575239 (1999)	total: 9.7s	remaining: 3.87s
# 2200:	learn: 0.6923485	test: 0.6568980	best: 0.6568980 (2200)	total: 10.7s	remaining: 2.92s
# 2400:	learn: 0.6899292	test: 0.6567903	best: 0.6567209 (2380)	total: 11.7s	remaining: 1.94s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6566574826
# bestIteration = 2445
#
# Shrink model to first 2446 iterations.
# CV Log Loss Score: 0.656657
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0783956	test: 1.0784411	best: 1.0784411 (0)	total: 6.8ms	remaining: 19s
# 200:	learn: 0.7648553	test: 0.7391948	best: 0.7391853 (198)	total: 914ms	remaining: 11.8s
# 400:	learn: 0.7326426	test: 0.6950866	best: 0.6950705 (397)	total: 1.85s	remaining: 11.1s
# 600:	learn: 0.7210968	test: 0.6807429	best: 0.6807423 (599)	total: 2.76s	remaining: 10.1s
# 800:	learn: 0.7146507	test: 0.6730755	best: 0.6730754 (797)	total: 3.66s	remaining: 9.13s
# 1000:	learn: 0.7113261	test: 0.6707847	best: 0.6707826 (987)	total: 4.54s	remaining: 8.15s
# 1200:	learn: 0.7083135	test: 0.6682261	best: 0.6682143 (1196)	total: 5.41s	remaining: 7.2s
# 1400:	learn: 0.7040556	test: 0.6663785	best: 0.6663785 (1400)	total: 6.44s	remaining: 6.43s
# 1600:	learn: 0.7006624	test: 0.6650234	best: 0.6650234 (1600)	total: 7.57s	remaining: 5.67s
# 1800:	learn: 0.6980973	test: 0.6641164	best: 0.6640833 (1772)	total: 8.56s	remaining: 4.75s
# 2000:	learn: 0.6956403	test: 0.6638360	best: 0.6638001 (1989)	total: 9.58s	remaining: 3.83s
# 2200:	learn: 0.6928584	test: 0.6634310	best: 0.6634024 (2190)	total: 10.7s	remaining: 2.91s
# 2400:	learn: 0.6905612	test: 0.6628768	best: 0.6628728 (2396)	total: 11.7s	remaining: 1.94s
# 2600:	learn: 0.6883503	test: 0.6624369	best: 0.6624369 (2600)	total: 12.7s	remaining: 972ms
# 2799:	learn: 0.6855793	test: 0.6621296	best: 0.6621113 (2797)	total: 13.8s	remaining: 0us
#
# bestTest = 0.6621112961
# bestIteration = 2797
#
# Shrink model to first 2798 iterations.
# CV Log Loss Score: 0.662111
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0784010	test: 1.0784240	best: 1.0784240 (0)	total: 6.57ms	remaining: 18.4s
# 200:	learn: 0.7593585	test: 0.7402933	best: 0.7402933 (200)	total: 880ms	remaining: 11.4s
# 400:	learn: 0.7319441	test: 0.7070681	best: 0.7070681 (400)	total: 1.79s	remaining: 10.7s
# 600:	learn: 0.7216620	test: 0.6957809	best: 0.6957735 (597)	total: 2.64s	remaining: 9.66s
# 800:	learn: 0.7131360	test: 0.6864785	best: 0.6864783 (798)	total: 3.63s	remaining: 9.05s
# 1000:	learn: 0.7086570	test: 0.6832949	best: 0.6832760 (992)	total: 4.6s	remaining: 8.26s
# 1200:	learn: 0.7050890	test: 0.6817750	best: 0.6817750 (1199)	total: 5.58s	remaining: 7.44s
# 1400:	learn: 0.7013604	test: 0.6802474	best: 0.6801908 (1381)	total: 6.68s	remaining: 6.67s
# 1600:	learn: 0.6979505	test: 0.6792296	best: 0.6792296 (1600)	total: 7.71s	remaining: 5.78s
# 1800:	learn: 0.6950459	test: 0.6790680	best: 0.6789645 (1777)	total: 8.72s	remaining: 4.84s
# 2000:	learn: 0.6921761	test: 0.6785251	best: 0.6784573 (1977)	total: 9.76s	remaining: 3.9s
# 2200:	learn: 0.6888088	test: 0.6784087	best: 0.6783306 (2134)	total: 10.8s	remaining: 2.93s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6783306029
# bestIteration = 2134
#
# Shrink model to first 2135 iterations.
# CV Log Loss Score: 0.678331
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0783982	test: 1.0784145	best: 1.0784145 (0)	total: 7ms	remaining: 19.6s
# 200:	learn: 0.7592282	test: 0.7342913	best: 0.7342913 (200)	total: 914ms	remaining: 11.8s
# 400:	learn: 0.7327444	test: 0.6995987	best: 0.6995987 (400)	total: 1.85s	remaining: 11.1s
# 600:	learn: 0.7203762	test: 0.6836375	best: 0.6836375 (600)	total: 2.85s	remaining: 10.4s
# 800:	learn: 0.7134725	test: 0.6761373	best: 0.6761372 (798)	total: 3.81s	remaining: 9.51s
# 1000:	learn: 0.7092477	test: 0.6730037	best: 0.6729913 (992)	total: 4.81s	remaining: 8.65s
# 1200:	learn: 0.7058313	test: 0.6706696	best: 0.6706529 (1197)	total: 5.83s	remaining: 7.76s
# 1400:	learn: 0.7025873	test: 0.6693482	best: 0.6693449 (1392)	total: 6.88s	remaining: 6.87s
# 1600:	learn: 0.6994322	test: 0.6683750	best: 0.6683750 (1600)	total: 7.91s	remaining: 5.93s
# 1800:	learn: 0.6966242	test: 0.6673937	best: 0.6673937 (1800)	total: 8.87s	remaining: 4.92s
# 2000:	learn: 0.6941436	test: 0.6669655	best: 0.6669655 (1999)	total: 9.85s	remaining: 3.93s
# 2200:	learn: 0.6910199	test: 0.6665807	best: 0.6665392 (2147)	total: 10.9s	remaining: 2.97s
# 2400:	learn: 0.6885561	test: 0.6663685	best: 0.6663514 (2329)	total: 11.9s	remaining: 1.97s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6663513567
# bestIteration = 2329
#
# Shrink model to first 2330 iterations.
# CV Log Loss Score: 0.666351
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0783920	test: 1.0784277	best: 1.0784277 (0)	total: 7.36ms	remaining: 20.6s
# 200:	learn: 0.7625692	test: 0.7452271	best: 0.7452271 (199)	total: 1.13s	remaining: 14.6s
# 400:	learn: 0.7301511	test: 0.7064907	best: 0.7064907 (400)	total: 2.18s	remaining: 13.1s
# 600:	learn: 0.7187411	test: 0.6935050	best: 0.6934698 (598)	total: 3.26s	remaining: 11.9s
# 800:	learn: 0.7130305	test: 0.6897296	best: 0.6897296 (800)	total: 4.32s	remaining: 10.8s
# 1000:	learn: 0.7094201	test: 0.6875601	best: 0.6875598 (999)	total: 5.33s	remaining: 9.57s
# 1200:	learn: 0.7060032	test: 0.6854976	best: 0.6854976 (1200)	total: 6.26s	remaining: 8.34s
# 1400:	learn: 0.7020068	test: 0.6842687	best: 0.6842262 (1393)	total: 7.31s	remaining: 7.3s
# 1600:	learn: 0.6989571	test: 0.6834963	best: 0.6834707 (1583)	total: 8.29s	remaining: 6.21s
# 1800:	learn: 0.6962684	test: 0.6832937	best: 0.6832849 (1798)	total: 9.25s	remaining: 5.13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6829706672
# bestIteration = 1841
#
# Shrink model to first 1842 iterations.
# CV Log Loss Score: 0.682971
#
# ----------------- Fold 7 -----------------
# 0:	learn: 1.0783979	test: 1.0784207	best: 1.0784207 (0)	total: 7.61ms	remaining: 21.3s
# 200:	learn: 0.7637600	test: 0.7396104	best: 0.7396104 (200)	total: 1s	remaining: 12.9s
# 400:	learn: 0.7333698	test: 0.6981468	best: 0.6981378 (398)	total: 2s	remaining: 12s
# 600:	learn: 0.7215694	test: 0.6842578	best: 0.6842361 (582)	total: 2.96s	remaining: 10.8s
# 800:	learn: 0.7152020	test: 0.6778552	best: 0.6778552 (799)	total: 3.94s	remaining: 9.84s
# 1000:	learn: 0.7112722	test: 0.6757449	best: 0.6757209 (986)	total: 4.91s	remaining: 8.82s
# 1200:	learn: 0.7071899	test: 0.6731985	best: 0.6731741 (1199)	total: 5.87s	remaining: 7.82s
# 1400:	learn: 0.7031685	test: 0.6707910	best: 0.6707910 (1400)	total: 6.9s	remaining: 6.89s
# 1600:	learn: 0.7000622	test: 0.6696508	best: 0.6696200 (1582)	total: 7.9s	remaining: 5.92s
# 1800:	learn: 0.6968545	test: 0.6690527	best: 0.6690021 (1792)	total: 8.86s	remaining: 4.92s
# 2000:	learn: 0.6943392	test: 0.6685474	best: 0.6684875 (1990)	total: 9.82s	remaining: 3.92s
# 2200:	learn: 0.6909923	test: 0.6682928	best: 0.6681147 (2143)	total: 10.9s	remaining: 2.96s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6681146983
# bestIteration = 2143
#
# Shrink model to first 2144 iterations.
# CV Log Loss Score: 0.668115
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0784030	test: 1.0783936	best: 1.0783936 (0)	total: 7.64ms	remaining: 21.4s
# 200:	learn: 0.7654626	test: 0.7432701	best: 0.7432701 (200)	total: 939ms	remaining: 12.1s
# 400:	learn: 0.7378938	test: 0.7110167	best: 0.7110028 (386)	total: 1.93s	remaining: 11.5s
# 600:	learn: 0.7236387	test: 0.6953924	best: 0.6953923 (599)	total: 2.86s	remaining: 10.5s
# 800:	learn: 0.7147626	test: 0.6857396	best: 0.6857396 (799)	total: 3.86s	remaining: 9.64s
# 1000:	learn: 0.7102754	test: 0.6818364	best: 0.6818266 (998)	total: 4.8s	remaining: 8.63s
# 1200:	learn: 0.7066457	test: 0.6800228	best: 0.6800228 (1200)	total: 5.69s	remaining: 7.57s
# 1400:	learn: 0.7028023	test: 0.6790458	best: 0.6790348 (1394)	total: 6.67s	remaining: 6.66s
# 1600:	learn: 0.6993176	test: 0.6775434	best: 0.6775124 (1582)	total: 7.62s	remaining: 5.71s
# 1800:	learn: 0.6961679	test: 0.6771034	best: 0.6770775 (1796)	total: 8.59s	remaining: 4.76s
# 2000:	learn: 0.6934928	test: 0.6764722	best: 0.6764720 (1999)	total: 9.6s	remaining: 3.83s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6764157174
# bestIteration = 2020
#
# Shrink model to first 2021 iterations.
# CV Log Loss Score: 0.676416
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0784002	test: 1.0783826	best: 1.0783826 (0)	total: 7.23ms	remaining: 20.2s
# 200:	learn: 0.7600722	test: 0.7357940	best: 0.7357940 (200)	total: 938ms	remaining: 12.1s
# 400:	learn: 0.7304001	test: 0.6985540	best: 0.6985540 (399)	total: 1.92s	remaining: 11.5s
# 600:	learn: 0.7194652	test: 0.6851641	best: 0.6851641 (600)	total: 2.88s	remaining: 10.5s
# 800:	learn: 0.7137020	test: 0.6800050	best: 0.6799976 (796)	total: 3.79s	remaining: 9.45s
# 1000:	learn: 0.7091697	test: 0.6756648	best: 0.6756648 (999)	total: 4.7s	remaining: 8.45s
# 1200:	learn: 0.7057469	test: 0.6736745	best: 0.6736735 (1193)	total: 5.62s	remaining: 7.49s
# 1400:	learn: 0.7023428	test: 0.6725390	best: 0.6725390 (1400)	total: 6.6s	remaining: 6.59s
# 1600:	learn: 0.6993218	test: 0.6716961	best: 0.6716637 (1591)	total: 7.6s	remaining: 5.69s
# 1800:	learn: 0.6970460	test: 0.6710670	best: 0.6710604 (1796)	total: 8.55s	remaining: 4.74s
# 2000:	learn: 0.6944026	test: 0.6706954	best: 0.6706611 (1936)	total: 9.53s	remaining: 3.8s
# 2200:	learn: 0.6918591	test: 0.6703058	best: 0.6701723 (2144)	total: 10.5s	remaining: 2.85s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6701722745
# bestIteration = 2144
#
# Shrink model to first 2145 iterations.
# CV Log Loss Score: 0.670172
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0784014	test: 1.0783965	best: 1.0783965 (0)	total: 7.19ms	remaining: 20.1s
# 200:	learn: 0.7653727	test: 0.7410159	best: 0.7410159 (200)	total: 989ms	remaining: 12.8s
# 400:	learn: 0.7368701	test: 0.7076172	best: 0.7076157 (398)	total: 2s	remaining: 12s
# 600:	learn: 0.7228452	test: 0.6925957	best: 0.6925957 (600)	total: 3.02s	remaining: 11s
# 800:	learn: 0.7159464	test: 0.6863125	best: 0.6862943 (797)	total: 3.97s	remaining: 9.91s
# 1000:	learn: 0.7104013	test: 0.6819424	best: 0.6819423 (998)	total: 4.92s	remaining: 8.85s
# 1200:	learn: 0.7065696	test: 0.6800390	best: 0.6800387 (1199)	total: 5.89s	remaining: 7.84s
# 1400:	learn: 0.7029572	test: 0.6789727	best: 0.6789704 (1389)	total: 6.97s	remaining: 6.96s
# 1600:	learn: 0.6997544	test: 0.6782767	best: 0.6782567 (1552)	total: 8.06s	remaining: 6.04s
# 1800:	learn: 0.6967140	test: 0.6770664	best: 0.6770664 (1800)	total: 9.22s	remaining: 5.12s
# 2000:	learn: 0.6941021	test: 0.6765507	best: 0.6765377 (1983)	total: 10.3s	remaining: 4.1s
# 2200:	learn: 0.6916317	test: 0.6758368	best: 0.6758368 (2200)	total: 11.4s	remaining: 3.11s
# 2400:	learn: 0.6896242	test: 0.6754417	best: 0.6753425 (2360)	total: 12.5s	remaining: 2.07s
# 2600:	learn: 0.6867316	test: 0.6752698	best: 0.6751652 (2537)	total: 13.6s	remaining: 1.04s
# 2799:	learn: 0.6838254	test: 0.6750845	best: 0.6750321 (2759)	total: 14.6s	remaining: 0us
#
# bestTest = 0.6750321089
# bestIteration = 2759
#
# Shrink model to first 2760 iterations.
# CV Log Loss Score: 0.675032
# 	Log Loss: 0.669318
# [I 2021-06-17 16:50:01,724] Trial 0 finished with value: 0.6693180374883876 and parameters: {'learning_rate': 0.04635497725342579, 'n_estimators': 2800, 'colsample_bylevel': 0.028446117328767603, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6693180374883876.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0859775	test: 1.0857679	best: 1.0857679 (0)	total: 8.02ms	remaining: 12.8s
# 200:	learn: 0.8207324	test: 0.8077732	best: 0.8077732 (200)	total: 854ms	remaining: 5.94s
# 400:	learn: 0.7865180	test: 0.7615739	best: 0.7615739 (400)	total: 1.74s	remaining: 5.21s
# 600:	learn: 0.7631501	test: 0.7296194	best: 0.7296193 (599)	total: 2.68s	remaining: 4.45s
# 800:	learn: 0.7501360	test: 0.7123956	best: 0.7123956 (800)	total: 3.67s	remaining: 3.66s
# 1000:	learn: 0.7394111	test: 0.6975823	best: 0.6975822 (997)	total: 4.61s	remaining: 2.76s
# 1200:	learn: 0.7323161	test: 0.6885622	best: 0.6885621 (1198)	total: 5.57s	remaining: 1.85s
# 1400:	learn: 0.7276622	test: 0.6823873	best: 0.6823872 (1397)	total: 6.54s	remaining: 929ms
# 1599:	learn: 0.7233959	test: 0.6777822	best: 0.6777821 (1597)	total: 7.52s	remaining: 0us
#
# bestTest = 0.6777821049
# bestIteration = 1597
#
# Shrink model to first 1598 iterations.
# CV Log Loss Score: 0.677782
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0890254	test: 1.0890323	best: 1.0890323 (0)	total: 7.25ms	remaining: 11.6s
# 200:	learn: 0.8172193	test: 0.8057363	best: 0.8057363 (200)	total: 940ms	remaining: 6.54s
# 400:	learn: 0.7820820	test: 0.7590824	best: 0.7590824 (399)	total: 1.87s	remaining: 5.58s
# 600:	learn: 0.7612259	test: 0.7309713	best: 0.7309713 (600)	total: 2.79s	remaining: 4.64s
# 800:	learn: 0.7495312	test: 0.7156393	best: 0.7156259 (796)	total: 3.85s	remaining: 3.84s
# 1000:	learn: 0.7402312	test: 0.7024572	best: 0.7024572 (1000)	total: 4.92s	remaining: 2.95s
# 1200:	learn: 0.7327450	test: 0.6918005	best: 0.6918005 (1198)	total: 5.94s	remaining: 1.97s
# 1400:	learn: 0.7279807	test: 0.6845493	best: 0.6845433 (1399)	total: 6.87s	remaining: 975ms
# 1599:	learn: 0.7233787	test: 0.6781945	best: 0.6781945 (1598)	total: 7.82s	remaining: 0us
#
# bestTest = 0.6781945073
# bestIteration = 1598
#
# Shrink model to first 1599 iterations.
# CV Log Loss Score: 0.678195
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0890232	test: 1.0890446	best: 1.0890446 (0)	total: 8.12ms	remaining: 13s
# 200:	learn: 0.8358844	test: 0.8336653	best: 0.8336634 (198)	total: 974ms	remaining: 6.78s
# 400:	learn: 0.7942333	test: 0.7799919	best: 0.7799919 (400)	total: 1.94s	remaining: 5.8s
# 600:	learn: 0.7695516	test: 0.7480238	best: 0.7480237 (598)	total: 2.86s	remaining: 4.76s
# 800:	learn: 0.7516198	test: 0.7259371	best: 0.7259371 (800)	total: 3.76s	remaining: 3.75s
# 1000:	learn: 0.7410391	test: 0.7122469	best: 0.7122469 (1000)	total: 4.68s	remaining: 2.8s
# 1200:	learn: 0.7339919	test: 0.7026421	best: 0.7026400 (1194)	total: 5.61s	remaining: 1.86s
# 1400:	learn: 0.7296685	test: 0.6973794	best: 0.6973788 (1398)	total: 6.46s	remaining: 917ms
# 1599:	learn: 0.7242033	test: 0.6901584	best: 0.6901513 (1594)	total: 7.53s	remaining: 0us
#
# bestTest = 0.6901513067
# bestIteration = 1594
#
# Shrink model to first 1595 iterations.
# CV Log Loss Score: 0.690151
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0890258	test: 1.0890367	best: 1.0890367 (0)	total: 8.26ms	remaining: 13.2s
# 200:	learn: 0.8181092	test: 0.8112528	best: 0.8112528 (200)	total: 977ms	remaining: 6.8s
# 400:	learn: 0.7792389	test: 0.7648665	best: 0.7648665 (400)	total: 1.92s	remaining: 5.75s
# 600:	learn: 0.7562984	test: 0.7365234	best: 0.7365232 (597)	total: 2.97s	remaining: 4.94s
# 800:	learn: 0.7417190	test: 0.7194239	best: 0.7194214 (795)	total: 3.91s	remaining: 3.9s
# 1000:	learn: 0.7342843	test: 0.7109838	best: 0.7109838 (998)	total: 4.78s	remaining: 2.86s
# 1200:	learn: 0.7273013	test: 0.7026721	best: 0.7026721 (1199)	total: 5.68s	remaining: 1.89s
# 1400:	learn: 0.7227654	test: 0.6970365	best: 0.6970318 (1398)	total: 6.51s	remaining: 925ms
# 1599:	learn: 0.7182135	test: 0.6919211	best: 0.6919211 (1599)	total: 7.47s	remaining: 0us
#
# bestTest = 0.691921053
# bestIteration = 1599
#
# CV Log Loss Score: 0.691921
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0890244	test: 1.0890321	best: 1.0890321 (0)	total: 6.85ms	remaining: 11s
# 200:	learn: 0.8148742	test: 0.8056822	best: 0.8056822 (200)	total: 865ms	remaining: 6.02s
# 400:	learn: 0.7812260	test: 0.7638376	best: 0.7638376 (400)	total: 1.87s	remaining: 5.6s
# 600:	learn: 0.7578281	test: 0.7338093	best: 0.7338092 (599)	total: 2.84s	remaining: 4.72s
# 800:	learn: 0.7446980	test: 0.7167767	best: 0.7167767 (800)	total: 3.7s	remaining: 3.69s
# 1000:	learn: 0.7354235	test: 0.7046364	best: 0.7046364 (998)	total: 4.65s	remaining: 2.78s
# 1200:	learn: 0.7289015	test: 0.6966749	best: 0.6966632 (1197)	total: 5.64s	remaining: 1.87s
# 1400:	learn: 0.7251823	test: 0.6923057	best: 0.6923057 (1399)	total: 6.5s	remaining: 924ms
# 1599:	learn: 0.7209276	test: 0.6877336	best: 0.6877335 (1597)	total: 7.47s	remaining: 0us
#
# bestTest = 0.6877335261
# bestIteration = 1597
#
# Shrink model to first 1598 iterations.
# CV Log Loss Score: 0.687734
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0890224	test: 1.0890337	best: 1.0890337 (0)	total: 7.71ms	remaining: 12.3s
# 200:	learn: 0.8238063	test: 0.8197429	best: 0.8197429 (200)	total: 906ms	remaining: 6.3s
# 400:	learn: 0.7837976	test: 0.7706541	best: 0.7706541 (400)	total: 1.73s	remaining: 5.17s
# 600:	learn: 0.7616926	test: 0.7443501	best: 0.7443486 (599)	total: 2.62s	remaining: 4.36s
# 800:	learn: 0.7470161	test: 0.7270955	best: 0.7270955 (800)	total: 3.51s	remaining: 3.5s
# 1000:	learn: 0.7378941	test: 0.7161981	best: 0.7161981 (1000)	total: 4.46s	remaining: 2.67s
# 1200:	learn: 0.7311832	test: 0.7085858	best: 0.7085825 (1198)	total: 5.4s	remaining: 1.79s
# 1400:	learn: 0.7270308	test: 0.7042465	best: 0.7042464 (1394)	total: 6.25s	remaining: 888ms
# 1599:	learn: 0.7220766	test: 0.6990434	best: 0.6990228 (1590)	total: 7.31s	remaining: 0us
#
# bestTest = 0.6990228273
# bestIteration = 1590
#
# Shrink model to first 1591 iterations.
# CV Log Loss Score: 0.699023
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0890243	test: 1.0890351	best: 1.0890351 (0)	total: 8.11ms	remaining: 13s
# 200:	learn: 0.8358227	test: 0.8324840	best: 0.8324840 (200)	total: 902ms	remaining: 6.28s
# 400:	learn: 0.7965975	test: 0.7834291	best: 0.7834291 (400)	total: 1.82s	remaining: 5.43s
# 600:	learn: 0.7728362	test: 0.7544332	best: 0.7544306 (590)	total: 2.67s	remaining: 4.44s
# 800:	learn: 0.7536734	test: 0.7294101	best: 0.7294101 (800)	total: 3.57s	remaining: 3.56s
# 1000:	learn: 0.7413901	test: 0.7132035	best: 0.7132014 (994)	total: 4.48s	remaining: 2.68s
# 1200:	learn: 0.7352121	test: 0.7056477	best: 0.7056477 (1200)	total: 5.33s	remaining: 1.77s
# 1400:	learn: 0.7302510	test: 0.6995515	best: 0.6995515 (1398)	total: 6.26s	remaining: 889ms
# 1599:	learn: 0.7244817	test: 0.6928481	best: 0.6928481 (1598)	total: 7.31s	remaining: 0us
#
# bestTest = 0.6928480966
# bestIteration = 1598
#
# Shrink model to first 1599 iterations.
# CV Log Loss Score: 0.692848
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0890267	test: 1.0890222	best: 1.0890222 (0)	total: 8.2ms	remaining: 13.1s
# 200:	learn: 0.8190021	test: 0.8119861	best: 0.8119861 (200)	total: 882ms	remaining: 6.13s
# 400:	learn: 0.7813550	test: 0.7651969	best: 0.7651969 (400)	total: 1.87s	remaining: 5.6s
# 600:	learn: 0.7593369	test: 0.7371418	best: 0.7371418 (598)	total: 2.86s	remaining: 4.75s
# 800:	learn: 0.7478515	test: 0.7236253	best: 0.7236253 (800)	total: 3.73s	remaining: 3.72s
# 1000:	learn: 0.7384709	test: 0.7120936	best: 0.7120919 (995)	total: 4.59s	remaining: 2.75s
# 1200:	learn: 0.7310216	test: 0.7029014	best: 0.7029014 (1198)	total: 5.51s	remaining: 1.83s
# 1400:	learn: 0.7267876	test: 0.6985625	best: 0.6985625 (1399)	total: 6.43s	remaining: 914ms
# 1599:	learn: 0.7216024	test: 0.6931331	best: 0.6931331 (1598)	total: 7.47s	remaining: 0us
#
# bestTest = 0.6931331365
# bestIteration = 1598
#
# Shrink model to first 1599 iterations.
# CV Log Loss Score: 0.693133
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0890253	test: 1.0890184	best: 1.0890184 (0)	total: 7.7ms	remaining: 12.3s
# 200:	learn: 0.8209367	test: 0.8159837	best: 0.8159837 (200)	total: 892ms	remaining: 6.21s
# 400:	learn: 0.7899406	test: 0.7792600	best: 0.7792600 (400)	total: 1.83s	remaining: 5.49s
# 600:	learn: 0.7637576	test: 0.7446189	best: 0.7446106 (599)	total: 2.79s	remaining: 4.63s
# 800:	learn: 0.7455834	test: 0.7210941	best: 0.7210941 (800)	total: 3.72s	remaining: 3.71s
# 1000:	learn: 0.7365041	test: 0.7090624	best: 0.7090624 (1000)	total: 4.67s	remaining: 2.79s
# 1200:	learn: 0.7304861	test: 0.7012787	best: 0.7012759 (1195)	total: 5.55s	remaining: 1.84s
# 1400:	learn: 0.7260086	test: 0.6953742	best: 0.6953742 (1400)	total: 6.4s	remaining: 909ms
# 1599:	learn: 0.7203581	test: 0.6882672	best: 0.6882672 (1599)	total: 7.38s	remaining: 0us
#
# bestTest = 0.6882672326
# bestIteration = 1599
#
# CV Log Loss Score: 0.688267
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0890260	test: 1.0890236	best: 1.0890236 (0)	total: 7.58ms	remaining: 12.1s
# 200:	learn: 0.8276835	test: 0.8175924	best: 0.8175924 (200)	total: 895ms	remaining: 6.23s
# 400:	learn: 0.7925783	test: 0.7753460	best: 0.7753339 (393)	total: 1.74s	remaining: 5.2s
# 600:	learn: 0.7655465	test: 0.7424198	best: 0.7424198 (599)	total: 2.63s	remaining: 4.37s
# 800:	learn: 0.7462535	test: 0.7188462	best: 0.7188436 (798)	total: 3.61s	remaining: 3.6s
# 1000:	learn: 0.7358913	test: 0.7066068	best: 0.7066068 (999)	total: 4.54s	remaining: 2.72s
# 1200:	learn: 0.7285704	test: 0.6983423	best: 0.6983423 (1200)	total: 5.45s	remaining: 1.81s
# 1400:	learn: 0.7239958	test: 0.6932504	best: 0.6932503 (1397)	total: 6.38s	remaining: 907ms
# 1599:	learn: 0.7195747	test: 0.6893179	best: 0.6893179 (1599)	total: 7.38s	remaining: 0us
#
# bestTest = 0.6893178788
# bestIteration = 1599
#
# CV Log Loss Score: 0.689318
# 	Log Loss: 0.688837
# [I 2021-06-17 16:51:21,713] Trial 1 finished with value: 0.688836749032952 and parameters: {'learning_rate': 0.021711359443392465, 'n_estimators': 1600, 'colsample_bylevel': 0.026439583708441586, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.6229306906254795}. Best is trial 0 with value: 0.6693180374883876.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0902771	test: 1.0902865	best: 1.0902865 (0)	total: 16.9ms	remaining: 1m 7s
# 200:	learn: 0.7590139	test: 0.7233567	best: 0.7233567 (200)	total: 5.46s	remaining: 1m 43s
# 400:	learn: 0.7299497	test: 0.6812588	best: 0.6812577 (398)	total: 10.7s	remaining: 1m 36s
# 600:	learn: 0.7193760	test: 0.6672243	best: 0.6672243 (600)	total: 16.6s	remaining: 1m 33s
# 800:	learn: 0.7110620	test: 0.6614379	best: 0.6614379 (800)	total: 24s	remaining: 1m 36s
# 1000:	learn: 0.7050628	test: 0.6596081	best: 0.6595910 (995)	total: 31.6s	remaining: 1m 34s
# 1200:	learn: 0.6994671	test: 0.6588554	best: 0.6588554 (1200)	total: 38.9s	remaining: 1m 30s
# 1400:	learn: 0.6943318	test: 0.6584950	best: 0.6584945 (1399)	total: 46.5s	remaining: 1m 26s
# 1600:	learn: 0.6891511	test: 0.6581319	best: 0.6581221 (1598)	total: 54.2s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6581069762
# bestIteration = 1651
#
# Shrink model to first 1652 iterations.
# CV Log Loss Score: 0.658107
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0902746	test: 1.0902797	best: 1.0902797 (0)	total: 21.2ms	remaining: 1m 24s
# 200:	learn: 0.7659637	test: 0.7373481	best: 0.7373481 (200)	total: 5.07s	remaining: 1m 35s
# 400:	learn: 0.7317346	test: 0.6843540	best: 0.6843540 (400)	total: 10.8s	remaining: 1m 36s
# 600:	learn: 0.7209886	test: 0.6677515	best: 0.6677515 (600)	total: 16.7s	remaining: 1m 34s
# 800:	learn: 0.7127165	test: 0.6605004	best: 0.6604989 (799)	total: 23.6s	remaining: 1m 34s
# 1000:	learn: 0.7060773	test: 0.6579738	best: 0.6579738 (1000)	total: 31.7s	remaining: 1m 34s
# 1200:	learn: 0.7004878	test: 0.6568207	best: 0.6568173 (1195)	total: 39.5s	remaining: 1m 31s
# 1400:	learn: 0.6951458	test: 0.6562654	best: 0.6562575 (1398)	total: 46.9s	remaining: 1m 27s
# 1600:	learn: 0.6899479	test: 0.6560595	best: 0.6559729 (1576)	total: 54.5s	remaining: 1m 21s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6559728531
# bestIteration = 1576
#
# Shrink model to first 1577 iterations.
# CV Log Loss Score: 0.655973
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0902716	test: 1.0902659	best: 1.0902659 (0)	total: 19.8ms	remaining: 1m 19s
# 200:	learn: 0.7710694	test: 0.7489721	best: 0.7489721 (200)	total: 4.86s	remaining: 1m 31s
# 400:	learn: 0.7337677	test: 0.6935854	best: 0.6935854 (400)	total: 9.85s	remaining: 1m 28s
# 600:	learn: 0.7213366	test: 0.6751991	best: 0.6751991 (600)	total: 15.5s	remaining: 1m 27s
# 800:	learn: 0.7139522	test: 0.6679242	best: 0.6679242 (800)	total: 23.8s	remaining: 1m 35s
# 1000:	learn: 0.7077208	test: 0.6652097	best: 0.6652097 (1000)	total: 33s	remaining: 1m 38s
# 1200:	learn: 0.7023934	test: 0.6636619	best: 0.6636467 (1197)	total: 42.7s	remaining: 1m 39s
# 1400:	learn: 0.6977603	test: 0.6627280	best: 0.6626990 (1398)	total: 51s	remaining: 1m 34s
# 1600:	learn: 0.6924675	test: 0.6621534	best: 0.6621251 (1596)	total: 58.8s	remaining: 1m 28s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6621250904
# bestIteration = 1596
#
# Shrink model to first 1597 iterations.
# CV Log Loss Score: 0.662125
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0902657	test: 1.0902742	best: 1.0902742 (0)	total: 19.8ms	remaining: 1m 19s
# 200:	learn: 0.7614402	test: 0.7424112	best: 0.7424112 (200)	total: 5.29s	remaining: 1m 39s
# 400:	learn: 0.7290644	test: 0.7001452	best: 0.7001452 (400)	total: 10.7s	remaining: 1m 36s
# 600:	learn: 0.7174071	test: 0.6851566	best: 0.6851566 (600)	total: 16.3s	remaining: 1m 31s
# 800:	learn: 0.7085068	test: 0.6778955	best: 0.6778955 (800)	total: 23.8s	remaining: 1m 34s
# 1000:	learn: 0.7024176	test: 0.6756244	best: 0.6756242 (996)	total: 31.9s	remaining: 1m 35s
# 1200:	learn: 0.6968745	test: 0.6747113	best: 0.6747113 (1199)	total: 39.8s	remaining: 1m 32s
# 1400:	learn: 0.6916510	test: 0.6743800	best: 0.6742782 (1358)	total: 47.6s	remaining: 1m 28s
# 1600:	learn: 0.6859551	test: 0.6739169	best: 0.6738834 (1596)	total: 56s	remaining: 1m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6738834139
# bestIteration = 1596
#
# Shrink model to first 1597 iterations.
# CV Log Loss Score: 0.673883
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0902657	test: 1.0902584	best: 1.0902584 (0)	total: 25.1ms	remaining: 1m 40s
# 200:	learn: 0.7672345	test: 0.7446446	best: 0.7446446 (200)	total: 5.46s	remaining: 1m 43s
# 400:	learn: 0.7300161	test: 0.6940965	best: 0.6940965 (400)	total: 11.6s	remaining: 1m 43s
# 600:	learn: 0.7186203	test: 0.6786452	best: 0.6786452 (600)	total: 17.5s	remaining: 1m 38s
# 800:	learn: 0.7099798	test: 0.6702972	best: 0.6702972 (800)	total: 25.2s	remaining: 1m 40s
# 1000:	learn: 0.7031984	test: 0.6677202	best: 0.6677182 (998)	total: 33.5s	remaining: 1m 40s
# 1200:	learn: 0.6977188	test: 0.6662302	best: 0.6662155 (1199)	total: 41.9s	remaining: 1m 37s
# 1400:	learn: 0.6924487	test: 0.6656247	best: 0.6656134 (1396)	total: 49.8s	remaining: 1m 32s
# 1600:	learn: 0.6875002	test: 0.6653713	best: 0.6653159 (1572)	total: 57.9s	remaining: 1m 26s
# 1800:	learn: 0.6828375	test: 0.6650805	best: 0.6650728 (1752)	total: 1m 5s	remaining: 1m 20s
# 2000:	learn: 0.6785002	test: 0.6649548	best: 0.6648796 (1902)	total: 1m 13s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6648795839
# bestIteration = 1902
#
# Shrink model to first 1903 iterations.
# CV Log Loss Score: 0.664880
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0902579	test: 1.0902808	best: 1.0902808 (0)	total: 17.5ms	remaining: 1m 9s
# 200:	learn: 0.7668832	test: 0.7529229	best: 0.7529229 (200)	total: 5.5s	remaining: 1m 44s
# 400:	learn: 0.7309382	test: 0.7048140	best: 0.7048140 (400)	total: 11.1s	remaining: 1m 39s
# 600:	learn: 0.7188536	test: 0.6899772	best: 0.6899772 (600)	total: 17.1s	remaining: 1m 36s
# 800:	learn: 0.7106989	test: 0.6842391	best: 0.6842348 (799)	total: 24.3s	remaining: 1m 36s
# 1000:	learn: 0.7046855	test: 0.6822860	best: 0.6822860 (1000)	total: 32.1s	remaining: 1m 36s
# 1200:	learn: 0.6990899	test: 0.6814641	best: 0.6814069 (1178)	total: 40.3s	remaining: 1m 33s
# 1400:	learn: 0.6943432	test: 0.6812316	best: 0.6811689 (1345)	total: 48.1s	remaining: 1m 29s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6811688886
# bestIteration = 1345
#
# Shrink model to first 1346 iterations.
# CV Log Loss Score: 0.681169
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0902788	test: 1.0902695	best: 1.0902695 (0)	total: 18.9ms	remaining: 1m 15s
# 200:	learn: 0.7648627	test: 0.7432023	best: 0.7432023 (200)	total: 5.39s	remaining: 1m 41s
# 400:	learn: 0.7284524	test: 0.6899562	best: 0.6899562 (400)	total: 11.1s	remaining: 1m 39s
# 600:	learn: 0.7183178	test: 0.6768725	best: 0.6768725 (600)	total: 17.2s	remaining: 1m 37s
# 800:	learn: 0.7103277	test: 0.6707591	best: 0.6707591 (800)	total: 25s	remaining: 1m 39s
# 1000:	learn: 0.7040632	test: 0.6682573	best: 0.6682458 (994)	total: 32.8s	remaining: 1m 38s
# 1200:	learn: 0.6982555	test: 0.6669487	best: 0.6668915 (1182)	total: 40.9s	remaining: 1m 35s
# 1400:	learn: 0.6927618	test: 0.6664302	best: 0.6664122 (1397)	total: 48.8s	remaining: 1m 30s
# 1600:	learn: 0.6875351	test: 0.6662171	best: 0.6661658 (1519)	total: 56.8s	remaining: 1m 25s
# 1800:	learn: 0.6818361	test: 0.6658790	best: 0.6658554 (1775)	total: 1m 4s	remaining: 1m 19s
# 2000:	learn: 0.6774025	test: 0.6655436	best: 0.6655345 (1988)	total: 1m 12s	remaining: 1m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6655345119
# bestIteration = 1988
#
# Shrink model to first 1989 iterations.
# CV Log Loss Score: 0.665535
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0902581	test: 1.0902771	best: 1.0902771 (0)	total: 20.3ms	remaining: 1m 21s
# 200:	learn: 0.7664270	test: 0.7466444	best: 0.7466444 (200)	total: 5.17s	remaining: 1m 37s
# 400:	learn: 0.7311852	test: 0.6992959	best: 0.6992900 (397)	total: 10.8s	remaining: 1m 37s
# 600:	learn: 0.7184489	test: 0.6837708	best: 0.6837707 (599)	total: 17.3s	remaining: 1m 37s
# 800:	learn: 0.7105468	test: 0.6773728	best: 0.6773385 (796)	total: 24.9s	remaining: 1m 39s
# 1000:	learn: 0.7036632	test: 0.6752321	best: 0.6752194 (999)	total: 33.1s	remaining: 1m 39s
# 1200:	learn: 0.6984981	test: 0.6742388	best: 0.6742018 (1190)	total: 40.7s	remaining: 1m 34s
# 1400:	learn: 0.6928081	test: 0.6737348	best: 0.6737112 (1377)	total: 48.6s	remaining: 1m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6736552089
# bestIteration = 1432
#
# Shrink model to first 1433 iterations.
# CV Log Loss Score: 0.673655
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0902644	test: 1.0902996	best: 1.0902996 (0)	total: 21.4ms	remaining: 1m 25s
# 200:	learn: 0.7705645	test: 0.7535918	best: 0.7535918 (200)	total: 5.16s	remaining: 1m 37s
# 400:	learn: 0.7292976	test: 0.6949743	best: 0.6949743 (400)	total: 10.8s	remaining: 1m 36s
# 600:	learn: 0.7192537	test: 0.6806237	best: 0.6806237 (599)	total: 16.3s	remaining: 1m 32s
# 800:	learn: 0.7107975	test: 0.6736113	best: 0.6736113 (800)	total: 24.2s	remaining: 1m 36s
# 1000:	learn: 0.7050496	test: 0.6712126	best: 0.6712126 (1000)	total: 32s	remaining: 1m 35s
# 1200:	learn: 0.6995678	test: 0.6702880	best: 0.6702695 (1199)	total: 39.8s	remaining: 1m 32s
# 1400:	learn: 0.6938760	test: 0.6692641	best: 0.6692501 (1397)	total: 47.7s	remaining: 1m 28s
# 1600:	learn: 0.6896271	test: 0.6689687	best: 0.6689687 (1600)	total: 55s	remaining: 1m 22s
# 1800:	learn: 0.6852295	test: 0.6685333	best: 0.6684409 (1784)	total: 1m 2s	remaining: 1m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6684409138
# bestIteration = 1784
#
# Shrink model to first 1785 iterations.
# CV Log Loss Score: 0.668441
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0902594	test: 1.0902512	best: 1.0902512 (0)	total: 21.3ms	remaining: 1m 25s
# 200:	learn: 0.7599632	test: 0.7352604	best: 0.7352604 (200)	total: 5.57s	remaining: 1m 45s
# 400:	learn: 0.7291108	test: 0.6955672	best: 0.6955672 (400)	total: 11.4s	remaining: 1m 42s
# 600:	learn: 0.7178316	test: 0.6824716	best: 0.6824716 (600)	total: 17.2s	remaining: 1m 37s
# 800:	learn: 0.7095489	test: 0.6765662	best: 0.6765662 (800)	total: 25.3s	remaining: 1m 41s
# 1000:	learn: 0.7032205	test: 0.6748135	best: 0.6748134 (999)	total: 33.8s	remaining: 1m 41s
# 1200:	learn: 0.6975311	test: 0.6740604	best: 0.6740601 (1199)	total: 42.2s	remaining: 1m 38s
# 1400:	learn: 0.6921059	test: 0.6736271	best: 0.6736034 (1394)	total: 50.8s	remaining: 1m 34s
# 1600:	learn: 0.6869486	test: 0.6732935	best: 0.6732837 (1599)	total: 59.2s	remaining: 1m 28s
# 1800:	learn: 0.6819783	test: 0.6731406	best: 0.6731263 (1786)	total: 1m 7s	remaining: 1m 22s
# 2000:	learn: 0.6774112	test: 0.6729152	best: 0.6729068 (1999)	total: 1m 15s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6727521804
# bestIteration = 2081
#
# Shrink model to first 2082 iterations.
# CV Log Loss Score: 0.672752
# 	Log Loss: 0.667652
# [I 2021-06-17 17:02:11,113] Trial 2 finished with value: 0.6676516012424974 and parameters: {'learning_rate': 0.018845800568165955, 'n_estimators': 4000, 'colsample_bylevel': 0.06138249106981117, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5833610870926725}. Best is trial 2 with value: 0.6676516012424974.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0626585	test: 1.0627002	best: 1.0627002 (0)	total: 3.48ms	remaining: 9.74s
# 200:	learn: 0.8094793	test: 0.7890382	best: 0.7890381 (199)	total: 675ms	remaining: 8.73s
# 400:	learn: 0.7749520	test: 0.7437819	best: 0.7437769 (399)	total: 1.37s	remaining: 8.17s
# 600:	learn: 0.7588390	test: 0.7225128	best: 0.7225092 (590)	total: 2.08s	remaining: 7.63s
# 800:	learn: 0.7455195	test: 0.7023907	best: 0.7023473 (789)	total: 2.77s	remaining: 6.91s
# 1000:	learn: 0.7424257	test: 0.6983657	best: 0.6983553 (999)	total: 3.41s	remaining: 6.13s
# 1200:	learn: 0.7392649	test: 0.6946307	best: 0.6946226 (1198)	total: 4.09s	remaining: 5.45s
# 1400:	learn: 0.7339386	test: 0.6874294	best: 0.6874294 (1400)	total: 4.78s	remaining: 4.78s
# 1600:	learn: 0.7309874	test: 0.6842126	best: 0.6842121 (1597)	total: 5.46s	remaining: 4.09s
# 1800:	learn: 0.7285299	test: 0.6812187	best: 0.6811899 (1787)	total: 6.21s	remaining: 3.45s
# 2000:	learn: 0.7269096	test: 0.6791526	best: 0.6791160 (1967)	total: 6.91s	remaining: 2.76s
# 2200:	learn: 0.7250753	test: 0.6767652	best: 0.6767290 (2147)	total: 7.62s	remaining: 2.07s
# 2400:	learn: 0.7238169	test: 0.6759413	best: 0.6759383 (2378)	total: 8.31s	remaining: 1.38s
# 2600:	learn: 0.7228214	test: 0.6750943	best: 0.6750873 (2583)	total: 9.09s	remaining: 695ms
# 2799:	learn: 0.7218696	test: 0.6738334	best: 0.6738334 (2799)	total: 9.9s	remaining: 0us
#
# bestTest = 0.6738334289
# bestIteration = 2799
#
# CV Log Loss Score: 0.673833
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0626658	test: 1.0626693	best: 1.0626693 (0)	total: 4.21ms	remaining: 11.8s
# 200:	learn: 0.8192942	test: 0.8079133	best: 0.8079133 (200)	total: 743ms	remaining: 9.61s
# 400:	learn: 0.7793398	test: 0.7565022	best: 0.7565022 (400)	total: 1.5s	remaining: 9.01s
# 600:	learn: 0.7586542	test: 0.7292194	best: 0.7292194 (599)	total: 2.26s	remaining: 8.28s
# 800:	learn: 0.7443622	test: 0.7057808	best: 0.7057808 (800)	total: 2.96s	remaining: 7.39s
# 1000:	learn: 0.7417259	test: 0.7016197	best: 0.7016099 (998)	total: 3.66s	remaining: 6.59s
# 1200:	learn: 0.7378758	test: 0.6960970	best: 0.6960791 (1170)	total: 4.39s	remaining: 5.85s
# 1400:	learn: 0.7343471	test: 0.6909535	best: 0.6909535 (1400)	total: 5.18s	remaining: 5.17s
# 1600:	learn: 0.7314145	test: 0.6854959	best: 0.6854959 (1598)	total: 5.94s	remaining: 4.45s
# 1800:	learn: 0.7282502	test: 0.6802392	best: 0.6802048 (1796)	total: 6.7s	remaining: 3.71s
# 2000:	learn: 0.7267091	test: 0.6780366	best: 0.6779757 (1977)	total: 7.4s	remaining: 2.95s
# 2200:	learn: 0.7249588	test: 0.6756338	best: 0.6756229 (2177)	total: 8.13s	remaining: 2.21s
# 2400:	learn: 0.7232538	test: 0.6737221	best: 0.6737221 (2394)	total: 8.91s	remaining: 1.48s
# 2600:	learn: 0.7217561	test: 0.6722141	best: 0.6721545 (2569)	total: 9.71s	remaining: 743ms
# 2799:	learn: 0.7208417	test: 0.6708977	best: 0.6708976 (2787)	total: 10.4s	remaining: 0us
#
# bestTest = 0.6708975783
# bestIteration = 2787
#
# Shrink model to first 2788 iterations.
# CV Log Loss Score: 0.670898
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0626658	test: 1.0626693	best: 1.0626693 (0)	total: 4.04ms	remaining: 11.3s
# 200:	learn: 0.8116888	test: 0.8035421	best: 0.8035421 (200)	total: 716ms	remaining: 9.26s
# 400:	learn: 0.7790276	test: 0.7610417	best: 0.7610417 (397)	total: 1.43s	remaining: 8.53s
# 600:	learn: 0.7555519	test: 0.7312339	best: 0.7312335 (597)	total: 2.15s	remaining: 7.86s
# 800:	learn: 0.7428741	test: 0.7112430	best: 0.7112429 (796)	total: 2.87s	remaining: 7.15s
# 1000:	learn: 0.7401331	test: 0.7079474	best: 0.7079272 (982)	total: 3.57s	remaining: 6.41s
# 1200:	learn: 0.7362259	test: 0.7026275	best: 0.7026274 (1198)	total: 4.28s	remaining: 5.69s
# 1400:	learn: 0.7312618	test: 0.6948377	best: 0.6948301 (1396)	total: 5.05s	remaining: 5.04s
# 1600:	learn: 0.7283056	test: 0.6911796	best: 0.6911778 (1597)	total: 5.8s	remaining: 4.35s
# 1800:	learn: 0.7265316	test: 0.6885347	best: 0.6885347 (1798)	total: 6.55s	remaining: 3.63s
# 2000:	learn: 0.7252252	test: 0.6866066	best: 0.6865691 (1979)	total: 7.27s	remaining: 2.9s
# 2200:	learn: 0.7233754	test: 0.6843274	best: 0.6843033 (2171)	total: 8.04s	remaining: 2.19s
# 2400:	learn: 0.7216503	test: 0.6824447	best: 0.6824431 (2399)	total: 8.86s	remaining: 1.47s
# 2600:	learn: 0.7201289	test: 0.6807266	best: 0.6807266 (2600)	total: 9.61s	remaining: 735ms
# 2799:	learn: 0.7190628	test: 0.6793141	best: 0.6793027 (2789)	total: 10.3s	remaining: 0us
#
# bestTest = 0.6793027187
# bestIteration = 2789
#
# Shrink model to first 2790 iterations.
# CV Log Loss Score: 0.679303
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0626658	test: 1.0626693	best: 1.0626693 (0)	total: 4.68ms	remaining: 13.1s
# 200:	learn: 0.8088846	test: 0.8005734	best: 0.8005734 (200)	total: 713ms	remaining: 9.22s
# 400:	learn: 0.7791436	test: 0.7645570	best: 0.7645569 (396)	total: 1.41s	remaining: 8.43s
# 600:	learn: 0.7530105	test: 0.7327566	best: 0.7327566 (600)	total: 2.14s	remaining: 7.82s
# 800:	learn: 0.7418898	test: 0.7185931	best: 0.7185931 (800)	total: 2.85s	remaining: 7.13s
# 1000:	learn: 0.7366259	test: 0.7110202	best: 0.7110202 (1000)	total: 3.54s	remaining: 6.36s
# 1200:	learn: 0.7332863	test: 0.7074240	best: 0.7074163 (1131)	total: 4.24s	remaining: 5.64s
# 1400:	learn: 0.7295490	test: 0.7023554	best: 0.7023554 (1400)	total: 5.07s	remaining: 5.06s
# 1600:	learn: 0.7263882	test: 0.6985391	best: 0.6985316 (1597)	total: 5.83s	remaining: 4.37s
# 1800:	learn: 0.7245207	test: 0.6966936	best: 0.6966824 (1751)	total: 6.57s	remaining: 3.64s
# 2000:	learn: 0.7228889	test: 0.6945080	best: 0.6944874 (1969)	total: 7.32s	remaining: 2.92s
# 2200:	learn: 0.7204953	test: 0.6915954	best: 0.6915949 (2197)	total: 8.14s	remaining: 2.22s
# 2400:	learn: 0.7187349	test: 0.6904576	best: 0.6904573 (2397)	total: 8.96s	remaining: 1.49s
# 2600:	learn: 0.7179629	test: 0.6900072	best: 0.6900072 (2600)	total: 9.68s	remaining: 741ms
# 2799:	learn: 0.7167442	test: 0.6884742	best: 0.6884729 (2786)	total: 10.4s	remaining: 0us
#
# bestTest = 0.6884729328
# bestIteration = 2786
#
# Shrink model to first 2787 iterations.
# CV Log Loss Score: 0.688473
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0626658	test: 1.0626693	best: 1.0626693 (0)	total: 4.75ms	remaining: 13.3s
# 200:	learn: 0.8101963	test: 0.8005408	best: 0.8005408 (200)	total: 728ms	remaining: 9.42s
# 400:	learn: 0.7829351	test: 0.7675674	best: 0.7675674 (399)	total: 1.49s	remaining: 8.94s
# 600:	learn: 0.7599120	test: 0.7389688	best: 0.7389685 (598)	total: 2.25s	remaining: 8.25s
# 800:	learn: 0.7443012	test: 0.7160775	best: 0.7160775 (800)	total: 2.99s	remaining: 7.46s
# 1000:	learn: 0.7414755	test: 0.7127708	best: 0.7127707 (995)	total: 3.7s	remaining: 6.65s
# 1200:	learn: 0.7378223	test: 0.7084338	best: 0.7084276 (1195)	total: 4.5s	remaining: 5.99s
# 1400:	learn: 0.7312938	test: 0.6991157	best: 0.6991137 (1398)	total: 5.3s	remaining: 5.29s
# 1600:	learn: 0.7285959	test: 0.6949835	best: 0.6949835 (1600)	total: 6.03s	remaining: 4.51s
# 1800:	learn: 0.7263867	test: 0.6918894	best: 0.6918894 (1800)	total: 6.76s	remaining: 3.75s
# 2000:	learn: 0.7250114	test: 0.6902648	best: 0.6902648 (1998)	total: 7.57s	remaining: 3.02s
# 2200:	learn: 0.7226548	test: 0.6867791	best: 0.6867720 (2196)	total: 8.42s	remaining: 2.29s
# 2400:	learn: 0.7211889	test: 0.6855502	best: 0.6855502 (2400)	total: 9.2s	remaining: 1.53s
# 2600:	learn: 0.7198726	test: 0.6835786	best: 0.6835426 (2538)	total: 10s	remaining: 767ms
# 2799:	learn: 0.7183417	test: 0.6822476	best: 0.6822467 (2792)	total: 10.8s	remaining: 0us
#
# bestTest = 0.6822467467
# bestIteration = 2792
#
# Shrink model to first 2793 iterations.
# CV Log Loss Score: 0.682247
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0626658	test: 1.0626693	best: 1.0626693 (0)	total: 4.43ms	remaining: 12.4s
# 200:	learn: 0.8113180	test: 0.8059348	best: 0.8059348 (200)	total: 785ms	remaining: 10.2s
# 400:	learn: 0.7794990	test: 0.7672964	best: 0.7672963 (398)	total: 1.56s	remaining: 9.36s
# 600:	learn: 0.7577087	test: 0.7413802	best: 0.7413517 (594)	total: 2.3s	remaining: 8.43s
# 800:	learn: 0.7498789	test: 0.7327476	best: 0.7327456 (793)	total: 3.02s	remaining: 7.54s
# 1000:	learn: 0.7434574	test: 0.7240921	best: 0.7240877 (993)	total: 3.82s	remaining: 6.87s
# 1200:	learn: 0.7397234	test: 0.7192800	best: 0.7192626 (1129)	total: 4.73s	remaining: 6.29s
# 1400:	learn: 0.7350307	test: 0.7135239	best: 0.7135239 (1400)	total: 5.57s	remaining: 5.56s
# 1600:	learn: 0.7309383	test: 0.7083166	best: 0.7083163 (1593)	total: 6.31s	remaining: 4.73s
# 1800:	learn: 0.7278079	test: 0.7049556	best: 0.7049555 (1797)	total: 7.18s	remaining: 3.98s
# 2000:	learn: 0.7261562	test: 0.7030436	best: 0.7030217 (1983)	total: 7.97s	remaining: 3.18s
# 2200:	learn: 0.7243793	test: 0.7013098	best: 0.7012574 (2153)	total: 8.77s	remaining: 2.39s
# 2400:	learn: 0.7229088	test: 0.7003920	best: 0.7003739 (2372)	total: 9.58s	remaining: 1.59s
# 2600:	learn: 0.7212499	test: 0.6980324	best: 0.6979942 (2517)	total: 10.4s	remaining: 797ms
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6979942369
# bestIteration = 2517
#
# Shrink model to first 2518 iterations.
# CV Log Loss Score: 0.697994
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0626658	test: 1.0626693	best: 1.0626693 (0)	total: 4.32ms	remaining: 12.1s
# 200:	learn: 0.8113804	test: 0.8041874	best: 0.8041874 (200)	total: 750ms	remaining: 9.7s
# 400:	learn: 0.7776120	test: 0.7599421	best: 0.7599421 (397)	total: 1.48s	remaining: 8.84s
# 600:	learn: 0.7579257	test: 0.7368936	best: 0.7368609 (599)	total: 2.23s	remaining: 8.14s
# 800:	learn: 0.7456438	test: 0.7182800	best: 0.7182758 (789)	total: 2.98s	remaining: 7.43s
# 1000:	learn: 0.7419756	test: 0.7132844	best: 0.7132684 (990)	total: 3.74s	remaining: 6.72s
# 1200:	learn: 0.7376064	test: 0.7076469	best: 0.7076468 (1198)	total: 4.58s	remaining: 6.09s
# 1400:	learn: 0.7324902	test: 0.6998398	best: 0.6998391 (1397)	total: 5.33s	remaining: 5.32s
# 1600:	learn: 0.7302895	test: 0.6966224	best: 0.6966183 (1597)	total: 6.03s	remaining: 4.51s
# 1800:	learn: 0.7262498	test: 0.6902490	best: 0.6902490 (1796)	total: 6.78s	remaining: 3.76s
# 2000:	learn: 0.7251801	test: 0.6890289	best: 0.6890007 (1965)	total: 7.55s	remaining: 3.02s
# 2200:	learn: 0.7229886	test: 0.6859924	best: 0.6859859 (2184)	total: 8.37s	remaining: 2.28s
# 2400:	learn: 0.7216848	test: 0.6849634	best: 0.6849400 (2390)	total: 9.15s	remaining: 1.52s
# 2600:	learn: 0.7206678	test: 0.6837162	best: 0.6837162 (2600)	total: 9.91s	remaining: 759ms
# 2799:	learn: 0.7195405	test: 0.6824937	best: 0.6824435 (2782)	total: 10.6s	remaining: 0us
#
# bestTest = 0.6824434563
# bestIteration = 2782
#
# Shrink model to first 2783 iterations.
# CV Log Loss Score: 0.682443
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0626740	test: 1.0626347	best: 1.0626347 (0)	total: 4.23ms	remaining: 11.8s
# 200:	learn: 0.8076029	test: 0.7974089	best: 0.7974088 (198)	total: 705ms	remaining: 9.11s
# 400:	learn: 0.7799381	test: 0.7634372	best: 0.7634189 (390)	total: 1.4s	remaining: 8.38s
# 600:	learn: 0.7603643	test: 0.7411731	best: 0.7411339 (595)	total: 2.11s	remaining: 7.72s
# 800:	learn: 0.7460681	test: 0.7225342	best: 0.7225091 (780)	total: 2.9s	remaining: 7.23s
# 1000:	learn: 0.7405594	test: 0.7151609	best: 0.7151452 (992)	total: 3.65s	remaining: 6.56s
# 1200:	learn: 0.7360910	test: 0.7095923	best: 0.7095829 (1198)	total: 4.39s	remaining: 5.84s
# 1400:	learn: 0.7306263	test: 0.7009890	best: 0.7009890 (1400)	total: 5.12s	remaining: 5.12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6979422731
# bestIteration = 1450
#
# Shrink model to first 1451 iterations.
# CV Log Loss Score: 0.697942
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0626740	test: 1.0626347	best: 1.0626347 (0)	total: 4.78ms	remaining: 13.4s
# 200:	learn: 0.8081979	test: 0.8002952	best: 0.8002952 (200)	total: 854ms	remaining: 11s
# 400:	learn: 0.7781129	test: 0.7617263	best: 0.7617262 (398)	total: 1.59s	remaining: 9.54s
# 600:	learn: 0.7566658	test: 0.7344557	best: 0.7344557 (600)	total: 2.34s	remaining: 8.56s
# 800:	learn: 0.7445517	test: 0.7179209	best: 0.7178990 (785)	total: 3.06s	remaining: 7.64s
# 1000:	learn: 0.7394853	test: 0.7105560	best: 0.7105560 (1000)	total: 3.79s	remaining: 6.81s
# 1200:	learn: 0.7362346	test: 0.7059080	best: 0.7059080 (1200)	total: 4.54s	remaining: 6.04s
# 1400:	learn: 0.7315963	test: 0.6992875	best: 0.6992875 (1400)	total: 5.26s	remaining: 5.25s
# 1600:	learn: 0.7283226	test: 0.6940644	best: 0.6940532 (1597)	total: 5.97s	remaining: 4.47s
# 1800:	learn: 0.7258325	test: 0.6908476	best: 0.6908476 (1796)	total: 6.78s	remaining: 3.76s
# 2000:	learn: 0.7241527	test: 0.6888802	best: 0.6888447 (1994)	total: 7.57s	remaining: 3.02s
# 2200:	learn: 0.7220617	test: 0.6864389	best: 0.6864389 (2200)	total: 8.31s	remaining: 2.26s
# 2400:	learn: 0.7212486	test: 0.6859060	best: 0.6858870 (2360)	total: 9.07s	remaining: 1.51s
# ...
# 800:	learn: 0.5948233	test: 0.6634813	best: 0.6634049 (789)	total: 5m 54s	remaining: 8m 50s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6630673737
# bestIteration = 820
#
# Shrink model to first 821 iterations.
# CV Log Loss Score: 0.663067
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0808870	test: 1.0808640	best: 1.0808640 (0)	total: 19ms	remaining: 37.9s
# 200:	learn: 0.7153800	test: 0.6868734	best: 0.6868734 (199)	total: 33s	remaining: 4m 55s
# 400:	learn: 0.6798803	test: 0.6796319	best: 0.6796319 (400)	total: 1m 43s	remaining: 6m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6790030896
# bestIteration = 433
#
# Shrink model to first 434 iterations.
# CV Log Loss Score: 0.679003
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0808791	test: 1.0808945	best: 1.0808945 (0)	total: 19ms	remaining: 38s
# 200:	learn: 0.7162282	test: 0.6784604	best: 0.6784604 (199)	total: 37.4s	remaining: 5m 34s
# 400:	learn: 0.6805783	test: 0.6696558	best: 0.6696558 (400)	total: 1m 56s	remaining: 7m 42s
# 600:	learn: 0.6358714	test: 0.6682229	best: 0.6679082 (556)	total: 3m 52s	remaining: 9m
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6679082303
# bestIteration = 556
#
# Shrink model to first 557 iterations.
# CV Log Loss Score: 0.667908
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0808773	test: 1.0809170	best: 1.0809170 (0)	total: 27.2ms	remaining: 54.3s
# 200:	learn: 0.7157016	test: 0.6905366	best: 0.6905366 (200)	total: 33.8s	remaining: 5m 2s
# 400:	learn: 0.6822987	test: 0.6828467	best: 0.6826318 (393)	total: 1m 50s	remaining: 7m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6826317934
# bestIteration = 393
#
# Shrink model to first 394 iterations.
# CV Log Loss Score: 0.682632
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0808831	test: 1.0808768	best: 1.0808768 (0)	total: 18.7ms	remaining: 37.4s
# 200:	learn: 0.7185792	test: 0.6811468	best: 0.6811311 (199)	total: 29.4s	remaining: 4m 22s
# 400:	learn: 0.6810108	test: 0.6712927	best: 0.6712655 (389)	total: 1m 51s	remaining: 7m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6700054207
# bestIteration = 488
#
# Shrink model to first 489 iterations.
# CV Log Loss Score: 0.670005
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0808802	test: 1.0808961	best: 1.0808961 (0)	total: 18.6ms	remaining: 37.3s
# 200:	learn: 0.7178167	test: 0.6860696	best: 0.6860687 (199)	total: 33.7s	remaining: 5m 1s
# 400:	learn: 0.6815367	test: 0.6777224	best: 0.6777223 (399)	total: 1m 55s	remaining: 7m 41s
# 600:	learn: 0.6332857	test: 0.6759103	best: 0.6758907 (588)	total: 3m 54s	remaining: 9m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6756949784
# bestIteration = 662
#
# Shrink model to first 663 iterations.
# CV Log Loss Score: 0.675695
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0808829	test: 1.0808700	best: 1.0808700 (0)	total: 25.7ms	remaining: 51.5s
# 200:	learn: 0.7176240	test: 0.6813453	best: 0.6813453 (200)	total: 31.4s	remaining: 4m 40s
# 400:	learn: 0.6836134	test: 0.6733833	best: 0.6733833 (400)	total: 1m 55s	remaining: 7m 42s
# 600:	learn: 0.6371341	test: 0.6720956	best: 0.6716404 (523)	total: 3m 50s	remaining: 8m 56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6716404448
# bestIteration = 523
#
# Shrink model to first 524 iterations.
# CV Log Loss Score: 0.671640
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0808853	test: 1.0808943	best: 1.0808943 (0)	total: 21.3ms	remaining: 42.5s
# 200:	learn: 0.7144524	test: 0.6835264	best: 0.6835264 (200)	total: 39.1s	remaining: 5m 50s
# 400:	learn: 0.6807324	test: 0.6768511	best: 0.6768386 (397)	total: 1m 50s	remaining: 7m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6762759821
# bestIteration = 467
#
# Shrink model to first 468 iterations.
# CV Log Loss Score: 0.676276
# 	Log Loss: 0.670586
# [I 2021-06-17 18:20:25,659] Trial 10 finished with value: 0.6705858303823019 and parameters: {'learning_rate': 0.040529377556869105, 'n_estimators': 2000, 'colsample_bylevel': 0.08335704164788042, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 7 with value: 0.6666297448976278.
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0936863	test: 1.0936918	best: 1.0936918 (0)	total: 19ms	remaining: 38.1s
# 200:	learn: 0.8011006	test: 0.7823063	best: 0.7823063 (200)	total: 7.82s	remaining: 1m 10s
# 400:	learn: 0.7582655	test: 0.7226973	best: 0.7226973 (400)	total: 14.7s	remaining: 58.6s
# 600:	learn: 0.7375857	test: 0.6930581	best: 0.6930581 (600)	total: 22.4s	remaining: 52.2s
# 800:	learn: 0.7256405	test: 0.6756428	best: 0.6756427 (798)	total: 32.3s	remaining: 48.3s
# 1000:	learn: 0.7198121	test: 0.6679512	best: 0.6679512 (1000)	total: 40.7s	remaining: 40.6s
# 1200:	learn: 0.7148531	test: 0.6628682	best: 0.6628682 (1200)	total: 52.4s	remaining: 34.9s
# 1400:	learn: 0.7099760	test: 0.6602557	best: 0.6602557 (1400)	total: 1m 10s	remaining: 29.9s
# 1600:	learn: 0.7060579	test: 0.6589713	best: 0.6589713 (1600)	total: 1m 26s	remaining: 21.5s
# 1800:	learn: 0.7026776	test: 0.6583699	best: 0.6583666 (1799)	total: 1m 42s	remaining: 11.3s
# 1999:	learn: 0.6987245	test: 0.6575042	best: 0.6575042 (1999)	total: 1m 59s	remaining: 0us
#
# bestTest = 0.6575042373
# bestIteration = 1999
#
# CV Log Loss Score: 0.657504
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0936817	test: 1.0936922	best: 1.0936922 (0)	total: 16.8ms	remaining: 33.6s
# 200:	learn: 0.8042689	test: 0.7897445	best: 0.7897445 (200)	total: 7.1s	remaining: 1m 3s
# 400:	learn: 0.7622490	test: 0.7317401	best: 0.7317401 (400)	total: 14.1s	remaining: 56.4s
# 600:	learn: 0.7389228	test: 0.6965379	best: 0.6965379 (600)	total: 22.7s	remaining: 52.9s
# 800:	learn: 0.7268614	test: 0.6770202	best: 0.6770202 (799)	total: 32.1s	remaining: 48s
# 1000:	learn: 0.7209516	test: 0.6684103	best: 0.6684103 (1000)	total: 40.3s	remaining: 40.2s
# 1200:	learn: 0.7154549	test: 0.6621194	best: 0.6621194 (1200)	total: 53s	remaining: 35.2s
# 1400:	learn: 0.7101969	test: 0.6588840	best: 0.6588840 (1400)	total: 1m 10s	remaining: 30.1s
# 1600:	learn: 0.7060130	test: 0.6573894	best: 0.6573894 (1599)	total: 1m 28s	remaining: 22s
# 1800:	learn: 0.7018992	test: 0.6563950	best: 0.6563927 (1799)	total: 1m 46s	remaining: 11.8s
# 1999:	learn: 0.6981227	test: 0.6559977	best: 0.6559977 (1999)	total: 2m 5s	remaining: 0us
#
# bestTest = 0.6559976653
# bestIteration = 1999
#
# CV Log Loss Score: 0.655998
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0936831	test: 1.0936797	best: 1.0936797 (0)	total: 26.2ms	remaining: 52.4s
# 200:	learn: 0.8018256	test: 0.7904214	best: 0.7904214 (200)	total: 7.43s	remaining: 1m 6s
# 400:	learn: 0.7613243	test: 0.7364915	best: 0.7364915 (400)	total: 14.9s	remaining: 59.3s
# 600:	learn: 0.7397680	test: 0.7043195	best: 0.7043195 (600)	total: 23.3s	remaining: 54.3s
# 800:	learn: 0.7283494	test: 0.6873266	best: 0.6873266 (800)	total: 31s	remaining: 46.4s
# 1000:	learn: 0.7216691	test: 0.6772430	best: 0.6772429 (999)	total: 39.6s	remaining: 39.5s
# 1200:	learn: 0.7160790	test: 0.6700397	best: 0.6700397 (1200)	total: 52.1s	remaining: 34.6s
# 1400:	learn: 0.7113557	test: 0.6662864	best: 0.6662864 (1400)	total: 1m 9s	remaining: 29.8s
# 1600:	learn: 0.7077073	test: 0.6645451	best: 0.6645383 (1599)	total: 1m 25s	remaining: 21.2s
# 1800:	learn: 0.7042386	test: 0.6636857	best: 0.6636857 (1800)	total: 1m 42s	remaining: 11.3s
# 1999:	learn: 0.7005816	test: 0.6629609	best: 0.6629560 (1998)	total: 2m 1s	remaining: 0us
#
# bestTest = 0.6629560171
# bestIteration = 1998
#
# Shrink model to first 1999 iterations.
# CV Log Loss Score: 0.662956
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0936796	test: 1.0936846	best: 1.0936846 (0)	total: 18.4ms	remaining: 36.8s
# 200:	learn: 0.7932244	test: 0.7825053	best: 0.7825053 (200)	total: 7.58s	remaining: 1m 7s
# 400:	learn: 0.7504237	test: 0.7288313	best: 0.7288313 (400)	total: 15.7s	remaining: 1m 2s
# 600:	learn: 0.7319385	test: 0.7048193	best: 0.7048193 (600)	total: 24s	remaining: 56s
# 800:	learn: 0.7221426	test: 0.6918673	best: 0.6918673 (800)	total: 32.1s	remaining: 48s
# 1000:	learn: 0.7163336	test: 0.6848685	best: 0.6848654 (996)	total: 40.1s	remaining: 40.1s
# 1200:	learn: 0.7111807	test: 0.6796906	best: 0.6796906 (1200)	total: 52.7s	remaining: 35.1s
# 1400:	learn: 0.7064823	test: 0.6771812	best: 0.6771812 (1400)	total: 1m 7s	remaining: 29s
# 1600:	learn: 0.7024554	test: 0.6759644	best: 0.6759644 (1600)	total: 1m 24s	remaining: 21.1s
# 1800:	learn: 0.6987377	test: 0.6752786	best: 0.6752732 (1796)	total: 1m 39s	remaining: 11s
# 1999:	learn: 0.6954458	test: 0.6749331	best: 0.6749305 (1995)	total: 1m 55s	remaining: 0us
#
# bestTest = 0.674930454
# bestIteration = 1995
#
# Shrink model to first 1996 iterations.
# CV Log Loss Score: 0.674930
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0936814	test: 1.0936872	best: 1.0936872 (0)	total: 22.7ms	remaining: 45.3s
# 200:	learn: 0.7928754	test: 0.7782974	best: 0.7782974 (200)	total: 7.93s	remaining: 1m 10s
# 400:	learn: 0.7530300	test: 0.7262159	best: 0.7262159 (400)	total: 15.5s	remaining: 1m 1s
# 600:	learn: 0.7341885	test: 0.7003937	best: 0.7003937 (600)	total: 23.2s	remaining: 53.9s
# 800:	learn: 0.7244062	test: 0.6862577	best: 0.6862577 (800)	total: 31.2s	remaining: 46.7s
# 1000:	learn: 0.7187533	test: 0.6779521	best: 0.6779521 (999)	total: 38.3s	remaining: 38.2s
# 1200:	learn: 0.7144459	test: 0.6727799	best: 0.6727799 (1200)	total: 48.2s	remaining: 32.1s
# 1400:	learn: 0.7090992	test: 0.6686225	best: 0.6686225 (1399)	total: 1m 5s	remaining: 28.1s
# 1600:	learn: 0.7051662	test: 0.6667902	best: 0.6667902 (1599)	total: 1m 21s	remaining: 20.4s
# 1800:	learn: 0.7014522	test: 0.6656999	best: 0.6656999 (1800)	total: 1m 39s	remaining: 11s
# 1999:	learn: 0.6979304	test: 0.6651081	best: 0.6651081 (1998)	total: 1m 55s	remaining: 0us
#
# bestTest = 0.6651080863
# bestIteration = 1998
#
# Shrink model to first 1999 iterations.
# CV Log Loss Score: 0.665108
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0936750	test: 1.0936884	best: 1.0936884 (0)	total: 18ms	remaining: 35.9s
# 200:	learn: 0.7879249	test: 0.7770963	best: 0.7770963 (200)	total: 8.86s	remaining: 1m 19s
# 400:	learn: 0.7483445	test: 0.7275138	best: 0.7275138 (400)	total: 16.5s	remaining: 1m 5s
# 600:	learn: 0.7323286	test: 0.7068669	best: 0.7068669 (600)	total: 24.6s	remaining: 57.3s
# 800:	learn: 0.7231178	test: 0.6951598	best: 0.6951598 (800)	total: 33.3s	remaining: 49.9s
# 1000:	learn: 0.7176400	test: 0.6889168	best: 0.6889168 (1000)	total: 42s	remaining: 41.9s
# 1200:	learn: 0.7127885	test: 0.6845814	best: 0.6845808 (1199)	total: 53.9s	remaining: 35.9s
# 1400:	learn: 0.7080845	test: 0.6825983	best: 0.6825970 (1398)	total: 1m 9s	remaining: 29.7s
# 1600:	learn: 0.7045695	test: 0.6817374	best: 0.6817222 (1581)	total: 1m 26s	remaining: 21.5s
# 1800:	learn: 0.7005167	test: 0.6812649	best: 0.6812056 (1745)	total: 1m 45s	remaining: 11.6s
# 1999:	learn: 0.6971341	test: 0.6812016	best: 0.6811010 (1919)	total: 2m 1s	remaining: 0us
#
# bestTest = 0.6811009845
# bestIteration = 1919
#
# Shrink model to first 1920 iterations.
# CV Log Loss Score: 0.681101
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0936873	test: 1.0936818	best: 1.0936818 (0)	total: 21.9ms	remaining: 43.7s
# 200:	learn: 0.8034200	test: 0.7932240	best: 0.7932240 (200)	total: 6.51s	remaining: 58.2s
# 400:	learn: 0.7578991	test: 0.7323968	best: 0.7323968 (400)	total: 13.2s	remaining: 52.8s
# 600:	learn: 0.7379484	test: 0.7039057	best: 0.7039049 (599)	total: 21.6s	remaining: 50.3s
# 800:	learn: 0.7275706	test: 0.6892856	best: 0.6892856 (800)	total: 29.1s	remaining: 43.5s
# 1000:	learn: 0.7194616	test: 0.6780081	best: 0.6780081 (1000)	total: 38.8s	remaining: 38.8s
# 1200:	learn: 0.7145574	test: 0.6727081	best: 0.6727081 (1200)	total: 50s	remaining: 33.3s
# 1400:	learn: 0.7091564	test: 0.6692409	best: 0.6692409 (1400)	total: 1m 6s	remaining: 28.5s
# 1600:	learn: 0.7054228	test: 0.6675233	best: 0.6675233 (1600)	total: 1m 23s	remaining: 20.9s
# 1800:	learn: 0.7014117	test: 0.6665516	best: 0.6665516 (1800)	total: 1m 41s	remaining: 11.2s
# 1999:	learn: 0.6972824	test: 0.6660737	best: 0.6660737 (1999)	total: 1m 58s	remaining: 0us
#
# bestTest = 0.6660737018
# bestIteration = 1999
#
# CV Log Loss Score: 0.666074
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0936751	test: 1.0936863	best: 1.0936863 (0)	total: 24.8ms	remaining: 49.6s
# 200:	learn: 0.7978047	test: 0.7867730	best: 0.7867730 (200)	total: 7.69s	remaining: 1m 8s
# 400:	learn: 0.7564326	test: 0.7342716	best: 0.7342712 (398)	total: 15.2s	remaining: 1m
# 600:	learn: 0.7364886	test: 0.7077112	best: 0.7077112 (600)	total: 22.6s	remaining: 52.7s
# 800:	learn: 0.7238688	test: 0.6906513	best: 0.6906513 (800)	total: 32s	remaining: 47.9s
# 1000:	learn: 0.7177543	test: 0.6830158	best: 0.6830158 (1000)	total: 40.1s	remaining: 40.1s
# 1200:	learn: 0.7128119	test: 0.6784535	best: 0.6784535 (1200)	total: 52s	remaining: 34.6s
# 1400:	learn: 0.7078601	test: 0.6757963	best: 0.6757963 (1400)	total: 1m 10s	remaining: 30s
# 1600:	learn: 0.7039733	test: 0.6746721	best: 0.6746615 (1597)	total: 1m 27s	remaining: 21.8s
# 1800:	learn: 0.7004163	test: 0.6740242	best: 0.6740202 (1799)	total: 1m 43s	remaining: 11.5s
# 1999:	learn: 0.6963246	test: 0.6734948	best: 0.6734948 (1999)	total: 2m 3s	remaining: 0us
#
# bestTest = 0.67349485
# bestIteration = 1999
#
# CV Log Loss Score: 0.673495
#
# ----------------- Fold 9 -----------------
#
# 0:	learn: 1.0936788	test: 1.0936995	best: 1.0936995 (0)	total: 21.9ms	remaining: 43.8s
# 200:	learn: 0.8034222	test: 0.7912412	best: 0.7912412 (200)	total: 6.75s	remaining: 1m
# 400:	learn: 0.7576279	test: 0.7328625	best: 0.7328625 (400)	total: 14.7s	remaining: 58.5s
# 600:	learn: 0.7375661	test: 0.7059532	best: 0.7059497 (599)	total: 22.2s	remaining: 51.6s
# 800:	learn: 0.7254952	test: 0.6896344	best: 0.6896344 (800)	total: 30.3s	remaining: 45.3s
# 1000:	learn: 0.7195733	test: 0.6816059	best: 0.6816059 (1000)	total: 37.5s	remaining: 37.5s
# 1200:	learn: 0.7141367	test: 0.6754960	best: 0.6754960 (1200)	total: 50.1s	remaining: 33.3s
# 1400:	learn: 0.7090940	test: 0.6716858	best: 0.6716858 (1400)	total: 1m 8s	remaining: 29.2s
# 1600:	learn: 0.7052901	test: 0.6702217	best: 0.6702142 (1595)	total: 1m 26s	remaining: 21.5s
# 1800:	learn: 0.7011214	test: 0.6694262	best: 0.6694212 (1798)	total: 1m 44s	remaining: 11.6s
# 1999:	learn: 0.6973939	test: 0.6687257	best: 0.6687257 (1999)	total: 2m 2s	remaining: 0us
#
# bestTest = 0.6687256588
# bestIteration = 1999
#
# CV Log Loss Score: 0.668726
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0936758	test: 1.0936709	best: 1.0936709 (0)	total: 18.1ms	remaining: 36.2s
# 200:	learn: 0.8009888	test: 0.7860774	best: 0.7860774 (200)	total: 7.17s	remaining: 1m 4s
# 400:	learn: 0.7589476	test: 0.7336549	best: 0.7336549 (400)	total: 14.4s	remaining: 57.4s
# 600:	learn: 0.7354870	test: 0.7036616	best: 0.7036591 (599)	total: 22.4s	remaining: 52.2s
# 800:	learn: 0.7235789	test: 0.6891724	best: 0.6891724 (800)	total: 31.9s	remaining: 47.7s
# 1000:	learn: 0.7171814	test: 0.6825877	best: 0.6825877 (1000)	total: 40.9s	remaining: 40.8s
# 1200:	learn: 0.7124770	test: 0.6786864	best: 0.6786863 (1198)	total: 51.9s	remaining: 34.5s
# 1400:	learn: 0.7076101	test: 0.6759070	best: 0.6759070 (1400)	total: 1m 9s	remaining: 29.8s
# 1600:	learn: 0.7031737	test: 0.6747184	best: 0.6747184 (1599)	total: 1m 27s	remaining: 21.9s
# 1800:	learn: 0.6992273	test: 0.6741771	best: 0.6741638 (1780)	total: 1m 47s	remaining: 11.8s
# 1999:	learn: 0.6954421	test: 0.6736731	best: 0.6736598 (1987)	total: 2m 4s	remaining: 0us
#
# bestTest = 0.6736597605
# bestIteration = 1987
#
# Shrink model to first 1988 iterations.
# CV Log Loss Score: 0.673660
# 	Log Loss: 0.667955
# [I 2021-06-17 18:40:42,294] Trial 11 finished with value: 0.6679547464488006 and parameters: {'learning_rate': 0.011094214686002694, 'n_estimators': 2000, 'colsample_bylevel': 0.05634563465934163, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9189877277551838}. Best is trial 7 with value: 0.6666297448976278.

# %%
print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 12
# Best trial:
#   Value: 0.6666297448976278
#   Params:
#     learning_rate: 0.03148804286737452
#     n_estimators: 2000
#     colsample_bylevel: 0.08550203288540487
#     depth: 8
#     boosting_type: Ordered
#     bootstrap_type: Bernoulli
#     subsample: 0.7777311966683135

# %%
trial.params
# Out:
# {'learning_rate': 0.03148804286737452,
#  'n_estimators': 2000,
#  'colsample_bylevel': 0.08550203288540487,
#  'depth': 8,
#  'boosting_type': 'Ordered',
#  'bootstrap_type': 'Bernoulli',
#  'subsample': 0.7777311966683135}

# %%
skfold = StratifiedKFold(n_splits=15, shuffle=True, random_state=55)
folds=[]
for train_idx, valid_idx in skfold.split(X, y):
        folds.append((train_idx, valid_idx))

cat_pred = np.zeros((X.shape[0], n_class))
cat_pred_test = np.zeros((X_test.shape[0], n_class))
cat_cols = categorical_feats
print('category features : {}'.format(cat_cols))
model_folds = [] 
# 15Fold-CV (StratifiedKFold)
for fold in range(len(folds)):
    print(f'\n----------------- Fold {fold+1} -----------------\n')
    train_idx, valid_idx = folds[fold]
    X_train, X_valid, y_train, y_valid = X.iloc[train_idx], X.iloc[valid_idx], y.iloc[train_idx], y.iloc[valid_idx]
    train_data = Pool(data=X_train, label=y_train, cat_features=cat_cols)
    valid_data = Pool(data=X_valid, label=y_valid, cat_features=cat_cols)

    model_cat = CatBoostClassifier(**trial.params)
    model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=50, verbose=100)
    model_folds.append(model_cat)

    cat_pred[valid_idx] = model_cat.predict_proba(X_valid)
    cat_pred_test += model_cat.predict_proba(X_test) / len(folds)
    print(f'CV Log Loss Score: {log_loss(y_valid, cat_pred[valid_idx]):.6f}')
    
print(f'\tLog Loss: {log_loss(y, cat_pred):.6f}')
# Out:
# category features : ['gender', 'car', 'reality', 'income_type', 'edu_type', 'family_type', 'house_type', 'occyp_type', 'personal_id', 'group_property', 'group_contacts', 'group_whoare_u']
#
# ----------------- Fold 1 -----------------
#
# 0:	learn: 1.0806170	test: 1.0806682	best: 1.0806682 (0)	total: 57.7ms	remaining: 1m 55s
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# 100:	learn: 0.7627445	test: 0.7495138	best: 0.7495138 (100)	total: 2.79s	remaining: 52.4s
# 200:	learn: 0.7254274	test: 0.6962753	best: 0.6962753 (200)	total: 6.02s	remaining: 53.9s
# 300:	learn: 0.7162122	test: 0.6825340	best: 0.6825340 (300)	total: 9.41s	remaining: 53.1s
# 400:	learn: 0.7101788	test: 0.6758263	best: 0.6758263 (400)	total: 13.1s	remaining: 52.4s
# 500:	learn: 0.7044683	test: 0.6735712	best: 0.6735051 (492)	total: 18.2s	remaining: 54.4s
# 600:	learn: 0.6997974	test: 0.6723796	best: 0.6723796 (600)	total: 23.1s	remaining: 53.8s
# 700:	learn: 0.6948198	test: 0.6713737	best: 0.6713737 (700)	total: 28.1s	remaining: 52s
# 800:	learn: 0.6897517	test: 0.6709966	best: 0.6709358 (799)	total: 33.3s	remaining: 49.9s
# 900:	learn: 0.6850216	test: 0.6702976	best: 0.6702422 (875)	total: 38.3s	remaining: 46.8s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6702422071
# bestIteration = 875
#
# Shrink model to first 876 iterations.
# CV Log Loss Score: 0.670242
#
# ----------------- Fold 2 -----------------
#
# 0:	learn: 1.0806085	test: 1.0807991	best: 1.0807991 (0)	total: 58.1ms	remaining: 1m 56s
# 100:	learn: 0.7732642	test: 0.7557384	best: 0.7557384 (100)	total: 2.67s	remaining: 50.3s
# 200:	learn: 0.7300240	test: 0.6854362	best: 0.6854362 (200)	total: 5.94s	remaining: 53.1s
# 300:	learn: 0.7200893	test: 0.6667663	best: 0.6667663 (300)	total: 9.13s	remaining: 51.5s
# 400:	learn: 0.7130293	test: 0.6566119	best: 0.6565944 (399)	total: 13.2s	remaining: 52.5s
# 500:	learn: 0.7071967	test: 0.6525391	best: 0.6525391 (500)	total: 18.3s	remaining: 54.9s
# 600:	learn: 0.7016775	test: 0.6502362	best: 0.6502362 (600)	total: 23.6s	remaining: 55s
# 700:	learn: 0.6966272	test: 0.6496768	best: 0.6496302 (689)	total: 28.6s	remaining: 52.9s
# 800:	learn: 0.6921397	test: 0.6490063	best: 0.6489611 (796)	total: 33.5s	remaining: 50.2s
# 900:	learn: 0.6871172	test: 0.6486227	best: 0.6486175 (882)	total: 38.9s	remaining: 47.4s
# 1000:	learn: 0.6825280	test: 0.6480183	best: 0.6480023 (996)	total: 43.9s	remaining: 43.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6477219242
# bestIteration = 1035
#
# Shrink model to first 1036 iterations.
# CV Log Loss Score: 0.647722
#
# ----------------- Fold 3 -----------------
#
# 0:	learn: 1.0806426	test: 1.0806126	best: 1.0806126 (0)	total: 60.9ms	remaining: 2m 1s
# 100:	learn: 0.7624737	test: 0.7386377	best: 0.7386377 (100)	total: 3.31s	remaining: 1m 2s
# 200:	learn: 0.7245856	test: 0.6886782	best: 0.6886782 (200)	total: 6.58s	remaining: 58.9s
# 300:	learn: 0.7152633	test: 0.6771582	best: 0.6771582 (300)	total: 9.63s	remaining: 54.4s
# 400:	learn: 0.7087457	test: 0.6728747	best: 0.6728747 (400)	total: 13.4s	remaining: 53.5s
# 500:	learn: 0.7034056	test: 0.6715068	best: 0.6714459 (490)	total: 17.9s	remaining: 53.7s
# 600:	learn: 0.6986212	test: 0.6710319	best: 0.6709860 (596)	total: 22.9s	remaining: 53.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.670964159
# bestIteration = 644
#
# Shrink model to first 645 iterations.
# CV Log Loss Score: 0.670964
#
# ----------------- Fold 4 -----------------
#
# 0:	learn: 1.0806599	test: 1.0804407	best: 1.0804407 (0)	total: 64.1ms	remaining: 2m 8s
# 100:	learn: 0.7656396	test: 0.7311152	best: 0.7311152 (100)	total: 2.85s	remaining: 53.7s
# 200:	learn: 0.7305324	test: 0.6735664	best: 0.6735664 (200)	total: 5.78s	remaining: 51.8s
# 300:	learn: 0.7188207	test: 0.6550001	best: 0.6550001 (300)	total: 9.07s	remaining: 51.2s
# 400:	learn: 0.7127498	test: 0.6484259	best: 0.6484259 (400)	total: 12.3s	remaining: 49.2s
# 500:	learn: 0.7069218	test: 0.6462280	best: 0.6462280 (500)	total: 17.1s	remaining: 51.3s
# 600:	learn: 0.7012022	test: 0.6454504	best: 0.6454266 (584)	total: 22.3s	remaining: 51.9s
# 700:	learn: 0.6962031	test: 0.6447262	best: 0.6446531 (685)	total: 27.5s	remaining: 50.9s
# 800:	learn: 0.6913722	test: 0.6444040	best: 0.6443496 (795)	total: 32.3s	remaining: 48.3s
# 900:	learn: 0.6871046	test: 0.6443312	best: 0.6441517 (854)	total: 37.1s	remaining: 45.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.644151707
# bestIteration = 854
#
# Shrink model to first 855 iterations.
# CV Log Loss Score: 0.644152
#
# ----------------- Fold 5 -----------------
#
# 0:	learn: 1.0806397	test: 1.0804757	best: 1.0804757 (0)	total: 60.2ms	remaining: 2m
# 100:	learn: 0.7544577	test: 0.7267242	best: 0.7267242 (100)	total: 3.17s	remaining: 59.7s
# 200:	learn: 0.7257092	test: 0.6820993	best: 0.6820931 (198)	total: 6.22s	remaining: 55.7s
# 300:	learn: 0.7170185	test: 0.6685157	best: 0.6685157 (300)	total: 9.42s	remaining: 53.2s
# 400:	learn: 0.7118725	test: 0.6628219	best: 0.6628219 (400)	total: 13.2s	remaining: 52.6s
# 500:	learn: 0.7058043	test: 0.6602736	best: 0.6602730 (498)	total: 18.2s	remaining: 54.4s
# 600:	learn: 0.6999987	test: 0.6596307	best: 0.6596307 (600)	total: 23.4s	remaining: 54.4s
# 700:	learn: 0.6946329	test: 0.6589956	best: 0.6589047 (693)	total: 28.4s	remaining: 52.6s
# 800:	learn: 0.6895044	test: 0.6587017	best: 0.6586604 (761)	total: 33.6s	remaining: 50.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6586603984
# bestIteration = 761
#
# Shrink model to first 762 iterations.
# CV Log Loss Score: 0.658660
#
# ----------------- Fold 6 -----------------
#
# 0:	learn: 1.0805866	test: 1.0809186	best: 1.0809186 (0)	total: 64ms	remaining: 2m 7s
# 100:	learn: 0.7601699	test: 0.7397543	best: 0.7397543 (100)	total: 3.35s	remaining: 1m 3s
# 200:	learn: 0.7224524	test: 0.6876313	best: 0.6876313 (200)	total: 6.98s	remaining: 1m 2s
# 300:	learn: 0.7143930	test: 0.6798175	best: 0.6798175 (300)	total: 10.2s	remaining: 57.5s
# 400:	learn: 0.7089705	test: 0.6769692	best: 0.6769554 (397)	total: 13.8s	remaining: 55.1s
# 500:	learn: 0.7029335	test: 0.6762199	best: 0.6762122 (492)	total: 19s	remaining: 56.9s
# 600:	learn: 0.6971187	test: 0.6760118	best: 0.6759758 (554)	total: 24s	remaining: 55.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6759757964
# bestIteration = 554
#
# Shrink model to first 555 iterations.
# CV Log Loss Score: 0.675976
#
# ----------------- Fold 7 -----------------
#
# 0:	learn: 1.0847380	test: 1.0847525	best: 1.0847525 (0)	total: 22.7ms	remaining: 45.4s
# 100:	learn: 0.7552861	test: 0.7416817	best: 0.7416817 (100)	total: 3.16s	remaining: 59.4s
# 200:	learn: 0.7248501	test: 0.7006881	best: 0.7006881 (200)	total: 6.43s	remaining: 57.6s
# 300:	learn: 0.7154435	test: 0.6893307	best: 0.6893307 (300)	total: 9.71s	remaining: 54.8s
# 400:	learn: 0.7094741	test: 0.6841597	best: 0.6841597 (400)	total: 13.5s	remaining: 53.8s
# 500:	learn: 0.7029942	test: 0.6813722	best: 0.6813482 (493)	total: 18.7s	remaining: 56.1s
# 600:	learn: 0.6976371	test: 0.6807147	best: 0.6807147 (600)	total: 24.2s	remaining: 56.3s
# 700:	learn: 0.6930661	test: 0.6802131	best: 0.6801912 (697)	total: 29.3s	remaining: 54.3s
# 800:	learn: 0.6880042	test: 0.6798103	best: 0.6798103 (800)	total: 34.5s	remaining: 51.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6796293819
# bestIteration = 820
#
# Shrink model to first 821 iterations.
# CV Log Loss Score: 0.679629
#
# ----------------- Fold 8 -----------------
#
# 0:	learn: 1.0847317	test: 1.0847227	best: 1.0847227 (0)	total: 20.5ms	remaining: 40.9s
# 100:	learn: 0.7607413	test: 0.7316996	best: 0.7316996 (100)	total: 3.28s	remaining: 1m 1s
# 200:	learn: 0.7231216	test: 0.6738224	best: 0.6738224 (200)	total: 6.99s	remaining: 1m 2s
# 300:	learn: 0.7161696	test: 0.6617949	best: 0.6617949 (300)	total: 10.2s	remaining: 57.5s
# 400:	learn: 0.7104255	test: 0.6557199	best: 0.6557199 (400)	total: 14.1s	remaining: 56.4s
# 500:	learn: 0.7045197	test: 0.6524906	best: 0.6524906 (500)	total: 19.4s	remaining: 57.9s
# 600:	learn: 0.6990495	test: 0.6519106	best: 0.6518998 (598)	total: 24.5s	remaining: 57.1s
# 700:	learn: 0.6934163	test: 0.6513787	best: 0.6513650 (699)	total: 30s	remaining: 55.6s
# 800:	learn: 0.6891052	test: 0.6510907	best: 0.6510896 (799)	total: 35s	remaining: 52.4s
# 900:	learn: 0.6846743	test: 0.6506473	best: 0.6505566 (884)	total: 40.2s	remaining: 49s
# 1000:	learn: 0.6805154	test: 0.6503933	best: 0.6503346 (986)	total: 45.2s	remaining: 45.1s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.650216944
# bestIteration = 1011
#
# Shrink model to first 1012 iterations.
# CV Log Loss Score: 0.650217
#
# ----------------- Fold 9 -----------------
# 0:	learn: 1.0847499	test: 1.0846703	best: 1.0846703 (0)	total: 22.3ms	remaining: 44.5s
# 100:	learn: 0.7576027	test: 0.7352514	best: 0.7352514 (100)	total: 3.33s	remaining: 1m 2s
# 200:	learn: 0.7272483	test: 0.6915637	best: 0.6915637 (200)	total: 6.41s	remaining: 57.3s
# 300:	learn: 0.7173648	test: 0.6759434	best: 0.6759434 (300)	total: 9.88s	remaining: 55.8s
# 400:	learn: 0.7107114	test: 0.6695557	best: 0.6695557 (400)	total: 14s	remaining: 55.7s
# 500:	learn: 0.7047929	test: 0.6671332	best: 0.6671332 (500)	total: 19.1s	remaining: 57.2s
# 600:	learn: 0.6990090	test: 0.6654321	best: 0.6653637 (584)	total: 24.4s	remaining: 56.9s
# 700:	learn: 0.6930584	test: 0.6643307	best: 0.6643307 (700)	total: 29.6s	remaining: 54.9s
# 800:	learn: 0.6881252	test: 0.6632413	best: 0.6632351 (797)	total: 34.8s	remaining: 52.1s
# 900:	learn: 0.6829231	test: 0.6627751	best: 0.6627706 (899)	total: 39.6s	remaining: 48.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6626651358
# bestIteration = 927
#
# Shrink model to first 928 iterations.
# CV Log Loss Score: 0.662665
#
# ----------------- Fold 10 -----------------
#
# 0:	learn: 1.0847375	test: 1.0847357	best: 1.0847357 (0)	total: 27.6ms	remaining: 55.2s
# 100:	learn: 0.7670434	test: 0.7375790	best: 0.7375790 (100)	total: 3.25s	remaining: 1m 1s
# 200:	learn: 0.7277255	test: 0.6731568	best: 0.6731568 (200)	total: 6.65s	remaining: 59.5s
# 300:	learn: 0.7184559	test: 0.6584087	best: 0.6584087 (300)	total: 9.86s	remaining: 55.7s
# 400:	learn: 0.7114863	test: 0.6512020	best: 0.6512020 (400)	total: 14s	remaining: 56s
# 500:	learn: 0.7050116	test: 0.6470854	best: 0.6470854 (500)	total: 19s	remaining: 57s
# 600:	learn: 0.6993324	test: 0.6454592	best: 0.6454592 (600)	total: 24.1s	remaining: 56s
# 700:	learn: 0.6938374	test: 0.6447123	best: 0.6446795 (695)	total: 29.1s	remaining: 53.9s
# 800:	learn: 0.6885356	test: 0.6437929	best: 0.6437929 (800)	total: 34.6s	remaining: 51.7s
# 900:	learn: 0.6835341	test: 0.6429476	best: 0.6429468 (898)	total: 39.8s	remaining: 48.6s
# 1000:	learn: 0.6791502	test: 0.6426269	best: 0.6425397 (983)	total: 44.9s	remaining: 44.9s
# 1100:	learn: 0.6739147	test: 0.6419118	best: 0.6418871 (1098)	total: 50.3s	remaining: 41s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.641823506
# bestIteration = 1109
#
# Shrink model to first 1110 iterations.
# CV Log Loss Score: 0.641824
#
# ----------------- Fold 11 -----------------
#
# 0:	learn: 1.0847459	test: 1.0847403	best: 1.0847403 (0)	total: 30ms	remaining: 1m
# 100:	learn: 0.7532425	test: 0.7333773	best: 0.7333773 (100)	total: 3.42s	remaining: 1m 4s
# 200:	learn: 0.7221033	test: 0.6888733	best: 0.6888733 (200)	total: 7.12s	remaining: 1m 3s
# 300:	learn: 0.7148518	test: 0.6794586	best: 0.6794546 (298)	total: 10.6s	remaining: 59.8s
# 400:	learn: 0.7097590	test: 0.6753459	best: 0.6753322 (398)	total: 14.7s	remaining: 58.7s
# 500:	learn: 0.7040458	test: 0.6736979	best: 0.6736979 (500)	total: 19.9s	remaining: 59.4s
# 600:	learn: 0.6990660	test: 0.6728790	best: 0.6728537 (597)	total: 25.2s	remaining: 58.6s
# 700:	learn: 0.6940824	test: 0.6725139	best: 0.6724344 (673)	total: 30.4s	remaining: 56.4s
# 800:	learn: 0.6894124	test: 0.6721789	best: 0.6720775 (784)	total: 35.6s	remaining: 53.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6720774588
# bestIteration = 784
#
# Shrink model to first 785 iterations.
# CV Log Loss Score: 0.672077
#
# ----------------- Fold 12 -----------------
#
# 0:	learn: 1.0847371	test: 1.0847589	best: 1.0847589 (0)	total: 20.4ms	remaining: 40.8s
# 100:	learn: 0.7617954	test: 0.7361001	best: 0.7361001 (100)	total: 3.16s	remaining: 59.5s
# 200:	learn: 0.7260925	test: 0.6833893	best: 0.6833893 (200)	total: 6.74s	remaining: 1m
# 300:	learn: 0.7166009	test: 0.6698101	best: 0.6698101 (300)	total: 10.2s	remaining: 57.8s
# 400:	learn: 0.7110175	test: 0.6639248	best: 0.6639248 (400)	total: 14s	remaining: 55.9s
# 500:	learn: 0.7049757	test: 0.6610354	best: 0.6610271 (497)	total: 19.2s	remaining: 57.5s
# 600:	learn: 0.6989162	test: 0.6593352	best: 0.6593060 (595)	total: 24.4s	remaining: 56.8s
# 700:	learn: 0.6939057	test: 0.6589094	best: 0.6588722 (696)	total: 29.8s	remaining: 55.1s
# 800:	learn: 0.6882840	test: 0.6580144	best: 0.6580144 (800)	total: 35.4s	remaining: 53.1s
# 900:	learn: 0.6832322	test: 0.6575334	best: 0.6574717 (873)	total: 40.8s	remaining: 49.8s
# 1000:	learn: 0.6783420	test: 0.6572664	best: 0.6572404 (994)	total: 46s	remaining: 45.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6571736062
# bestIteration = 1015
#
# Shrink model to first 1016 iterations.
# CV Log Loss Score: 0.657174
#
# ----------------- Fold 13 -----------------
#
# 0:	learn: 1.0847430	test: 1.0848009	best: 1.0848009 (0)	total: 26.6ms	remaining: 53.1s
# 100:	learn: 0.7528586	test: 0.7284551	best: 0.7284551 (100)	total: 3.5s	remaining: 1m 5s
# 200:	learn: 0.7236895	test: 0.6854535	best: 0.6854535 (200)	total: 7.19s	remaining: 1m 4s
# 300:	learn: 0.7168215	test: 0.6753780	best: 0.6753780 (300)	total: 10.3s	remaining: 58.3s
# 400:	learn: 0.7102228	test: 0.6687237	best: 0.6687237 (400)	total: 14.7s	remaining: 58.7s
# 500:	learn: 0.7041659	test: 0.6673835	best: 0.6672915 (480)	total: 19.7s	remaining: 59.1s
# 600:	learn: 0.6984844	test: 0.6663389	best: 0.6663389 (600)	total: 24.6s	remaining: 57.3s
# 700:	learn: 0.6932805	test: 0.6657075	best: 0.6656409 (685)	total: 29.9s	remaining: 55.4s
# 800:	learn: 0.6881414	test: 0.6656666	best: 0.6655110 (751)	total: 34.7s	remaining: 52s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6655109974
# bestIteration = 751
#
# Shrink model to first 752 iterations.
# CV Log Loss Score: 0.665511
#
# ----------------- Fold 14 -----------------
#
# 0:	learn: 1.0847452	test: 1.0847866	best: 1.0847866 (0)	total: 27.5ms	remaining: 54.9s
# 100:	learn: 0.7642675	test: 0.7488040	best: 0.7488040 (100)	total: 2.81s	remaining: 52.9s
# 200:	learn: 0.7267049	test: 0.7004257	best: 0.7004257 (200)	total: 5.94s	remaining: 53.2s
# 300:	learn: 0.7154818	test: 0.6881648	best: 0.6881648 (300)	total: 9.31s	remaining: 52.5s
# 400:	learn: 0.7090231	test: 0.6845101	best: 0.6845101 (400)	total: 13.1s	remaining: 52.4s
# 500:	learn: 0.7026472	test: 0.6838347	best: 0.6838046 (487)	total: 18.2s	remaining: 54.6s
# 600:	learn: 0.6974772	test: 0.6836416	best: 0.6835728 (582)	total: 23s	remaining: 53.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.6835727774
# bestIteration = 582
#
# Shrink model to first 583 iterations.
# CV Log Loss Score: 0.683573
#
# ----------------- Fold 15 -----------------
#
# 0:	learn: 1.0847385	test: 1.0847965	best: 1.0847965 (0)	total: 21.9ms	remaining: 43.8s
# 100:	learn: 0.7559827	test: 0.7237677	best: 0.7237677 (100)	total: 3.83s	remaining: 1m 11s
# 200:	learn: 0.7247108	test: 0.6776745	best: 0.6776745 (200)	total: 6.88s	remaining: 1m 1s
# 300:	learn: 0.7162460	test: 0.6661430	best: 0.6661430 (300)	total: 10.2s	remaining: 57.8s
# 400:	learn: 0.7109857	test: 0.6613718	best: 0.6613718 (400)	total: 13.8s	remaining: 55.1s
# 500:	learn: 0.7044552	test: 0.6585993	best: 0.6585993 (500)	total: 18.8s	remaining: 56.2s
# 600:	learn: 0.6990133	test: 0.6572754	best: 0.6572615 (594)	total: 24.3s	remaining: 56.5s
# 700:	learn: 0.6934671	test: 0.6565744	best: 0.6565717 (678)	total: 29.4s	remaining: 54.4s
# 800:	learn: 0.6881444	test: 0.6559766	best: 0.6559716 (799)	total: 34.5s	remaining: 51.7s
# 900:	learn: 0.6828342	test: 0.6555265	best: 0.6555016 (897)	total: 39.8s	remaining: 48.5s
# 1000:	learn: 0.6771576	test: 0.6553318	best: 0.6552630 (980)	total: 45s	remaining: 44.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.655262967
# bestIteration = 980
#
# Shrink model to first 981 iterations.
# CV Log Loss Score: 0.655263
# 	Log Loss: 0.662376

# %%
# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(12, 8))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('CATBOOST Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances01.png')

# %%
feats = X.columns
feature_importance_df = pd.DataFrame()
n = len(model_folds)
for i in range(n):
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = model_folds[i].feature_importances_
    fold_importance_df["fold"] = i
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
display_importances(feature_importance_df)

# %%
for i in range(3):
    submit[str(i)] = (cat_pred_test)[:,i]

# %%
submit.set_index('index').apply(np.argmax, axis = 1).value_counts()
# Out:
# 2    8099
# 1    1417
# 0     484
# dtype: int64

# %%
submit.to_csv('/Users/gangtaro/competition_data/DACON/14thMonthlyDacon/open/preprocessing/catboost_renew+optuna.csv', index = False)
